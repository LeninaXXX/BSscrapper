# %%
import requests
import bs4 as bs
import lxml

httpaddr = "https://www.clarin.com"

requests_ret = requests.get(httpaddr)
print(requests_ret, end = ' || ')
soup = bs.BeautifulSoup(requests_ret.text, 'lxml')
# Notas:
# Everything semmantically a header, is tagged with <h2>. To all scrapping practical
# purposes, all headers except h2 are deemded irrelevant
articles = soup.find_all("article"); print("articles :", len(articles), end = ' / ')
sections = soup.find_all("section"); print("sections :", len(sections), end = ' / ')
headers = soup.find_all("header"); print("headers :", len(headers), end = ' / ')
h1s = soup.find_all("h1"); print("h1s :", len(h1s), end = ' / ')
h2s = soup.find_all("h2"); print("h2s :", len(h2s), end = ' / ')
h3s = soup.find_all("h3"); print("h3s :", len(h3s), end = ' / ')
h4s = soup.find_all("h4"); print("h4s :", len(h4s), end = ' / ')
h5s = soup.find_all("h5"); print("h5s :", len(h5s), end = ' / ')
h6s = soup.find_all("h6"); print("h6s :", len(h6s))
# only <h2>s hold relevance
# the only <h1> holds an SVG graphic

for discard_tag in ("script", "style"):
    for t in soup.find_all(discard_tag): t.extract()
# Out:
# <Response [200]> || articles : 105 / sections : 18 / headers : 13 / h1s : 1 / h2s : 133 / h3s : 0 / h4s : 0 / h5s : 0 / h6s : 0

# %%
# DUMPS A REPORT ON THE NESTING OF <article>s IN <section>s:
# TODO: This can be generalized as a routine that, for any two lists of nodes, gives a report on nesting

# Check for section nesting
# There's an almost strict hierarchical nesting in which articles are always inside some section
# The double belonging of to sections 2 and 3 are due to the fact that section 2 is nested inside section 3 (July 24, 2022)
print("+++ <section> NESTING CHECK :: ")
for (i, j) in [(i, j) for (i, section_i) in enumerate(sections) for (j, section_j) in enumerate(sections) if section_j in section_i.descendants]:
    print(("\t<section>[%" + str(len(str(len(sections)))) + "d] is nested in <section>[%" + str(len(str(len(sections)))) + "d]") % (j, i))

print("+++ <article> NESTING CHECK :: ")
for (i, j) in [(i, j) for (i, article_i) in enumerate(articles) for (j, article_j) in enumerate(articles) if article_j in article_i.descendants]:
    print(("\t<article>[%" + str(len(str(len(articles)))) + "d] is nested in <article>[%" + str(len(str(len(articles)))) + "d]") % (j, i))

# dangling <article>s
# these, the <article>s not-in-any-section, are the articles depicted as "LO MAS VISTO POR LOS SUSCRIPTORES" at the tail of the page
articles_not_in_sections = articles[:]              # copy articles ...
articles_in_sections_set = set()
for section in sections:
    for article in articles:
        if article in section.descendants:
            articles_in_sections_set = articles_in_sections_set | {article} # need to use this notation. set() notation consumes an interable and therefore iterates over article's members
for article in articles_in_sections_set:
    while article in articles_not_in_sections:      # while instead of if, just in case of repetition
        articles_not_in_sections.remove(article)    # ... then substract every article already under a <section>
print("+++ NUMBER OF <article>s NOT UNDER ANY <section> :", len(articles_not_in_sections))

# Report which <article> is nested in which <section>s
maxlen = max( (len('section[' + 'x' * len(str(len(sections))) + ']:' + str(section.attrs['class'])) for section in sections) )
for i, section in enumerate(sections):
    line = (('section[%' + str(len(str(len(sections)))) + 'd]: %s' + ' ' * 100) % (i, str(section.attrs['class']),))[:maxlen] + " ||"
    for article in articles: line += "X" if article in section.descendants else '.'; 
    line += "|"
    # get nearest <header> previous sibling -- filter only tags
    cursor = section
    while cursor and cursor.name != 'header':
        cursor = cursor.previous_sibling
        try:
            if cursor.name == 'header':
                line += ' ' + cursor.text.strip()
        except:
            pass
        
    print(line)
# Out:
# +++ <section> NESTING CHECK ::
# 	<section>[ 3] is nested in <section>[ 2]
# +++ <article> NESTING CHECK ::
# +++ NUMBER OF <article>s NOT UNDER ANY <section> : 6
# section[ 0]: ['container', 'no-p']                                         ||XXXXX....................................................................................................|
# section[ 1]: ['container', 'no-p', 'listado']                              ||.....XXXXXXXXXXXXXX......................................................................................|
# section[ 2]: ['container', 'listado', 'no-p']                              ||...................XXXXXXXXXXXX..........................................................................|
# section[ 3]: ['columnas']                                                  ||...................XXXXXX................................................................................|
# section[ 4]: ['container', 'listado', 'no-p']                              ||...............................XXXXXXX...................................................................|
# section[ 5]: ['container', 'no-p', 'listado']                              ||......................................XXXX...............................................................|
# section[ 6]: ['container', 'no-p', 'listado', 'suscriptor-content', 'back' ||..........................................XXXXX..........................................................|
# section[ 7]: ['container', 'no-p', 'listado']                              ||...............................................XXXX......................................................|
# section[ 8]: ['container', 'no-p', 'listado']                              ||...................................................XXXXXXX...............................................|
# section[ 9]: ['container', 'no-p', 'listado', 'grey-section', 'back']      ||..........................................................XXXXXX.........................................|
# section[10]: ['container', 'no-p', 'listado']                              ||................................................................XXXXXX...................................|
# section[11]: ['container', 'no-p', 'listado']                              ||......................................................................XXXXXX.............................|
# section[12]: ['container', 'no-p', 'listado']                              ||............................................................................XXXX.........................|
# section[13]: ['container', 'no-p']                                         ||................................................................................X........................|
# section[14]: ['container', 'no-p', 'listado']                              ||.................................................................................XXXXXX..................|
# section[15]: ['container', 'no-p', 'listado']                              ||.......................................................................................XXXX..............|
# section[16]: ['container', 'no-p', 'listado']                              ||...........................................................................................XXXX..........|
# section[17]: ['container', 'no-p']                                         ||...............................................................................................XXXX......|

# %%
articles_by_section = [[] for _ in sections]    # ... beware of reference replication...
for i, section in enumerate(sections):
    for j, article in enumerate(articles):
        if article in section.descendants: 
            articles_by_section[i].append(article)

# for i, art_by_sect in enumerate(articles_by_section): print(("<section>[%0" + str(len(str(len(sections)))) + "d]") % (i, ), "contains", len(art_by_sect), "articles")

articles_by_section_dict = {i : l for (i, l) in enumerate(articles_by_section)}
articles_by_section_dict.update({'none' : articles_not_in_sections})
# for k in articles_by_section_dict:
#     print(("For articles in <section>[%" + str(max([len(str(k)) for k in articles_by_section_dict])) + "s] number of articles:") % k, len(articles_by_section_dict[k]))

idx_width = max([len(str(k)) for k in articles_by_section_dict])
val_width = max([len(str(len(articles_by_section_dict[k]))) for k in articles_by_section_dict])
for i, k in enumerate(articles_by_section_dict):
    print(("<section>[%" + str(idx_width) + "s] " + "= %" + str(val_width) + "s") % 
          (k, str(len(articles_by_section_dict[k]))), end = '\n' if (i + 1) % 6 == 0 else ' // ')
# Out:
# <section>[   0] =  5 // <section>[   1] = 14 // <section>[   2] = 12 // <section>[   3] =  6 // <section>[   4] =  7 // <section>[   5] =  4
# <section>[   6] =  5 // <section>[   7] =  4 // <section>[   8] =  7 // <section>[   9] =  6 // <section>[  10] =  6 // <section>[  11] =  6
# <section>[  12] =  4 // <section>[  13] =  1 // <section>[  14] =  6 // <section>[  15] =  4 // <section>[  16] =  4 // <section>[  17] =  4
# <section>[none] =  6 //

# %%
# dumping some data by article as classified in articles_by_section_dict
for k, a_list in articles_by_section_dict.items():
    for j, article in enumerate(a_list):
        
        h2ss = article.find_all('h2') if article.find_all('h2') else None
        
        volanta = article.find(class_ = 'volanta') if article.find(class_ = 'volanta') else ''
        author = article.find(class_ = 'author') if article.find(class_ = 'author') else ''
        author_rel = article.find(class_ = 'author-rel') if article.find(class_ = 'author-rel') else ''
        summary = article.find(class_ = 'summary') if article.find(class_ = 'summary') else ''
        section = article.find(class_ = 'section') if article.find(class_ = 'section') else ''
        section_rel = article.find(class_ = 'section-rel') if article.find(class_ = 'section-rel') else ''
        
        print("<section>[%s] / <article>[%d]" % (str(k), j))
        print('-' * len("<section>[%s] / <article>[%d]" % (str(k), j)))
        if len(h2ss) != 1:
            if len(h2ss) > 1:
                print('\t++++++++MORE THAN ONE <h2>!!!++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++')
            else:
                print('\t++++++++NO <h2>!!!+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++')
        for i, h in enumerate(h2ss):
            print('\th2[%d] = %s' % (i, h))
#         print( '\tvolanta = "%s"' % (volanta, ),
#                '\n\tauthor = "%s"' % (author, ),
#                '\n\tsummary = "%s"' % (summary, ),
#                '\n\tsection = "%s"' % (section, ))
#         if volanta : print('\tvolanta = "%s"' % (volanta.strip()[:60], ))
#         if author : print('\tauthor = "%s"' % (author.strip()[:60], ))
#         if summary : print('\tsummary = "%s"' % (summary.strip()[:60], ))
#         if section : print('\tsection = "%s"' % (section.strip()[:60], ))
        if volanta : print('\tvolanta = "%s"' % (str(volanta)[:80], ))
        if author : print('\tauthor = "%s"' % (str(author)[:80], ))
        if author_rel : print('\tauthor = "%s"' % (str(author_rel)[:80], ))
        if summary : print('\tsummary = "%s"' % (str(summary)[:80], ))
        if section : print('\tsection = "%s"' % (str(section)[:80], ))
        if section_rel : print('\tsection_rel = "%s"' % (str(section_rel)[:80], ))
        print()
    print('-' * 60)
# Out:
# <section>[0] / <article>[0]
# ---------------------------
# 	h2[0] = <h2>Ante la presión de la oposición, el kirchnerismo cede para sumar votos y aprobar el Presupuesto 2023</h2>
# 	volanta = "<p class="volanta">La pelea en Diputados</p>"
# 	author = "<p class="author">Gustavo Berón</p>"
# 	summary = "<p class="summary">Tuvo que aceptar varias modificaciones al proyecto original e"
#
# <section>[0] / <article>[1]
# ---------------------------
# 	h2[0] = <h2 class="title-rel">Frente al derrumbe, Kicillof, Máximo y los intendentes intentan “blindar” el GBA</h2>
# 	author = "<span class="author-rel">Federico Mayol</span>"
# 	section_rel = "<span class="section-rel">Política.</span>"
#
# <section>[0] / <article>[2]
# ---------------------------
# 	h2[0] = <h2>Réplica del Gobierno a La Cámpora: dice que el acuerdo con el FMI está vigente</h2>
# 	volanta = "<p class="volanta">Interna sin tregua</p>"
# 	author = "<p class="author">Federico Mayol</p>"
#
# <section>[0] / <article>[3]
# ---------------------------
# 	h2[0] = <h2>El Gobierno le pide una rectificación a Gran Hermano por la acusación contra el Presidente</h2>
# 	volanta = "<p class="volanta">Reality y polémica</p>"
# 	section = "<p class="section">Política</p>"
#
# <section>[0] / <article>[4]
# ---------------------------
# 	h2[0] = <h2>Ironías de la oposición: “¿De verdad Alberto está preocupado por Gran Hermano?”</h2>
# 	volanta = "<p class="volanta">Cruces con Cerruti</p>"
# 	section = "<p class="section">Política</p>"
#
# ------------------------------------------------------------
# <section>[1] / <article>[0]
# ---------------------------
# 	h2[0] = <h2>El encargado de la Base Marambio fue atacado con una maza mientras dormía </h2>
# 	volanta = "<p class="volanta">Brutal pelea en la Antártida</p>"
# 	section = "<p class="section">Sociedad</p>"
#
# <section>[1] / <article>[1]
# ---------------------------
# 	h2[0] = <h2>Ataques en la cama de la Argentina precaria</h2>
# 	volanta = "<p class="volanta">Del editor</p>"
# 	author = "<p class="author">Héctor Gambini</p>"
#
# <section>[1] / <article>[2]
# ---------------------------
# 	h2[0] = <h2>La candidata tapada de Alberto Fernández y un dirigente social a los escobazos</h2>
# 	volanta = "<p class="volanta">Por los pasillos</p>"
# 	author = "<p class="author">Pablo de León</p>"
#
# <section>[1] / <article>[3]
# ---------------------------
# 	h2[0] = <h2>Terror en vuelo de Aerolíneas: por qué se da la turbulencia que afectó al avión</h2>
# 	volanta = "<p class="volanta">Hubo 12 heridos</p>"
# 	author = "<p class="author">Irene Hartmann</p>"
#
# <section>[1] / <article>[4]
# ---------------------------
# 	h2[0] = <h2>15 segundos de pánico en un avión: “Nunca estuve tan cerca de la muerte”</h2>
# 	volanta = "<p class="volanta">Una de las pasajeras heridas</p>"
# 	section = "<p class="section">Sociedad</p>"
#
# <section>[1] / <article>[5]
# ---------------------------
# 	h2[0] = <h2>Sorpresivo pedido del abogado de la vice para el jefe de los copitos, que ya no soporta la cárcel</h2>
# 	volanta = "<p class="volanta">Atentado a Cristina</p>"
# 	author = "<p class="author">Daniel Santoro</p>"
#
# <section>[1] / <article>[6]
# ---------------------------
# 	h2[0] = <h2>El incómodo momento de Alicia Kirchner cuando la increpó una funcionaria</h2>
# 	volanta = "<p class="volanta">En Caleta Olivia</p>"
# 	section = "<p class="section">Política</p>"
#
# <section>[1] / <article>[7]
# ---------------------------
# 	h2[0] = <h2>Esteban Bullrich cuestionó la interna de Juntos por el Cambio: "Llevamos meses cascoteándonos el rancho"</h2>
#
# <section>[1] / <article>[8]
# ---------------------------
# 	h2[0] = <h2>NBA: Facundo Campazzo no pudo debutar en Dallas y Leandro Bolmaro tuvo un fugaz estreno en Utah</h2>
#
# <section>[1] / <article>[9]
# ---------------------------
# 	h2[0] = <h2>Juan Ignacio de Mendiguren y Martín Tetaz, en un tenso cruce en televisión: "No podés ser tan animal" y "No resistís las reglas"</h2>
#
# <section>[1] / <article>[10]
# ----------------------------
# 	h2[0] = <h2>Carlos Melconian admitió que quiere ser ministro de Mauricio Macri o Rodríguez Larreta: "Donde me pongan, yo estoy"</h2>
#
# <section>[1] / <article>[11]
# ----------------------------
# 	h2[0] = <h2>Santiago del Moro rechazó que Gran Hermano deba rectificarse ante el Gobierno: "Lo que digan los participantes corre por su cuenta"</h2>
#
# <section>[1] / <article>[12]
# ----------------------------
# 	h2[0] = <h2>"Dejen de hacer papelones": duro cruce entre Diego Santilli, María Eugenia Vidal y Gabriela Cerruti por la acusación contra Gran Hermano</h2>
#
# <section>[1] / <article>[13]
# ----------------------------
# 	h2[0] = <h2>Cuáles son las cuentas que ahora pagan 60% de interés sólo por tener saldo</h2>
# 	volanta = "<p class="volanta">Tasa anual</p>"
# 	author = "<p class="author">Martín Grosz</p>"
#
# ------------------------------------------------------------
# <section>[2] / <article>[0]
# ---------------------------
# 	h2[0] = <h2 class="small__h2">Mucho acto por el 17 de octubre, pero más bien de desbande que de lealtad</h2>
#
# <section>[2] / <article>[1]
# ---------------------------
# 	h2[0] = <h2 class="small__h2">Signos inquietantes por la descomposición del Frente y el desbande del Gobierno</h2>
#
# <section>[2] / <article>[2]
# ---------------------------
# 	h2[0] = <h2 class="small__h2">La amenaza nuclear</h2>
#
# <section>[2] / <article>[3]
# ---------------------------
# 	h2[0] = <h2 class="small__h2">Hacia una estrategia mas virtuosa de inserción internacional</h2>
#
# <section>[2] / <article>[4]
# ---------------------------
# 	h2[0] = <h2 class="small__h2">Un metaverso humano</h2>
#
# <section>[2] / <article>[5]
# ---------------------------
# 	h2[0] = <h2 class="small__h2">Argentina, 1985 y el encuentro</h2>
#
# <section>[2] / <article>[6]
# ---------------------------
# 	h2[0] = <h2>Misterio en Villa Pueyrredón: encuentran a dos hermanos muertos en un departamento</h2>
# 	volanta = "<p class="volanta">Tenían 56 y 63 años</p>"
# 	section = "<p class="section">Policiales</p>"
#
# <section>[2] / <article>[7]
# ---------------------------
# 	h2[0] = <h2>Los jubilados podrán comprar TV, celulares, lavarropas y heladeras en 42 cuotas</h2>
# 	volanta = "<p class="volanta">Extienden el Ahora 30</p>"
# 	author = "<p class="author">Damián Kantor</p>"
#
# <section>[2] / <article>[8]
# ---------------------------
# 	h2[0] = <h2>La dura respuesta de Mauricio Macri a las críticas de Facundo Manes</h2>
# 	volanta = "<p class="volanta">“Les va a ir mal”</p>"
# 	section = "<p class="section">Política</p>"
#
# <section>[2] / <article>[9]
# ---------------------------
# 	h2[0] = <h2>Descubrimiento científico: por primera vez hallan una “familia” de neandertales</h2>
# 	volanta = "<p class="volanta">Trece cuerpos en dos cuevas</p>"
# 	section = "<p class="section">Sociedad</p>"
#
# <section>[2] / <article>[10]
# ----------------------------
# 	h2[0] = <h2>Cuatro razones por las que hay cada vez menos pediatras y un pronóstico alarmante</h2>
# 	volanta = "<p class="volanta">La falta de médicos</p>"
# 	author = "<p class="author">Gonzalo Herman</p>"
#
# <section>[2] / <article>[11]
# ----------------------------
# 	h2[0] = <h2>Cristiano Ronaldo se enojó y abandonó la cancha en pleno partido</h2>
# 	volanta = "<p class="volanta">Dudas sobre su futuro</p>"
# 	section = "<p class="section">Deportes</p>"
#
# ------------------------------------------------------------
# <section>[3] / <article>[0]
# ---------------------------
# 	h2[0] = <h2 class="small__h2">Mucho acto por el 17 de octubre, pero más bien de desbande que de lealtad</h2>
#
# <section>[3] / <article>[1]
# ---------------------------
# 	h2[0] = <h2 class="small__h2">Signos inquietantes por la descomposición del Frente y el desbande del Gobierno</h2>
#
# <section>[3] / <article>[2]
# ---------------------------
# 	h2[0] = <h2 class="small__h2">La amenaza nuclear</h2>
#
# <section>[3] / <article>[3]
# ---------------------------
# 	h2[0] = <h2 class="small__h2">Hacia una estrategia mas virtuosa de inserción internacional</h2>
#
# <section>[3] / <article>[4]
# ---------------------------
# 	h2[0] = <h2 class="small__h2">Un metaverso humano</h2>
#
# <section>[3] / <article>[5]
# ---------------------------
# 	h2[0] = <h2 class="small__h2">Argentina, 1985 y el encuentro</h2>
#
# ------------------------------------------------------------
# <section>[4] / <article>[0]
# ---------------------------
# 	h2[0] = <h2>La increíble historia del segundo marido de Marilyn Monroe, que era más famoso que ella </h2>
# 	volanta = "<p class="volanta">Recuerdo</p>"
# 	author = "<p class="author">Luis Vinker</p>"
#
# <section>[4] / <article>[1]
# ---------------------------
# 	h2[0] = <h2>Con insultos, Fernando Iglesias y Caparrós tuvieron otro fuerte cruce en redes</h2>
# 	volanta = "<p class="volanta">Ahora, por el libro de Macri</p>"
# 	section = "<p class="section">Política</p>"
#
# <section>[4] / <article>[2]
# ---------------------------
# 	h2[0] = <h2>Putin declara la ley marcial en los cuatro territorios anexados en Ucrania</h2>
# 	volanta = "<p class="volanta">La guerra, minuto a minuto</p>"
# 	section = "<p class="section">Mundo</p>"
#
# <section>[4] / <article>[3]
# ---------------------------
# 	h2[0] = <h2>La argentina que vive en Qatar y fue elegida 'fan líder' por el Comité organizador</h2>
# 	volanta = "<p class="volanta">Copa del Mundo</p>"
# 	author = "<p class="author">Alejandra Fernández Guida</p>"
#
# <section>[4] / <article>[4]
# ---------------------------
# 	h2[0] = <h2>Fue monje 10 años, dejó el monasterio y hoy es un sastre top</h2>
# 	volanta = "<p class="volanta">Criado en Azul</p>"
# 	author = "<p class="author">Carla Rodríguez</p>"
#
# <section>[4] / <article>[5]
# ---------------------------
# 	h2[0] = <h2>Aumento de casos de gripe A: cómo evitar un impacto grave</h2>
# 	volanta = "<p class="volanta">Síntomas y tratamiento</p>"
# 	author = "<p class="author">Florencia Cunzolo</p>"
#
# <section>[4] / <article>[6]
# ---------------------------
# 	h2[0] = <h2>La mitad del mundo tiene clítoris, ¿por qué nadie lo estudia?</h2>
# 	volanta = "<p class="volanta">Operaciones y orgasmos</p>"
# 	author = "<p class="author">Rachel E. Gross</p>"
#
# ------------------------------------------------------------
# <section>[5] / <article>[0]
# ---------------------------
# 	h2[0] = <h2>Al aire, Del Moro rechazó el pedido de retractación que le hizo el Gobierno a Gran Hermano</h2>
# 	volanta = "<p class="volanta">Tras la acusación a Alberto F.</p>"
# 	section = "<p class="section">Fama</p>"
#
# <section>[5] / <article>[1]
# ---------------------------
# 	h2[0] = <h2>Quiénes son los primeros cuatro nominados de Gran Hermano</h2>
# 	volanta = "<p class="volanta">“Alfa”, entre ellos</p>"
# 	section = "<p class="section">Fama</p>"
#
# <section>[5] / <article>[2]
# ---------------------------
# 	h2[0] = <h2>Marianela Mirra reveló que es lo que no le gusta del nuevo Gran Hermano: “No lo veo más”</h2>
# 	volanta = "<p class="volanta">Muy crítica</p>"
# 	section = "<p class="section"></p>"
#
# <section>[5] / <article>[3]
# ---------------------------
# 	h2[0] = <h2>Tamara Báez se mostró junto a su nuevo novio y aseguró que quiere tener un hijo</h2>
# 	volanta = "<p class="volanta">¿L-Gante? Cosa del pasado</p>"
# 	section = "<p class="section"></p>"
#
# ------------------------------------------------------------
# <section>[6] / <article>[0]
# ---------------------------
# 	h2[0] = <h2>Secretos de la educación en Finlandia: con pocas horas de clase, son los mejores </h2>
# 	volanta = "<p class="volanta">Clarín en Helsinki</p>"
# 	author = "<p class="author">Irene Hartmann</p>"
#
# <section>[6] / <article>[1]
# ---------------------------
# 	h2[0] = <h2>La incómoda vía libre del Gobierno con la promo de una gaseosa</h2>
# 	volanta = "<p class="volanta">Figuritas del Mundial</p>"
# 	author = "<p class="author">Pablo Sigal</p>"
#
# <section>[6] / <article>[2]
# ---------------------------
# 	h2[0] = <h2>El bono ANSeS alcanzaría a un millón de personas que no tienen ayuda del Estado</h2>
# 	volanta = "<p class="volanta">Similar al IFE</p>"
# 	author = "<p class="author">Ismael Bermúdez</p>"
#
# <section>[6] / <article>[3]
# ---------------------------
# 	h2[0] = <h2>Los problemas más comunes cuando los hijos emigran y los padres se quedan</h2>
# 	volanta = "<p class="volanta">Cómo resolverlos a distancia</p>"
# 	author = "<p class="author">Silvana Saldisuri</p>"
#
# <section>[6] / <article>[4]
# ---------------------------
# 	h2[0] = <h2>Viajó al espacio y sintió una “tristeza abrumadora”: qué es el “efecto perspectiva”</h2>
# 	volanta = "<p class="volanta">El actor de Star Trek</p>"
# 	author = "<p class="author">Marcelo Bellucci</p>"
#
# ------------------------------------------------------------
# <section>[7] / <article>[0]
# ---------------------------
# 	h2[0] = <h2>“Tenía que sobrevivir”: 50 años de la tragedia de los Andes</h2>
# 	volanta = "<p class="volanta">Especial Clarín</p>"
# 	author = "<p class="author">Gonzalo Sánchez</p>"
#
# <section>[7] / <article>[1]
# ---------------------------
# 	h2[0] = <h2>El Servicio Meteorológico cumple 150 años: 15 hitos que “rompieron el termómetro”</h2>
# 	volanta = "<p class="volanta">Sociedad</p>"
# 	author = "<p class="author">Jazmín Bazán</p>"
#
# <section>[7] / <article>[2]
# ---------------------------
# 	h2[0] = <h2>Hablan las víctimas del terrorismo mapuche en Bariloche</h2>
# 	volanta = "<p class="volanta">Villa Mascardi</p>"
# 	author = "<p class="author">Gonzalo Sánchez</p>"
#
# <section>[7] / <article>[3]
# ---------------------------
# 	h2[0] = <h2>La nueva tierra prometida: el país vecino que no para de atraer inversiones argentinas</h2>
# 	volanta = "<p class="volanta">Sociedad</p>"
# 	author = "<p class="author">Penélope Canonico</p>"
#
# ------------------------------------------------------------
# <section>[8] / <article>[0]
# ---------------------------
# 	h2[0] = <h2>Definición con clásicos cruzados: los antecedentes de una pelea a puro morbo</h2>
# 	volanta = "<p class="volanta">Boca y Racing van por el título</p>"
# 	author = "<p class="author">Oscar Barnade</p>"
#
# <section>[8] / <article>[1]
# ---------------------------
# 	h2[0] = <h2>El milagro Huracán: qué necesita el tercero en discordia para ser campeón</h2>
# 	volanta = "<p class="volanta">Visita a Patronato</p>"
# 	author = "<p class="author">Martín Rubino</p>"
#
# <section>[8] / <article>[2]
# ---------------------------
# 	h2[0] = <h2>El presidente del Atlético de Madrid habló de las dudas con De Paul tras el affaire con Tini</h2>
# 	volanta = "<p class="volanta">Lo buscan de Italia</p>"
# 	section = "<p class="section">Deportes</p>"
#
# <section>[8] / <article>[3]
# ---------------------------
# 	h2[0] = <h2>A 100 años del primer muerto en el fútbol argentino y la irrupción de las mortales balas policiales</h2>
# 	volanta = "<p class="volanta">FUERA DE JUEGO</p>"
# 	author = "<p class="author">DIARIO OLÉ</p>"
#
# <section>[8] / <article>[4]
# ---------------------------
# 	h2[0] = <h2>Ya está en la Argentina la camiseta que usó Maradona en la final de México '86</h2>
# 	volanta = "<p class="volanta">MARADONA</p>"
# 	author = "<p class="author">DIARIO OLÉ</p>"
#
# <section>[8] / <article>[5]
# ---------------------------
# 	h2[0] = <h2>Apareció el nombre de Messi en el juicio a Neymar: qué dijo el ex representante</h2>
# 	volanta = "<p class="volanta">En España</p>"
# 	section = "<p class="section">Deportes</p>"
#
# <section>[8] / <article>[6]
# ---------------------------
# 	h2[0] = <h2>El argentino que “inventó” el yachting en Canadá y triunfa con su pasión</h2>
# 	volanta = "<p class="volanta">Federico Donzino</p>"
# 	author = "<p class="author">Luciana Aranguiz</p>"
#
# ------------------------------------------------------------
# <section>[9] / <article>[0]
# ---------------------------
# 	h2[0] = <h2>Canasta Básica: una familia necesitó $ 128.214 en septiembre para no caer en la pobreza</h2>
# 	volanta = "<p class="volanta">Datos del INDEC</p>"
# 	author = "<p class="author">Natalia Muscatelli</p>"
# 	summary = "<p class="summary">El costo de la CBT subió 7,1% el último mes. En tanto, la CBA"
#
# <section>[9] / <article>[1]
# ---------------------------
# 	h2[0] = <h2>Puso en subasta una tonelada de monedas pero luego se echó para atrás</h2>
# 	volanta = "<p class="volanta">“Blooper” del Banco Central</p>"
# 	section = "<p class="section">Economía</p>"
#
# <section>[9] / <article>[2]
# ---------------------------
# 	h2[0] = <h2>Estiman que la inflación de octubre superará el 6%: qué es lo que impulsa la suba</h2>
# 	volanta = "<p class="volanta">Precios sin freno</p>"
# 	author = "<p class="author">Soledad Navarro</p>"
#
# <section>[9] / <article>[3]
# ---------------------------
# 	h2[0] = <h2>Las empresas evalúan pagar un bono en dólares al personal</h2>
# 	volanta = "<p class="volanta">Dólar tecno</p>"
# 	author = "<p class="author">Juan Manuel Barca</p>"
#
# <section>[9] / <article>[4]
# ---------------------------
# 	h2[0] = <h2>Nuevo Ahora 30: qué se podrá comprar, cuándo empieza y cuál será la tasa</h2>
# 	volanta = "<p class="volanta">Rubro por rubro</p>"
# 	section = "<p class="section">Economía</p>"
#
# <section>[9] / <article>[5]
# ---------------------------
# 	h2[0] = <h2>Tienda Nube sale a competir en el segmento de medios de pagos</h2>
# 	volanta = "<p class="volanta">Inversión</p>"
# 	author = "<p class="author">Ana Clara Pedotti</p>"
#
# ------------------------------------------------------------
# <section>[10] / <article>[0]
# ----------------------------
# 	h2[0] = <h2>De una limusina a un Hummer, cómo es el millonario garaje de L-Gante</h2>
# 	volanta = "<p class="volanta">Fanático de las cuatro ruedas</p>"
# 	section = "<p class="section">Autos</p>"
#
# <section>[10] / <article>[1]
# ----------------------------
# 	h2[0] = <h2>Netflix anunció que eliminará la función que cobraba un extra por compartir la cuenta</h2>
# 	volanta = "<p class="volanta">Habrá cambios en 2023</p>"
# 	section = "<p class="section">Tecnología</p>"
#
# <section>[10] / <article>[2]
# ----------------------------
# 	h2[0] = <h2>Cómo bloquear mensajes de texto molestos en cualquier teléfono celular</h2>
# 	volanta = "<p class="volanta">Paso a paso</p>"
# 	section = "<p class="section">Tecnología</p>"
#
# <section>[10] / <article>[3]
# ----------------------------
# 	h2[0] = <h2>Día del Gin Tonic: cómo preparar la receta clásica y otras 6 versiones</h2>
# 	volanta = "<p class="volanta">Un clásico</p>"
# 	section = "<p class="section">Gourmet</p>"
#
# <section>[10] / <article>[4]
# ----------------------------
# 	h2[0] = <h2>Una noche diferente: hoteles en vagones y estaciones de tren</h2>
# 	volanta = "<p class="volanta">Propuestas</p>"
# 	author = "<p class="author">Gabriel Silveira</p>"
#
# <section>[10] / <article>[5]
# ----------------------------
# 	h2[0] = <h2>Una playa nudista en Mar del Plata, la preferida de las parejas</h2>
# 	volanta = "<p class="volanta">La Escondida</p>"
# 	section = "<p class="section">Relaciones</p>"
#
# ------------------------------------------------------------
# <section>[11] / <article>[0]
# ----------------------------
# 	h2[0] = <h2>Exhiben un modelo hiperrealista de Jesucristo con todas sus heridas</h2>
# 	volanta = "<p class="volanta">Tiene cabello humano</p>"
# 	section = "<p class="section">Viste</p>"
#
# <section>[11] / <article>[1]
# ----------------------------
# 	h2[0] = <h2>Un bebé escapó de su casa y dos perros le salvaron la vida</h2>
# 	volanta = "<p class="volanta">Quedó grabado</p>"
# 	section = "<p class="section">Viste</p>"
#
# <section>[11] / <article>[2]
# ----------------------------
# 	h2[0] = <h2>Tremenda lucha cuerpo a cuerpo entre un oso grizzly y dos estudiantes</h2>
# 	volanta = "<p class="volanta">Mutilados, pero vivos</p>"
# 	section = "<p class="section">Internacional</p>"
#
# <section>[11] / <article>[3]
# ----------------------------
# 	h2[0] = <h2>La actriz de She-Hulk habla del final de la serie y de los pros y contras de Marvel</h2>
# 	volanta = "<p class="volanta">Entrevista a Tatiana Maslany </p>"
# 	author = "<p class="author">Marcelo Fernández Bitar</p>"
#
# <section>[11] / <article>[4]
# ----------------------------
# 	h2[0] = <h2>Un mago murió en plena actuación y la gente creyó que era un truco</h2>
# 	volanta = "<p class="volanta">En España</p>"
# 	section = "<p class="section">Viste</p>"
#
# <section>[11] / <article>[5]
# ----------------------------
# 	h2[0] = <h2>Cómo sos según tu signo lunar</h2>
# 	volanta = "<p class="volanta">Carta natal</p>"
# 	author = "<p class="author">Beatriz Leveratto</p>"
#
# ------------------------------------------------------------
# <section>[12] / <article>[0]
# ----------------------------
# 	h2[0] = <h2>Las predicciones para Argentina</h2>
# 	volanta = "<p class="volanta">Qatar 2022</p>"
# 	section = "<p class="section">deportes</p>"
#
# <section>[12] / <article>[1]
# ----------------------------
# 	h2[0] = <h2>El asesino serial “que no mató a nadie”</h2>
# 	volanta = "<p class="volanta">Magnus Mefisto</p>"
# 	section = "<p class="section">Política</p>"
#
# <section>[12] / <article>[2]
# ----------------------------
# 	h2[0] = <h2>A días del Mundial más esperado para los argentinos</h2>
# 	volanta = "<p class="volanta">Qatar 2022</p>"
# 	section = "<p class="section">Deportes</p>"
#
# <section>[12] / <article>[3]
# ----------------------------
# 	h2[0] = <h2>Su origen y secretos</h2>
# 	volanta = "<p class="volanta">Fiesta Nacional en Mercedes </p>"
# 	section = "<p class="section">Espectáculos</p>"
#
# ------------------------------------------------------------
# <section>[13] / <article>[0]
# ----------------------------
# 	h2[0] = <h2>Las mejores imágenes de hoy en la Argentina y el mundo</h2>
# 	volanta = "<p class="volanta">Historias Visuales</p>"
#
# ------------------------------------------------------------
# <section>[14] / <article>[0]
# ----------------------------
# 	h2[0] = <h2>Comida, vestimenta y viajes: una década de cambios en China</h2>
# 	volanta = "<p class="volanta">Crecimiento</p>"
# 	section = "<p class="section">BrandStudio</p>"
#
# <section>[14] / <article>[1]
# ----------------------------
# 	h2[0] = <h2>“Pensá en grande”: la campaña innovadora del Banco Macro que se enfoca en las personas</h2>
# 	volanta = "<p class="volanta">Continuo crecimiento</p>"
# 	section = "<p class="section">BrandStudio</p>"
#
# <section>[14] / <article>[2]
# ----------------------------
# 	h2[0] = <h2>Nerdearla llega a todos los hogares de Argentina</h2>
# 	volanta = "<p class="volanta">Lo que se viene</p>"
# 	section = "<p class="section">BrandStudio</p>"
#
# <section>[14] / <article>[3]
# ----------------------------
# 	h2[0] = <h2>Isla Corona: un espacio para conectar con la naturaleza</h2>
# 	volanta = "<p class="volanta">Un oasis exclusivo</p>"
# 	section = "<p class="section">BrandStudio</p>"
#
# <section>[14] / <article>[4]
# ----------------------------
# 	h2[0] = <h2>YPF y Editorial Planeta presentan “Una historia del Conurbano”, de Pedro Saborido</h2>
# 	volanta = "<p class="volanta">Lanzamiento</p>"
# 	section = "<p class="section">BrandStudio</p>"
#
# <section>[14] / <article>[5]
# ----------------------------
# 	h2[0] = <h2>Una semana para analizar tus seguros y tener tranquilidad todo el año</h2>
# 	volanta = "<p class="volanta">Tranqui Week</p>"
# 	section = "<p class="section">BrandStudio</p>"
#
# ------------------------------------------------------------
# <section>[15] / <article>[0]
# ----------------------------
# 	h2[0] = <h2>Guerra en Ucrania: ¿A dónde se han ido todos los hombres de Moscú?</h2>
# 	volanta = "<p class="volanta">Escenario</p>"
# 	author = "<p class="author">Valerie Hopkins</p>"
#
# <section>[15] / <article>[1]
# ----------------------------
# 	h2[0] = <h2>Preparándose para el chantaje republicano de la deuda</h2>
# 	volanta = "<p class="volanta">Opinión</p>"
# 	author = "<p class="author">Paul Krugman</p>"
#
# <section>[15] / <article>[2]
# ----------------------------
# 	h2[0] = <h2>Irán envía entrenadores de drones a Crimea para ayudar al ejército ruso</h2>
# 	volanta = "<p class="volanta">Guerra en Ucrania</p>"
# 	author = "<p class="author">Julian E. Barnes</p>"
#
# <section>[15] / <article>[3]
# ----------------------------
# 	h2[0] = <h2>Gracias Xi Jinping</h2>
# 	volanta = "<p class="volanta">Opinión</p>"
# 	author = "<p class="author">Bret Stephens</p>"
#
# ------------------------------------------------------------
# <section>[16] / <article>[0]
# ----------------------------
# 	h2[0] = <h2>Cuál es la línea de colectivos que sigue haciendo el recorrido con el que la crearon </h2>
# 	volanta = "<p class="volanta">Desde hace 100 años</p>"
# 	author = "<p class="author">Ariana López Pasquare</p>"
#
# <section>[16] / <article>[1]
# ----------------------------
# 	h2[0] = <h2>De chico estuvo 25 minutos en el fondo de una pileta y ahora se luce como rapero</h2>
# 	volanta = "<p class="volanta">Mato Vive</p>"
# 	author = "<p class="author">Tito Lescano</p>"
#
# <section>[16] / <article>[2]
# ----------------------------
# 	h2[0] = <h2>Tendencia que crece en el GBA: dónde estará la primera bicisenda de Moreno</h2>
# 	volanta = "<p class="volanta">Cambio de cara</p>"
# 	section = "<p class="section">Zonales</p>"
#
# <section>[16] / <article>[3]
# ----------------------------
# 	h2[0] = <h2>El ex intendente que se hizo un by pass gástrico para la campaña 2023</h2>
# 	volanta = "<p class="volanta">“Tengo que estar en forma”</p>"
# 	author = "<p class="author">Juan Pablo Estevez</p>"
#
# ------------------------------------------------------------
# <section>[17] / <article>[0]
# ----------------------------
# 	h2[0] = <h2>Claves para transitarla mejor</h2>
# 	volanta = "<p class="volanta">Menopausia</p>"
# 	section = "<p class="section">Belleza - Salud</p>"
#
# <section>[17] / <article>[1]
# ----------------------------
# 	h2[0] = <h2> Tratamientos con ingredientes de origen natural</h2>
# 	volanta = "<p class="volanta">Cuidado del cabello</p>"
# 	section = "<p class="section">Belleza - Pelo</p>"
#
# <section>[17] / <article>[2]
# ----------------------------
# 	h2[0] = <h2>Moda &amp; tecnología</h2>
# 	volanta = "<p class="volanta">Lifestyle</p>"
# 	section = "<p class="section">Estilo de vida - Consumo</p>"
#
# <section>[17] / <article>[3]
# ----------------------------
# 	h2[0] = <h2>El nuevo hit</h2>
# 	volanta = "<p class="volanta">Delineador blanco</p>"
# 	section = "<p class="section">Belleza - Maquillaje</p>"
#
# ------------------------------------------------------------
# <section>[none] / <article>[0]
# ------------------------------
# 	h2[0] = <h2>El Gobierno pide una rectificación a Gran Hermano por la acusación de un participante del reality sobre Alberto Fernández</h2>
# 	volanta = "<p class="volanta"></p>"
# 	author = "<p class="author"></p>"
#
# <section>[none] / <article>[1]
# ------------------------------
# 	h2[0] = <h2>Brutal pelea en la Antártida: el encargado de la Base Marambio fue atacado con una maza mientras dormía</h2>
# 	volanta = "<p class="volanta"></p>"
# 	author = "<p class="author"></p>"
#
# <section>[none] / <article>[2]
# ------------------------------
# 	h2[0] = <h2>15 segundos de pánico en un avión de Aerolíneas: "Nunca sentí que estuve tan cercana a la muerte"</h2>
# 	volanta = "<p class="volanta"></p>"
# 	author = "<p class="author"></p>"
#
# <section>[none] / <article>[3]
# ------------------------------
# 	h2[0] = <h2>Alerta en al aire: por qué se dan turbulencias como la que afectó al avión de Aerolíneas</h2>
# 	volanta = "<p class="volanta"></p>"
# 	author = "<p class="author"></p>"
#
# <section>[none] / <article>[4]
# ------------------------------
# 	h2[0] = <h2>"Dejen de hacer papelones": duro cruce entre Diego Santilli, María Eugenia Vidal y Gabriela Cerruti por la acusación contra Gran Hermano</h2>
# 	volanta = "<p class="volanta"></p>"
# 	author = "<p class="author"></p>"
#
# <section>[none] / <article>[5]
# ------------------------------
# 	h2[0] = <h2>Por los pasillos: la candidata tapada de Alberto Fernández, un dirigente social a los escobazos y el osobuco de De Loredo</h2>
# 	volanta = "<p class="volanta"></p>"
# 	author = "<p class="author"></p>"
#
# ------------------------------------------------------------

# %%
# dump source under every single <article>:
for i, article in enumerate(articles_by_section[0]):
    print("<article>[%d] : %s" % (i, len(article.parent.find_all('li', class_ = 'item-related'))))
    print("-------------")
    
    print(article.parent.prettify())
    print('-' * 60)
# Out:
# <article>[0] : 1
# -------------
# <div class="m-box child h300 col-lg-6 col-md-8 col-sm-12 col-xs-12 no-p m2x1" data-classes="m-box child m2x1 h300  col-lg-6 col-md-8 col-sm-12 col-xs-12 no-p" data-name="content" data-size-h="1" data-size-w="2">
#  <article class="content-nota list-format twoxone_no_foto">
#   <div class="mt">
#    <div class="max-h flex-change">
#     <h2>
#      Ante la presión de la oposición, el kirchnerismo cede para sumar votos y aprobar el Presupuesto 2023
#     </h2>
#     <p class="volanta">
#      La pelea en Diputados
#     </p>
#    </div>
#    <div class="data-txt">
#     <p class="author">
#      Gustavo Berón
#     </p>
#    </div>
#    <p class="summary">
#     Tuvo que aceptar varias modificaciones al proyecto original enviado por Massa. Así, el oficialismo busca darle dictamen hoy y tratarlo la semana próxima en el recinto.
#    </p>
#   </div>
#   <a aria-label="/politica/oficialismo-cede-presion-oposicion-aprobar-presupuesto-2023_0_wVtJkpdq8V.html" class="link_article" href="/politica/oficialismo-cede-presion-oposicion-aprobar-presupuesto-2023_0_wVtJkpdq8V.html" onclick="metricsView('bloques_home','contenedor_1_piso_tipo_b|wVtJkpdq8V');" target="_self">
#   </a>
#  </article>
#  <ul class="content-related">
#   <li class="item-related">
#    <article class="related_aperture">
#     <a aria-label="/politica/cumbre-plata-medio-interna-kicillof-maximo-kirchner-intendentes-definen-estrategia-cara-2023_0_VmRbBqspRs.html" href="/politica/cumbre-plata-medio-interna-kicillof-maximo-kirchner-intendentes-definen-estrategia-cara-2023_0_VmRbBqspRs.html" onclick="metricsView('bloques_home','VmRbBqspRs');" target="_self">
#      <div class="box-title-rel">
#       <span class="section-rel">
#        Política.
#       </span>
#       <h2 class="title-rel">
#        Frente al derrumbe, Kicillof, Máximo y los intendentes intentan “blindar” el GBA
#       </h2>
#       <span class="author-rel">
#        Federico Mayol
#       </span>
#      </div>
#     </a>
#    </article>
#   </li>
#  </ul>
# </div>
#
# ------------------------------------------------------------
# <article>[1] : 0
# -------------
# <li class="item-related">
#  <article class="related_aperture">
#   <a aria-label="/politica/cumbre-plata-medio-interna-kicillof-maximo-kirchner-intendentes-definen-estrategia-cara-2023_0_VmRbBqspRs.html" href="/politica/cumbre-plata-medio-interna-kicillof-maximo-kirchner-intendentes-definen-estrategia-cara-2023_0_VmRbBqspRs.html" onclick="metricsView('bloques_home','VmRbBqspRs');" target="_self">
#    <div class="box-title-rel">
#     <span class="section-rel">
#      Política.
#     </span>
#     <h2 class="title-rel">
#      Frente al derrumbe, Kicillof, Máximo y los intendentes intentan “blindar” el GBA
#     </h2>
#     <span class="author-rel">
#      Federico Mayol
#     </span>
#    </div>
#   </a>
#  </article>
# </li>
#
# ------------------------------------------------------------
# <article>[2] : 0
# -------------
# <div class="m-box h300 child col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p list-format" data-classes="m-box child h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p list-format" data-name="content" data-size-h="1" data-size-w="1">
#  <article class="content-nota onexone_foto list-format flex-change">
#   <div class="mt">
#    <div class="flex-change">
#     <h2>
#      Réplica del Gobierno a La Cámpora: dice que el acuerdo con el FMI está vigente
#     </h2>
#     <p class="volanta">
#      Interna sin tregua
#     </p>
#    </div>
#    <div class="data-txt">
#     <p class="author">
#      Federico Mayol
#     </p>
#    </div>
#   </div>
#   <div class="wrap-figure">
#    <picture id="imgmod_202291317127001">
#     <source media="(min-width: 720px)" srcset="//www.clarin.com/img/2022/10/19/czksjSD51_600x290__2.jpg#1666229179545"/>
#     <img alt="Réplica del Gobierno a La Cámpora: dice que el acuerdo con el FMI está vigente" class="img-responsive intelResolution" height="100" loading="lazy" src="//www.clarin.com/img/2022/10/19/czksjSD51_600x290__2.jpg#1666229179545" width="100"/>
#    </picture>
#   </div>
#   <a aria-label="/politica/gobierno-replica-campora-dice-acuerdo-fmi-vigente-cumpliran-metas_0_BJADy9KZ7O.html" class="link_article" href="/politica/gobierno-replica-campora-dice-acuerdo-fmi-vigente-cumpliran-metas_0_BJADy9KZ7O.html" onclick="metricsView('bloques_home','contenedor_1_piso_tipo_b|BJADy9KZ7O');" target="_self">
#   </a>
#  </article>
# </div>
#
# ------------------------------------------------------------
# <article>[3] : 0
# -------------
# <div class="m-box child h150 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p" data-classes="m-box child h150 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p" data-name="content" data-size-h="0.5" data-size-w="1">
#  <article class="content-nota list-format onexone_doble">
#   <div class="mt">
#    <div class="flex-change">
#     <h2>
#      El Gobierno le pide una rectificación a Gran Hermano por la acusación contra el Presidente
#     </h2>
#     <p class="volanta">
#      Reality y polémica
#     </p>
#    </div>
#    <div class="data-txt">
#     <p class="section">
#      Política
#     </p>
#    </div>
#   </div>
#   <div class="wrap-figure">
#    <picture id="imgmod_202293430413117">
#     <source media="(min-width: 720px)" srcset="//www.clarin.com/img/2022/10/19/Cct64sWP8_110x110__1.jpg"/>
#     <img alt="El Gobierno le pide una rectificación a Gran Hermano por la acusación contra el Presidente" class="img-responsive intelResolution" height="100" loading="lazy" src="//www.clarin.com/img/2022/10/19/E3Pd0gBDo_600x290__2.jpg#1666227347793" width="100"/>
#    </picture>
#   </div>
#   <a aria-label="/politica/gobierno-pide-rectificacion-gran-hermano-dichos-participante-reality-alberto-fernandez_0_jOYnJQPEb0.html" class="link_article" href="/politica/gobierno-pide-rectificacion-gran-hermano-dichos-participante-reality-alberto-fernandez_0_jOYnJQPEb0.html" onclick="metricsView('bloques_home','contenedor_1_piso_tipo_b|jOYnJQPEb0');" target="_self">
#   </a>
#  </article>
# </div>
#
# ------------------------------------------------------------
# <article>[4] : 0
# -------------
# <div class="m-box child h150 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p" data-classes="m-box child h150 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p" data-name="content" data-size-h="0.5" data-size-w="1">
#  <article class="content-nota list-format onexone_doble">
#   <div class="mt">
#    <div class="flex-change">
#     <h2>
#      Ironías de la oposición: “¿De verdad Alberto está preocupado por Gran Hermano?”
#     </h2>
#     <p class="volanta">
#      Cruces con Cerruti
#     </p>
#    </div>
#    <div class="data-txt">
#     <p class="section">
#      Política
#     </p>
#    </div>
#   </div>
#   <div class="wrap-figure">
#    <picture id="imgmod_202293717233315">
#     <source media="(min-width: 720px)" srcset="//www.clarin.com/img/2022/10/19/uGq-Xp36S_110x110__2.jpg#1666234434912"/>
#     <img alt='Ironías de la oposición: "¿De verdad Alberto está preocupado por Gran Hermano?"' class="img-responsive intelResolution" height="100" loading="lazy" src="//www.clarin.com/img/2022/10/19/uGq-Xp36S_290x140__1.jpg" width="100"/>
#    </picture>
#   </div>
#   <a aria-label="/politica/-dejen-hacer-papelones-duro-cruce-diego-santilli-maria-eugenia-vidal-gabriela-cerruti-acusacion-gran-hermano_0_Ms9pa8f7Rs.html" class="link_article" href="/politica/-dejen-hacer-papelones-duro-cruce-diego-santilli-maria-eugenia-vidal-gabriela-cerruti-acusacion-gran-hermano_0_Ms9pa8f7Rs.html" onclick="metricsView('bloques_home','contenedor_1_piso_tipo_b|Ms9pa8f7Rs');" target="_self">
#   </a>
#  </article>
# </div>
#
# ------------------------------------------------------------

# %%
# How many <li>s are on each <article>?

for i, article in enumerate(articles):
    print("<article>[%3s]" % i, str(len(list(article.parent.find_all('li')))) if len(list(article.parent.find_all('li'))) != 0 else "", 
          end = ' ' if (i+1) % 8 != 0 else '\n')
# Out:
# <article>[  0] 1 <article>[  1]  <article>[  2]  <article>[  3]  <article>[  4]  <article>[  5]  <article>[  6]  <article>[  7]
# <article>[  8]  <article>[  9]  <article>[ 10]  <article>[ 11]  <article>[ 12]  <article>[ 13]  <article>[ 14]  <article>[ 15]
# <article>[ 16]  <article>[ 17]  <article>[ 18]  <article>[ 19]  <article>[ 20]  <article>[ 21]  <article>[ 22]  <article>[ 23]
# <article>[ 24]  <article>[ 25]  <article>[ 26]  <article>[ 27]  <article>[ 28]  <article>[ 29]  <article>[ 30]  <article>[ 31]
# <article>[ 32]  <article>[ 33]  <article>[ 34]  <article>[ 35]  <article>[ 36]  <article>[ 37]  <article>[ 38]  <article>[ 39]
# <article>[ 40]  <article>[ 41]  <article>[ 42]  <article>[ 43]  <article>[ 44]  <article>[ 45]  <article>[ 46]  <article>[ 47]
# <article>[ 48]  <article>[ 49]  <article>[ 50]  <article>[ 51]  <article>[ 52]  <article>[ 53]  <article>[ 54]  <article>[ 55]
# <article>[ 56]  <article>[ 57]  <article>[ 58]  <article>[ 59]  <article>[ 60]  <article>[ 61]  <article>[ 62]  <article>[ 63]
# <article>[ 64]  <article>[ 65]  <article>[ 66]  <article>[ 67]  <article>[ 68]  <article>[ 69]  <article>[ 70]  <article>[ 71]
# <article>[ 72]  <article>[ 73]  <article>[ 74]  <article>[ 75]  <article>[ 76]  <article>[ 77]  <article>[ 78]  <article>[ 79]
# <article>[ 80] 9 <article>[ 81]  <article>[ 82]  <article>[ 83]  <article>[ 84]  <article>[ 85]  <article>[ 86]  <article>[ 87]
# <article>[ 88]  <article>[ 89]  <article>[ 90]  <article>[ 91]  <article>[ 92]  <article>[ 93]  <article>[ 94]  <article>[ 95]
# <article>[ 96]  <article>[ 97]  <article>[ 98]  <article>[ 99]  <article>[100]  <article>[101]  <article>[102]  <article>[103]
# <article>[104]

# %%
for i, art in enumerate(articles_by_section_dict[1][7:]):
    print(i, '\n', art.parent.parent.parent)
# Out:
# 0
#  <ul class="box-items">
# <li aria-label="/politica/esteban-bullrich-cuestiono-interna-juntos-cambio-llevamos-meses-cascoteandonos-rancho-_0_opIgF9sv95.html" style="cursor: pointer;">
# <a href="/politica/esteban-bullrich-cuestiono-interna-juntos-cambio-llevamos-meses-cascoteandonos-rancho-_0_opIgF9sv95.html" onclick="metricsView('bloques_home','bloque_ultimo_momento|opIgF9sv95', true);">
# <article class="flex-change">
# <h2>Esteban Bullrich cuestionó la interna de Juntos por el Cambio: "Llevamos meses cascoteándonos el rancho"</h2>
# <span>04:16</span>
# </article>
# </a>
# </li>
# <li aria-label="/deportes/nba-facundo-campazzo-pudo-debutar-dallas-leandro-bolmaro-fugaz-estreno-utah_0_1gXdb6AxHx.html" style="cursor: pointer;">
# <a href="/deportes/nba-facundo-campazzo-pudo-debutar-dallas-leandro-bolmaro-fugaz-estreno-utah_0_1gXdb6AxHx.html" onclick="metricsView('bloques_home','bloque_ultimo_momento|1gXdb6AxHx', true);">
# <article class="flex-change">
# <h2>NBA: Facundo Campazzo no pudo debutar en Dallas y Leandro Bolmaro tuvo un fugaz estreno en Utah</h2>
# <span>02:55</span>
# </article>
# </a>
# </li>
# <li aria-label="/politica/juan-ignacio-mendiguren-martin-tetaz-tenso-cruce-television-podes-animal-resistis-reglas-_0_Dox3z22RVW.html" style="cursor: pointer;">
# <a href="/politica/juan-ignacio-mendiguren-martin-tetaz-tenso-cruce-television-podes-animal-resistis-reglas-_0_Dox3z22RVW.html" onclick="metricsView('bloques_home','bloque_ultimo_momento|Dox3z22RVW', true);">
# <article class="flex-change">
# <h2>Juan Ignacio de Mendiguren y Martín Tetaz, en un tenso cruce en televisión: "No podés ser tan animal" y "No resistís las reglas"</h2>
# <span>02:07</span>
# </article>
# </a>
# </li>
# <li aria-label="/politica/carlos-melconian-admitio-quiere-ministro-mauricio-macri-rodriguez-larreta-pongan-_0_w38PYAdZOS.html" style="cursor: pointer;">
# <a href="/politica/carlos-melconian-admitio-quiere-ministro-mauricio-macri-rodriguez-larreta-pongan-_0_w38PYAdZOS.html" onclick="metricsView('bloques_home','bloque_ultimo_momento|w38PYAdZOS', true);">
# <article class="flex-change">
# <h2>Carlos Melconian admitió que quiere ser ministro de Mauricio Macri o Rodríguez Larreta: "Donde me pongan, yo estoy"</h2>
# <span>01:54</span>
# </article>
# </a>
# </li>
# <li aria-label="/fama/santiago-moro-rechazo-gran-hermano-deba-rectificarse-gobierno-digan-participantes-corre-cuenta-_0_4iUAgOvaG0.html" style="cursor: pointer;">
# <a href="/fama/santiago-moro-rechazo-gran-hermano-deba-rectificarse-gobierno-digan-participantes-corre-cuenta-_0_4iUAgOvaG0.html" onclick="metricsView('bloques_home','bloque_ultimo_momento|4iUAgOvaG0', true);">
# <article class="flex-change">
# <h2>Santiago del Moro rechazó que Gran Hermano deba rectificarse ante el Gobierno: "Lo que digan los participantes corre por su cuenta"</h2>
# <span>00:13</span>
# </article>
# </a>
# </li>
# <li aria-label="/politica/-dejen-hacer-papelones-duro-cruce-diego-santilli-maria-eugenia-vidal-gabriela-cerruti-acusacion-gran-hermano_0_Ms9pa8f7Rs.html" style="cursor: pointer;">
# <a href="/politica/-dejen-hacer-papelones-duro-cruce-diego-santilli-maria-eugenia-vidal-gabriela-cerruti-acusacion-gran-hermano_0_Ms9pa8f7Rs.html" onclick="metricsView('bloques_home','bloque_ultimo_momento|Ms9pa8f7Rs', true);">
# <article class="flex-change">
# <h2>"Dejen de hacer papelones": duro cruce entre Diego Santilli, María Eugenia Vidal y Gabriela Cerruti por la acusación contra Gran Hermano</h2>
# <span>19/10/22</span>
# </article>
# </a>
# </li>
# </ul>
# 1
#  <ul class="box-items">
# <li aria-label="/politica/esteban-bullrich-cuestiono-interna-juntos-cambio-llevamos-meses-cascoteandonos-rancho-_0_opIgF9sv95.html" style="cursor: pointer;">
# <a href="/politica/esteban-bullrich-cuestiono-interna-juntos-cambio-llevamos-meses-cascoteandonos-rancho-_0_opIgF9sv95.html" onclick="metricsView('bloques_home','bloque_ultimo_momento|opIgF9sv95', true);">
# <article class="flex-change">
# <h2>Esteban Bullrich cuestionó la interna de Juntos por el Cambio: "Llevamos meses cascoteándonos el rancho"</h2>
# <span>04:16</span>
# </article>
# </a>
# </li>
# <li aria-label="/deportes/nba-facundo-campazzo-pudo-debutar-dallas-leandro-bolmaro-fugaz-estreno-utah_0_1gXdb6AxHx.html" style="cursor: pointer;">
# <a href="/deportes/nba-facundo-campazzo-pudo-debutar-dallas-leandro-bolmaro-fugaz-estreno-utah_0_1gXdb6AxHx.html" onclick="metricsView('bloques_home','bloque_ultimo_momento|1gXdb6AxHx', true);">
# <article class="flex-change">
# <h2>NBA: Facundo Campazzo no pudo debutar en Dallas y Leandro Bolmaro tuvo un fugaz estreno en Utah</h2>
# <span>02:55</span>
# </article>
# </a>
# </li>
# <li aria-label="/politica/juan-ignacio-mendiguren-martin-tetaz-tenso-cruce-television-podes-animal-resistis-reglas-_0_Dox3z22RVW.html" style="cursor: pointer;">
# <a href="/politica/juan-ignacio-mendiguren-martin-tetaz-tenso-cruce-television-podes-animal-resistis-reglas-_0_Dox3z22RVW.html" onclick="metricsView('bloques_home','bloque_ultimo_momento|Dox3z22RVW', true);">
# <article class="flex-change">
# <h2>Juan Ignacio de Mendiguren y Martín Tetaz, en un tenso cruce en televisión: "No podés ser tan animal" y "No resistís las reglas"</h2>
# <span>02:07</span>
# </article>
# </a>
# </li>
# <li aria-label="/politica/carlos-melconian-admitio-quiere-ministro-mauricio-macri-rodriguez-larreta-pongan-_0_w38PYAdZOS.html" style="cursor: pointer;">
# <a href="/politica/carlos-melconian-admitio-quiere-ministro-mauricio-macri-rodriguez-larreta-pongan-_0_w38PYAdZOS.html" onclick="metricsView('bloques_home','bloque_ultimo_momento|w38PYAdZOS', true);">
# <article class="flex-change">
# <h2>Carlos Melconian admitió que quiere ser ministro de Mauricio Macri o Rodríguez Larreta: "Donde me pongan, yo estoy"</h2>
# <span>01:54</span>
# </article>
# </a>
# </li>
# <li aria-label="/fama/santiago-moro-rechazo-gran-hermano-deba-rectificarse-gobierno-digan-participantes-corre-cuenta-_0_4iUAgOvaG0.html" style="cursor: pointer;">
# <a href="/fama/santiago-moro-rechazo-gran-hermano-deba-rectificarse-gobierno-digan-participantes-corre-cuenta-_0_4iUAgOvaG0.html" onclick="metricsView('bloques_home','bloque_ultimo_momento|4iUAgOvaG0', true);">
# <article class="flex-change">
# <h2>Santiago del Moro rechazó que Gran Hermano deba rectificarse ante el Gobierno: "Lo que digan los participantes corre por su cuenta"</h2>
# <span>00:13</span>
# </article>
# </a>
# </li>
# <li aria-label="/politica/-dejen-hacer-papelones-duro-cruce-diego-santilli-maria-eugenia-vidal-gabriela-cerruti-acusacion-gran-hermano_0_Ms9pa8f7Rs.html" style="cursor: pointer;">
# <a href="/politica/-dejen-hacer-papelones-duro-cruce-diego-santilli-maria-eugenia-vidal-gabriela-cerruti-acusacion-gran-hermano_0_Ms9pa8f7Rs.html" onclick="metricsView('bloques_home','bloque_ultimo_momento|Ms9pa8f7Rs', true);">
# <article class="flex-change">
# <h2>"Dejen de hacer papelones": duro cruce entre Diego Santilli, María Eugenia Vidal y Gabriela Cerruti por la acusación contra Gran Hermano</h2>
# <span>19/10/22</span>
# </article>
# </a>
# </li>
# </ul>
# 2
#  <ul class="box-items">
# <li aria-label="/politica/esteban-bullrich-cuestiono-interna-juntos-cambio-llevamos-meses-cascoteandonos-rancho-_0_opIgF9sv95.html" style="cursor: pointer;">
# <a href="/politica/esteban-bullrich-cuestiono-interna-juntos-cambio-llevamos-meses-cascoteandonos-rancho-_0_opIgF9sv95.html" onclick="metricsView('bloques_home','bloque_ultimo_momento|opIgF9sv95', true);">
# <article class="flex-change">
# <h2>Esteban Bullrich cuestionó la interna de Juntos por el Cambio: "Llevamos meses cascoteándonos el rancho"</h2>
# <span>04:16</span>
# </article>
# </a>
# </li>
# <li aria-label="/deportes/nba-facundo-campazzo-pudo-debutar-dallas-leandro-bolmaro-fugaz-estreno-utah_0_1gXdb6AxHx.html" style="cursor: pointer;">
# <a href="/deportes/nba-facundo-campazzo-pudo-debutar-dallas-leandro-bolmaro-fugaz-estreno-utah_0_1gXdb6AxHx.html" onclick="metricsView('bloques_home','bloque_ultimo_momento|1gXdb6AxHx', true);">
# <article class="flex-change">
# <h2>NBA: Facundo Campazzo no pudo debutar en Dallas y Leandro Bolmaro tuvo un fugaz estreno en Utah</h2>
# <span>02:55</span>
# </article>
# </a>
# </li>
# <li aria-label="/politica/juan-ignacio-mendiguren-martin-tetaz-tenso-cruce-television-podes-animal-resistis-reglas-_0_Dox3z22RVW.html" style="cursor: pointer;">
# <a href="/politica/juan-ignacio-mendiguren-martin-tetaz-tenso-cruce-television-podes-animal-resistis-reglas-_0_Dox3z22RVW.html" onclick="metricsView('bloques_home','bloque_ultimo_momento|Dox3z22RVW', true);">
# <article class="flex-change">
# <h2>Juan Ignacio de Mendiguren y Martín Tetaz, en un tenso cruce en televisión: "No podés ser tan animal" y "No resistís las reglas"</h2>
# <span>02:07</span>
# </article>
# </a>
# </li>
# <li aria-label="/politica/carlos-melconian-admitio-quiere-ministro-mauricio-macri-rodriguez-larreta-pongan-_0_w38PYAdZOS.html" style="cursor: pointer;">
# <a href="/politica/carlos-melconian-admitio-quiere-ministro-mauricio-macri-rodriguez-larreta-pongan-_0_w38PYAdZOS.html" onclick="metricsView('bloques_home','bloque_ultimo_momento|w38PYAdZOS', true);">
# <article class="flex-change">
# <h2>Carlos Melconian admitió que quiere ser ministro de Mauricio Macri o Rodríguez Larreta: "Donde me pongan, yo estoy"</h2>
# <span>01:54</span>
# </article>
# </a>
# </li>
# <li aria-label="/fama/santiago-moro-rechazo-gran-hermano-deba-rectificarse-gobierno-digan-participantes-corre-cuenta-_0_4iUAgOvaG0.html" style="cursor: pointer;">
# <a href="/fama/santiago-moro-rechazo-gran-hermano-deba-rectificarse-gobierno-digan-participantes-corre-cuenta-_0_4iUAgOvaG0.html" onclick="metricsView('bloques_home','bloque_ultimo_momento|4iUAgOvaG0', true);">
# <article class="flex-change">
# <h2>Santiago del Moro rechazó que Gran Hermano deba rectificarse ante el Gobierno: "Lo que digan los participantes corre por su cuenta"</h2>
# <span>00:13</span>
# </article>
# </a>
# </li>
# <li aria-label="/politica/-dejen-hacer-papelones-duro-cruce-diego-santilli-maria-eugenia-vidal-gabriela-cerruti-acusacion-gran-hermano_0_Ms9pa8f7Rs.html" style="cursor: pointer;">
# <a href="/politica/-dejen-hacer-papelones-duro-cruce-diego-santilli-maria-eugenia-vidal-gabriela-cerruti-acusacion-gran-hermano_0_Ms9pa8f7Rs.html" onclick="metricsView('bloques_home','bloque_ultimo_momento|Ms9pa8f7Rs', true);">
# <article class="flex-change">
# <h2>"Dejen de hacer papelones": duro cruce entre Diego Santilli, María Eugenia Vidal y Gabriela Cerruti por la acusación contra Gran Hermano</h2>
# <span>19/10/22</span>
# </article>
# </a>
# </li>
# </ul>
# 3
#  <ul class="box-items">
# <li aria-label="/politica/esteban-bullrich-cuestiono-interna-juntos-cambio-llevamos-meses-cascoteandonos-rancho-_0_opIgF9sv95.html" style="cursor: pointer;">
# <a href="/politica/esteban-bullrich-cuestiono-interna-juntos-cambio-llevamos-meses-cascoteandonos-rancho-_0_opIgF9sv95.html" onclick="metricsView('bloques_home','bloque_ultimo_momento|opIgF9sv95', true);">
# <article class="flex-change">
# <h2>Esteban Bullrich cuestionó la interna de Juntos por el Cambio: "Llevamos meses cascoteándonos el rancho"</h2>
# <span>04:16</span>
# </article>
# </a>
# </li>
# <li aria-label="/deportes/nba-facundo-campazzo-pudo-debutar-dallas-leandro-bolmaro-fugaz-estreno-utah_0_1gXdb6AxHx.html" style="cursor: pointer;">
# <a href="/deportes/nba-facundo-campazzo-pudo-debutar-dallas-leandro-bolmaro-fugaz-estreno-utah_0_1gXdb6AxHx.html" onclick="metricsView('bloques_home','bloque_ultimo_momento|1gXdb6AxHx', true);">
# <article class="flex-change">
# <h2>NBA: Facundo Campazzo no pudo debutar en Dallas y Leandro Bolmaro tuvo un fugaz estreno en Utah</h2>
# <span>02:55</span>
# </article>
# </a>
# </li>
# <li aria-label="/politica/juan-ignacio-mendiguren-martin-tetaz-tenso-cruce-television-podes-animal-resistis-reglas-_0_Dox3z22RVW.html" style="cursor: pointer;">
# <a href="/politica/juan-ignacio-mendiguren-martin-tetaz-tenso-cruce-television-podes-animal-resistis-reglas-_0_Dox3z22RVW.html" onclick="metricsView('bloques_home','bloque_ultimo_momento|Dox3z22RVW', true);">
# <article class="flex-change">
# <h2>Juan Ignacio de Mendiguren y Martín Tetaz, en un tenso cruce en televisión: "No podés ser tan animal" y "No resistís las reglas"</h2>
# <span>02:07</span>
# </article>
# </a>
# </li>
# <li aria-label="/politica/carlos-melconian-admitio-quiere-ministro-mauricio-macri-rodriguez-larreta-pongan-_0_w38PYAdZOS.html" style="cursor: pointer;">
# <a href="/politica/carlos-melconian-admitio-quiere-ministro-mauricio-macri-rodriguez-larreta-pongan-_0_w38PYAdZOS.html" onclick="metricsView('bloques_home','bloque_ultimo_momento|w38PYAdZOS', true);">
# <article class="flex-change">
# <h2>Carlos Melconian admitió que quiere ser ministro de Mauricio Macri o Rodríguez Larreta: "Donde me pongan, yo estoy"</h2>
# <span>01:54</span>
# </article>
# </a>
# </li>
# <li aria-label="/fama/santiago-moro-rechazo-gran-hermano-deba-rectificarse-gobierno-digan-participantes-corre-cuenta-_0_4iUAgOvaG0.html" style="cursor: pointer;">
# <a href="/fama/santiago-moro-rechazo-gran-hermano-deba-rectificarse-gobierno-digan-participantes-corre-cuenta-_0_4iUAgOvaG0.html" onclick="metricsView('bloques_home','bloque_ultimo_momento|4iUAgOvaG0', true);">
# <article class="flex-change">
# <h2>Santiago del Moro rechazó que Gran Hermano deba rectificarse ante el Gobierno: "Lo que digan los participantes corre por su cuenta"</h2>
# <span>00:13</span>
# </article>
# </a>
# </li>
# <li aria-label="/politica/-dejen-hacer-papelones-duro-cruce-diego-santilli-maria-eugenia-vidal-gabriela-cerruti-acusacion-gran-hermano_0_Ms9pa8f7Rs.html" style="cursor: pointer;">
# <a href="/politica/-dejen-hacer-papelones-duro-cruce-diego-santilli-maria-eugenia-vidal-gabriela-cerruti-acusacion-gran-hermano_0_Ms9pa8f7Rs.html" onclick="metricsView('bloques_home','bloque_ultimo_momento|Ms9pa8f7Rs', true);">
# <article class="flex-change">
# <h2>"Dejen de hacer papelones": duro cruce entre Diego Santilli, María Eugenia Vidal y Gabriela Cerruti por la acusación contra Gran Hermano</h2>
# <span>19/10/22</span>
# </article>
# </a>
# </li>
# </ul>
# 4
#  <ul class="box-items">
# <li aria-label="/politica/esteban-bullrich-cuestiono-interna-juntos-cambio-llevamos-meses-cascoteandonos-rancho-_0_opIgF9sv95.html" style="cursor: pointer;">
# <a href="/politica/esteban-bullrich-cuestiono-interna-juntos-cambio-llevamos-meses-cascoteandonos-rancho-_0_opIgF9sv95.html" onclick="metricsView('bloques_home','bloque_ultimo_momento|opIgF9sv95', true);">
# <article class="flex-change">
# <h2>Esteban Bullrich cuestionó la interna de Juntos por el Cambio: "Llevamos meses cascoteándonos el rancho"</h2>
# <span>04:16</span>
# </article>
# </a>
# </li>
# <li aria-label="/deportes/nba-facundo-campazzo-pudo-debutar-dallas-leandro-bolmaro-fugaz-estreno-utah_0_1gXdb6AxHx.html" style="cursor: pointer;">
# <a href="/deportes/nba-facundo-campazzo-pudo-debutar-dallas-leandro-bolmaro-fugaz-estreno-utah_0_1gXdb6AxHx.html" onclick="metricsView('bloques_home','bloque_ultimo_momento|1gXdb6AxHx', true);">
# <article class="flex-change">
# <h2>NBA: Facundo Campazzo no pudo debutar en Dallas y Leandro Bolmaro tuvo un fugaz estreno en Utah</h2>
# <span>02:55</span>
# </article>
# </a>
# </li>
# <li aria-label="/politica/juan-ignacio-mendiguren-martin-tetaz-tenso-cruce-television-podes-animal-resistis-reglas-_0_Dox3z22RVW.html" style="cursor: pointer;">
# <a href="/politica/juan-ignacio-mendiguren-martin-tetaz-tenso-cruce-television-podes-animal-resistis-reglas-_0_Dox3z22RVW.html" onclick="metricsView('bloques_home','bloque_ultimo_momento|Dox3z22RVW', true);">
# <article class="flex-change">
# <h2>Juan Ignacio de Mendiguren y Martín Tetaz, en un tenso cruce en televisión: "No podés ser tan animal" y "No resistís las reglas"</h2>
# <span>02:07</span>
# </article>
# </a>
# </li>
# <li aria-label="/politica/carlos-melconian-admitio-quiere-ministro-mauricio-macri-rodriguez-larreta-pongan-_0_w38PYAdZOS.html" style="cursor: pointer;">
# <a href="/politica/carlos-melconian-admitio-quiere-ministro-mauricio-macri-rodriguez-larreta-pongan-_0_w38PYAdZOS.html" onclick="metricsView('bloques_home','bloque_ultimo_momento|w38PYAdZOS', true);">
# <article class="flex-change">
# <h2>Carlos Melconian admitió que quiere ser ministro de Mauricio Macri o Rodríguez Larreta: "Donde me pongan, yo estoy"</h2>
# <span>01:54</span>
# </article>
# </a>
# </li>
# <li aria-label="/fama/santiago-moro-rechazo-gran-hermano-deba-rectificarse-gobierno-digan-participantes-corre-cuenta-_0_4iUAgOvaG0.html" style="cursor: pointer;">
# <a href="/fama/santiago-moro-rechazo-gran-hermano-deba-rectificarse-gobierno-digan-participantes-corre-cuenta-_0_4iUAgOvaG0.html" onclick="metricsView('bloques_home','bloque_ultimo_momento|4iUAgOvaG0', true);">
# <article class="flex-change">
# <h2>Santiago del Moro rechazó que Gran Hermano deba rectificarse ante el Gobierno: "Lo que digan los participantes corre por su cuenta"</h2>
# <span>00:13</span>
# </article>
# </a>
# </li>
# <li aria-label="/politica/-dejen-hacer-papelones-duro-cruce-diego-santilli-maria-eugenia-vidal-gabriela-cerruti-acusacion-gran-hermano_0_Ms9pa8f7Rs.html" style="cursor: pointer;">
# <a href="/politica/-dejen-hacer-papelones-duro-cruce-diego-santilli-maria-eugenia-vidal-gabriela-cerruti-acusacion-gran-hermano_0_Ms9pa8f7Rs.html" onclick="metricsView('bloques_home','bloque_ultimo_momento|Ms9pa8f7Rs', true);">
# <article class="flex-change">
# <h2>"Dejen de hacer papelones": duro cruce entre Diego Santilli, María Eugenia Vidal y Gabriela Cerruti por la acusación contra Gran Hermano</h2>
# <span>19/10/22</span>
# </article>
# </a>
# </li>
# </ul>
# 5
#  <ul class="box-items">
# <li aria-label="/politica/esteban-bullrich-cuestiono-interna-juntos-cambio-llevamos-meses-cascoteandonos-rancho-_0_opIgF9sv95.html" style="cursor: pointer;">
# <a href="/politica/esteban-bullrich-cuestiono-interna-juntos-cambio-llevamos-meses-cascoteandonos-rancho-_0_opIgF9sv95.html" onclick="metricsView('bloques_home','bloque_ultimo_momento|opIgF9sv95', true);">
# <article class="flex-change">
# <h2>Esteban Bullrich cuestionó la interna de Juntos por el Cambio: "Llevamos meses cascoteándonos el rancho"</h2>
# <span>04:16</span>
# </article>
# </a>
# </li>
# <li aria-label="/deportes/nba-facundo-campazzo-pudo-debutar-dallas-leandro-bolmaro-fugaz-estreno-utah_0_1gXdb6AxHx.html" style="cursor: pointer;">
# <a href="/deportes/nba-facundo-campazzo-pudo-debutar-dallas-leandro-bolmaro-fugaz-estreno-utah_0_1gXdb6AxHx.html" onclick="metricsView('bloques_home','bloque_ultimo_momento|1gXdb6AxHx', true);">
# <article class="flex-change">
# <h2>NBA: Facundo Campazzo no pudo debutar en Dallas y Leandro Bolmaro tuvo un fugaz estreno en Utah</h2>
# <span>02:55</span>
# </article>
# </a>
# </li>
# <li aria-label="/politica/juan-ignacio-mendiguren-martin-tetaz-tenso-cruce-television-podes-animal-resistis-reglas-_0_Dox3z22RVW.html" style="cursor: pointer;">
# <a href="/politica/juan-ignacio-mendiguren-martin-tetaz-tenso-cruce-television-podes-animal-resistis-reglas-_0_Dox3z22RVW.html" onclick="metricsView('bloques_home','bloque_ultimo_momento|Dox3z22RVW', true);">
# <article class="flex-change">
# <h2>Juan Ignacio de Mendiguren y Martín Tetaz, en un tenso cruce en televisión: "No podés ser tan animal" y "No resistís las reglas"</h2>
# <span>02:07</span>
# </article>
# </a>
# </li>
# <li aria-label="/politica/carlos-melconian-admitio-quiere-ministro-mauricio-macri-rodriguez-larreta-pongan-_0_w38PYAdZOS.html" style="cursor: pointer;">
# <a href="/politica/carlos-melconian-admitio-quiere-ministro-mauricio-macri-rodriguez-larreta-pongan-_0_w38PYAdZOS.html" onclick="metricsView('bloques_home','bloque_ultimo_momento|w38PYAdZOS', true);">
# <article class="flex-change">
# <h2>Carlos Melconian admitió que quiere ser ministro de Mauricio Macri o Rodríguez Larreta: "Donde me pongan, yo estoy"</h2>
# <span>01:54</span>
# </article>
# </a>
# </li>
# <li aria-label="/fama/santiago-moro-rechazo-gran-hermano-deba-rectificarse-gobierno-digan-participantes-corre-cuenta-_0_4iUAgOvaG0.html" style="cursor: pointer;">
# <a href="/fama/santiago-moro-rechazo-gran-hermano-deba-rectificarse-gobierno-digan-participantes-corre-cuenta-_0_4iUAgOvaG0.html" onclick="metricsView('bloques_home','bloque_ultimo_momento|4iUAgOvaG0', true);">
# <article class="flex-change">
# <h2>Santiago del Moro rechazó que Gran Hermano deba rectificarse ante el Gobierno: "Lo que digan los participantes corre por su cuenta"</h2>
# <span>00:13</span>
# </article>
# </a>
# </li>
# <li aria-label="/politica/-dejen-hacer-papelones-duro-cruce-diego-santilli-maria-eugenia-vidal-gabriela-cerruti-acusacion-gran-hermano_0_Ms9pa8f7Rs.html" style="cursor: pointer;">
# <a href="/politica/-dejen-hacer-papelones-duro-cruce-diego-santilli-maria-eugenia-vidal-gabriela-cerruti-acusacion-gran-hermano_0_Ms9pa8f7Rs.html" onclick="metricsView('bloques_home','bloque_ultimo_momento|Ms9pa8f7Rs', true);">
# <article class="flex-change">
# <h2>"Dejen de hacer papelones": duro cruce entre Diego Santilli, María Eugenia Vidal y Gabriela Cerruti por la acusación contra Gran Hermano</h2>
# <span>19/10/22</span>
# </article>
# </a>
# </li>
# </ul>
# 6
#  <section class="container no-p listado" data-classes="container listado " data-name="cont4B" data-type="container">
# <div class="count-first bb-container bb-moduleId_4B_mod_2021101690248929" data-classes="" data-count="16">
# <div class="border col-lg-6 col-md-8 col-sm-12 col-xs-12 no-p size4x2 special" data-classes="border col-lg-6 col-md-8 col-sm-12 col-xs-12 no-p size4x2  special" data-name="container4x2" id="fourxtwo_mod_2021101690248929">
# <div class="m-box child h300 col-sm-6 col-xs-12 pl-pr" data-classes="m-box child h300 col-sm-6 col-xs-12 pl-pr " data-name="content" data-size-h="1" data-size-w="1">
# <article class="content-nota onexone_foto list-format flex-change">
# <div class="mt">
# <div class="flex-change">
# <h2>El encargado de la Base Marambio fue atacado con una maza mientras dormía </h2>
# <p class="volanta">Brutal pelea en la Antártida</p>
# </div>
# <div class="data-txt">
# <p class="section">Sociedad</p>
# </div>
# </div>
# <div class="wrap-figure">
# <div class="ico-tx-news">
# <div class="ico">
# <div class="mdia media-aud onlyIcon"></div>
# </div>
# </div>
# <picture id="imgmod_202290104358572">
# <source media="(min-width: 720px)" srcset="//www.clarin.com/img/2022/10/19/vWNhX2AAc_600x290__1.jpg"/>
# <img alt="El encargado de la Base Marambio fue atacado con una maza mientras dormía " class="img-responsive intelResolution" height="100" loading="lazy" src="//www.clarin.com/img/2022/10/19/vWNhX2AAc_600x290__1.jpg" width="100"/>
# </picture>
# </div>
# <a aria-label="/politica/brutal-pelea-antartida-encargado-base-marambio-atacado-atacado-subalterno-dormia_0_fnfGyfBqIM.html" class="link_article" href="/politica/brutal-pelea-antartida-encargado-base-marambio-atacado-atacado-subalterno-dormia_0_fnfGyfBqIM.html" onclick="metricsView('bloques_home','contenedor_2_por_4|fnfGyfBqIM');" target="_self"></a>
# </article>
# </div>
# <div class="m-box child h300 col-sm-6 col-xs-12 pl-pr" data-classes="m-box child h300 col-sm-6 col-xs-12 pl-pr " data-name="content" data-size-h="1" data-size-w="1">
# <article class="content-nota onexone_foto list-format flex-change">
# <div class="mt">
# <div class="flex-change">
# <h2>Ataques en la cama de la Argentina precaria</h2>
# <p class="volanta">Del editor</p>
# </div>
# <div class="data-txt">
# <p class="author">Héctor Gambini</p>
# </div>
# </div>
# <div class="wrap-figure">
# <picture id="imgmod_202293110029786">
# <source media="(min-width: 720px)" srcset="//www.clarin.com/img/2022/10/19/WXKGGD_w7_600x290__2.jpg#1666224147837"/>
# <img alt="Ataques en la cama de la Argentina precaria" class="img-responsive intelResolution" height="100" loading="lazy" src="//www.clarin.com/img/2022/10/19/WXKGGD_w7_600x290__2.jpg#1666224147837" width="100"/>
# </picture>
# </div>
# <a aria-label="/opinion/ataques-cama-argentina-precaria_0_GSOAs81gpG.html" class="link_article" href="/opinion/ataques-cama-argentina-precaria_0_GSOAs81gpG.html" onclick="metricsView('bloques_home','contenedor_2_por_4|GSOAs81gpG');" target="_self"></a>
# </article>
# </div>
# <div class="m-box child h300 col-sm-6 col-xs-12 pl-pr" data-classes="m-box child h300 col-sm-6 col-xs-12 pl-pr" data-name="content" data-size-h="1" data-size-w="1">
# <article class="onexone_foto_grey content-nota list-format">
# <div class="mt">
# <div class="flex-change">
# <h2>La candidata tapada de Alberto Fernández y un dirigente social a los escobazos</h2>
# <p class="volanta">Por los pasillos</p>
# </div>
# <div class="data-txt">
# <span class="paywall-ico"></span>
# <p class="author">Pablo de León</p>
# </div>
# </div>
# <div class="wrap-figure">
# <picture id="imgmod_202296999867067">
# <source media="(min-width: 720px)" srcset="//www.clarin.com/img/2022/10/19/kAa1pu7Fu_290x140__1.jpg"/>
# <img alt="La candidata tapada de Alberto Fernández y un dirigente social a los escobazos" class="img-responsive intelResolution" height="100" loading="lazy" src="//www.clarin.com/img/2022/10/19/kAa1pu7Fu_290x140__1.jpg" width="100"/>
# </picture>
# </div>
# <a aria-label="/politica/pasillos-candidata-tapada-alberto-fernandez-tostadas-palta-chino-navarro-osobuco-rodrigo-loredo_0_MGzyQDXiAx.html" class="link_article" href="/politica/pasillos-candidata-tapada-alberto-fernandez-tostadas-palta-chino-navarro-osobuco-rodrigo-loredo_0_MGzyQDXiAx.html" onclick="metricsView('bloques_home','contenedor_2_por_4|MGzyQDXiAx');" target="_self"></a>
# </article>
# </div>
# <div class="m-box child h300 col-sm-6 col-xs-12 pl-pr" data-classes="m-box child h300 col-sm-6 col-xs-12 pl-pr " data-name="content" data-size-h="1" data-size-w="1">
# <article class="content-nota onexone_foto list-format flex-change">
# <div class="mt">
# <div class="flex-change">
# <h2>Terror en vuelo de Aerolíneas: por qué se da la turbulencia que afectó al avión</h2>
# <p class="volanta">Hubo 12 heridos</p>
# </div>
# <div class="data-txt">
# <p class="author">Irene Hartmann</p>
# </div>
# </div>
# <div class="wrap-figure">
# <picture id="imgmod_202292967994050">
# <source media="(min-width: 720px)" srcset="//www.clarin.com/img/2022/10/19/_unwTotKp_600x290__1.jpg"/>
# <img alt="Terror en vuelo de Aerolíneas: por qué se da la turbulencia que afectó al avión" class="img-responsive intelResolution" height="100" loading="lazy" src="//www.clarin.com/img/2022/10/19/_unwTotKp_600x290__1.jpg" width="100"/>
# </picture>
# </div>
# <a aria-label="/sociedad/alerta-aire-dan-turbulencias-afecto-avion-venia-madrid_0_NmSnJ1MOhm.html" class="link_article" href="/sociedad/alerta-aire-dan-turbulencias-afecto-avion-venia-madrid_0_NmSnJ1MOhm.html" onclick="metricsView('bloques_home','contenedor_2_por_4|NmSnJ1MOhm');" target="_self"></a>
# </article>
# </div>
# <div class="m-box child h300 col-xs-12 pl-pr" data-classes="m-box child h300  col-xs-12 pl-pr" data-name="content" data-size-h="1" data-size-w="2">
# <article class="visual bottom_degrade content-nota twoxone_visual t-bottom t-left list-format">
# <div class="mt title-bottom">
# <div class="max-h flex-change">
# <h2>15 segundos de pánico en un avión: “Nunca estuve tan cerca de la muerte”</h2>
# <p class="volanta">Una de las pasajeras heridas</p>
# </div>
# <div class="data-txt">
# <p class="section">Sociedad</p>
# </div>
# </div>
# <div class="wrap-img title-bottom">
# <picture id="imgmod_202291247257645">
# <source media="(min-width: 720px)" srcset="//www.clarin.com/img/2022/10/19/9NJOOc7vW_600x290__2.jpg#1666227871217"/>
# <img alt='15 segundos de pánico en un avión: "Nunca estuve tan cerca de la muerte"' class="img-responsive intelResolution" height="100" loading="lazy" src="//www.clarin.com/img/2022/10/19/9NJOOc7vW_600x600__1.jpg" width="100"/>
# </picture>
# <div class="bg_picture_degree"></div>
# </div>
# <div class="bg_picture_degree"></div>
# <a aria-label="/sociedad/pesadilla-avion-aerolineas-choque-cabeza-techo-parti-_0_sp9exvhfzP.html" class="link_article" href="/sociedad/pesadilla-avion-aerolineas-choque-cabeza-techo-parti-_0_sp9exvhfzP.html" onclick="metricsView('bloques_home','contenedor_2_por_4|sp9exvhfzP');" target="_self"></a>
# </article>
# </div>
# <div class="m-box adv child h300 col-lg-6 col-md-6 col-sm-6 col-xs-12 pl-pr" data-classes="m-box adv child h300 col-lg-6 col-md-6 col-sm-6 col-xs-12 pl-pr" data-name="advert" data-size-h="1" data-size-w="1">
# <div class="banner_center ad-slot box-adv" data-adtype="caja" id="div-gpt-ad-caja6">
#
# </div>
# </div>
# <div class="m-box child h150 col-lg-6 col-md-6 col-sm-6 col-xs-12 pl-pr" data-classes="m-box h150 col-lg-6 col-md-6 col-sm-6 col-xs-12 pl-pr" data-name="content" data-size-h="0.5" data-size-w="1">
# <article class="content-nota list-format onexone_doble">
# <div class="mt">
# <div class="flex-change">
# <h2>Sorpresivo pedido del abogado de la vice para el jefe de los copitos, que ya no soporta la cárcel</h2>
# <p class="volanta">Atentado a Cristina</p>
# </div>
# <div class="data-txt">
# <p class="author">Daniel Santoro</p>
# </div>
# </div>
# <div class="wrap-figure">
# <picture id="imgmod_202293474185646">
# <source media="(min-width: 720px)" srcset="//www.clarin.com/img/2022/09/14/inzTjzvRI_110x110__1.jpg"/>
# <img alt="Sorpresivo pedido del abogado de la vice para el jefe de los copitos" class="img-responsive intelResolution" height="100" loading="lazy" src="//www.clarin.com/img/2022/09/14/inzTjzvRI_600x290__3.jpg#1664628313814" width="100"/>
# </picture>
# </div>
# <a aria-label="/politica/atentado-cristina-kirchner-abogado-vice-pidio-morigerar-procesamiento-jefe-banda-copitos-_0_VllZBKRobZ.html" class="link_article" href="/politica/atentado-cristina-kirchner-abogado-vice-pidio-morigerar-procesamiento-jefe-banda-copitos-_0_VllZBKRobZ.html" onclick="metricsView('bloques_home','contenedor_2_por_4|VllZBKRobZ');" target="_self"></a>
# </article>
# </div>
# <div class="m-box child h150 col-lg-6 col-md-6 col-sm-6 col-xs-12 pl-pr" data-classes="m-box h150 col-lg-6 col-md-6 col-sm-6 col-xs-12 pl-pr" data-name="content" data-size-h="0.5" data-size-w="1">
# <article class="content-nota list-format onexone_doble">
# <div class="mt">
# <div class="flex-change">
# <h2>El incómodo momento de Alicia Kirchner cuando la increpó una funcionaria</h2>
# <p class="volanta">En Caleta Olivia</p>
# </div>
# <div class="data-txt">
# <p class="section">Política</p>
# </div>
# </div>
# <div class="wrap-figure">
# <picture id="imgmod_202293165859037">
# <source media="(min-width: 720px)" srcset="//www.clarin.com/img/2022/10/19/v-sVrFhH6_110x110__1.jpg"/>
# <img alt="El incómodo momento de Alicia Kirchner cuando la increpó una funcionaria" class="img-responsive intelResolution" height="100" loading="lazy" src="//www.clarin.com/img/2022/10/19/v-sVrFhH6_600x290__1.jpg" width="100"/>
# </picture>
# <div class="ico-tx-news xs">
# <span class="content-ico">
# <div class="ico">
# <div class="mdia media-vid onlyIcon"></div>
# </div>
# </span>
# </div>
# </div>
# <a aria-label="/politica/incomodo-momento-alicia-kirchner-caleta-olivia-increpada-funcionaria-municipal-arruinaste-acto-_0_CGs71qYLCW.html" class="link_article" href="/politica/incomodo-momento-alicia-kirchner-caleta-olivia-increpada-funcionaria-municipal-arruinaste-acto-_0_CGs71qYLCW.html" onclick="metricsView('bloques_home','contenedor_2_por_4|CGs71qYLCW');" target="_self"></a>
# </article>
# </div>
# </div>
# <div class="m-box adv h1200 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p size1x4" data-classes=" m-box adv h1200 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p size1x4" data-name="advert" data-size-h="4" data-size-w="1">
# <div class="box-adv">
# <div class="banner_center ad-slot ad-sticky" data-adtype="caja" id="div-gpt-ad-caja0">
#
# </div>
# </div>
# </div>
# <div class="h600 m-box last-moment m-box col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p" data-classes="h600 m-box last-moment m-box col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p" data-name="lastmoment" data-size-h="2" data-size-w="1">
# <div class="last-moment" id="lmvmod_202271582272926" xmlns="http://www.w3.org/1999/html">
# <a class="tag" href="https://www.clarin.com/ultimo-momento/" style="cursor: pointer;" target="_blank"></a>
# <ul class="box-items">
# <li aria-label="/politica/esteban-bullrich-cuestiono-interna-juntos-cambio-llevamos-meses-cascoteandonos-rancho-_0_opIgF9sv95.html" style="cursor: pointer;">
# <a href="/politica/esteban-bullrich-cuestiono-interna-juntos-cambio-llevamos-meses-cascoteandonos-rancho-_0_opIgF9sv95.html" onclick="metricsView('bloques_home','bloque_ultimo_momento|opIgF9sv95', true);">
# <article class="flex-change">
# <h2>Esteban Bullrich cuestionó la interna de Juntos por el Cambio: "Llevamos meses cascoteándonos el rancho"</h2>
# <span>04:16</span>
# </article>
# </a>
# </li>
# <li aria-label="/deportes/nba-facundo-campazzo-pudo-debutar-dallas-leandro-bolmaro-fugaz-estreno-utah_0_1gXdb6AxHx.html" style="cursor: pointer;">
# <a href="/deportes/nba-facundo-campazzo-pudo-debutar-dallas-leandro-bolmaro-fugaz-estreno-utah_0_1gXdb6AxHx.html" onclick="metricsView('bloques_home','bloque_ultimo_momento|1gXdb6AxHx', true);">
# <article class="flex-change">
# <h2>NBA: Facundo Campazzo no pudo debutar en Dallas y Leandro Bolmaro tuvo un fugaz estreno en Utah</h2>
# <span>02:55</span>
# </article>
# </a>
# </li>
# <li aria-label="/politica/juan-ignacio-mendiguren-martin-tetaz-tenso-cruce-television-podes-animal-resistis-reglas-_0_Dox3z22RVW.html" style="cursor: pointer;">
# <a href="/politica/juan-ignacio-mendiguren-martin-tetaz-tenso-cruce-television-podes-animal-resistis-reglas-_0_Dox3z22RVW.html" onclick="metricsView('bloques_home','bloque_ultimo_momento|Dox3z22RVW', true);">
# <article class="flex-change">
# <h2>Juan Ignacio de Mendiguren y Martín Tetaz, en un tenso cruce en televisión: "No podés ser tan animal" y "No resistís las reglas"</h2>
# <span>02:07</span>
# </article>
# </a>
# </li>
# <li aria-label="/politica/carlos-melconian-admitio-quiere-ministro-mauricio-macri-rodriguez-larreta-pongan-_0_w38PYAdZOS.html" style="cursor: pointer;">
# <a href="/politica/carlos-melconian-admitio-quiere-ministro-mauricio-macri-rodriguez-larreta-pongan-_0_w38PYAdZOS.html" onclick="metricsView('bloques_home','bloque_ultimo_momento|w38PYAdZOS', true);">
# <article class="flex-change">
# <h2>Carlos Melconian admitió que quiere ser ministro de Mauricio Macri o Rodríguez Larreta: "Donde me pongan, yo estoy"</h2>
# <span>01:54</span>
# </article>
# </a>
# </li>
# <li aria-label="/fama/santiago-moro-rechazo-gran-hermano-deba-rectificarse-gobierno-digan-participantes-corre-cuenta-_0_4iUAgOvaG0.html" style="cursor: pointer;">
# <a href="/fama/santiago-moro-rechazo-gran-hermano-deba-rectificarse-gobierno-digan-participantes-corre-cuenta-_0_4iUAgOvaG0.html" onclick="metricsView('bloques_home','bloque_ultimo_momento|4iUAgOvaG0', true);">
# <article class="flex-change">
# <h2>Santiago del Moro rechazó que Gran Hermano deba rectificarse ante el Gobierno: "Lo que digan los participantes corre por su cuenta"</h2>
# <span>00:13</span>
# </article>
# </a>
# </li>
# <li aria-label="/politica/-dejen-hacer-papelones-duro-cruce-diego-santilli-maria-eugenia-vidal-gabriela-cerruti-acusacion-gran-hermano_0_Ms9pa8f7Rs.html" style="cursor: pointer;">
# <a href="/politica/-dejen-hacer-papelones-duro-cruce-diego-santilli-maria-eugenia-vidal-gabriela-cerruti-acusacion-gran-hermano_0_Ms9pa8f7Rs.html" onclick="metricsView('bloques_home','bloque_ultimo_momento|Ms9pa8f7Rs', true);">
# <article class="flex-change">
# <h2>"Dejen de hacer papelones": duro cruce entre Diego Santilli, María Eugenia Vidal y Gabriela Cerruti por la acusación contra Gran Hermano</h2>
# <span>19/10/22</span>
# </article>
# </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="m-box child h300 border col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p" data-classes="m-box child h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p" data-name="content" data-size-h="1" data-size-w="1">
# <article class="onexone_foto_grey content-nota list-format">
# <div class="mt">
# <div class="flex-change">
# <h2>Cuáles son las cuentas que ahora pagan 60% de interés sólo por tener saldo</h2>
# <p class="volanta">Tasa anual</p>
# </div>
# <div class="data-txt">
# <span class="paywall-ico"></span>
# <p class="author">Martín Grosz</p>
# </div>
# </div>
# <div class="wrap-figure">
# <picture id="imgmod_202296313385591">
# <source media="(min-width: 720px)" srcset="//www.clarin.com/img/2022/08/23/PgiwWmAbt_600x290__1.jpg"/>
# <img alt="Cuáles son las cuentas que ahora pagan 60% de interés sólo por tener saldo" class="img-responsive intelResolution" height="100" loading="lazy" src="//www.clarin.com/img/2022/08/23/PgiwWmAbt_600x290__1.jpg" width="100"/>
# </picture>
# </div>
# <a aria-label="/servicios/cuentas-ahora-pagan-60-interes-solo-tener-saldo_0_StbX9U8Ge3.html" class="link_article" href="/servicios/cuentas-ahora-pagan-60-interes-solo-tener-saldo_0_StbX9U8Ge3.html" onclick="metricsView('bloques_home','contenedor_4_pisos_banner|StbX9U8Ge3');" target="_self"></a>
# </article>
# </div>
# <div class="m-box adv h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p" data-classes="m-box adv h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p" data-name="advert" data-size-h="1" data-size-w="1">
# <div class="banner_center ad-slot box-adv" id="div-gpt-ad-caja1">
#
# </div>
# </div>
# </div>
# </section>

# %%
# treewalk a given node and dump source structure under that node's tag:
def dumptree(n, prefix):
    # global articles
    # global sections   
    stack = []
    stack.extend(reversed([ch for ch in n.children if type(ch) == bs.element.Tag]))     # Warning! Generators tend to explode...
    print(prefix + n.name + ' // ', end = '')
    try:
        if n.name == 'h2' : print(n.attrs, '/', n.get_text().strip()[:1000])
        elif n.name == 'p' : print(n.attrs, '/', n.get_text().strip()[:100])
        elif n.name == 'span' : print(n.attrs, '/', n.get_text().strip()[:100])
        elif  n.name == 'a' : print(n.attrs['href'][:100], '/', ' '.join(n.get_text().strip().split('\n')))
        elif  n.name == 'div' : print(n.attrs['class'][:100])
        elif  n.name == 'section':
            print(n.name + '[' + str(sections.index(n)) + ']')
        elif  n.name == 'article':
            print(n.name + '[' + str(articles.index(n)) + ']')
        else:
            print(n.name)
    except KeyError:
        print("+++ ERROR WHILE TRYING TO ACCESS NONEXISTANT KEY!!!+++")
    while stack:
        dumptree(stack.pop(), '|   ' + prefix)
    return None


i = 0
print("<section>[%02d]" % i)
print("-------------")
dumptree(sections[i].parent, '')
# Out:
# <section>[00]
# -------------
# div // ['container', 'father', 'no-p']
# |   section // section[0]
# |   |   div // ['count-first', 'bb-container', 'one-floor', 'bb-moduleId_1B_mod_202294940664041']
# |   |   |   div // ['m-box', 'child', 'h300', 'col-lg-6', 'col-md-8', 'col-sm-12', 'col-xs-12', 'no-p', 'm2x1']
# |   |   |   |   article // article[0]
# |   |   |   |   |   div // ['mt']
# |   |   |   |   |   |   div // ['max-h', 'flex-change']
# |   |   |   |   |   |   |   h2 // {} / Ante la presión de la oposición, el kirchnerismo cede para sumar votos y aprobar el Presupuesto 2023
# |   |   |   |   |   |   |   p // {'class': ['volanta']} / La pelea en Diputados
# |   |   |   |   |   |   div // ['data-txt']
# |   |   |   |   |   |   |   p // {'class': ['author']} / Gustavo Berón
# |   |   |   |   |   |   p // {'class': ['summary']} / Tuvo que aceptar varias modificaciones al proyecto original enviado por Massa. Así, el oficialismo b
# |   |   |   |   |   a // /politica/oficialismo-cede-presion-oposicion-aprobar-presupuesto-2023_0_wVtJkpdq8V.html /
# |   |   |   |   ul // ul
# |   |   |   |   |   li // li
# |   |   |   |   |   |   article // article[1]
# |   |   |   |   |   |   |   a // /politica/cumbre-plata-medio-interna-kicillof-maximo-kirchner-intendentes-definen-estrategia-cara-20 / Política. Frente al derrumbe, Kicillof, Máximo y los intendentes intentan “blindar” el GBA Federico Mayol
# |   |   |   |   |   |   |   |   div // ['box-title-rel']
# |   |   |   |   |   |   |   |   |   span // {'class': ['section-rel']} / Política.
# |   |   |   |   |   |   |   |   |   h2 // {'class': ['title-rel']} / Frente al derrumbe, Kicillof, Máximo y los intendentes intentan “blindar” el GBA
# |   |   |   |   |   |   |   |   |   span // {'class': ['author-rel']} / Federico Mayol
# |   |   |   div // ['m-box', 'h300', 'child', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p', 'list-format']
# |   |   |   |   article // article[2]
# |   |   |   |   |   div // ['mt']
# |   |   |   |   |   |   div // ['flex-change']
# |   |   |   |   |   |   |   h2 // {} / Réplica del Gobierno a La Cámpora: dice que el acuerdo con el FMI está vigente
# |   |   |   |   |   |   |   p // {'class': ['volanta']} / Interna sin tregua
# |   |   |   |   |   |   div // ['data-txt']
# |   |   |   |   |   |   |   p // {'class': ['author']} / Federico Mayol
# |   |   |   |   |   div // ['wrap-figure']
# |   |   |   |   |   |   picture // picture
# |   |   |   |   |   |   |   source // source
# |   |   |   |   |   |   |   img // img
# |   |   |   |   |   a // /politica/gobierno-replica-campora-dice-acuerdo-fmi-vigente-cumpliran-metas_0_BJADy9KZ7O.html /
# |   |   |   div // ['m-box', 'child', 'h150', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p']
# |   |   |   |   article // article[3]
# |   |   |   |   |   div // ['mt']
# |   |   |   |   |   |   div // ['flex-change']
# |   |   |   |   |   |   |   h2 // {} / El Gobierno le pide una rectificación a Gran Hermano por la acusación contra el Presidente
# |   |   |   |   |   |   |   p // {'class': ['volanta']} / Reality y polémica
# |   |   |   |   |   |   div // ['data-txt']
# |   |   |   |   |   |   |   p // {'class': ['section']} / Política
# |   |   |   |   |   div // ['wrap-figure']
# |   |   |   |   |   |   picture // picture
# |   |   |   |   |   |   |   source // source
# |   |   |   |   |   |   |   img // img
# |   |   |   |   |   a // /politica/gobierno-pide-rectificacion-gran-hermano-dichos-participante-reality-alberto-fernandez_0_j /
# |   |   |   div // ['m-box', 'child', 'h150', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p']
# |   |   |   |   article // article[4]
# |   |   |   |   |   div // ['mt']
# |   |   |   |   |   |   div // ['flex-change']
# |   |   |   |   |   |   |   h2 // {} / Ironías de la oposición: “¿De verdad Alberto está preocupado por Gran Hermano?”
# |   |   |   |   |   |   |   p // {'class': ['volanta']} / Cruces con Cerruti
# |   |   |   |   |   |   div // ['data-txt']
# |   |   |   |   |   |   |   p // {'class': ['section']} / Política
# |   |   |   |   |   div // ['wrap-figure']
# |   |   |   |   |   |   picture // picture
# |   |   |   |   |   |   |   source // source
# |   |   |   |   |   |   |   img // img
# |   |   |   |   |   a // /politica/-dejen-hacer-papelones-duro-cruce-diego-santilli-maria-eugenia-vidal-gabriela-cerruti-acus /
# |   section // section[1]
# |   |   div // ['count-first', 'bb-container', 'bb-moduleId_4B_mod_2021101690248929']
# |   |   |   div // ['border', 'col-lg-6', 'col-md-8', 'col-sm-12', 'col-xs-12', 'no-p', 'size4x2', 'special']
# |   |   |   |   div // ['m-box', 'child', 'h300', 'col-sm-6', 'col-xs-12', 'pl-pr']
# |   |   |   |   |   article // article[5]
# |   |   |   |   |   |   div // ['mt']
# |   |   |   |   |   |   |   div // ['flex-change']
# |   |   |   |   |   |   |   |   h2 // {} / El encargado de la Base Marambio fue atacado con una maza mientras dormía
# |   |   |   |   |   |   |   |   p // {'class': ['volanta']} / Brutal pelea en la Antártida
# |   |   |   |   |   |   |   div // ['data-txt']
# |   |   |   |   |   |   |   |   p // {'class': ['section']} / Sociedad
# |   |   |   |   |   |   div // ['wrap-figure']
# |   |   |   |   |   |   |   div // ['ico-tx-news']
# |   |   |   |   |   |   |   |   div // ['ico']
# |   |   |   |   |   |   |   |   |   div // ['mdia', 'media-aud', 'onlyIcon']
# |   |   |   |   |   |   |   picture // picture
# |   |   |   |   |   |   |   |   source // source
# |   |   |   |   |   |   |   |   img // img
# |   |   |   |   |   |   a // /politica/brutal-pelea-antartida-encargado-base-marambio-atacado-atacado-subalterno-dormia_0_fnfGyfB /
# |   |   |   |   div // ['m-box', 'child', 'h300', 'col-sm-6', 'col-xs-12', 'pl-pr']
# |   |   |   |   |   article // article[6]
# |   |   |   |   |   |   div // ['mt']
# |   |   |   |   |   |   |   div // ['flex-change']
# |   |   |   |   |   |   |   |   h2 // {} / Ataques en la cama de la Argentina precaria
# |   |   |   |   |   |   |   |   p // {'class': ['volanta']} / Del editor
# |   |   |   |   |   |   |   div // ['data-txt']
# |   |   |   |   |   |   |   |   p // {'class': ['author']} / Héctor Gambini
# |   |   |   |   |   |   div // ['wrap-figure']
# |   |   |   |   |   |   |   picture // picture
# |   |   |   |   |   |   |   |   source // source
# |   |   |   |   |   |   |   |   img // img
# |   |   |   |   |   |   a // /opinion/ataques-cama-argentina-precaria_0_GSOAs81gpG.html /
# |   |   |   |   div // ['m-box', 'child', 'h300', 'col-sm-6', 'col-xs-12', 'pl-pr']
# |   |   |   |   |   article // article[7]
# |   |   |   |   |   |   div // ['mt']
# |   |   |   |   |   |   |   div // ['flex-change']
# |   |   |   |   |   |   |   |   h2 // {} / La candidata tapada de Alberto Fernández y un dirigente social a los escobazos
# |   |   |   |   |   |   |   |   p // {'class': ['volanta']} / Por los pasillos
# |   |   |   |   |   |   |   div // ['data-txt']
# |   |   |   |   |   |   |   |   span // {'class': ['paywall-ico']} /
# |   |   |   |   |   |   |   |   p // {'class': ['author']} / Pablo de León
# |   |   |   |   |   |   div // ['wrap-figure']
# |   |   |   |   |   |   |   picture // picture
# |   |   |   |   |   |   |   |   source // source
# |   |   |   |   |   |   |   |   img // img
# |   |   |   |   |   |   a // /politica/pasillos-candidata-tapada-alberto-fernandez-tostadas-palta-chino-navarro-osobuco-rodrigo-l /
# |   |   |   |   div // ['m-box', 'child', 'h300', 'col-sm-6', 'col-xs-12', 'pl-pr']
# |   |   |   |   |   article // article[8]
# |   |   |   |   |   |   div // ['mt']
# |   |   |   |   |   |   |   div // ['flex-change']
# |   |   |   |   |   |   |   |   h2 // {} / Terror en vuelo de Aerolíneas: por qué se da la turbulencia que afectó al avión
# |   |   |   |   |   |   |   |   p // {'class': ['volanta']} / Hubo 12 heridos
# |   |   |   |   |   |   |   div // ['data-txt']
# |   |   |   |   |   |   |   |   p // {'class': ['author']} / Irene Hartmann
# |   |   |   |   |   |   div // ['wrap-figure']
# |   |   |   |   |   |   |   picture // picture
# |   |   |   |   |   |   |   |   source // source
# |   |   |   |   |   |   |   |   img // img
# |   |   |   |   |   |   a // /sociedad/alerta-aire-dan-turbulencias-afecto-avion-venia-madrid_0_NmSnJ1MOhm.html /
# |   |   |   |   div // ['m-box', 'child', 'h300', 'col-xs-12', 'pl-pr']
# |   |   |   |   |   article // article[9]
# |   |   |   |   |   |   div // ['mt', 'title-bottom']
# |   |   |   |   |   |   |   div // ['max-h', 'flex-change']
# |   |   |   |   |   |   |   |   h2 // {} / 15 segundos de pánico en un avión: “Nunca estuve tan cerca de la muerte”
# |   |   |   |   |   |   |   |   p // {'class': ['volanta']} / Una de las pasajeras heridas
# |   |   |   |   |   |   |   div // ['data-txt']
# |   |   |   |   |   |   |   |   p // {'class': ['section']} / Sociedad
# |   |   |   |   |   |   div // ['wrap-img', 'title-bottom']
# |   |   |   |   |   |   |   picture // picture
# |   |   |   |   |   |   |   |   source // source
# |   |   |   |   |   |   |   |   img // img
# |   |   |   |   |   |   |   div // ['bg_picture_degree']
# |   |   |   |   |   |   div // ['bg_picture_degree']
# |   |   |   |   |   |   a // /sociedad/pesadilla-avion-aerolineas-choque-cabeza-techo-parti-_0_sp9exvhfzP.html /
# |   |   |   |   div // ['m-box', 'adv', 'child', 'h300', 'col-lg-6', 'col-md-6', 'col-sm-6', 'col-xs-12', 'pl-pr']
# |   |   |   |   |   div // ['banner_center', 'ad-slot', 'box-adv']
# |   |   |   |   div // ['m-box', 'child', 'h150', 'col-lg-6', 'col-md-6', 'col-sm-6', 'col-xs-12', 'pl-pr']
# |   |   |   |   |   article // article[10]
# |   |   |   |   |   |   div // ['mt']
# |   |   |   |   |   |   |   div // ['flex-change']
# |   |   |   |   |   |   |   |   h2 // {} / Sorpresivo pedido del abogado de la vice para el jefe de los copitos, que ya no soporta la cárcel
# |   |   |   |   |   |   |   |   p // {'class': ['volanta']} / Atentado a Cristina
# |   |   |   |   |   |   |   div // ['data-txt']
# |   |   |   |   |   |   |   |   p // {'class': ['author']} / Daniel Santoro
# |   |   |   |   |   |   div // ['wrap-figure']
# |   |   |   |   |   |   |   picture // picture
# |   |   |   |   |   |   |   |   source // source
# |   |   |   |   |   |   |   |   img // img
# |   |   |   |   |   |   a // /politica/atentado-cristina-kirchner-abogado-vice-pidio-morigerar-procesamiento-jefe-banda-copitos-_ /
# |   |   |   |   div // ['m-box', 'child', 'h150', 'col-lg-6', 'col-md-6', 'col-sm-6', 'col-xs-12', 'pl-pr']
# |   |   |   |   |   article // article[11]
# |   |   |   |   |   |   div // ['mt']
# |   |   |   |   |   |   |   div // ['flex-change']
# |   |   |   |   |   |   |   |   h2 // {} / El incómodo momento de Alicia Kirchner cuando la increpó una funcionaria
# |   |   |   |   |   |   |   |   p // {'class': ['volanta']} / En Caleta Olivia
# |   |   |   |   |   |   |   div // ['data-txt']
# |   |   |   |   |   |   |   |   p // {'class': ['section']} / Política
# |   |   |   |   |   |   div // ['wrap-figure']
# |   |   |   |   |   |   |   picture // picture
# |   |   |   |   |   |   |   |   source // source
# |   |   |   |   |   |   |   |   img // img
# |   |   |   |   |   |   |   div // ['ico-tx-news', 'xs']
# |   |   |   |   |   |   |   |   span // {'class': ['content-ico']} /
# |   |   |   |   |   |   |   |   |   div // ['ico']
# |   |   |   |   |   |   |   |   |   |   div // ['mdia', 'media-vid', 'onlyIcon']
# |   |   |   |   |   |   a // /politica/incomodo-momento-alicia-kirchner-caleta-olivia-increpada-funcionaria-municipal-arruinaste- /
# |   |   |   div // ['m-box', 'adv', 'h1200', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p', 'size1x4']
# |   |   |   |   div // ['box-adv']
# |   |   |   |   |   div // ['banner_center', 'ad-slot', 'ad-sticky']
# |   |   |   div // ['h600', 'm-box', 'last-moment', 'm-box', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p']
# |   |   |   |   div // ['last-moment']
# |   |   |   |   |   a // https://www.clarin.com/ultimo-momento/ /
# |   |   |   |   |   ul // ul
# |   |   |   |   |   |   li // li
# |   |   |   |   |   |   |   a // /politica/esteban-bullrich-cuestiono-interna-juntos-cambio-llevamos-meses-cascoteandonos-rancho-_0_o / Esteban Bullrich cuestionó la interna de Juntos por el Cambio: "Llevamos meses cascoteándonos el rancho" 04:16
# |   |   |   |   |   |   |   |   article // article[12]
# |   |   |   |   |   |   |   |   |   h2 // {} / Esteban Bullrich cuestionó la interna de Juntos por el Cambio: "Llevamos meses cascoteándonos el rancho"
# |   |   |   |   |   |   |   |   |   span // {} / 04:16
# |   |   |   |   |   |   li // li
# |   |   |   |   |   |   |   a // /deportes/nba-facundo-campazzo-pudo-debutar-dallas-leandro-bolmaro-fugaz-estreno-utah_0_1gXdb6AxHx.h / NBA: Facundo Campazzo no pudo debutar en Dallas y Leandro Bolmaro tuvo un fugaz estreno en Utah 02:55
# |   |   |   |   |   |   |   |   article // article[13]
# |   |   |   |   |   |   |   |   |   h2 // {} / NBA: Facundo Campazzo no pudo debutar en Dallas y Leandro Bolmaro tuvo un fugaz estreno en Utah
# |   |   |   |   |   |   |   |   |   span // {} / 02:55
# |   |   |   |   |   |   li // li
# |   |   |   |   |   |   |   a // /politica/juan-ignacio-mendiguren-martin-tetaz-tenso-cruce-television-podes-animal-resistis-reglas-_ / Juan Ignacio de Mendiguren y Martín Tetaz, en un tenso cruce en televisión: "No podés ser tan animal" y "No resistís las reglas" 02:07
# |   |   |   |   |   |   |   |   article // article[14]
# |   |   |   |   |   |   |   |   |   h2 // {} / Juan Ignacio de Mendiguren y Martín Tetaz, en un tenso cruce en televisión: "No podés ser tan animal" y "No resistís las reglas"
# |   |   |   |   |   |   |   |   |   span // {} / 02:07
# |   |   |   |   |   |   li // li
# |   |   |   |   |   |   |   a // /politica/carlos-melconian-admitio-quiere-ministro-mauricio-macri-rodriguez-larreta-pongan-_0_w38PYA / Carlos Melconian admitió que quiere ser ministro de Mauricio Macri o Rodríguez Larreta: "Donde me pongan, yo estoy" 01:54
# |   |   |   |   |   |   |   |   article // article[15]
# |   |   |   |   |   |   |   |   |   h2 // {} / Carlos Melconian admitió que quiere ser ministro de Mauricio Macri o Rodríguez Larreta: "Donde me pongan, yo estoy"
# |   |   |   |   |   |   |   |   |   span // {} / 01:54
# |   |   |   |   |   |   li // li
# |   |   |   |   |   |   |   a // /fama/santiago-moro-rechazo-gran-hermano-deba-rectificarse-gobierno-digan-participantes-corre-cuenta / Santiago del Moro rechazó que Gran Hermano deba rectificarse ante el Gobierno: "Lo que digan los participantes corre por su cuenta" 00:13
# |   |   |   |   |   |   |   |   article // article[16]
# |   |   |   |   |   |   |   |   |   h2 // {} / Santiago del Moro rechazó que Gran Hermano deba rectificarse ante el Gobierno: "Lo que digan los participantes corre por su cuenta"
# |   |   |   |   |   |   |   |   |   span // {} / 00:13
# |   |   |   |   |   |   li // li
# |   |   |   |   |   |   |   a // /politica/-dejen-hacer-papelones-duro-cruce-diego-santilli-maria-eugenia-vidal-gabriela-cerruti-acus / "Dejen de hacer papelones": duro cruce entre Diego Santilli, María Eugenia Vidal y Gabriela Cerruti por la acusación contra Gran Hermano 19/10/22
# |   |   |   |   |   |   |   |   article // article[17]
# |   |   |   |   |   |   |   |   |   h2 // {} / "Dejen de hacer papelones": duro cruce entre Diego Santilli, María Eugenia Vidal y Gabriela Cerruti por la acusación contra Gran Hermano
# |   |   |   |   |   |   |   |   |   span // {} / 19/10/22
# |   |   |   div // ['m-box', 'child', 'h300', 'border', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p']
# |   |   |   |   article // article[18]
# |   |   |   |   |   div // ['mt']
# |   |   |   |   |   |   div // ['flex-change']
# |   |   |   |   |   |   |   h2 // {} / Cuáles son las cuentas que ahora pagan 60% de interés sólo por tener saldo
# |   |   |   |   |   |   |   p // {'class': ['volanta']} / Tasa anual
# |   |   |   |   |   |   div // ['data-txt']
# |   |   |   |   |   |   |   span // {'class': ['paywall-ico']} /
# |   |   |   |   |   |   |   p // {'class': ['author']} / Martín Grosz
# |   |   |   |   |   div // ['wrap-figure']
# |   |   |   |   |   |   picture // picture
# |   |   |   |   |   |   |   source // source
# |   |   |   |   |   |   |   img // img
# |   |   |   |   |   a // /servicios/cuentas-ahora-pagan-60-interes-solo-tener-saldo_0_StbX9U8Ge3.html /
# |   |   |   div // ['m-box', 'adv', 'h300', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p']
# |   |   |   |   div // ['banner_center', 'ad-slot', 'box-adv']

# %%
parent_lis = []
gparent_uls = []
ggparent_uls = []
gggparent_uls = []
ggggparent_uls = []

for article in articles:
    if article.parent.name == 'li':
        parent_lis.append(article.parent)
        gparent_uls.append(article.parent.parent)
        ggparent_uls.append(article.parent.parent.parent)
        gggparent_uls.append(article.parent.parent.parent.parent)
        ggggparent_uls.append(article.parent.parent.parent.parent.parent)

i = 5
for s in "parent_lis", "gparent_uls", "ggparent_uls", "gggparent_uls", "ggggparent_uls":
    exec(f'dumptree({s}[{i}], "")')
    print()
# Out:
# li // li
# |   article // article[23]
# |   |   a // /opinion/metaverso-humano_0_vcFRxzGK5a.html /
# |   |   div // ['mt', 'small__content']
# |   |   |   span // {'class': ['author-name', 'small__name']} / Mariángeles Castro Sánchez
# |   |   |   h2 // {'class': ['small__h2']} / Un metaverso humano
# |   |   picture // picture
# |   |   |   img // img
#
# ul // ul
# |   li // li
# |   |   article // article[19]
# |   |   |   a // /opinion/acto-17-octubre-bien-desbande-lealtad_0_rWuiCvxP6Q.html /
# |   |   |   div // ['mt', 'small__content']
# |   |   |   |   span // {'class': ['author-name', 'small__name']} / Ricardo Roa
# |   |   |   |   h2 // {'class': ['small__h2']} / Mucho acto por el 17 de octubre, pero más bien de desbande que de lealtad
# |   |   |   picture // picture
# |   |   |   |   img // img
# |   li // li
# |   |   article // article[20]
# |   |   |   a // /opinion/signos-inquietantes-descomposicion-frente-desbande-gobierno_0_6TsB5PzXd7.html /
# |   |   |   div // ['mt', 'small__content']
# |   |   |   |   span // {'class': ['author-name', 'small__name']} / Eduardo van der Kooy
# |   |   |   |   h2 // {'class': ['small__h2']} / Signos inquietantes por la descomposición del Frente y el desbande del Gobierno
# |   |   |   picture // picture
# |   |   |   |   img // img
# |   li // li
# |   |   article // article[21]
# |   |   |   a // /opinion/amenaza-nuclear_0_MRfI476vLb.html /
# |   |   |   div // ['mt', 'small__content']
# |   |   |   |   span // {'class': ['author-name', 'small__name']} / Carlos Ruckauf
# |   |   |   |   h2 // {'class': ['small__h2']} / La amenaza nuclear
# |   |   |   picture // picture
# |   |   |   |   img // img
# |   li // li
# |   |   article // article[22]
# |   |   |   a // /opinion/estrategia-virtuosa-insercion-internacional_0_iDWn9ieHkf.html /
# |   |   |   div // ['mt', 'small__content']
# |   |   |   |   span // {'class': ['author-name', 'small__name']} / Roberto Bouzas
# |   |   |   |   h2 // {'class': ['small__h2']} / Hacia una estrategia mas virtuosa de inserción internacional
# |   |   |   picture // picture
# |   |   |   |   img // img
# |   li // li
# |   |   article // article[23]
# |   |   |   a // /opinion/metaverso-humano_0_vcFRxzGK5a.html /
# |   |   |   div // ['mt', 'small__content']
# |   |   |   |   span // {'class': ['author-name', 'small__name']} / Mariángeles Castro Sánchez
# |   |   |   |   h2 // {'class': ['small__h2']} / Un metaverso humano
# |   |   |   picture // picture
# |   |   |   |   img // img
# |   li // li
# |   |   article // article[24]
# |   |   |   a // /opinion/argentina-1985-encuentro_0_gMBNAkZEC9.html /
# |   |   |   div // ['mt', 'small__content']
# |   |   |   |   span // {'class': ['author-name', 'small__name']} / Débora Campos
# |   |   |   |   h2 // {'class': ['small__h2']} / Argentina, 1985 y el encuentro
# |   |   |   picture // picture
# |   |   |   |   img // img
#
# section // section[3]
# |   div // ['title']
# |   |   a // https://www.clarin.com/opinion/ / Las firmas
# |   ul // ul
# |   |   li // li
# |   |   |   article // article[19]
# |   |   |   |   a // /opinion/acto-17-octubre-bien-desbande-lealtad_0_rWuiCvxP6Q.html /
# |   |   |   |   div // ['mt', 'small__content']
# |   |   |   |   |   span // {'class': ['author-name', 'small__name']} / Ricardo Roa
# |   |   |   |   |   h2 // {'class': ['small__h2']} / Mucho acto por el 17 de octubre, pero más bien de desbande que de lealtad
# |   |   |   |   picture // picture
# |   |   |   |   |   img // img
# |   |   li // li
# |   |   |   article // article[20]
# |   |   |   |   a // /opinion/signos-inquietantes-descomposicion-frente-desbande-gobierno_0_6TsB5PzXd7.html /
# |   |   |   |   div // ['mt', 'small__content']
# |   |   |   |   |   span // {'class': ['author-name', 'small__name']} / Eduardo van der Kooy
# |   |   |   |   |   h2 // {'class': ['small__h2']} / Signos inquietantes por la descomposición del Frente y el desbande del Gobierno
# |   |   |   |   picture // picture
# |   |   |   |   |   img // img
# |   |   li // li
# |   |   |   article // article[21]
# |   |   |   |   a // /opinion/amenaza-nuclear_0_MRfI476vLb.html /
# |   |   |   |   div // ['mt', 'small__content']
# |   |   |   |   |   span // {'class': ['author-name', 'small__name']} / Carlos Ruckauf
# |   |   |   |   |   h2 // {'class': ['small__h2']} / La amenaza nuclear
# |   |   |   |   picture // picture
# |   |   |   |   |   img // img
# |   |   li // li
# |   |   |   article // article[22]
# |   |   |   |   a // /opinion/estrategia-virtuosa-insercion-internacional_0_iDWn9ieHkf.html /
# |   |   |   |   div // ['mt', 'small__content']
# |   |   |   |   |   span // {'class': ['author-name', 'small__name']} / Roberto Bouzas
# |   |   |   |   |   h2 // {'class': ['small__h2']} / Hacia una estrategia mas virtuosa de inserción internacional
# |   |   |   |   picture // picture
# |   |   |   |   |   img // img
# |   |   li // li
# |   |   |   article // article[23]
# |   |   |   |   a // /opinion/metaverso-humano_0_vcFRxzGK5a.html /
# |   |   |   |   div // ['mt', 'small__content']
# |   |   |   |   |   span // {'class': ['author-name', 'small__name']} / Mariángeles Castro Sánchez
# |   |   |   |   |   h2 // {'class': ['small__h2']} / Un metaverso humano
# |   |   |   |   picture // picture
# |   |   |   |   |   img // img
# |   |   li // li
# |   |   |   article // article[24]
# |   |   |   |   a // /opinion/argentina-1985-encuentro_0_gMBNAkZEC9.html /
# |   |   |   |   div // ['mt', 'small__content']
# |   |   |   |   |   span // {'class': ['author-name', 'small__name']} / Débora Campos
# |   |   |   |   |   h2 // {'class': ['small__h2']} / Argentina, 1985 y el encuentro
# |   |   |   |   picture // picture
# |   |   |   |   |   img // img
#
# div // ['m-box', 'gray_bg', 'h600', 'col-lg-6', 'col-md-8', 'col-sm-12', 'col-xs-12', 'no-p', 'size2x2']
# |   section // section[3]
# |   |   div // ['title']
# |   |   |   a // https://www.clarin.com/opinion/ / Las firmas
# |   |   ul // ul
# |   |   |   li // li
# |   |   |   |   article // article[19]
# |   |   |   |   |   a // /opinion/acto-17-octubre-bien-desbande-lealtad_0_rWuiCvxP6Q.html /
# |   |   |   |   |   div // ['mt', 'small__content']
# |   |   |   |   |   |   span // {'class': ['author-name', 'small__name']} / Ricardo Roa
# |   |   |   |   |   |   h2 // {'class': ['small__h2']} / Mucho acto por el 17 de octubre, pero más bien de desbande que de lealtad
# |   |   |   |   |   picture // picture
# |   |   |   |   |   |   img // img
# |   |   |   li // li
# |   |   |   |   article // article[20]
# |   |   |   |   |   a // /opinion/signos-inquietantes-descomposicion-frente-desbande-gobierno_0_6TsB5PzXd7.html /
# |   |   |   |   |   div // ['mt', 'small__content']
# |   |   |   |   |   |   span // {'class': ['author-name', 'small__name']} / Eduardo van der Kooy
# |   |   |   |   |   |   h2 // {'class': ['small__h2']} / Signos inquietantes por la descomposición del Frente y el desbande del Gobierno
# |   |   |   |   |   picture // picture
# |   |   |   |   |   |   img // img
# |   |   |   li // li
# |   |   |   |   article // article[21]
# |   |   |   |   |   a // /opinion/amenaza-nuclear_0_MRfI476vLb.html /
# |   |   |   |   |   div // ['mt', 'small__content']
# |   |   |   |   |   |   span // {'class': ['author-name', 'small__name']} / Carlos Ruckauf
# |   |   |   |   |   |   h2 // {'class': ['small__h2']} / La amenaza nuclear
# |   |   |   |   |   picture // picture
# |   |   |   |   |   |   img // img
# |   |   |   li // li
# |   |   |   |   article // article[22]
# |   |   |   |   |   a // /opinion/estrategia-virtuosa-insercion-internacional_0_iDWn9ieHkf.html /
# |   |   |   |   |   div // ['mt', 'small__content']
# |   |   |   |   |   |   span // {'class': ['author-name', 'small__name']} / Roberto Bouzas
# |   |   |   |   |   |   h2 // {'class': ['small__h2']} / Hacia una estrategia mas virtuosa de inserción internacional
# |   |   |   |   |   picture // picture
# |   |   |   |   |   |   img // img
# |   |   |   li // li
# |   |   |   |   article // article[23]
# |   |   |   |   |   a // /opinion/metaverso-humano_0_vcFRxzGK5a.html /
# |   |   |   |   |   div // ['mt', 'small__content']
# |   |   |   |   |   |   span // {'class': ['author-name', 'small__name']} / Mariángeles Castro Sánchez
# |   |   |   |   |   |   h2 // {'class': ['small__h2']} / Un metaverso humano
# |   |   |   |   |   picture // picture
# |   |   |   |   |   |   img // img
# |   |   |   li // li
# |   |   |   |   article // article[24]
# |   |   |   |   |   a // /opinion/argentina-1985-encuentro_0_gMBNAkZEC9.html /
# |   |   |   |   |   div // ['mt', 'small__content']
# |   |   |   |   |   |   span // {'class': ['author-name', 'small__name']} / Débora Campos
# |   |   |   |   |   |   h2 // {'class': ['small__h2']} / Argentina, 1985 y el encuentro
# |   |   |   |   |   picture // picture
# |   |   |   |   |   |   img // img
#
# div // ['count-first', 'bb-container', 'three-floor-banner', 'bb-moduleId_3B_mod_202164929140454']
# |   div // ['m-box', 'gray_bg', 'h600', 'col-lg-6', 'col-md-8', 'col-sm-12', 'col-xs-12', 'no-p', 'size2x2']
# |   |   section // section[3]
# |   |   |   div // ['title']
# |   |   |   |   a // https://www.clarin.com/opinion/ / Las firmas
# |   |   |   ul // ul
# |   |   |   |   li // li
# |   |   |   |   |   article // article[19]
# |   |   |   |   |   |   a // /opinion/acto-17-octubre-bien-desbande-lealtad_0_rWuiCvxP6Q.html /
# |   |   |   |   |   |   div // ['mt', 'small__content']
# |   |   |   |   |   |   |   span // {'class': ['author-name', 'small__name']} / Ricardo Roa
# |   |   |   |   |   |   |   h2 // {'class': ['small__h2']} / Mucho acto por el 17 de octubre, pero más bien de desbande que de lealtad
# |   |   |   |   |   |   picture // picture
# |   |   |   |   |   |   |   img // img
# |   |   |   |   li // li
# |   |   |   |   |   article // article[20]
# |   |   |   |   |   |   a // /opinion/signos-inquietantes-descomposicion-frente-desbande-gobierno_0_6TsB5PzXd7.html /
# |   |   |   |   |   |   div // ['mt', 'small__content']
# |   |   |   |   |   |   |   span // {'class': ['author-name', 'small__name']} / Eduardo van der Kooy
# |   |   |   |   |   |   |   h2 // {'class': ['small__h2']} / Signos inquietantes por la descomposición del Frente y el desbande del Gobierno
# |   |   |   |   |   |   picture // picture
# |   |   |   |   |   |   |   img // img
# |   |   |   |   li // li
# |   |   |   |   |   article // article[21]
# |   |   |   |   |   |   a // /opinion/amenaza-nuclear_0_MRfI476vLb.html /
# |   |   |   |   |   |   div // ['mt', 'small__content']
# |   |   |   |   |   |   |   span // {'class': ['author-name', 'small__name']} / Carlos Ruckauf
# |   |   |   |   |   |   |   h2 // {'class': ['small__h2']} / La amenaza nuclear
# |   |   |   |   |   |   picture // picture
# |   |   |   |   |   |   |   img // img
# |   |   |   |   li // li
# |   |   |   |   |   article // article[22]
# |   |   |   |   |   |   a // /opinion/estrategia-virtuosa-insercion-internacional_0_iDWn9ieHkf.html /
# |   |   |   |   |   |   div // ['mt', 'small__content']
# |   |   |   |   |   |   |   span // {'class': ['author-name', 'small__name']} / Roberto Bouzas
# |   |   |   |   |   |   |   h2 // {'class': ['small__h2']} / Hacia una estrategia mas virtuosa de inserción internacional
# |   |   |   |   |   |   picture // picture
# |   |   |   |   |   |   |   img // img
# |   |   |   |   li // li
# |   |   |   |   |   article // article[23]
# |   |   |   |   |   |   a // /opinion/metaverso-humano_0_vcFRxzGK5a.html /
# |   |   |   |   |   |   div // ['mt', 'small__content']
# |   |   |   |   |   |   |   span // {'class': ['author-name', 'small__name']} / Mariángeles Castro Sánchez
# |   |   |   |   |   |   |   h2 // {'class': ['small__h2']} / Un metaverso humano
# |   |   |   |   |   |   picture // picture
# |   |   |   |   |   |   |   img // img
# |   |   |   |   li // li
# |   |   |   |   |   article // article[24]
# |   |   |   |   |   |   a // /opinion/argentina-1985-encuentro_0_gMBNAkZEC9.html /
# |   |   |   |   |   |   div // ['mt', 'small__content']
# |   |   |   |   |   |   |   span // {'class': ['author-name', 'small__name']} / Débora Campos
# |   |   |   |   |   |   |   h2 // {'class': ['small__h2']} / Argentina, 1985 y el encuentro
# |   |   |   |   |   |   picture // picture
# |   |   |   |   |   |   |   img // img
# |   div // ['m-box', 'h300', 'child', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p', 'list-format']
# |   |   article // article[25]
# |   |   |   div // ['mt']
# |   |   |   |   div // ['flex-change']
# |   |   |   |   |   h2 // {} / Misterio en Villa Pueyrredón: encuentran a dos hermanos muertos en un departamento
# |   |   |   |   |   p // {'class': ['volanta']} / Tenían 56 y 63 años
# |   |   |   |   div // ['data-txt']
# |   |   |   |   |   p // {'class': ['section']} / Policiales
# |   |   |   div // ['wrap-figure']
# |   |   |   |   picture // picture
# |   |   |   |   |   source // source
# |   |   |   |   |   img // img
# |   |   |   a // https://www.clarin.com/policiales/crimen-misterio-villa-pueyrredon-encuentran-hermanos-muertos-depar /
# |   div // ['m-box', 'h300', 'child', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p', 'list-format']
# |   |   article // article[26]
# |   |   |   div // ['mt']
# |   |   |   |   div // ['flex-change']
# |   |   |   |   |   h2 // {} / Los jubilados podrán comprar TV, celulares, lavarropas y heladeras en 42 cuotas
# |   |   |   |   |   p // {'class': ['volanta']} / Extienden el Ahora 30
# |   |   |   |   div // ['data-txt']
# |   |   |   |   |   p // {'class': ['author']} / Damián Kantor
# |   |   |   div // ['wrap-figure']
# |   |   |   |   picture // picture
# |   |   |   |   |   source // source
# |   |   |   |   |   img // img
# |   |   |   a // /economia/guino-gobierno-jubilados-podran-comprar-electronicos-42-cuotas_0_an84O5JGOK.html /
# |   div // ['m-box', 'h300', 'child', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p', 'list-format']
# |   |   article // article[27]
# |   |   |   div // ['mt']
# |   |   |   |   div // ['flex-change']
# |   |   |   |   |   h2 // {} / La dura respuesta de Mauricio Macri a las críticas de Facundo Manes
# |   |   |   |   |   p // {'class': ['volanta']} / “Les va a ir mal”
# |   |   |   |   div // ['data-txt']
# |   |   |   |   |   p // {'class': ['section']} / Política
# |   |   |   div // ['wrap-figure']
# |   |   |   |   div // ['ico-tx-news']
# |   |   |   |   |   span // {'class': ['content-ico', 'dsdsd']} /
# |   |   |   |   |   |   div // ['ico']
# |   |   |   |   |   |   |   div // ['mdia', 'media-aud', 'onlyIcon']
# |   |   |   |   picture // picture
# |   |   |   |   |   source // source
# |   |   |   |   |   img // img
# |   |   |   a // /politica/dura-respuesta-mauricio-macri-criticas-facundo-manes-agrediendo-coalicion-va-ir-mal-_0_Cfi /
# |   div // ['m-box', 'h300', 'child', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p', 'list-format']
# |   |   article // article[28]
# |   |   |   div // ['mt']
# |   |   |   |   div // ['flex-change']
# |   |   |   |   |   h2 // {} / Descubrimiento científico: por primera vez hallan una “familia” de neandertales
# |   |   |   |   |   p // {'class': ['volanta']} / Trece cuerpos en dos cuevas
# |   |   |   |   div // ['data-txt']
# |   |   |   |   |   p // {'class': ['section']} / Sociedad
# |   |   |   div // ['wrap-figure']
# |   |   |   |   picture // picture
# |   |   |   |   |   source // source
# |   |   |   |   |   img // img
# |   |   |   a // /sociedad/descubrimiento-cientifico-primera-vez-hallan-familia-neandertales_0_jV3jc1Vm8F.html /
# |   div // ['m-box', 'h300', 'child', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p', 'list-format']
# |   |   article // article[29]
# |   |   |   div // ['mt']
# |   |   |   |   div // ['flex-change']
# |   |   |   |   |   h2 // {} / Cuatro razones por las que hay cada vez menos pediatras y un pronóstico alarmante
# |   |   |   |   |   p // {'class': ['volanta']} / La falta de médicos
# |   |   |   |   div // ['data-txt']
# |   |   |   |   |   p // {'class': ['author']} / Gonzalo Herman
# |   |   |   div // ['wrap-figure']
# |   |   |   |   picture // picture
# |   |   |   |   |   source // source
# |   |   |   |   |   img // img
# |   |   |   a // /sociedad/razones-vez-pediatras-pronostico-alarmante_0_OAXibsijZa.html /
# |   div // ['m-box', 'adv', 'h300', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p']
# |   |   div // ['banner_center', 'ad-slot', 'box-adv']
# |   div // ['m-box', 'child', 'h300', 'col-lg-6', 'col-md-8', 'col-sm-12', 'col-xs-12', 'no-p', 'm2x1', 't-top', 't-right']
# |   |   article // article[30]
# |   |   |   div // ['mt', 'title-top']
# |   |   |   |   div // ['max-h', 'flex-change']
# |   |   |   |   |   h2 // {} / Cristiano Ronaldo se enojó y abandonó la cancha en pleno partido
# |   |   |   |   |   p // {'class': ['volanta']} / Dudas sobre su futuro
# |   |   |   |   div // ['data-txt']
# |   |   |   |   |   p // {'class': ['section']} / Deportes
# |   |   |   div // ['wrap-img', 'title-top']
# |   |   |   |   picture // picture
# |   |   |   |   |   source // source
# |   |   |   |   |   img // img
# |   |   |   |   div // ['bg_picture_degree']
# |   |   |   div // ['bg_picture_degree']
# |   |   |   a // /deportes/cristiano-ronaldo-united-ten-hag_0_vCRbjz3v7N.html /

# %%
# def dumptreeul(n, prefix):
def dumptreeul(n, prefix):
    tags_to_show = {'h2', 'div', 'ul', 'section', 'article', 'header', 'span', 'p', 'li'}
    
    stack = []
    stack.extend(reversed([ch for ch in n.children if type(ch) == bs.element.Tag]))

    if n.name in tags_to_show:
        print(prefix + n.name, end = '')
        if n in sections:
            print(f"[{sections.index(n)}]:", end = '')
        if n in articles:
            print(f"[{articles.index(n)}]:", end = '')
        if n in headers:
            print(f"[{headers.index(n)}]:", end = '')
        try:
            print('', n.attrs, end = '')
        except:
            print("+++ NO ATTRIBUTES +++", end = '')
        print()
        
        try:
            if n.name in {'h2', 'p', 'header'}:
                print(prefix + '\t', "<CRLF>".join(n.text.split('\n')))
        except:
            print(prefix + '\t')

    while stack:
            dumptreeul(stack.pop(), '| ' + prefix)
    return None

# %%
# BY <section> -- <section>[0] -- MAIN HEADLINES
dumptreeul(sections[0].parent, '')
# Out:
# div {'class': ['container', 'father', 'no-p'], 'data-classes': 'container', 'data-type': 'container_father', 'data-name': 'container_father'}
# | section[0]: {'data-name': 'cont1B', 'class': ['container', 'no-p'], 'data-classes': 'container ', 'data-type': 'container'}
# | | div {'class': ['count-first', 'bb-container', 'one-floor', 'bb-moduleId_1B_mod_202294940664041'], 'data-count': '4', 'data-classes': ''}
# | | | div {'class': ['m-box', 'child', 'h300', 'col-lg-6', 'col-md-8', 'col-sm-12', 'col-xs-12', 'no-p', 'm2x1'], 'data-size-w': '2', 'data-size-h': '1', 'data-classes': 'm-box child m2x1 h300  col-lg-6 col-md-8 col-sm-12 col-xs-12 no-p', 'data-name': 'content'}
# | | | | article[0]: {'class': ['content-nota', 'list-format', 'twoxone_no_foto']}
# | | | | | div {'class': ['mt']}
# | | | | | | div {'class': ['max-h', 'flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 Ante la presión de la oposición, el kirchnerismo cede para sumar votos y aprobar el Presupuesto 2023
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 La pelea en Diputados
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | p {'class': ['author']}
# | | | | | | | 	 Gustavo Berón
# | | | | | | p {'class': ['summary']}
# | | | | | | 	 Tuvo que aceptar varias modificaciones al proyecto original enviado por Massa. Así, el oficialismo busca darle dictamen hoy y tratarlo la semana próxima en el recinto.
# | | | | ul {'class': ['content-related']}
# | | | | | li {'class': ['item-related']}
# | | | | | | article[1]: {'class': ['related_aperture']}
# | | | | | | | | div {'class': ['box-title-rel']}
# | | | | | | | | | span {'class': ['section-rel']}
# | | | | | | | | | h2 {'class': ['title-rel']}
# | | | | | | | | | 	 Frente al derrumbe, Kicillof, Máximo y los intendentes intentan “blindar” el GBA
# | | | | | | | | | span {'class': ['author-rel']}
# | | | div {'class': ['m-box', 'h300', 'child', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p', 'list-format'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p list-format', 'data-name': 'content'}
# | | | | article[2]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | div {'class': ['mt']}
# | | | | | | div {'class': ['flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 Réplica del Gobierno a La Cámpora: dice que el acuerdo con el FMI está vigente
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 Interna sin tregua
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | p {'class': ['author']}
# | | | | | | | 	 Federico Mayol
# | | | | | div {'class': ['wrap-figure']}
# | | | div {'class': ['m-box', 'child', 'h150', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p'], 'data-classes': 'm-box child h150 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p', 'data-size-w': '1', 'data-size-h': '0.5', 'data-name': 'content'}
# | | | | article[3]: {'class': ['content-nota', 'list-format', 'onexone_doble']}
# | | | | | div {'class': ['mt']}
# | | | | | | div {'class': ['flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 El Gobierno le pide una rectificación a Gran Hermano por la acusación contra el Presidente
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 Reality y polémica
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | p {'class': ['section']}
# | | | | | | | 	 Política
# | | | | | div {'class': ['wrap-figure']}
# | | | div {'class': ['m-box', 'child', 'h150', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p'], 'data-classes': 'm-box child h150 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p', 'data-size-w': '1', 'data-size-h': '0.5', 'data-name': 'content'}
# | | | | article[4]: {'class': ['content-nota', 'list-format', 'onexone_doble']}
# | | | | | div {'class': ['mt']}
# | | | | | | div {'class': ['flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 Ironías de la oposición: “¿De verdad Alberto está preocupado por Gran Hermano?”
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 Cruces con Cerruti
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | p {'class': ['section']}
# | | | | | | | 	 Política
# | | | | | div {'class': ['wrap-figure']}
# | section[1]: {'data-name': 'cont4B', 'class': ['container', 'no-p', 'listado'], 'data-classes': 'container listado ', 'data-type': 'container'}
# | | div {'class': ['count-first', 'bb-container', 'bb-moduleId_4B_mod_2021101690248929'], 'data-count': '16', 'data-classes': ''}
# | | | div {'id': 'fourxtwo_mod_2021101690248929', 'class': ['border', 'col-lg-6', 'col-md-8', 'col-sm-12', 'col-xs-12', 'no-p', 'size4x2', 'special'], 'data-classes': 'border col-lg-6 col-md-8 col-sm-12 col-xs-12 no-p size4x2  special', 'data-name': 'container4x2'}
# | | | | div {'class': ['m-box', 'child', 'h300', 'col-sm-6', 'col-xs-12', 'pl-pr'], 'data-classes': 'm-box child h300 col-sm-6 col-xs-12 pl-pr ', 'data-name': 'content', 'data-size-w': '1', 'data-size-h': '1'}
# | | | | | article[5]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | | div {'class': ['mt']}
# | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | h2 {}
# | | | | | | | | 	 El encargado de la Base Marambio fue atacado con una maza mientras dormía
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | 	 Brutal pelea en la Antártida
# | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | p {'class': ['section']}
# | | | | | | | | 	 Sociedad
# | | | | | | div {'class': ['wrap-figure']}
# | | | | | | | div {'class': ['ico-tx-news']}
# | | | | | | | | div {'class': ['ico']}
# | | | | | | | | | div {'class': ['mdia', 'media-aud', 'onlyIcon']}
# | | | | div {'class': ['m-box', 'child', 'h300', 'col-sm-6', 'col-xs-12', 'pl-pr'], 'data-classes': 'm-box child h300 col-sm-6 col-xs-12 pl-pr ', 'data-name': 'content', 'data-size-w': '1', 'data-size-h': '1'}
# | | | | | article[6]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | | div {'class': ['mt']}
# | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | h2 {}
# | | | | | | | | 	 Ataques en la cama de la Argentina precaria
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | 	 Del editor
# | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | p {'class': ['author']}
# | | | | | | | | 	 Héctor Gambini
# | | | | | | div {'class': ['wrap-figure']}
# | | | | div {'class': ['m-box', 'child', 'h300', 'col-sm-6', 'col-xs-12', 'pl-pr'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-sm-6 col-xs-12 pl-pr', 'data-name': 'content'}
# | | | | | article[7]: {'class': ['onexone_foto_grey', 'content-nota', 'list-format']}
# | | | | | | div {'class': ['mt']}
# | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | h2 {}
# | | | | | | | | 	 La candidata tapada de Alberto Fernández y un dirigente social a los escobazos
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | 	 Por los pasillos
# | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | span {'class': ['paywall-ico']}
# | | | | | | | | p {'class': ['author']}
# | | | | | | | | 	 Pablo de León
# | | | | | | div {'class': ['wrap-figure']}
# | | | | div {'class': ['m-box', 'child', 'h300', 'col-sm-6', 'col-xs-12', 'pl-pr'], 'data-classes': 'm-box child h300 col-sm-6 col-xs-12 pl-pr ', 'data-name': 'content', 'data-size-w': '1', 'data-size-h': '1'}
# | | | | | article[8]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | | div {'class': ['mt']}
# | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | h2 {}
# | | | | | | | | 	 Terror en vuelo de Aerolíneas: por qué se da la turbulencia que afectó al avión
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | 	 Hubo 12 heridos
# | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | p {'class': ['author']}
# | | | | | | | | 	 Irene Hartmann
# | | | | | | div {'class': ['wrap-figure']}
# | | | | div {'class': ['m-box', 'child', 'h300', 'col-xs-12', 'pl-pr'], 'data-classes': 'm-box child h300  col-xs-12 pl-pr', 'data-name': 'content', 'data-size-w': '2', 'data-size-h': '1'}
# | | | | | article[9]: {'class': ['visual', 'bottom_degrade', 'content-nota', 'twoxone_visual', 't-bottom', 't-left', 'list-format']}
# | | | | | | div {'class': ['mt', 'title-bottom']}
# | | | | | | | div {'class': ['max-h', 'flex-change']}
# | | | | | | | | h2 {}
# | | | | | | | | 	 15 segundos de pánico en un avión: “Nunca estuve tan cerca de la muerte”
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | 	 Una de las pasajeras heridas
# | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | p {'class': ['section']}
# | | | | | | | | 	 Sociedad
# | | | | | | div {'class': ['wrap-img', 'title-bottom']}
# | | | | | | | div {'class': ['bg_picture_degree']}
# | | | | | | div {'class': ['bg_picture_degree']}
# | | | | div {'class': ['m-box', 'adv', 'child', 'h300', 'col-lg-6', 'col-md-6', 'col-sm-6', 'col-xs-12', 'pl-pr'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box adv child h300 col-lg-6 col-md-6 col-sm-6 col-xs-12 pl-pr', 'data-name': 'advert'}
# | | | | | div {'id': 'div-gpt-ad-caja6', 'class': ['banner_center', 'ad-slot', 'box-adv'], 'data-adtype': 'caja'}
# | | | | div {'class': ['m-box', 'child', 'h150', 'col-lg-6', 'col-md-6', 'col-sm-6', 'col-xs-12', 'pl-pr'], 'data-size-w': '1', 'data-size-h': '0.5', 'data-classes': 'm-box h150 col-lg-6 col-md-6 col-sm-6 col-xs-12 pl-pr', 'data-name': 'content'}
# | | | | | article[10]: {'class': ['content-nota', 'list-format', 'onexone_doble']}
# | | | | | | div {'class': ['mt']}
# | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | h2 {}
# | | | | | | | | 	 Sorpresivo pedido del abogado de la vice para el jefe de los copitos, que ya no soporta la cárcel
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | 	 Atentado a Cristina
# | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | p {'class': ['author']}
# | | | | | | | | 	 Daniel Santoro
# | | | | | | div {'class': ['wrap-figure']}
# | | | | div {'class': ['m-box', 'child', 'h150', 'col-lg-6', 'col-md-6', 'col-sm-6', 'col-xs-12', 'pl-pr'], 'data-size-w': '1', 'data-size-h': '0.5', 'data-classes': 'm-box h150 col-lg-6 col-md-6 col-sm-6 col-xs-12 pl-pr', 'data-name': 'content'}
# | | | | | article[11]: {'class': ['content-nota', 'list-format', 'onexone_doble']}
# | | | | | | div {'class': ['mt']}
# | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | h2 {}
# | | | | | | | | 	 El incómodo momento de Alicia Kirchner cuando la increpó una funcionaria
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | 	 En Caleta Olivia
# | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | p {'class': ['section']}
# | | | | | | | | 	 Política
# | | | | | | div {'class': ['wrap-figure']}
# | | | | | | | div {'class': ['ico-tx-news', 'xs']}
# | | | | | | | | span {'class': ['content-ico']}
# | | | | | | | | | div {'class': ['ico']}
# | | | | | | | | | | div {'class': ['mdia', 'media-vid', 'onlyIcon']}
# | | | div {'class': ['m-box', 'adv', 'h1200', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p', 'size1x4'], 'data-size-w': '1', 'data-size-h': '4', 'data-classes': ' m-box adv h1200 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p size1x4', 'data-name': 'advert'}
# | | | | div {'class': ['box-adv']}
# | | | | | div {'id': 'div-gpt-ad-caja0', 'class': ['banner_center', 'ad-slot', 'ad-sticky'], 'data-adtype': 'caja'}
# | | | div {'class': ['h600', 'm-box', 'last-moment', 'm-box', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p'], 'data-size-w': '1', 'data-size-h': '2', 'data-classes': 'h600 m-box last-moment m-box col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p', 'data-name': 'lastmoment'}
# | | | | div {'class': ['last-moment'], 'xmlns': 'http://www.w3.org/1999/html', 'id': 'lmvmod_202271582272926'}
# | | | | | ul {'class': ['box-items']}
# | | | | | | li {'aria-label': '/politica/esteban-bullrich-cuestiono-interna-juntos-cambio-llevamos-meses-cascoteandonos-rancho-_0_opIgF9sv95.html', 'style': 'cursor: pointer;'}
# | | | | | | | | article[12]: {'class': ['flex-change']}
# | | | | | | | | | h2 {}
# | | | | | | | | | 	 Esteban Bullrich cuestionó la interna de Juntos por el Cambio: "Llevamos meses cascoteándonos el rancho"
# | | | | | | | | | span {}
# | | | | | | li {'aria-label': '/deportes/nba-facundo-campazzo-pudo-debutar-dallas-leandro-bolmaro-fugaz-estreno-utah_0_1gXdb6AxHx.html', 'style': 'cursor: pointer;'}
# | | | | | | | | article[13]: {'class': ['flex-change']}
# | | | | | | | | | h2 {}
# | | | | | | | | | 	 NBA: Facundo Campazzo no pudo debutar en Dallas y Leandro Bolmaro tuvo un fugaz estreno en Utah
# | | | | | | | | | span {}
# | | | | | | li {'aria-label': '/politica/juan-ignacio-mendiguren-martin-tetaz-tenso-cruce-television-podes-animal-resistis-reglas-_0_Dox3z22RVW.html', 'style': 'cursor: pointer;'}
# | | | | | | | | article[14]: {'class': ['flex-change']}
# | | | | | | | | | h2 {}
# | | | | | | | | | 	 Juan Ignacio de Mendiguren y Martín Tetaz, en un tenso cruce en televisión: "No podés ser tan animal" y "No resistís las reglas"
# | | | | | | | | | span {}
# | | | | | | li {'aria-label': '/politica/carlos-melconian-admitio-quiere-ministro-mauricio-macri-rodriguez-larreta-pongan-_0_w38PYAdZOS.html', 'style': 'cursor: pointer;'}
# | | | | | | | | article[15]: {'class': ['flex-change']}
# | | | | | | | | | h2 {}
# | | | | | | | | | 	 Carlos Melconian admitió que quiere ser ministro de Mauricio Macri o Rodríguez Larreta: "Donde me pongan, yo estoy"
# | | | | | | | | | span {}
# | | | | | | li {'aria-label': '/fama/santiago-moro-rechazo-gran-hermano-deba-rectificarse-gobierno-digan-participantes-corre-cuenta-_0_4iUAgOvaG0.html', 'style': 'cursor: pointer;'}
# | | | | | | | | article[16]: {'class': ['flex-change']}
# | | | | | | | | | h2 {}
# | | | | | | | | | 	 Santiago del Moro rechazó que Gran Hermano deba rectificarse ante el Gobierno: "Lo que digan los participantes corre por su cuenta"
# | | | | | | | | | span {}
# | | | | | | li {'aria-label': '/politica/-dejen-hacer-papelones-duro-cruce-diego-santilli-maria-eugenia-vidal-gabriela-cerruti-acusacion-gran-hermano_0_Ms9pa8f7Rs.html', 'style': 'cursor: pointer;'}
# | | | | | | | | article[17]: {'class': ['flex-change']}
# | | | | | | | | | h2 {}
# | | | | | | | | | 	 "Dejen de hacer papelones": duro cruce entre Diego Santilli, María Eugenia Vidal y Gabriela Cerruti por la acusación contra Gran Hermano
# | | | | | | | | | span {}
# | | | div {'class': ['m-box', 'child', 'h300', 'border', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p', 'data-name': 'content'}
# | | | | article[18]: {'class': ['onexone_foto_grey', 'content-nota', 'list-format']}
# | | | | | div {'class': ['mt']}
# | | | | | | div {'class': ['flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 Cuáles son las cuentas que ahora pagan 60% de interés sólo por tener saldo
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 Tasa anual
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | span {'class': ['paywall-ico']}
# | | | | | | | p {'class': ['author']}
# | | | | | | | 	 Martín Grosz
# | | | | | div {'class': ['wrap-figure']}
# | | | div {'class': ['m-box', 'adv', 'h300', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box adv h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p', 'data-name': 'advert'}
# | | | | div {'id': 'div-gpt-ad-caja1', 'class': ['banner_center', 'ad-slot', 'box-adv']}

# %%
# BY <section> -- <section>[1] -- Includes last moment. Sibling with main headline
dumptreeul(sections[1].parent, '')
# Out:
# div {'class': ['container', 'father', 'no-p'], 'data-classes': 'container', 'data-type': 'container_father', 'data-name': 'container_father'}
# | section[0]: {'data-name': 'cont1B', 'class': ['container', 'no-p'], 'data-classes': 'container ', 'data-type': 'container'}
# | | div {'class': ['count-first', 'bb-container', 'one-floor', 'bb-moduleId_1B_mod_202294940664041'], 'data-count': '4', 'data-classes': ''}
# | | | div {'class': ['m-box', 'child', 'h300', 'col-lg-6', 'col-md-8', 'col-sm-12', 'col-xs-12', 'no-p', 'm2x1'], 'data-size-w': '2', 'data-size-h': '1', 'data-classes': 'm-box child m2x1 h300  col-lg-6 col-md-8 col-sm-12 col-xs-12 no-p', 'data-name': 'content'}
# | | | | article[0]: {'class': ['content-nota', 'list-format', 'twoxone_no_foto']}
# | | | | | div {'class': ['mt']}
# | | | | | | div {'class': ['max-h', 'flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 Ante la presión de la oposición, el kirchnerismo cede para sumar votos y aprobar el Presupuesto 2023
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 La pelea en Diputados
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | p {'class': ['author']}
# | | | | | | | 	 Gustavo Berón
# | | | | | | p {'class': ['summary']}
# | | | | | | 	 Tuvo que aceptar varias modificaciones al proyecto original enviado por Massa. Así, el oficialismo busca darle dictamen hoy y tratarlo la semana próxima en el recinto.
# | | | | ul {'class': ['content-related']}
# | | | | | li {'class': ['item-related']}
# | | | | | | article[1]: {'class': ['related_aperture']}
# | | | | | | | | div {'class': ['box-title-rel']}
# | | | | | | | | | span {'class': ['section-rel']}
# | | | | | | | | | h2 {'class': ['title-rel']}
# | | | | | | | | | 	 Frente al derrumbe, Kicillof, Máximo y los intendentes intentan “blindar” el GBA
# | | | | | | | | | span {'class': ['author-rel']}
# | | | div {'class': ['m-box', 'h300', 'child', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p', 'list-format'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p list-format', 'data-name': 'content'}
# | | | | article[2]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | div {'class': ['mt']}
# | | | | | | div {'class': ['flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 Réplica del Gobierno a La Cámpora: dice que el acuerdo con el FMI está vigente
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 Interna sin tregua
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | p {'class': ['author']}
# | | | | | | | 	 Federico Mayol
# | | | | | div {'class': ['wrap-figure']}
# | | | div {'class': ['m-box', 'child', 'h150', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p'], 'data-classes': 'm-box child h150 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p', 'data-size-w': '1', 'data-size-h': '0.5', 'data-name': 'content'}
# | | | | article[3]: {'class': ['content-nota', 'list-format', 'onexone_doble']}
# | | | | | div {'class': ['mt']}
# | | | | | | div {'class': ['flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 El Gobierno le pide una rectificación a Gran Hermano por la acusación contra el Presidente
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 Reality y polémica
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | p {'class': ['section']}
# | | | | | | | 	 Política
# | | | | | div {'class': ['wrap-figure']}
# | | | div {'class': ['m-box', 'child', 'h150', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p'], 'data-classes': 'm-box child h150 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p', 'data-size-w': '1', 'data-size-h': '0.5', 'data-name': 'content'}
# | | | | article[4]: {'class': ['content-nota', 'list-format', 'onexone_doble']}
# | | | | | div {'class': ['mt']}
# | | | | | | div {'class': ['flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 Ironías de la oposición: “¿De verdad Alberto está preocupado por Gran Hermano?”
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 Cruces con Cerruti
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | p {'class': ['section']}
# | | | | | | | 	 Política
# | | | | | div {'class': ['wrap-figure']}
# | section[1]: {'data-name': 'cont4B', 'class': ['container', 'no-p', 'listado'], 'data-classes': 'container listado ', 'data-type': 'container'}
# | | div {'class': ['count-first', 'bb-container', 'bb-moduleId_4B_mod_2021101690248929'], 'data-count': '16', 'data-classes': ''}
# | | | div {'id': 'fourxtwo_mod_2021101690248929', 'class': ['border', 'col-lg-6', 'col-md-8', 'col-sm-12', 'col-xs-12', 'no-p', 'size4x2', 'special'], 'data-classes': 'border col-lg-6 col-md-8 col-sm-12 col-xs-12 no-p size4x2  special', 'data-name': 'container4x2'}
# | | | | div {'class': ['m-box', 'child', 'h300', 'col-sm-6', 'col-xs-12', 'pl-pr'], 'data-classes': 'm-box child h300 col-sm-6 col-xs-12 pl-pr ', 'data-name': 'content', 'data-size-w': '1', 'data-size-h': '1'}
# | | | | | article[5]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | | div {'class': ['mt']}
# | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | h2 {}
# | | | | | | | | 	 El encargado de la Base Marambio fue atacado con una maza mientras dormía
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | 	 Brutal pelea en la Antártida
# | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | p {'class': ['section']}
# | | | | | | | | 	 Sociedad
# | | | | | | div {'class': ['wrap-figure']}
# | | | | | | | div {'class': ['ico-tx-news']}
# | | | | | | | | div {'class': ['ico']}
# | | | | | | | | | div {'class': ['mdia', 'media-aud', 'onlyIcon']}
# | | | | div {'class': ['m-box', 'child', 'h300', 'col-sm-6', 'col-xs-12', 'pl-pr'], 'data-classes': 'm-box child h300 col-sm-6 col-xs-12 pl-pr ', 'data-name': 'content', 'data-size-w': '1', 'data-size-h': '1'}
# | | | | | article[6]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | | div {'class': ['mt']}
# | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | h2 {}
# | | | | | | | | 	 Ataques en la cama de la Argentina precaria
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | 	 Del editor
# | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | p {'class': ['author']}
# | | | | | | | | 	 Héctor Gambini
# | | | | | | div {'class': ['wrap-figure']}
# | | | | div {'class': ['m-box', 'child', 'h300', 'col-sm-6', 'col-xs-12', 'pl-pr'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-sm-6 col-xs-12 pl-pr', 'data-name': 'content'}
# | | | | | article[7]: {'class': ['onexone_foto_grey', 'content-nota', 'list-format']}
# | | | | | | div {'class': ['mt']}
# | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | h2 {}
# | | | | | | | | 	 La candidata tapada de Alberto Fernández y un dirigente social a los escobazos
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | 	 Por los pasillos
# | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | span {'class': ['paywall-ico']}
# | | | | | | | | p {'class': ['author']}
# | | | | | | | | 	 Pablo de León
# | | | | | | div {'class': ['wrap-figure']}
# | | | | div {'class': ['m-box', 'child', 'h300', 'col-sm-6', 'col-xs-12', 'pl-pr'], 'data-classes': 'm-box child h300 col-sm-6 col-xs-12 pl-pr ', 'data-name': 'content', 'data-size-w': '1', 'data-size-h': '1'}
# | | | | | article[8]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | | div {'class': ['mt']}
# | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | h2 {}
# | | | | | | | | 	 Terror en vuelo de Aerolíneas: por qué se da la turbulencia que afectó al avión
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | 	 Hubo 12 heridos
# | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | p {'class': ['author']}
# | | | | | | | | 	 Irene Hartmann
# | | | | | | div {'class': ['wrap-figure']}
# | | | | div {'class': ['m-box', 'child', 'h300', 'col-xs-12', 'pl-pr'], 'data-classes': 'm-box child h300  col-xs-12 pl-pr', 'data-name': 'content', 'data-size-w': '2', 'data-size-h': '1'}
# | | | | | article[9]: {'class': ['visual', 'bottom_degrade', 'content-nota', 'twoxone_visual', 't-bottom', 't-left', 'list-format']}
# | | | | | | div {'class': ['mt', 'title-bottom']}
# | | | | | | | div {'class': ['max-h', 'flex-change']}
# | | | | | | | | h2 {}
# | | | | | | | | 	 15 segundos de pánico en un avión: “Nunca estuve tan cerca de la muerte”
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | 	 Una de las pasajeras heridas
# | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | p {'class': ['section']}
# | | | | | | | | 	 Sociedad
# | | | | | | div {'class': ['wrap-img', 'title-bottom']}
# | | | | | | | div {'class': ['bg_picture_degree']}
# | | | | | | div {'class': ['bg_picture_degree']}
# | | | | div {'class': ['m-box', 'adv', 'child', 'h300', 'col-lg-6', 'col-md-6', 'col-sm-6', 'col-xs-12', 'pl-pr'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box adv child h300 col-lg-6 col-md-6 col-sm-6 col-xs-12 pl-pr', 'data-name': 'advert'}
# | | | | | div {'id': 'div-gpt-ad-caja6', 'class': ['banner_center', 'ad-slot', 'box-adv'], 'data-adtype': 'caja'}
# | | | | div {'class': ['m-box', 'child', 'h150', 'col-lg-6', 'col-md-6', 'col-sm-6', 'col-xs-12', 'pl-pr'], 'data-size-w': '1', 'data-size-h': '0.5', 'data-classes': 'm-box h150 col-lg-6 col-md-6 col-sm-6 col-xs-12 pl-pr', 'data-name': 'content'}
# | | | | | article[10]: {'class': ['content-nota', 'list-format', 'onexone_doble']}
# | | | | | | div {'class': ['mt']}
# | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | h2 {}
# | | | | | | | | 	 Sorpresivo pedido del abogado de la vice para el jefe de los copitos, que ya no soporta la cárcel
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | 	 Atentado a Cristina
# | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | p {'class': ['author']}
# | | | | | | | | 	 Daniel Santoro
# | | | | | | div {'class': ['wrap-figure']}
# | | | | div {'class': ['m-box', 'child', 'h150', 'col-lg-6', 'col-md-6', 'col-sm-6', 'col-xs-12', 'pl-pr'], 'data-size-w': '1', 'data-size-h': '0.5', 'data-classes': 'm-box h150 col-lg-6 col-md-6 col-sm-6 col-xs-12 pl-pr', 'data-name': 'content'}
# | | | | | article[11]: {'class': ['content-nota', 'list-format', 'onexone_doble']}
# | | | | | | div {'class': ['mt']}
# | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | h2 {}
# | | | | | | | | 	 El incómodo momento de Alicia Kirchner cuando la increpó una funcionaria
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | 	 En Caleta Olivia
# | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | p {'class': ['section']}
# | | | | | | | | 	 Política
# | | | | | | div {'class': ['wrap-figure']}
# | | | | | | | div {'class': ['ico-tx-news', 'xs']}
# | | | | | | | | span {'class': ['content-ico']}
# | | | | | | | | | div {'class': ['ico']}
# | | | | | | | | | | div {'class': ['mdia', 'media-vid', 'onlyIcon']}
# | | | div {'class': ['m-box', 'adv', 'h1200', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p', 'size1x4'], 'data-size-w': '1', 'data-size-h': '4', 'data-classes': ' m-box adv h1200 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p size1x4', 'data-name': 'advert'}
# | | | | div {'class': ['box-adv']}
# | | | | | div {'id': 'div-gpt-ad-caja0', 'class': ['banner_center', 'ad-slot', 'ad-sticky'], 'data-adtype': 'caja'}
# | | | div {'class': ['h600', 'm-box', 'last-moment', 'm-box', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p'], 'data-size-w': '1', 'data-size-h': '2', 'data-classes': 'h600 m-box last-moment m-box col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p', 'data-name': 'lastmoment'}
# | | | | div {'class': ['last-moment'], 'xmlns': 'http://www.w3.org/1999/html', 'id': 'lmvmod_202271582272926'}
# | | | | | ul {'class': ['box-items']}
# | | | | | | li {'aria-label': '/politica/esteban-bullrich-cuestiono-interna-juntos-cambio-llevamos-meses-cascoteandonos-rancho-_0_opIgF9sv95.html', 'style': 'cursor: pointer;'}
# | | | | | | | | article[12]: {'class': ['flex-change']}
# | | | | | | | | | h2 {}
# | | | | | | | | | 	 Esteban Bullrich cuestionó la interna de Juntos por el Cambio: "Llevamos meses cascoteándonos el rancho"
# | | | | | | | | | span {}
# | | | | | | li {'aria-label': '/deportes/nba-facundo-campazzo-pudo-debutar-dallas-leandro-bolmaro-fugaz-estreno-utah_0_1gXdb6AxHx.html', 'style': 'cursor: pointer;'}
# | | | | | | | | article[13]: {'class': ['flex-change']}
# | | | | | | | | | h2 {}
# | | | | | | | | | 	 NBA: Facundo Campazzo no pudo debutar en Dallas y Leandro Bolmaro tuvo un fugaz estreno en Utah
# | | | | | | | | | span {}
# | | | | | | li {'aria-label': '/politica/juan-ignacio-mendiguren-martin-tetaz-tenso-cruce-television-podes-animal-resistis-reglas-_0_Dox3z22RVW.html', 'style': 'cursor: pointer;'}
# | | | | | | | | article[14]: {'class': ['flex-change']}
# | | | | | | | | | h2 {}
# | | | | | | | | | 	 Juan Ignacio de Mendiguren y Martín Tetaz, en un tenso cruce en televisión: "No podés ser tan animal" y "No resistís las reglas"
# | | | | | | | | | span {}
# | | | | | | li {'aria-label': '/politica/carlos-melconian-admitio-quiere-ministro-mauricio-macri-rodriguez-larreta-pongan-_0_w38PYAdZOS.html', 'style': 'cursor: pointer;'}
# | | | | | | | | article[15]: {'class': ['flex-change']}
# | | | | | | | | | h2 {}
# | | | | | | | | | 	 Carlos Melconian admitió que quiere ser ministro de Mauricio Macri o Rodríguez Larreta: "Donde me pongan, yo estoy"
# | | | | | | | | | span {}
# | | | | | | li {'aria-label': '/fama/santiago-moro-rechazo-gran-hermano-deba-rectificarse-gobierno-digan-participantes-corre-cuenta-_0_4iUAgOvaG0.html', 'style': 'cursor: pointer;'}
# | | | | | | | | article[16]: {'class': ['flex-change']}
# | | | | | | | | | h2 {}
# | | | | | | | | | 	 Santiago del Moro rechazó que Gran Hermano deba rectificarse ante el Gobierno: "Lo que digan los participantes corre por su cuenta"
# | | | | | | | | | span {}
# | | | | | | li {'aria-label': '/politica/-dejen-hacer-papelones-duro-cruce-diego-santilli-maria-eugenia-vidal-gabriela-cerruti-acusacion-gran-hermano_0_Ms9pa8f7Rs.html', 'style': 'cursor: pointer;'}
# | | | | | | | | article[17]: {'class': ['flex-change']}
# | | | | | | | | | h2 {}
# | | | | | | | | | 	 "Dejen de hacer papelones": duro cruce entre Diego Santilli, María Eugenia Vidal y Gabriela Cerruti por la acusación contra Gran Hermano
# | | | | | | | | | span {}
# | | | div {'class': ['m-box', 'child', 'h300', 'border', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p', 'data-name': 'content'}
# | | | | article[18]: {'class': ['onexone_foto_grey', 'content-nota', 'list-format']}
# | | | | | div {'class': ['mt']}
# | | | | | | div {'class': ['flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 Cuáles son las cuentas que ahora pagan 60% de interés sólo por tener saldo
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 Tasa anual
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | span {'class': ['paywall-ico']}
# | | | | | | | p {'class': ['author']}
# | | | | | | | 	 Martín Grosz
# | | | | | div {'class': ['wrap-figure']}
# | | | div {'class': ['m-box', 'adv', 'h300', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box adv h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p', 'data-name': 'advert'}
# | | | | div {'id': 'div-gpt-ad-caja1', 'class': ['banner_center', 'ad-slot', 'box-adv']}

# %%
# BY <section> -- <section>[2] -- "Las Firmas" -- Commentary & Opinion Articles
dumptreeul(sections[2].parent, '')
# Out:
# div {'class': ['container', 'father', 'no-p'], 'data-classes': 'container', 'data-type': 'container_father', 'data-name': 'container_father'}
# | section[2]: {'data-name': 'cont3B', 'class': ['container', 'listado', 'no-p'], 'data-classes': 'container listado ', 'data-type': 'container'}
# | | div {'class': ['count-first', 'bb-container', 'three-floor-banner', 'bb-moduleId_3B_mod_202164929140454'], 'data-count': '12', 'data-classes': ''}
# | | | div {'class': ['m-box', 'gray_bg', 'h600', 'col-lg-6', 'col-md-8', 'col-sm-12', 'col-xs-12', 'no-p', 'size2x2'], 'data-classes': 'm-box h600 col-lg-6 col-md-8 col-sm-12 col-xs-12 no-p size2x2', 'data-size-w': '2', 'data-size-h': '2', 'data-name': 'content'}
# | | | | section[3]: {'class': ['columnas'], 'id': 'columnas'}
# | | | | | div {'class': ['title']}
# | | | | | ul {'class': ['main__container']}
# | | | | | | li {}
# | | | | | | | article[19]: {'class': ['colum__container', 'small__colum']}
# | | | | | | | | div {'class': ['mt', 'small__content']}
# | | | | | | | | | span {'class': ['author-name', 'small__name']}
# | | | | | | | | | h2 {'class': ['small__h2']}
# | | | | | | | | | 	 Mucho acto por el 17 de octubre, pero más bien de desbande que de lealtad
# | | | | | | li {}
# | | | | | | | article[20]: {'class': ['colum__container', 'small__colum']}
# | | | | | | | | div {'class': ['mt', 'small__content']}
# | | | | | | | | | span {'class': ['author-name', 'small__name']}
# | | | | | | | | | h2 {'class': ['small__h2']}
# | | | | | | | | | 	 Signos inquietantes por la descomposición del Frente y el desbande del Gobierno
# | | | | | | li {}
# | | | | | | | article[21]: {'class': ['colum__container', 'small__colum']}
# | | | | | | | | div {'class': ['mt', 'small__content']}
# | | | | | | | | | span {'class': ['author-name', 'small__name']}
# | | | | | | | | | h2 {'class': ['small__h2']}
# | | | | | | | | | 	 La amenaza nuclear
# | | | | | | li {}
# | | | | | | | article[22]: {'class': ['colum__container', 'small__colum']}
# | | | | | | | | div {'class': ['mt', 'small__content']}
# | | | | | | | | | span {'class': ['author-name', 'small__name']}
# | | | | | | | | | h2 {'class': ['small__h2']}
# | | | | | | | | | 	 Hacia una estrategia mas virtuosa de inserción internacional
# | | | | | | li {}
# | | | | | | | article[23]: {'class': ['colum__container', 'small__colum']}
# | | | | | | | | div {'class': ['mt', 'small__content']}
# | | | | | | | | | span {'class': ['author-name', 'small__name']}
# | | | | | | | | | h2 {'class': ['small__h2']}
# | | | | | | | | | 	 Un metaverso humano
# | | | | | | li {}
# | | | | | | | article[24]: {'class': ['colum__container', 'small__colum']}
# | | | | | | | | div {'class': ['mt', 'small__content']}
# | | | | | | | | | span {'class': ['author-name', 'small__name']}
# | | | | | | | | | h2 {'class': ['small__h2']}
# | | | | | | | | | 	 Argentina, 1985 y el encuentro
# | | | div {'class': ['m-box', 'h300', 'child', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p', 'list-format'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p list-format', 'data-name': 'content'}
# | | | | article[25]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | div {'class': ['mt']}
# | | | | | | div {'class': ['flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 Misterio en Villa Pueyrredón: encuentran a dos hermanos muertos en un departamento
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 Tenían 56 y 63 años
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | p {'class': ['section']}
# | | | | | | | 	 Policiales
# | | | | | div {'class': ['wrap-figure']}
# | | | div {'class': ['m-box', 'h300', 'child', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p', 'list-format'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p list-format', 'data-name': 'content'}
# | | | | article[26]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | div {'class': ['mt']}
# | | | | | | div {'class': ['flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 Los jubilados podrán comprar TV, celulares, lavarropas y heladeras en 42 cuotas
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 Extienden el Ahora 30
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | p {'class': ['author']}
# | | | | | | | 	 Damián Kantor
# | | | | | div {'class': ['wrap-figure']}
# | | | div {'class': ['m-box', 'h300', 'child', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p', 'list-format'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p list-format', 'data-name': 'content'}
# | | | | article[27]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | div {'class': ['mt']}
# | | | | | | div {'class': ['flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 La dura respuesta de Mauricio Macri a las críticas de Facundo Manes
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 “Les va a ir mal”
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | p {'class': ['section']}
# | | | | | | | 	 Política
# | | | | | div {'class': ['wrap-figure']}
# | | | | | | div {'class': ['ico-tx-news']}
# | | | | | | | span {'class': ['content-ico', 'dsdsd']}
# | | | | | | | | div {'class': ['ico']}
# | | | | | | | | | div {'class': ['mdia', 'media-aud', 'onlyIcon']}
# | | | div {'class': ['m-box', 'h300', 'child', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p', 'list-format'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p list-format', 'data-name': 'content'}
# | | | | article[28]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | div {'class': ['mt']}
# | | | | | | div {'class': ['flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 Descubrimiento científico: por primera vez hallan una “familia” de neandertales
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 Trece cuerpos en dos cuevas
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | p {'class': ['section']}
# | | | | | | | 	 Sociedad
# | | | | | div {'class': ['wrap-figure']}
# | | | div {'class': ['m-box', 'h300', 'child', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p', 'list-format'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p list-format', 'data-name': 'content'}
# | | | | article[29]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | div {'class': ['mt']}
# | | | | | | div {'class': ['flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 Cuatro razones por las que hay cada vez menos pediatras y un pronóstico alarmante
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 La falta de médicos
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | p {'class': ['author']}
# | | | | | | | 	 Gonzalo Herman
# | | | | | div {'class': ['wrap-figure']}
# | | | div {'class': ['m-box', 'adv', 'h300', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box adv h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p', 'data-name': 'advert'}
# | | | | div {'id': 'div-gpt-ad-caja2', 'class': ['banner_center', 'ad-slot', 'box-adv']}
# | | | div {'class': ['m-box', 'child', 'h300', 'col-lg-6', 'col-md-8', 'col-sm-12', 'col-xs-12', 'no-p', 'm2x1', 't-top', 't-right'], 'data-size-w': '2', 'data-size-h': '1', 'data-classes': 'm-box child h300  col-lg-6 col-md-8 col-sm-12 col-xs-12 no-p t-top t-right', 'data-name': 'content'}
# | | | | article[30]: {'class': ['visual', 'bottom_degrade', 'content-nota', 'twoxone_visual', 't-top', 't-right', 'list-format']}
# | | | | | div {'class': ['mt', 'title-top']}
# | | | | | | div {'class': ['max-h', 'flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 Cristiano Ronaldo se enojó y abandonó la cancha en pleno partido
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 Dudas sobre su futuro
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | p {'class': ['section']}
# | | | | | | | 	 Deportes
# | | | | | div {'class': ['wrap-img', 'title-top']}
# | | | | | | div {'class': ['bg_picture_degree']}
# | | | | | div {'class': ['bg_picture_degree']}

# %%
# BY <section> -- <section>[3]
dumptreeul(sections[3].parent, '')
# Out:
# div {'class': ['m-box', 'gray_bg', 'h600', 'col-lg-6', 'col-md-8', 'col-sm-12', 'col-xs-12', 'no-p', 'size2x2'], 'data-classes': 'm-box h600 col-lg-6 col-md-8 col-sm-12 col-xs-12 no-p size2x2', 'data-size-w': '2', 'data-size-h': '2', 'data-name': 'content'}
# | section[3]: {'class': ['columnas'], 'id': 'columnas'}
# | | div {'class': ['title']}
# | | ul {'class': ['main__container']}
# | | | li {}
# | | | | article[19]: {'class': ['colum__container', 'small__colum']}
# | | | | | div {'class': ['mt', 'small__content']}
# | | | | | | span {'class': ['author-name', 'small__name']}
# | | | | | | h2 {'class': ['small__h2']}
# | | | | | | 	 Mucho acto por el 17 de octubre, pero más bien de desbande que de lealtad
# | | | li {}
# | | | | article[20]: {'class': ['colum__container', 'small__colum']}
# | | | | | div {'class': ['mt', 'small__content']}
# | | | | | | span {'class': ['author-name', 'small__name']}
# | | | | | | h2 {'class': ['small__h2']}
# | | | | | | 	 Signos inquietantes por la descomposición del Frente y el desbande del Gobierno
# | | | li {}
# | | | | article[21]: {'class': ['colum__container', 'small__colum']}
# | | | | | div {'class': ['mt', 'small__content']}
# | | | | | | span {'class': ['author-name', 'small__name']}
# | | | | | | h2 {'class': ['small__h2']}
# | | | | | | 	 La amenaza nuclear
# | | | li {}
# | | | | article[22]: {'class': ['colum__container', 'small__colum']}
# | | | | | div {'class': ['mt', 'small__content']}
# | | | | | | span {'class': ['author-name', 'small__name']}
# | | | | | | h2 {'class': ['small__h2']}
# | | | | | | 	 Hacia una estrategia mas virtuosa de inserción internacional
# | | | li {}
# | | | | article[23]: {'class': ['colum__container', 'small__colum']}
# | | | | | div {'class': ['mt', 'small__content']}
# | | | | | | span {'class': ['author-name', 'small__name']}
# | | | | | | h2 {'class': ['small__h2']}
# | | | | | | 	 Un metaverso humano
# | | | li {}
# | | | | article[24]: {'class': ['colum__container', 'small__colum']}
# | | | | | div {'class': ['mt', 'small__content']}
# | | | | | | span {'class': ['author-name', 'small__name']}
# | | | | | | h2 {'class': ['small__h2']}
# | | | | | | 	 Argentina, 1985 y el encuentro

# %%
# BY <section> -- <section>[4]
dumptreeul(sections[4].parent, '')
# Out:
# div {'class': ['container', 'father', 'no-p'], 'data-classes': 'container', 'data-type': 'container_father', 'data-name': 'container_father'}
# | section[4]: {'data-name': 'cont3B', 'class': ['container', 'listado', 'no-p'], 'data-classes': 'container listado ', 'data-type': 'container'}
# | | div {'class': ['count-first', 'bb-container', 'three-floor-banner', 'bb-moduleId_3B_mod_202225241679411'], 'data-count': '12', 'data-classes': ''}
# | | | div {'class': ['suscribers-only', 'm-box', 'child', 'h600', 'col-lg-6', 'col-md-8', 'col-sm-12', 'col-xs-12', 'no-p', 'size2x2', 't-bottom', 't-left'], 'data-size-w': '2', 'data-size-h': '2', 'data-classes': 'suscribers-only child m-box h600 col-lg-6 col-md-8 col-sm-12 col-xs-12 size2x2 t-bottom t-left', 'data-name': 'content'}
# | | | | article[31]: {'class': ['visual', 'bottom_degrade_large', 'content-nota', 'list-format', 'twoxtwo_visual', 't-bottom', 't-left']}
# | | | | | div {'class': ['mt', 'title-bottom']}
# | | | | | | div {'class': ['max-h']}
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 Recuerdo
# | | | | | | | h2 {}
# | | | | | | | 	 La increíble historia del segundo marido de Marilyn Monroe, que era más famoso que ella
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | span {'class': ['paywall-ico']}
# | | | | | | | p {'class': ['author']}
# | | | | | | | 	 Luis Vinker
# | | | | | div {'class': ['wrap-img', 'title-bottom']}
# | | | | | | div {'class': ['bg_picture_degree']}
# | | | div {'class': ['m-box', 'h300', 'child', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p', 'list-format'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p list-format', 'data-name': 'content'}
# | | | | article[32]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | div {'class': ['mt']}
# | | | | | | div {'class': ['flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 Con insultos, Fernando Iglesias y Caparrós tuvieron otro fuerte cruce en redes
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 Ahora, por el libro de Macri
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | p {'class': ['section']}
# | | | | | | | 	 Política
# | | | | | div {'class': ['wrap-figure']}
# | | | div {'class': ['m-box', 'h300', 'child', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p', 'list-format'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p list-format', 'data-name': 'content'}
# | | | | article[33]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | div {'class': ['mt']}
# | | | | | | div {'class': ['flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 Putin declara la ley marcial en los cuatro territorios anexados en Ucrania
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 La guerra, minuto a minuto
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | p {'class': ['section']}
# | | | | | | | 	 Mundo
# | | | | | div {'class': ['wrap-figure']}
# | | | | | | div {'class': ['ico-tx-news']}
# | | | | | | | span {'class': ['content-ico', 'dsdsd']}
# | | | | | | | | div {'class': ['ico']}
# | | | | | | | | | div {'class': ['mdia', 'media-ico-live', 'onlyIcon']}
# | | | div {'class': ['m-box', 'child', 'h300', 'border', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p', 'data-name': 'content'}
# | | | | article[34]: {'class': ['onexone_foto_grey', 'content-nota', 'list-format']}
# | | | | | div {'class': ['mt']}
# | | | | | | div {'class': ['flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 La argentina que vive en Qatar y fue elegida 'fan líder' por el Comité organizador
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 Copa del Mundo
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | span {'class': ['paywall-ico']}
# | | | | | | | p {'class': ['author']}
# | | | | | | | 	 Alejandra Fernández Guida
# | | | | | div {'class': ['wrap-figure']}
# | | | | | | div {'class': ['ico-tx-news']}
# | | | | | | | div {'class': ['ico']}
# | | | | | | | | div {'class': ['mdia', 'media-vid', 'onlyIcon']}
# | | | div {'class': ['m-box', 'h300', 'child', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p', 'list-format'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p list-format', 'data-name': 'content'}
# | | | | article[35]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | div {'class': ['mt']}
# | | | | | | div {'class': ['flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 Fue monje 10 años, dejó el monasterio y hoy es un sastre top
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 Criado en Azul
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | p {'class': ['author']}
# | | | | | | | 	 Carla Rodríguez
# | | | | | div {'class': ['wrap-figure']}
# | | | div {'class': ['m-box', 'h300', 'child', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p', 'list-format'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p list-format', 'data-name': 'content'}
# | | | | article[36]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | div {'class': ['mt']}
# | | | | | | div {'class': ['flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 Aumento de casos de gripe A: cómo evitar un impacto grave
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 Síntomas y tratamiento
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | p {'class': ['author']}
# | | | | | | | 	 Florencia Cunzolo
# | | | | | div {'class': ['wrap-figure']}
# | | | div {'class': ['m-box', 'adv', 'h300', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box adv h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p', 'data-name': 'advert'}
# | | | | div {'id': 'div-gpt-ad-caja3', 'class': ['banner_center', 'ad-slot', 'box-adv']}
# | | | div {'class': ['m-box', 'child', 'h300', 'col-lg-6', 'col-md-8', 'col-sm-12', 'col-xs-12', 'no-p', 'm2x1', 't-top', 't-right'], 'data-size-w': '2', 'data-size-h': '1', 'data-classes': 'm-box child h300  col-lg-6 col-md-8 col-sm-12 col-xs-12 no-p t-top t-right', 'data-name': 'content'}
# | | | | article[37]: {'class': ['visual', 'bottom_degrade', 'content-nota', 'twoxone_visual', 't-top', 't-right', 'list-format']}
# | | | | | div {'class': ['mt', 'title-bottom']}
# | | | | | | div {'class': ['max-h', 'flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 La mitad del mundo tiene clítoris, ¿por qué nadie lo estudia?
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 Operaciones y orgasmos
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | p {'class': ['author']}
# | | | | | | | 	 Rachel E. Gross
# | | | | | div {'class': ['wrap-img', 'title-bottom']}
# | | | | | | div {'class': ['bg_picture_degree']}
# | | | | | div {'class': ['bg_picture_degree']}

# %%
# BY <section> -- <section>[5]
print(
    [sec.name for sec in sections[5].previous_siblings]
)

dumptreeul(sections[5].parent, '')
# Out:
# [None, 'div', None]
# div {'class': ['carcasaSkin']}
# | div {'class': ['full', 'item-content', 'orange-section', 'back'], 'data-classes': 'full item-content orange-section back', 'data-name': 'separador', 'data-linkcontent': 'https://www.clarin.com/fama/'}
# | | header[1]: {'class': ['separador-home']}
# | | 	 <CRLF><CRLF><CRLF>FAMA<CRLF><CRLF>
# | | | div {'class': ['content-separador']}
# | | | | h2 {'class': ['heading']}
# | | | | 	 FAMA
# | section[5]: {'data-name': 'cont1A', 'class': ['container', 'no-p', 'listado'], 'data-classes': 'container no-p listado ', 'data-type': 'container'}
# | | div {'class': ['count-first', 'bb-container', 'one-floor-A', 'bb-moduleId_1A_mod_202164244066916', 'orange-section', 'back'], 'data-classes': ' orange-section back', 'data-count': '4'}
# | | | div {'class': ['m-box', 'h300', 'child', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p', 'list-format'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p list-format', 'data-name': 'content'}
# | | | | article[38]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | div {'class': ['mt']}
# | | | | | | div {'class': ['flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 Al aire, Del Moro rechazó el pedido de retractación que le hizo el Gobierno a Gran Hermano
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 Tras la acusación a Alberto F.
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | p {'class': ['section']}
# | | | | | | | 	 Fama
# | | | | | div {'class': ['wrap-figure']}
# | | | | | | div {'class': ['ico-tx-news']}
# | | | | | | | span {'class': ['content-ico', 'dsdsd']}
# | | | | | | | | div {'class': ['ico']}
# | | | | | | | | | div {'class': ['mdia', 'media-vid', 'onlyIcon']}
# | | | div {'class': ['m-box', 'h300', 'child', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p', 'list-format'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p list-format', 'data-name': 'content'}
# | | | | article[39]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | div {'class': ['mt']}
# | | | | | | div {'class': ['flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 Quiénes son los primeros cuatro nominados de Gran Hermano
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 “Alfa”, entre ellos
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | p {'class': ['section']}
# | | | | | | | 	 Fama
# | | | | | div {'class': ['wrap-figure']}
# | | | | | | div {'class': ['ico-tx-news']}
# | | | | | | | span {'class': ['content-ico', 'dsdsd']}
# | | | | | | | | div {'class': ['ico']}
# | | | | | | | | | div {'class': ['mdia', 'media-ico-live']}
# | | | div {'class': ['m-box', 'h300', 'child', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p', 'list-format'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p list-format', 'data-name': 'content'}
# | | | | article[40]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | div {'class': ['mt']}
# | | | | | | div {'class': ['flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 Marianela Mirra reveló que es lo que no le gusta del nuevo Gran Hermano: “No lo veo más”
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 Muy crítica
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | p {'class': ['section']}
# | | | | | | |
# | | | | | div {'class': ['wrap-figure']}
# | | | div {'class': ['m-box', 'h300', 'child', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p', 'list-format'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p list-format', 'data-name': 'content'}
# | | | | article[41]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | div {'class': ['mt']}
# | | | | | | div {'class': ['flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 Tamara Báez se mostró junto a su nuevo novio y aseguró que quiere tener un hijo
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 ¿L-Gante? Cosa del pasado
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | p {'class': ['section']}
# | | | | | | |
# | | | | | div {'class': ['wrap-figure']}

# %%
# BY <section> -- <section>[6]
dumptreeul(sections[6].parent, '')
# Out:
# div {'class': ['carcasaSkin']}
# | div {'class': ['full', 'item-content', 'suscriptor-content', 'back'], 'data-classes': 'full item-content suscriptor-content back', 'data-name': 'separador', 'data-linkcontent': 'https://www.clarin.com/exclusivo-suscriptores/'}
# | | header[2]: {'class': ['separador-home']}
# | | 	 <CRLF><CRLF><CRLF>Exclusivo suscriptores<CRLF><CRLF>
# | | | div {'class': ['content-separador']}
# | | | | h2 {'class': ['heading']}
# | | | | 	 Exclusivo suscriptores
# | section[6]: {'data-name': 'cont2B', 'class': ['container', 'no-p', 'listado', 'suscriptor-content', 'back'], 'data-classes': 'container listado suscriptor-content back', 'data-type': 'container'}
# | | div {'class': ['count-first', 'bb-container', 'two-floor', 'bb-moduleId_2B_mod_2021112110957595', 'suscriptor-content', 'back'], 'data-classes': 'suscriptor-content back', 'data-count': '8'}
# | | | div {'class': ['suscribers-only', 'm-box', 'child', 'h600', 'col-lg-6', 'col-md-8', 'col-sm-12', 'col-xs-12', 'no-p', 'size2x2', 't-bottom', 't-left'], 'data-size-w': '2', 'data-size-h': '2', 'data-classes': 'suscribers-only child m-box h600 col-lg-6 col-md-8 col-sm-12 col-xs-12 size2x2 t-bottom t-left', 'data-name': 'content'}
# | | | | article[42]: {'class': ['visual', 'bottom_degrade_large', 'content-nota', 'list-format', 'twoxtwo_visual', 't-bottom', 't-left']}
# | | | | | div {'class': ['mt', 'title-top']}
# | | | | | | div {'class': ['max-h']}
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 Clarín en Helsinki
# | | | | | | | h2 {}
# | | | | | | | 	 Secretos de la educación en Finlandia: con pocas horas de clase, son los mejores
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | span {'class': ['paywall-ico']}
# | | | | | | | p {'class': ['author']}
# | | | | | | | 	 Irene Hartmann
# | | | | | div {'class': ['wrap-img', 'title-top']}
# | | | | | | div {'class': ['bg_picture_degree']}
# | | | div {'class': ['m-box', 'child', 'h300', 'border', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p', 'data-name': 'content'}
# | | | | article[43]: {'class': ['onexone_foto_grey', 'content-nota', 'list-format']}
# | | | | | div {'class': ['mt']}
# | | | | | | div {'class': ['flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 La incómoda vía libre del Gobierno con la promo de una gaseosa
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 Figuritas del Mundial
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | span {'class': ['paywall-ico']}
# | | | | | | | p {'class': ['author']}
# | | | | | | | 	 Pablo Sigal
# | | | | | div {'class': ['wrap-figure']}
# | | | div {'class': ['m-box', 'h300', 'child', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p', 'list-format'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p list-format', 'data-name': 'content'}
# | | | | article[44]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | div {'class': ['mt']}
# | | | | | | div {'class': ['flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 El bono ANSeS alcanzaría a un millón de personas que no tienen ayuda del Estado
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 Similar al IFE
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | span {'class': ['paywall-ico']}
# | | | | | | | p {'class': ['author']}
# | | | | | | | 	 Ismael Bermúdez
# | | | | | div {'class': ['wrap-figure']}
# | | | div {'class': ['m-box', 'child', 'h300', 'border', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p', 'data-name': 'content'}
# | | | | article[45]: {'class': ['onexone_foto_grey', 'content-nota', 'list-format']}
# | | | | | div {'class': ['mt']}
# | | | | | | div {'class': ['flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 Los problemas más comunes cuando los hijos emigran y los padres se quedan
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 Cómo resolverlos a distancia
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | span {'class': ['paywall-ico']}
# | | | | | | | p {'class': ['author']}
# | | | | | | | 	 Silvana Saldisuri
# | | | | | div {'class': ['wrap-figure']}
# | | | div {'class': ['m-box', 'h300', 'child', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p', 'list-format'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p list-format', 'data-name': 'content'}
# | | | | article[46]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | div {'class': ['mt']}
# | | | | | | div {'class': ['flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 Viajó al espacio y sintió una “tristeza abrumadora”: qué es el “efecto perspectiva”
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 El actor de Star Trek
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | span {'class': ['paywall-ico']}
# | | | | | | | p {'class': ['author']}
# | | | | | | | 	 Marcelo Bellucci
# | | | | | div {'class': ['wrap-figure']}

# %%
# BY <section> -- <section>[7]
dumptreeul(sections[0].parent, '')
# Out:
# div {'class': ['container', 'father', 'no-p'], 'data-classes': 'container', 'data-type': 'container_father', 'data-name': 'container_father'}
# | section[0]: {'data-name': 'cont1B', 'class': ['container', 'no-p'], 'data-classes': 'container ', 'data-type': 'container'}
# | | div {'class': ['count-first', 'bb-container', 'one-floor', 'bb-moduleId_1B_mod_202294940664041'], 'data-count': '4', 'data-classes': ''}
# | | | div {'class': ['m-box', 'child', 'h300', 'col-lg-6', 'col-md-8', 'col-sm-12', 'col-xs-12', 'no-p', 'm2x1'], 'data-size-w': '2', 'data-size-h': '1', 'data-classes': 'm-box child m2x1 h300  col-lg-6 col-md-8 col-sm-12 col-xs-12 no-p', 'data-name': 'content'}
# | | | | article[0]: {'class': ['content-nota', 'list-format', 'twoxone_no_foto']}
# | | | | | div {'class': ['mt']}
# | | | | | | div {'class': ['max-h', 'flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 Ante la presión de la oposición, el kirchnerismo cede para sumar votos y aprobar el Presupuesto 2023
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 La pelea en Diputados
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | p {'class': ['author']}
# | | | | | | | 	 Gustavo Berón
# | | | | | | p {'class': ['summary']}
# | | | | | | 	 Tuvo que aceptar varias modificaciones al proyecto original enviado por Massa. Así, el oficialismo busca darle dictamen hoy y tratarlo la semana próxima en el recinto.
# | | | | ul {'class': ['content-related']}
# | | | | | li {'class': ['item-related']}
# | | | | | | article[1]: {'class': ['related_aperture']}
# | | | | | | | | div {'class': ['box-title-rel']}
# | | | | | | | | | span {'class': ['section-rel']}
# | | | | | | | | | h2 {'class': ['title-rel']}
# | | | | | | | | | 	 Frente al derrumbe, Kicillof, Máximo y los intendentes intentan “blindar” el GBA
# | | | | | | | | | span {'class': ['author-rel']}
# | | | div {'class': ['m-box', 'h300', 'child', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p', 'list-format'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p list-format', 'data-name': 'content'}
# | | | | article[2]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | div {'class': ['mt']}
# | | | | | | div {'class': ['flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 Réplica del Gobierno a La Cámpora: dice que el acuerdo con el FMI está vigente
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 Interna sin tregua
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | p {'class': ['author']}
# | | | | | | | 	 Federico Mayol
# | | | | | div {'class': ['wrap-figure']}
# | | | div {'class': ['m-box', 'child', 'h150', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p'], 'data-classes': 'm-box child h150 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p', 'data-size-w': '1', 'data-size-h': '0.5', 'data-name': 'content'}
# | | | | article[3]: {'class': ['content-nota', 'list-format', 'onexone_doble']}
# | | | | | div {'class': ['mt']}
# | | | | | | div {'class': ['flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 El Gobierno le pide una rectificación a Gran Hermano por la acusación contra el Presidente
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 Reality y polémica
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | p {'class': ['section']}
# | | | | | | | 	 Política
# | | | | | div {'class': ['wrap-figure']}
# | | | div {'class': ['m-box', 'child', 'h150', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p'], 'data-classes': 'm-box child h150 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p', 'data-size-w': '1', 'data-size-h': '0.5', 'data-name': 'content'}
# | | | | article[4]: {'class': ['content-nota', 'list-format', 'onexone_doble']}
# | | | | | div {'class': ['mt']}
# | | | | | | div {'class': ['flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 Ironías de la oposición: “¿De verdad Alberto está preocupado por Gran Hermano?”
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 Cruces con Cerruti
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | p {'class': ['section']}
# | | | | | | | 	 Política
# | | | | | div {'class': ['wrap-figure']}
# | section[1]: {'data-name': 'cont4B', 'class': ['container', 'no-p', 'listado'], 'data-classes': 'container listado ', 'data-type': 'container'}
# | | div {'class': ['count-first', 'bb-container', 'bb-moduleId_4B_mod_2021101690248929'], 'data-count': '16', 'data-classes': ''}
# | | | div {'id': 'fourxtwo_mod_2021101690248929', 'class': ['border', 'col-lg-6', 'col-md-8', 'col-sm-12', 'col-xs-12', 'no-p', 'size4x2', 'special'], 'data-classes': 'border col-lg-6 col-md-8 col-sm-12 col-xs-12 no-p size4x2  special', 'data-name': 'container4x2'}
# | | | | div {'class': ['m-box', 'child', 'h300', 'col-sm-6', 'col-xs-12', 'pl-pr'], 'data-classes': 'm-box child h300 col-sm-6 col-xs-12 pl-pr ', 'data-name': 'content', 'data-size-w': '1', 'data-size-h': '1'}
# | | | | | article[5]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | | div {'class': ['mt']}
# | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | h2 {}
# | | | | | | | | 	 El encargado de la Base Marambio fue atacado con una maza mientras dormía
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | 	 Brutal pelea en la Antártida
# | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | p {'class': ['section']}
# | | | | | | | | 	 Sociedad
# | | | | | | div {'class': ['wrap-figure']}
# | | | | | | | div {'class': ['ico-tx-news']}
# | | | | | | | | div {'class': ['ico']}
# | | | | | | | | | div {'class': ['mdia', 'media-aud', 'onlyIcon']}
# | | | | div {'class': ['m-box', 'child', 'h300', 'col-sm-6', 'col-xs-12', 'pl-pr'], 'data-classes': 'm-box child h300 col-sm-6 col-xs-12 pl-pr ', 'data-name': 'content', 'data-size-w': '1', 'data-size-h': '1'}
# | | | | | article[6]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | | div {'class': ['mt']}
# | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | h2 {}
# | | | | | | | | 	 Ataques en la cama de la Argentina precaria
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | 	 Del editor
# | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | p {'class': ['author']}
# | | | | | | | | 	 Héctor Gambini
# | | | | | | div {'class': ['wrap-figure']}
# | | | | div {'class': ['m-box', 'child', 'h300', 'col-sm-6', 'col-xs-12', 'pl-pr'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-sm-6 col-xs-12 pl-pr', 'data-name': 'content'}
# | | | | | article[7]: {'class': ['onexone_foto_grey', 'content-nota', 'list-format']}
# | | | | | | div {'class': ['mt']}
# | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | h2 {}
# | | | | | | | | 	 La candidata tapada de Alberto Fernández y un dirigente social a los escobazos
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | 	 Por los pasillos
# | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | span {'class': ['paywall-ico']}
# | | | | | | | | p {'class': ['author']}
# | | | | | | | | 	 Pablo de León
# | | | | | | div {'class': ['wrap-figure']}
# | | | | div {'class': ['m-box', 'child', 'h300', 'col-sm-6', 'col-xs-12', 'pl-pr'], 'data-classes': 'm-box child h300 col-sm-6 col-xs-12 pl-pr ', 'data-name': 'content', 'data-size-w': '1', 'data-size-h': '1'}
# | | | | | article[8]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | | div {'class': ['mt']}
# | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | h2 {}
# | | | | | | | | 	 Terror en vuelo de Aerolíneas: por qué se da la turbulencia que afectó al avión
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | 	 Hubo 12 heridos
# | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | p {'class': ['author']}
# | | | | | | | | 	 Irene Hartmann
# | | | | | | div {'class': ['wrap-figure']}
# | | | | div {'class': ['m-box', 'child', 'h300', 'col-xs-12', 'pl-pr'], 'data-classes': 'm-box child h300  col-xs-12 pl-pr', 'data-name': 'content', 'data-size-w': '2', 'data-size-h': '1'}
# | | | | | article[9]: {'class': ['visual', 'bottom_degrade', 'content-nota', 'twoxone_visual', 't-bottom', 't-left', 'list-format']}
# | | | | | | div {'class': ['mt', 'title-bottom']}
# | | | | | | | div {'class': ['max-h', 'flex-change']}
# | | | | | | | | h2 {}
# | | | | | | | | 	 15 segundos de pánico en un avión: “Nunca estuve tan cerca de la muerte”
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | 	 Una de las pasajeras heridas
# | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | p {'class': ['section']}
# | | | | | | | | 	 Sociedad
# | | | | | | div {'class': ['wrap-img', 'title-bottom']}
# | | | | | | | div {'class': ['bg_picture_degree']}
# | | | | | | div {'class': ['bg_picture_degree']}
# | | | | div {'class': ['m-box', 'adv', 'child', 'h300', 'col-lg-6', 'col-md-6', 'col-sm-6', 'col-xs-12', 'pl-pr'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box adv child h300 col-lg-6 col-md-6 col-sm-6 col-xs-12 pl-pr', 'data-name': 'advert'}
# | | | | | div {'id': 'div-gpt-ad-caja6', 'class': ['banner_center', 'ad-slot', 'box-adv'], 'data-adtype': 'caja'}
# | | | | div {'class': ['m-box', 'child', 'h150', 'col-lg-6', 'col-md-6', 'col-sm-6', 'col-xs-12', 'pl-pr'], 'data-size-w': '1', 'data-size-h': '0.5', 'data-classes': 'm-box h150 col-lg-6 col-md-6 col-sm-6 col-xs-12 pl-pr', 'data-name': 'content'}
# | | | | | article[10]: {'class': ['content-nota', 'list-format', 'onexone_doble']}
# | | | | | | div {'class': ['mt']}
# | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | h2 {}
# | | | | | | | | 	 Sorpresivo pedido del abogado de la vice para el jefe de los copitos, que ya no soporta la cárcel
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | 	 Atentado a Cristina
# | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | p {'class': ['author']}
# | | | | | | | | 	 Daniel Santoro
# | | | | | | div {'class': ['wrap-figure']}
# | | | | div {'class': ['m-box', 'child', 'h150', 'col-lg-6', 'col-md-6', 'col-sm-6', 'col-xs-12', 'pl-pr'], 'data-size-w': '1', 'data-size-h': '0.5', 'data-classes': 'm-box h150 col-lg-6 col-md-6 col-sm-6 col-xs-12 pl-pr', 'data-name': 'content'}
# | | | | | article[11]: {'class': ['content-nota', 'list-format', 'onexone_doble']}
# | | | | | | div {'class': ['mt']}
# | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | h2 {}
# | | | | | | | | 	 El incómodo momento de Alicia Kirchner cuando la increpó una funcionaria
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | 	 En Caleta Olivia
# | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | p {'class': ['section']}
# | | | | | | | | 	 Política
# | | | | | | div {'class': ['wrap-figure']}
# | | | | | | | div {'class': ['ico-tx-news', 'xs']}
# | | | | | | | | span {'class': ['content-ico']}
# | | | | | | | | | div {'class': ['ico']}
# | | | | | | | | | | div {'class': ['mdia', 'media-vid', 'onlyIcon']}
# | | | div {'class': ['m-box', 'adv', 'h1200', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p', 'size1x4'], 'data-size-w': '1', 'data-size-h': '4', 'data-classes': ' m-box adv h1200 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p size1x4', 'data-name': 'advert'}
# | | | | div {'class': ['box-adv']}
# | | | | | div {'id': 'div-gpt-ad-caja0', 'class': ['banner_center', 'ad-slot', 'ad-sticky'], 'data-adtype': 'caja'}
# | | | div {'class': ['h600', 'm-box', 'last-moment', 'm-box', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p'], 'data-size-w': '1', 'data-size-h': '2', 'data-classes': 'h600 m-box last-moment m-box col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p', 'data-name': 'lastmoment'}
# | | | | div {'class': ['last-moment'], 'xmlns': 'http://www.w3.org/1999/html', 'id': 'lmvmod_202271582272926'}
# | | | | | ul {'class': ['box-items']}
# | | | | | | li {'aria-label': '/politica/esteban-bullrich-cuestiono-interna-juntos-cambio-llevamos-meses-cascoteandonos-rancho-_0_opIgF9sv95.html', 'style': 'cursor: pointer;'}
# | | | | | | | | article[12]: {'class': ['flex-change']}
# | | | | | | | | | h2 {}
# | | | | | | | | | 	 Esteban Bullrich cuestionó la interna de Juntos por el Cambio: "Llevamos meses cascoteándonos el rancho"
# | | | | | | | | | span {}
# | | | | | | li {'aria-label': '/deportes/nba-facundo-campazzo-pudo-debutar-dallas-leandro-bolmaro-fugaz-estreno-utah_0_1gXdb6AxHx.html', 'style': 'cursor: pointer;'}
# | | | | | | | | article[13]: {'class': ['flex-change']}
# | | | | | | | | | h2 {}
# | | | | | | | | | 	 NBA: Facundo Campazzo no pudo debutar en Dallas y Leandro Bolmaro tuvo un fugaz estreno en Utah
# | | | | | | | | | span {}
# | | | | | | li {'aria-label': '/politica/juan-ignacio-mendiguren-martin-tetaz-tenso-cruce-television-podes-animal-resistis-reglas-_0_Dox3z22RVW.html', 'style': 'cursor: pointer;'}
# | | | | | | | | article[14]: {'class': ['flex-change']}
# | | | | | | | | | h2 {}
# | | | | | | | | | 	 Juan Ignacio de Mendiguren y Martín Tetaz, en un tenso cruce en televisión: "No podés ser tan animal" y "No resistís las reglas"
# | | | | | | | | | span {}
# | | | | | | li {'aria-label': '/politica/carlos-melconian-admitio-quiere-ministro-mauricio-macri-rodriguez-larreta-pongan-_0_w38PYAdZOS.html', 'style': 'cursor: pointer;'}
# | | | | | | | | article[15]: {'class': ['flex-change']}
# | | | | | | | | | h2 {}
# | | | | | | | | | 	 Carlos Melconian admitió que quiere ser ministro de Mauricio Macri o Rodríguez Larreta: "Donde me pongan, yo estoy"
# | | | | | | | | | span {}
# | | | | | | li {'aria-label': '/fama/santiago-moro-rechazo-gran-hermano-deba-rectificarse-gobierno-digan-participantes-corre-cuenta-_0_4iUAgOvaG0.html', 'style': 'cursor: pointer;'}
# | | | | | | | | article[16]: {'class': ['flex-change']}
# | | | | | | | | | h2 {}
# | | | | | | | | | 	 Santiago del Moro rechazó que Gran Hermano deba rectificarse ante el Gobierno: "Lo que digan los participantes corre por su cuenta"
# | | | | | | | | | span {}
# | | | | | | li {'aria-label': '/politica/-dejen-hacer-papelones-duro-cruce-diego-santilli-maria-eugenia-vidal-gabriela-cerruti-acusacion-gran-hermano_0_Ms9pa8f7Rs.html', 'style': 'cursor: pointer;'}
# | | | | | | | | article[17]: {'class': ['flex-change']}
# | | | | | | | | | h2 {}
# | | | | | | | | | 	 "Dejen de hacer papelones": duro cruce entre Diego Santilli, María Eugenia Vidal y Gabriela Cerruti por la acusación contra Gran Hermano
# | | | | | | | | | span {}
# | | | div {'class': ['m-box', 'child', 'h300', 'border', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p', 'data-name': 'content'}
# | | | | article[18]: {'class': ['onexone_foto_grey', 'content-nota', 'list-format']}
# | | | | | div {'class': ['mt']}
# | | | | | | div {'class': ['flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 Cuáles son las cuentas que ahora pagan 60% de interés sólo por tener saldo
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 Tasa anual
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | span {'class': ['paywall-ico']}
# | | | | | | | p {'class': ['author']}
# | | | | | | | 	 Martín Grosz
# | | | | | div {'class': ['wrap-figure']}
# | | | div {'class': ['m-box', 'adv', 'h300', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box adv h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p', 'data-name': 'advert'}
# | | | | div {'id': 'div-gpt-ad-caja1', 'class': ['banner_center', 'ad-slot', 'box-adv']}

# %%
# BY <section> -- <section>[8]
dumptreeul(sections[8].parent, '')
# Out:
# div {'class': ['container', 'father', 'no-p'], 'data-classes': 'container', 'data-type': 'container_father', 'data-name': 'container_father'}
# | div {'class': ['carcasaSkin']}
# | | div {'class': ['full', 'item-content', 'orange-section', 'back'], 'data-classes': 'full item-content orange-section back', 'data-name': 'separador', 'data-linkcontent': 'https://www.clarin.com/fama/'}
# | | | header[1]: {'class': ['separador-home']}
# | | | 	 <CRLF><CRLF><CRLF>FAMA<CRLF><CRLF>
# | | | | div {'class': ['content-separador']}
# | | | | | h2 {'class': ['heading']}
# | | | | | 	 FAMA
# | | section[5]: {'data-name': 'cont1A', 'class': ['container', 'no-p', 'listado'], 'data-classes': 'container no-p listado ', 'data-type': 'container'}
# | | | div {'class': ['count-first', 'bb-container', 'one-floor-A', 'bb-moduleId_1A_mod_202164244066916', 'orange-section', 'back'], 'data-classes': ' orange-section back', 'data-count': '4'}
# | | | | div {'class': ['m-box', 'h300', 'child', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p', 'list-format'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p list-format', 'data-name': 'content'}
# | | | | | article[38]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | | div {'class': ['mt']}
# | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | h2 {}
# | | | | | | | | 	 Al aire, Del Moro rechazó el pedido de retractación que le hizo el Gobierno a Gran Hermano
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | 	 Tras la acusación a Alberto F.
# | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | p {'class': ['section']}
# | | | | | | | | 	 Fama
# | | | | | | div {'class': ['wrap-figure']}
# | | | | | | | div {'class': ['ico-tx-news']}
# | | | | | | | | span {'class': ['content-ico', 'dsdsd']}
# | | | | | | | | | div {'class': ['ico']}
# | | | | | | | | | | div {'class': ['mdia', 'media-vid', 'onlyIcon']}
# | | | | div {'class': ['m-box', 'h300', 'child', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p', 'list-format'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p list-format', 'data-name': 'content'}
# | | | | | article[39]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | | div {'class': ['mt']}
# | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | h2 {}
# | | | | | | | | 	 Quiénes son los primeros cuatro nominados de Gran Hermano
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | 	 “Alfa”, entre ellos
# | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | p {'class': ['section']}
# | | | | | | | | 	 Fama
# | | | | | | div {'class': ['wrap-figure']}
# | | | | | | | div {'class': ['ico-tx-news']}
# | | | | | | | | span {'class': ['content-ico', 'dsdsd']}
# | | | | | | | | | div {'class': ['ico']}
# | | | | | | | | | | div {'class': ['mdia', 'media-ico-live']}
# | | | | div {'class': ['m-box', 'h300', 'child', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p', 'list-format'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p list-format', 'data-name': 'content'}
# | | | | | article[40]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | | div {'class': ['mt']}
# | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | h2 {}
# | | | | | | | | 	 Marianela Mirra reveló que es lo que no le gusta del nuevo Gran Hermano: “No lo veo más”
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | 	 Muy crítica
# | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | p {'class': ['section']}
# | | | | | | | |
# | | | | | | div {'class': ['wrap-figure']}
# | | | | div {'class': ['m-box', 'h300', 'child', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p', 'list-format'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p list-format', 'data-name': 'content'}
# | | | | | article[41]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | | div {'class': ['mt']}
# | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | h2 {}
# | | | | | | | | 	 Tamara Báez se mostró junto a su nuevo novio y aseguró que quiere tener un hijo
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | 	 ¿L-Gante? Cosa del pasado
# | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | p {'class': ['section']}
# | | | | | | | |
# | | | | | | div {'class': ['wrap-figure']}
# | div {'class': ['carcasaSkin']}
# | | div {'class': ['full', 'item-content', 'suscriptor-content', 'back'], 'data-classes': 'full item-content suscriptor-content back', 'data-name': 'separador', 'data-linkcontent': 'https://www.clarin.com/exclusivo-suscriptores/'}
# | | | header[2]: {'class': ['separador-home']}
# | | | 	 <CRLF><CRLF><CRLF>Exclusivo suscriptores<CRLF><CRLF>
# | | | | div {'class': ['content-separador']}
# | | | | | h2 {'class': ['heading']}
# | | | | | 	 Exclusivo suscriptores
# | | section[6]: {'data-name': 'cont2B', 'class': ['container', 'no-p', 'listado', 'suscriptor-content', 'back'], 'data-classes': 'container listado suscriptor-content back', 'data-type': 'container'}
# | | | div {'class': ['count-first', 'bb-container', 'two-floor', 'bb-moduleId_2B_mod_2021112110957595', 'suscriptor-content', 'back'], 'data-classes': 'suscriptor-content back', 'data-count': '8'}
# | | | | div {'class': ['suscribers-only', 'm-box', 'child', 'h600', 'col-lg-6', 'col-md-8', 'col-sm-12', 'col-xs-12', 'no-p', 'size2x2', 't-bottom', 't-left'], 'data-size-w': '2', 'data-size-h': '2', 'data-classes': 'suscribers-only child m-box h600 col-lg-6 col-md-8 col-sm-12 col-xs-12 size2x2 t-bottom t-left', 'data-name': 'content'}
# | | | | | article[42]: {'class': ['visual', 'bottom_degrade_large', 'content-nota', 'list-format', 'twoxtwo_visual', 't-bottom', 't-left']}
# | | | | | | div {'class': ['mt', 'title-top']}
# | | | | | | | div {'class': ['max-h']}
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | 	 Clarín en Helsinki
# | | | | | | | | h2 {}
# | | | | | | | | 	 Secretos de la educación en Finlandia: con pocas horas de clase, son los mejores
# | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | span {'class': ['paywall-ico']}
# | | | | | | | | p {'class': ['author']}
# | | | | | | | | 	 Irene Hartmann
# | | | | | | div {'class': ['wrap-img', 'title-top']}
# | | | | | | | div {'class': ['bg_picture_degree']}
# | | | | div {'class': ['m-box', 'child', 'h300', 'border', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p', 'data-name': 'content'}
# | | | | | article[43]: {'class': ['onexone_foto_grey', 'content-nota', 'list-format']}
# | | | | | | div {'class': ['mt']}
# | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | h2 {}
# | | | | | | | | 	 La incómoda vía libre del Gobierno con la promo de una gaseosa
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | 	 Figuritas del Mundial
# | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | span {'class': ['paywall-ico']}
# | | | | | | | | p {'class': ['author']}
# | | | | | | | | 	 Pablo Sigal
# | | | | | | div {'class': ['wrap-figure']}
# | | | | div {'class': ['m-box', 'h300', 'child', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p', 'list-format'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p list-format', 'data-name': 'content'}
# | | | | | article[44]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | | div {'class': ['mt']}
# | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | h2 {}
# | | | | | | | | 	 El bono ANSeS alcanzaría a un millón de personas que no tienen ayuda del Estado
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | 	 Similar al IFE
# | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | span {'class': ['paywall-ico']}
# | | | | | | | | p {'class': ['author']}
# | | | | | | | | 	 Ismael Bermúdez
# | | | | | | div {'class': ['wrap-figure']}
# | | | | div {'class': ['m-box', 'child', 'h300', 'border', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p', 'data-name': 'content'}
# | | | | | article[45]: {'class': ['onexone_foto_grey', 'content-nota', 'list-format']}
# | | | | | | div {'class': ['mt']}
# | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | h2 {}
# | | | | | | | | 	 Los problemas más comunes cuando los hijos emigran y los padres se quedan
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | 	 Cómo resolverlos a distancia
# | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | span {'class': ['paywall-ico']}
# | | | | | | | | p {'class': ['author']}
# | | | | | | | | 	 Silvana Saldisuri
# | | | | | | div {'class': ['wrap-figure']}
# | | | | div {'class': ['m-box', 'h300', 'child', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p', 'list-format'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p list-format', 'data-name': 'content'}
# | | | | | article[46]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | | div {'class': ['mt']}
# | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | h2 {}
# | | | | | | | | 	 Viajó al espacio y sintió una “tristeza abrumadora”: qué es el “efecto perspectiva”
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | 	 El actor de Star Trek
# | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | span {'class': ['paywall-ico']}
# | | | | | | | | p {'class': ['author']}
# | | | | | | | | 	 Marcelo Bellucci
# | | | | | | div {'class': ['wrap-figure']}
# | | div {'id': 'div-gpt-ad-horizontal2', 'class': ['banner_center', 'ad-slot', 'box-adv'], 'data-adtype': 'horizontal'}
# | div {'class': ['carcasaSkin']}
# | | div {'class': ['full', 'item-content', 'especial-clarin', 'back'], 'data-classes': 'full item-content especial-clarin back', 'data-name': 'separador', 'data-linkcontent': 'https://www.clarin.com/tema/especial-clarin.html'}
# | | | header[3]: {'class': ['separador-home']}
# | | | 	 <CRLF><CRLF><CRLF>ESPECIALES CLARÍN<CRLF><CRLF>
# | | | | div {'class': ['content-separador']}
# | | | | | h2 {'class': ['heading']}
# | | | | | 	 ESPECIALES CLARÍN
# | | section[7]: {'data-name': 'cont1A', 'class': ['container', 'no-p', 'listado'], 'data-classes': 'container no-p listado ', 'data-type': 'container'}
# | | | div {'class': ['count-first', 'bb-container', 'one-floor-A', 'bb-moduleId_1A_mod_202164530211374', 'especial-clarin', 'back'], 'data-classes': ' especial-clarin back', 'data-count': '4'}
# | | | | div {'class': ['m-box', 'h300', 'child', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p', 'list-format'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p list-format', 'data-name': 'content'}
# | | | | | article[47]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | | div {'class': ['mt']}
# | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | h2 {}
# | | | | | | | | 	 “Tenía que sobrevivir”: 50 años de la tragedia de los Andes
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | 	 Especial Clarín
# | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | p {'class': ['author']}
# | | | | | | | | 	 Gonzalo Sánchez
# | | | | | | div {'class': ['wrap-figure']}
# | | | | div {'class': ['m-box', 'h300', 'child', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p', 'list-format'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p list-format', 'data-name': 'content'}
# | | | | | article[48]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | | div {'class': ['mt']}
# | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | h2 {}
# | | | | | | | | 	 El Servicio Meteorológico cumple 150 años: 15 hitos que “rompieron el termómetro”
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | 	 Sociedad
# | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | span {'class': ['paywall-ico']}
# | | | | | | | | p {'class': ['author']}
# | | | | | | | | 	 Jazmín Bazán
# | | | | | | div {'class': ['wrap-figure']}
# | | | | div {'class': ['m-box', 'h300', 'child', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p', 'list-format'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p list-format', 'data-name': 'content'}
# | | | | | article[49]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | | div {'class': ['mt']}
# | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | h2 {}
# | | | | | | | | 	 Hablan las víctimas del terrorismo mapuche en Bariloche
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | 	 Villa Mascardi
# | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | span {'class': ['paywall-ico']}
# | | | | | | | | p {'class': ['author']}
# | | | | | | | | 	 Gonzalo Sánchez
# | | | | | | div {'class': ['wrap-figure']}
# | | | | div {'class': ['m-box', 'h300', 'child', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p', 'list-format'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p list-format', 'data-name': 'content'}
# | | | | | article[50]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | | div {'class': ['mt']}
# | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | h2 {}
# | | | | | | | | 	 La nueva tierra prometida: el país vecino que no para de atraer inversiones argentinas
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | 	 Sociedad
# | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | span {'class': ['paywall-ico']}
# | | | | | | | | p {'class': ['author']}
# | | | | | | | | 	 Penélope Canonico
# | | | | | | div {'class': ['wrap-figure']}
# | div {'class': ['full', 'item-content'], 'data-classes': 'full item-content ', 'data-name': 'separador', 'data-linkcontent': 'https://www.clarin.com/deportes/'}
# | | header[4]: {'class': ['separador-home']}
# | | 	 <CRLF><CRLF><CRLF>Deportes<CRLF><CRLF>
# | | | div {'class': ['content-separador']}
# | | | | h2 {'class': ['heading']}
# | | | | 	 Deportes
# | section[8]: {'data-name': 'cont2WB', 'class': ['container', 'no-p', 'listado'], 'data-classes': 'container listado ', 'data-type': 'container'}
# | | div {'class': ['count-first', 'bb-container', 'two-floor-banner', 'bb-moduleId_2WB_mod_202274767544974'], 'data-count': '8', 'data-classes': ''}
# | | | div {'class': ['border', 'box-large', 'col-lg-6', 'col-md-8', 'col-sm-12', 'col-xs-12', 'no-p', 'size2x2', 'twox_container', 'c-pad', 'special'], 'data-size-w': '2', 'data-size-h': '2', 'data-classes': 'border box-large col-lg-6 col-md-8 col-sm-12 col-xs-12 no-p size2x2 twox_container  special', 'data-name': 'container2x2'}
# | | | | div {'class': ['top-head']}
# | | | | | div {'class': ['count-first', 'row', 'bb-container', 'bb-moduleId_twoxtwo_mod_202285587665011'], 'data-count': '4'}
# | | | | | | div {'class': ['m-box', 'child', 'h300', 'col-xs-12', 'pl-pr'], 'data-classes': 'm-box child h300  col-xs-12 pl-pr', 'data-name': 'content', 'data-size-w': '2', 'data-size-h': '1'}
# | | | | | | | article[51]: {'class': ['visual', 'bottom_degrade', 'content-nota', 'twoxone_visual', 't-bottom', 't-left', 'list-format']}
# | | | | | | | | div {'class': ['mt', 'title-bottom']}
# | | | | | | | | | div {'class': ['max-h', 'flex-change']}
# | | | | | | | | | | h2 {}
# | | | | | | | | | | 	 Definición con clásicos cruzados: los antecedentes de una pelea a puro morbo
# | | | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | | | 	 Boca y Racing van por el título
# | | | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | | | p {'class': ['author']}
# | | | | | | | | | | 	 Oscar Barnade
# | | | | | | | | div {'class': ['wrap-img', 'title-bottom']}
# | | | | | | | | | div {'class': ['bg_picture_degree']}
# | | | | | | | | div {'class': ['bg_picture_degree']}
# | | | | | | div {'class': ['m-box', 'child', 'h300', 'col-sm-6', 'col-xs-12', 'pl-pr'], 'data-classes': 'm-box child h300 col-sm-6 col-xs-12 pl-pr ', 'data-name': 'content', 'data-size-w': '1', 'data-size-h': '1'}
# | | | | | | | article[52]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | | | | div {'class': ['mt']}
# | | | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | | | h2 {}
# | | | | | | | | | | 	 El milagro Huracán: qué necesita el tercero en discordia para ser campeón
# | | | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | | | 	 Visita a Patronato
# | | | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | | | p {'class': ['author']}
# | | | | | | | | | | 	 Martín Rubino
# | | | | | | | | div {'class': ['wrap-figure']}
# | | | | | | div {'class': ['m-box', 'child', 'h300', 'col-sm-6', 'col-xs-12', 'pl-pr'], 'data-classes': 'm-box child h300 col-sm-6 col-xs-12 pl-pr ', 'data-name': 'content', 'data-size-w': '1', 'data-size-h': '1'}
# | | | | | | | article[53]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | | | | div {'class': ['mt']}
# | | | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | | | h2 {}
# | | | | | | | | | | 	 El presidente del Atlético de Madrid habló de las dudas con De Paul tras el affaire con Tini
# | | | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | | | 	 Lo buscan de Italia
# | | | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | | | p {'class': ['section']}
# | | | | | | | | | | 	 Deportes
# | | | | | | | | div {'class': ['wrap-figure']}
# | | | div {'class': ['m-box', 'adv', 'h600', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p', 'size1x4'], 'data-size-w': '1', 'data-size-h': '2', 'data-classes': ' des-adv   m-box adv h600 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p size1x4', 'data-name': 'advert'}
# | | | | div {'id': 'div-gpt-ad-caja4', 'class': ['banner_center', 'ad-slot', 'box-adv']}
# | | | div {'class': ['m-box', 'child', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p', 'oleEnClarin'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p oleEnClarin ', 'data-name': 'content'}
# | | | | div {'class': ['mt', 'vtwoxone']}
# | | | | | div {'class': ['oleLogoContainer']}
# | | | | | ul {}
# | | | | | | li {'aria-label': '/fuera-de-juego/primer-muerto-futbol-argentino_0_XSgVaNWPdG.html', 'style': 'cursor: pointer;'}
# | | | | | | | article[54]: {'class': ['twoxone']}
# | | | | | | | | div {'class': ['mt']}
# | | | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | | | h2 {}
# | | | | | | | | | | 	 A 100 años del primer muerto en el fútbol argentino y la irrupción de las mortales balas policiales
# | | | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | | | 	 FUERA DE JUEGO
# | | | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | | | p {'class': ['author']}
# | | | | | | | | | | 	 DIARIO OLÉ
# | | | | | | | | div {'class': ['wrap-figure']}
# | | | | | | li {'aria-label': '/maradona/camiseta-diego-maradona-llego-argentina-final-mundial-mexico_0_2Vx1FLxJ5U.html', 'style': 'cursor: pointer;'}
# | | | | | | | article[55]: {'class': ['twoxone']}
# | | | | | | | | div {'class': ['mt']}
# | | | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | | | h2 {}
# | | | | | | | | | | 	 Ya está en la Argentina la camiseta que usó Maradona en la final de México '86
# | | | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | | | 	 MARADONA
# | | | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | | | p {'class': ['author']}
# | | | | | | | | | | 	 DIARIO OLÉ
# | | | | | | | | div {'class': ['wrap-figure']}
# | | | div {'class': ['m-box', 'child', 'h150', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p'], 'data-classes': 'm-box child h150 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p', 'data-size-w': '1', 'data-size-h': '0.5', 'data-name': 'content'}
# | | | | article[56]: {'class': ['content-nota', 'list-format', 'onexone_doble']}
# | | | | | div {'class': ['mt']}
# | | | | | | div {'class': ['flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 Apareció el nombre de Messi en el juicio a Neymar: qué dijo el ex representante
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 En España
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | p {'class': ['section']}
# | | | | | | | 	 Deportes
# | | | | | div {'class': ['wrap-figure']}
# | | | div {'class': ['m-box', 'child', 'h150', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p'], 'data-classes': 'm-box child h150 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p', 'data-size-w': '1', 'data-size-h': '0.5', 'data-name': 'content'}
# | | | | article[57]: {'class': ['content-nota', 'list-format', 'onexone_doble']}
# | | | | | div {'class': ['mt']}
# | | | | | | div {'class': ['flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 El argentino que “inventó” el yachting en Canadá y triunfa con su pasión
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 Federico Donzino
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | p {'class': ['author']}
# | | | | | | | 	 Luciana Aranguiz
# | | | | | div {'class': ['wrap-figure']}
# | | div {'id': 'div-gpt-ad-horizontal3', 'class': ['banner_center', 'ad-slot', 'box-adv'], 'data-adtype': 'horizontal'}
# | div {'class': ['carcasaSkin']}
# | | div {'class': ['full', 'item-content', 'grey-section', 'back'], 'data-classes': 'full item-content grey-section back', 'data-name': 'separador', 'data-linkcontent': 'https://www.clarin.com/economia/'}
# | | | header[5]: {'class': ['separador-home']}
# | | | 	 <CRLF><CRLF><CRLF>Economía y Servicios<CRLF><CRLF>
# | | | | div {'class': ['content-separador']}
# | | | | | h2 {'class': ['heading']}
# | | | | | 	 Economía y Servicios
# | | section[9]: {'data-name': 'cont2WB', 'class': ['container', 'no-p', 'listado', 'grey-section', 'back'], 'data-classes': 'container listado grey-section back', 'data-type': 'container'}
# | | | div {'class': ['count-first', 'bb-container', 'two-floor-banner', 'bb-moduleId_2WB_mod_202173729665159', 'grey-section', 'back'], 'data-count': '8', 'data-classes': 'grey-section back'}
# | | | | div {'class': ['border', 'box-large', 'col-lg-6', 'col-md-8', 'col-sm-12', 'col-xs-12', 'no-p', 'size2x2', 'twox_container', 'c-pad', 'special'], 'data-size-w': '2', 'data-size-h': '2', 'data-classes': 'border box-large col-lg-6 col-md-8 col-sm-12 col-xs-12 no-p size2x2 twox_container  special', 'data-name': 'container2x2'}
# | | | | | div {'class': ['top-head']}
# | | | | | | div {'class': ['count-first', 'row', 'bb-container', 'bb-moduleId_twoxtwo_mod_202173752603788'], 'data-count': '4'}
# | | | | | | | div {'class': ['m-box', 'child', 'h300', 'col-lg-12', 'col-md-12', 'col-sm-12', 'col-xs-12', 'pl-pr'], 'data-size-w': '2', 'data-size-h': '1', 'data-classes': 'm-box h300  child col-lg-12 col-md-12 col-sm-12 col-xs-12 pl-pr', 'data-name': 'content'}
# | | | | | | | | article[58]: {'class': ['content-nota', 'list-format', 'twoxone_no_foto']}
# | | | | | | | | | div {'class': ['mt']}
# | | | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | | | 	 Datos del INDEC
# | | | | | | | | | | h2 {}
# | | | | | | | | | | 	 Canasta Básica: una familia necesitó $ 128.214 en septiembre para no caer en la pobreza
# | | | | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | | | | p {'class': ['author']}
# | | | | | | | | | | | 	 Natalia Muscatelli
# | | | | | | | | | | p {'class': ['summary']}
# | | | | | | | | | | 	 El costo de la CBT subió 7,1% el último mes. En tanto, la CBA, que mide el umbral de indigencia, aumentó la misma cifra hasta los $56.732.
# | | | | | | | | ul {'class': ['content-related']}
# | | | | | | | div {'class': ['m-box', 'child', 'h300', 'col-sm-6', 'col-xs-12', 'pl-pr'], 'data-classes': 'm-box child h300 col-sm-6 col-xs-12 pl-pr ', 'data-name': 'content', 'data-size-w': '1', 'data-size-h': '1'}
# | | | | | | | | article[59]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | | | | | div {'class': ['mt']}
# | | | | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | | | | h2 {}
# | | | | | | | | | | | 	 Puso en subasta una tonelada de monedas pero luego se echó para atrás
# | | | | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | | | | 	 “Blooper” del Banco Central
# | | | | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | | | | p {'class': ['section']}
# | | | | | | | | | | | 	 Economía
# | | | | | | | | | div {'class': ['wrap-figure']}
# | | | | | | | div {'class': ['m-box', 'child', 'h300', 'col-sm-6', 'col-xs-12', 'pl-pr'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-sm-6 col-xs-12 pl-pr', 'data-name': 'content'}
# | | | | | | | | article[60]: {'class': ['onexone_foto_grey', 'content-nota', 'list-format']}
# | | | | | | | | | div {'class': ['mt']}
# | | | | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | | | | h2 {}
# | | | | | | | | | | | 	 Estiman que la inflación de octubre superará el 6%: qué es lo que impulsa la suba
# | | | | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | | | | 	 Precios sin freno
# | | | | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | | | | span {'class': ['paywall-ico']}
# | | | | | | | | | | | p {'class': ['author']}
# | | | | | | | | | | | 	 Soledad Navarro
# | | | | | | | | | div {'class': ['wrap-figure']}
# | | | | div {'class': ['m-box', 'adv', 'h600', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p', 'size1x4'], 'data-size-w': '1', 'data-size-h': '2', 'data-classes': ' des-adv   m-box adv h600 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p size1x4', 'data-name': 'advert'}
# | | | | | div {'id': 'div-gpt-ad-caja5', 'class': ['banner_center', 'ad-slot', 'box-adv']}
# | | | | div {'class': ['m-box', 'h300', 'child', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p', 'list-format'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p list-format', 'data-name': 'content'}
# | | | | | article[61]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | | div {'class': ['mt']}
# | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | h2 {}
# | | | | | | | | 	 Las empresas evalúan pagar un bono en dólares al personal
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | 	 Dólar tecno
# | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | p {'class': ['author']}
# | | | | | | | | 	 Juan Manuel Barca
# | | | | | | div {'class': ['wrap-figure']}
# | | | | div {'class': ['m-box', 'child', 'h150', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p'], 'data-classes': 'm-box child h150 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p', 'data-size-w': '1', 'data-size-h': '0.5', 'data-name': 'content'}
# | | | | | article[62]: {'class': ['content-nota', 'list-format', 'onexone_doble']}
# | | | | | | div {'class': ['mt']}
# | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | h2 {}
# | | | | | | | | 	 Nuevo Ahora 30: qué se podrá comprar, cuándo empieza y cuál será la tasa
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | 	 Rubro por rubro
# | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | p {'class': ['section']}
# | | | | | | | | 	 Economía
# | | | | | | div {'class': ['wrap-figure']}
# | | | | div {'class': ['m-box', 'child', 'h150', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p'], 'data-classes': 'm-box child h150 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p', 'data-size-w': '1', 'data-size-h': '0.5', 'data-name': 'content'}
# | | | | | article[63]: {'class': ['content-nota', 'list-format', 'onexone_doble']}
# | | | | | | div {'class': ['mt']}
# | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | h2 {}
# | | | | | | | | 	 Tienda Nube sale a competir en el segmento de medios de pagos
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | 	 Inversión
# | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | p {'class': ['author']}
# | | | | | | | | 	 Ana Clara Pedotti
# | | | | | | div {'class': ['wrap-figure']}
# | | div {'id': 'div-gpt-ad-horizontal4', 'class': ['banner_center', 'ad-slot', 'box-adv'], 'data-adtype': 'horizontal'}
# | div {'class': ['carcasaSkin']}
# | | div {'class': ['full', 'item-content'], 'data-classes': 'full item-content ', 'data-name': 'separador', 'data-linkcontent': ''}
# | | | header[6]: {'class': ['separador-home']}
# | | | 	 <CRLF><CRLF><CRLF>Estilo<CRLF><CRLF>
# | | | | div {'class': ['content-separador']}
# | | | | | h2 {'class': ['heading']}
# | | | | | 	 Estilo
# | | section[10]: {'data-name': 'cont2WB', 'class': ['container', 'no-p', 'listado'], 'data-classes': 'container listado ', 'data-type': 'container'}
# | | | div {'class': ['count-first', 'bb-container', 'two-floor-banner', 'bb-moduleId_2WB_mod_201756636671203'], 'data-count': '8', 'data-classes': ''}
# | | | | div {'class': ['border', 'box-large', 'col-lg-6', 'col-md-8', 'col-sm-12', 'col-xs-12', 'no-p', 'size2x2', 'twox_container', 'c-pad', 'special'], 'data-size-w': '2', 'data-size-h': '2', 'data-classes': 'border box-large col-lg-6 col-md-8 col-sm-12 col-xs-12 no-p size2x2 twox_container  special', 'data-name': 'container2x2'}
# | | | | | div {'class': ['top-head']}
# | | | | | | div {'class': ['count-first', 'row', 'bb-container', 'bb-moduleId_twoxtwo_mod_202202321550045'], 'data-count': '4'}
# | | | | | | | div {'class': ['m-box', 'child', 'h300', 'col-xs-12', 'pl-pr'], 'data-classes': 'm-box child h300  col-xs-12 pl-pr', 'data-name': 'content', 'data-size-w': '2', 'data-size-h': '1'}
# | | | | | | | | article[64]: {'class': ['visual', 'bottom_degrade', 'content-nota', 'twoxone_visual', 't-top', 't-left', 'list-format']}
# | | | | | | | | | div {'class': ['mt', 'title-bottom']}
# | | | | | | | | | | div {'class': ['max-h', 'flex-change']}
# | | | | | | | | | | | h2 {}
# | | | | | | | | | | | 	 De una limusina a un Hummer, cómo es el millonario garaje de L-Gante
# | | | | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | | | | 	 Fanático de las cuatro ruedas
# | | | | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | | | | p {'class': ['section']}
# | | | | | | | | | | | 	 Autos
# | | | | | | | | | div {'class': ['wrap-img', 'title-bottom']}
# | | | | | | | | | | div {'class': ['ico-tx-news']}
# | | | | | | | | | | | span {'class': ['content-ico', 'dsdsd']}
# | | | | | | | | | | | | div {'class': ['ico']}
# | | | | | | | | | | | | | div {'class': ['mdia', 'media-vid', 'onlyIcon']}
# | | | | | | | | | | div {'class': ['bg_picture_degree']}
# | | | | | | | | | div {'class': ['bg_picture_degree']}
# | | | | | | | div {'class': ['m-box', 'child', 'h300', 'col-sm-6', 'col-xs-12', 'pl-pr'], 'data-classes': 'm-box child h300 col-sm-6 col-xs-12 pl-pr ', 'data-name': 'content', 'data-size-w': '1', 'data-size-h': '1'}
# | | | | | | | | article[65]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | | | | | div {'class': ['mt']}
# | | | | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | | | | h2 {}
# | | | | | | | | | | | 	 Netflix anunció que eliminará la función que cobraba un extra por compartir la cuenta
# | | | | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | | | | 	 Habrá cambios en 2023
# | | | | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | | | | p {'class': ['section']}
# | | | | | | | | | | | 	 Tecnología
# | | | | | | | | | div {'class': ['wrap-figure']}
# | | | | | | | div {'class': ['m-box', 'child', 'h300', 'col-sm-6', 'col-xs-12', 'pl-pr'], 'data-classes': 'm-box child h300 col-sm-6 col-xs-12 pl-pr ', 'data-name': 'content', 'data-size-w': '1', 'data-size-h': '1'}
# | | | | | | | | article[66]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | | | | | div {'class': ['mt']}
# | | | | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | | | | h2 {}
# | | | | | | | | | | | 	 Cómo bloquear mensajes de texto molestos en cualquier teléfono celular
# | | | | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | | | | 	 Paso a paso
# | | | | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | | | | p {'class': ['section']}
# | | | | | | | | | | | 	 Tecnología
# | | | | | | | | | div {'class': ['wrap-figure']}
# | | | | div {'class': ['m-box', 'adv', 'h600', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p', 'size1x4'], 'data-size-w': '1', 'data-size-h': '2', 'data-classes': ' des-adv   m-box adv h600 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p size1x4', 'data-name': 'advert'}
# | | | | | div {'id': 'div-gpt-ad-caja7', 'class': ['banner_center', 'ad-slot', 'box-adv']}
# | | | | div {'class': ['m-box', 'h300', 'child', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p', 'list-format'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p list-format', 'data-name': 'content'}
# | | | | | article[67]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | | div {'class': ['mt']}
# | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | h2 {}
# | | | | | | | | 	 Día del Gin Tonic: cómo preparar la receta clásica y otras 6 versiones
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | 	 Un clásico
# | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | p {'class': ['section']}
# | | | | | | | | 	 Gourmet
# | | | | | | div {'class': ['wrap-figure']}
# | | | | div {'class': ['m-box', 'child', 'h150', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p'], 'data-classes': 'm-box child h150 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p', 'data-size-w': '1', 'data-size-h': '0.5', 'data-name': 'content'}
# | | | | | article[68]: {'class': ['content-nota', 'list-format', 'onexone_doble']}
# | | | | | | div {'class': ['mt']}
# | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | h2 {}
# | | | | | | | | 	 Una noche diferente: hoteles en vagones y estaciones de tren
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | 	 Propuestas
# | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | p {'class': ['author']}
# | | | | | | | | 	 Gabriel Silveira
# | | | | | | div {'class': ['wrap-figure']}
# | | | | div {'class': ['m-box', 'child', 'h150', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p'], 'data-classes': 'm-box child h150 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p', 'data-size-w': '1', 'data-size-h': '0.5', 'data-name': 'content'}
# | | | | | article[69]: {'class': ['content-nota', 'list-format', 'onexone_doble']}
# | | | | | | div {'class': ['mt']}
# | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | h2 {}
# | | | | | | | | 	 Una playa nudista en Mar del Plata, la preferida de las parejas
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | 	 La Escondida
# | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | p {'class': ['section']}
# | | | | | | | | 	 Relaciones
# | | | | | | div {'class': ['wrap-figure']}

# %%
# BY <section> -- <section>[9]
dumptreeul(sections[9].parent, '')
# Out:
# div {'class': ['carcasaSkin']}
# | div {'class': ['full', 'item-content', 'grey-section', 'back'], 'data-classes': 'full item-content grey-section back', 'data-name': 'separador', 'data-linkcontent': 'https://www.clarin.com/economia/'}
# | | header[5]: {'class': ['separador-home']}
# | | 	 <CRLF><CRLF><CRLF>Economía y Servicios<CRLF><CRLF>
# | | | div {'class': ['content-separador']}
# | | | | h2 {'class': ['heading']}
# | | | | 	 Economía y Servicios
# | section[9]: {'data-name': 'cont2WB', 'class': ['container', 'no-p', 'listado', 'grey-section', 'back'], 'data-classes': 'container listado grey-section back', 'data-type': 'container'}
# | | div {'class': ['count-first', 'bb-container', 'two-floor-banner', 'bb-moduleId_2WB_mod_202173729665159', 'grey-section', 'back'], 'data-count': '8', 'data-classes': 'grey-section back'}
# | | | div {'class': ['border', 'box-large', 'col-lg-6', 'col-md-8', 'col-sm-12', 'col-xs-12', 'no-p', 'size2x2', 'twox_container', 'c-pad', 'special'], 'data-size-w': '2', 'data-size-h': '2', 'data-classes': 'border box-large col-lg-6 col-md-8 col-sm-12 col-xs-12 no-p size2x2 twox_container  special', 'data-name': 'container2x2'}
# | | | | div {'class': ['top-head']}
# | | | | | div {'class': ['count-first', 'row', 'bb-container', 'bb-moduleId_twoxtwo_mod_202173752603788'], 'data-count': '4'}
# | | | | | | div {'class': ['m-box', 'child', 'h300', 'col-lg-12', 'col-md-12', 'col-sm-12', 'col-xs-12', 'pl-pr'], 'data-size-w': '2', 'data-size-h': '1', 'data-classes': 'm-box h300  child col-lg-12 col-md-12 col-sm-12 col-xs-12 pl-pr', 'data-name': 'content'}
# | | | | | | | article[58]: {'class': ['content-nota', 'list-format', 'twoxone_no_foto']}
# | | | | | | | | div {'class': ['mt']}
# | | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | | 	 Datos del INDEC
# | | | | | | | | | h2 {}
# | | | | | | | | | 	 Canasta Básica: una familia necesitó $ 128.214 en septiembre para no caer en la pobreza
# | | | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | | | p {'class': ['author']}
# | | | | | | | | | | 	 Natalia Muscatelli
# | | | | | | | | | p {'class': ['summary']}
# | | | | | | | | | 	 El costo de la CBT subió 7,1% el último mes. En tanto, la CBA, que mide el umbral de indigencia, aumentó la misma cifra hasta los $56.732.
# | | | | | | | ul {'class': ['content-related']}
# | | | | | | div {'class': ['m-box', 'child', 'h300', 'col-sm-6', 'col-xs-12', 'pl-pr'], 'data-classes': 'm-box child h300 col-sm-6 col-xs-12 pl-pr ', 'data-name': 'content', 'data-size-w': '1', 'data-size-h': '1'}
# | | | | | | | article[59]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | | | | div {'class': ['mt']}
# | | | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | | | h2 {}
# | | | | | | | | | | 	 Puso en subasta una tonelada de monedas pero luego se echó para atrás
# | | | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | | | 	 “Blooper” del Banco Central
# | | | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | | | p {'class': ['section']}
# | | | | | | | | | | 	 Economía
# | | | | | | | | div {'class': ['wrap-figure']}
# | | | | | | div {'class': ['m-box', 'child', 'h300', 'col-sm-6', 'col-xs-12', 'pl-pr'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-sm-6 col-xs-12 pl-pr', 'data-name': 'content'}
# | | | | | | | article[60]: {'class': ['onexone_foto_grey', 'content-nota', 'list-format']}
# | | | | | | | | div {'class': ['mt']}
# | | | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | | | h2 {}
# | | | | | | | | | | 	 Estiman que la inflación de octubre superará el 6%: qué es lo que impulsa la suba
# | | | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | | | 	 Precios sin freno
# | | | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | | | span {'class': ['paywall-ico']}
# | | | | | | | | | | p {'class': ['author']}
# | | | | | | | | | | 	 Soledad Navarro
# | | | | | | | | div {'class': ['wrap-figure']}
# | | | div {'class': ['m-box', 'adv', 'h600', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p', 'size1x4'], 'data-size-w': '1', 'data-size-h': '2', 'data-classes': ' des-adv   m-box adv h600 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p size1x4', 'data-name': 'advert'}
# | | | | div {'id': 'div-gpt-ad-caja5', 'class': ['banner_center', 'ad-slot', 'box-adv']}
# | | | div {'class': ['m-box', 'h300', 'child', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p', 'list-format'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p list-format', 'data-name': 'content'}
# | | | | article[61]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | div {'class': ['mt']}
# | | | | | | div {'class': ['flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 Las empresas evalúan pagar un bono en dólares al personal
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 Dólar tecno
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | p {'class': ['author']}
# | | | | | | | 	 Juan Manuel Barca
# | | | | | div {'class': ['wrap-figure']}
# | | | div {'class': ['m-box', 'child', 'h150', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p'], 'data-classes': 'm-box child h150 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p', 'data-size-w': '1', 'data-size-h': '0.5', 'data-name': 'content'}
# | | | | article[62]: {'class': ['content-nota', 'list-format', 'onexone_doble']}
# | | | | | div {'class': ['mt']}
# | | | | | | div {'class': ['flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 Nuevo Ahora 30: qué se podrá comprar, cuándo empieza y cuál será la tasa
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 Rubro por rubro
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | p {'class': ['section']}
# | | | | | | | 	 Economía
# | | | | | div {'class': ['wrap-figure']}
# | | | div {'class': ['m-box', 'child', 'h150', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p'], 'data-classes': 'm-box child h150 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p', 'data-size-w': '1', 'data-size-h': '0.5', 'data-name': 'content'}
# | | | | article[63]: {'class': ['content-nota', 'list-format', 'onexone_doble']}
# | | | | | div {'class': ['mt']}
# | | | | | | div {'class': ['flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 Tienda Nube sale a competir en el segmento de medios de pagos
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 Inversión
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | p {'class': ['author']}
# | | | | | | | 	 Ana Clara Pedotti
# | | | | | div {'class': ['wrap-figure']}

# %%
# BY <section> -- <section>[10]
dumptreeul(sections[10].parent, '')
# Out:
# div {'class': ['carcasaSkin']}
# | div {'class': ['full', 'item-content'], 'data-classes': 'full item-content ', 'data-name': 'separador', 'data-linkcontent': ''}
# | | header[6]: {'class': ['separador-home']}
# | | 	 <CRLF><CRLF><CRLF>Estilo<CRLF><CRLF>
# | | | div {'class': ['content-separador']}
# | | | | h2 {'class': ['heading']}
# | | | | 	 Estilo
# | section[10]: {'data-name': 'cont2WB', 'class': ['container', 'no-p', 'listado'], 'data-classes': 'container listado ', 'data-type': 'container'}
# | | div {'class': ['count-first', 'bb-container', 'two-floor-banner', 'bb-moduleId_2WB_mod_201756636671203'], 'data-count': '8', 'data-classes': ''}
# | | | div {'class': ['border', 'box-large', 'col-lg-6', 'col-md-8', 'col-sm-12', 'col-xs-12', 'no-p', 'size2x2', 'twox_container', 'c-pad', 'special'], 'data-size-w': '2', 'data-size-h': '2', 'data-classes': 'border box-large col-lg-6 col-md-8 col-sm-12 col-xs-12 no-p size2x2 twox_container  special', 'data-name': 'container2x2'}
# | | | | div {'class': ['top-head']}
# | | | | | div {'class': ['count-first', 'row', 'bb-container', 'bb-moduleId_twoxtwo_mod_202202321550045'], 'data-count': '4'}
# | | | | | | div {'class': ['m-box', 'child', 'h300', 'col-xs-12', 'pl-pr'], 'data-classes': 'm-box child h300  col-xs-12 pl-pr', 'data-name': 'content', 'data-size-w': '2', 'data-size-h': '1'}
# | | | | | | | article[64]: {'class': ['visual', 'bottom_degrade', 'content-nota', 'twoxone_visual', 't-top', 't-left', 'list-format']}
# | | | | | | | | div {'class': ['mt', 'title-bottom']}
# | | | | | | | | | div {'class': ['max-h', 'flex-change']}
# | | | | | | | | | | h2 {}
# | | | | | | | | | | 	 De una limusina a un Hummer, cómo es el millonario garaje de L-Gante
# | | | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | | | 	 Fanático de las cuatro ruedas
# | | | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | | | p {'class': ['section']}
# | | | | | | | | | | 	 Autos
# | | | | | | | | div {'class': ['wrap-img', 'title-bottom']}
# | | | | | | | | | div {'class': ['ico-tx-news']}
# | | | | | | | | | | span {'class': ['content-ico', 'dsdsd']}
# | | | | | | | | | | | div {'class': ['ico']}
# | | | | | | | | | | | | div {'class': ['mdia', 'media-vid', 'onlyIcon']}
# | | | | | | | | | div {'class': ['bg_picture_degree']}
# | | | | | | | | div {'class': ['bg_picture_degree']}
# | | | | | | div {'class': ['m-box', 'child', 'h300', 'col-sm-6', 'col-xs-12', 'pl-pr'], 'data-classes': 'm-box child h300 col-sm-6 col-xs-12 pl-pr ', 'data-name': 'content', 'data-size-w': '1', 'data-size-h': '1'}
# | | | | | | | article[65]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | | | | div {'class': ['mt']}
# | | | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | | | h2 {}
# | | | | | | | | | | 	 Netflix anunció que eliminará la función que cobraba un extra por compartir la cuenta
# | | | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | | | 	 Habrá cambios en 2023
# | | | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | | | p {'class': ['section']}
# | | | | | | | | | | 	 Tecnología
# | | | | | | | | div {'class': ['wrap-figure']}
# | | | | | | div {'class': ['m-box', 'child', 'h300', 'col-sm-6', 'col-xs-12', 'pl-pr'], 'data-classes': 'm-box child h300 col-sm-6 col-xs-12 pl-pr ', 'data-name': 'content', 'data-size-w': '1', 'data-size-h': '1'}
# | | | | | | | article[66]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | | | | div {'class': ['mt']}
# | | | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | | | h2 {}
# | | | | | | | | | | 	 Cómo bloquear mensajes de texto molestos en cualquier teléfono celular
# | | | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | | | 	 Paso a paso
# | | | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | | | p {'class': ['section']}
# | | | | | | | | | | 	 Tecnología
# | | | | | | | | div {'class': ['wrap-figure']}
# | | | div {'class': ['m-box', 'adv', 'h600', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p', 'size1x4'], 'data-size-w': '1', 'data-size-h': '2', 'data-classes': ' des-adv   m-box adv h600 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p size1x4', 'data-name': 'advert'}
# | | | | div {'id': 'div-gpt-ad-caja7', 'class': ['banner_center', 'ad-slot', 'box-adv']}
# | | | div {'class': ['m-box', 'h300', 'child', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p', 'list-format'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p list-format', 'data-name': 'content'}
# | | | | article[67]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | div {'class': ['mt']}
# | | | | | | div {'class': ['flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 Día del Gin Tonic: cómo preparar la receta clásica y otras 6 versiones
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 Un clásico
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | p {'class': ['section']}
# | | | | | | | 	 Gourmet
# | | | | | div {'class': ['wrap-figure']}
# | | | div {'class': ['m-box', 'child', 'h150', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p'], 'data-classes': 'm-box child h150 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p', 'data-size-w': '1', 'data-size-h': '0.5', 'data-name': 'content'}
# | | | | article[68]: {'class': ['content-nota', 'list-format', 'onexone_doble']}
# | | | | | div {'class': ['mt']}
# | | | | | | div {'class': ['flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 Una noche diferente: hoteles en vagones y estaciones de tren
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 Propuestas
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | p {'class': ['author']}
# | | | | | | | 	 Gabriel Silveira
# | | | | | div {'class': ['wrap-figure']}
# | | | div {'class': ['m-box', 'child', 'h150', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p'], 'data-classes': 'm-box child h150 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p', 'data-size-w': '1', 'data-size-h': '0.5', 'data-name': 'content'}
# | | | | article[69]: {'class': ['content-nota', 'list-format', 'onexone_doble']}
# | | | | | div {'class': ['mt']}
# | | | | | | div {'class': ['flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 Una playa nudista en Mar del Plata, la preferida de las parejas
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 La Escondida
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | p {'class': ['section']}
# | | | | | | | 	 Relaciones
# | | | | | div {'class': ['wrap-figure']}

# %%
# BY <section> -- <section>[11]
dumptreeul(sections[11].parent, '')
# Out:
# div {'class': ['carcasaSkin']}
# | div {'class': ['full', 'item-content'], 'data-classes': 'full item-content ', 'data-name': 'separador', 'data-linkcontent': ''}
# | | header[7]: {'class': ['separador-home']}
# | | 	 <CRLF><CRLF><CRLF>Clic<CRLF><CRLF>
# | | | div {'class': ['content-separador']}
# | | | | h2 {'class': ['heading']}
# | | | | 	 Clic
# | section[11]: {'data-name': 'cont2WB', 'class': ['container', 'no-p', 'listado'], 'data-classes': 'container listado ', 'data-type': 'container'}
# | | div {'class': ['count-first', 'bb-container', 'two-floor-banner', 'bb-moduleId_2WB_mod_202164463708654'], 'data-count': '8', 'data-classes': ''}
# | | | div {'class': ['border', 'box-large', 'col-lg-6', 'col-md-8', 'col-sm-12', 'col-xs-12', 'no-p', 'size2x2', 'twox_container', 'c-pad', 'special'], 'data-size-w': '2', 'data-size-h': '2', 'data-classes': 'border box-large col-lg-6 col-md-8 col-sm-12 col-xs-12 no-p size2x2 twox_container  special', 'data-name': 'container2x2'}
# | | | | div {'class': ['top-head']}
# | | | | | div {'class': ['count-first', 'row', 'bb-container', 'bb-moduleId_twoxtwo_mod_202164470166150'], 'data-count': '4'}
# | | | | | | div {'class': ['m-box', 'child', 'h300', 'col-xs-12', 'pl-pr'], 'data-classes': 'm-box child h300  col-xs-12 pl-pr', 'data-name': 'content', 'data-size-w': '2', 'data-size-h': '1'}
# | | | | | | | article[70]: {'class': ['visual', 'bottom_degrade', 'content-nota', 'twoxone_visual', 't-bottom', 't-left', 'list-format']}
# | | | | | | | | div {'class': ['mt', 'title-top']}
# | | | | | | | | | div {'class': ['max-h', 'flex-change']}
# | | | | | | | | | | h2 {}
# | | | | | | | | | | 	 Exhiben un modelo hiperrealista de Jesucristo con todas sus heridas
# | | | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | | | 	 Tiene cabello humano
# | | | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | | | p {'class': ['section']}
# | | | | | | | | | | 	 Viste
# | | | | | | | | div {'class': ['wrap-img', 'title-top']}
# | | | | | | | | | div {'class': ['bg_picture_degree']}
# | | | | | | | | div {'class': ['bg_picture_degree']}
# | | | | | | div {'class': ['m-box', 'child', 'h300', 'col-sm-6', 'col-xs-12', 'pl-pr'], 'data-classes': 'm-box child h300 col-sm-6 col-xs-12 pl-pr ', 'data-name': 'content', 'data-size-w': '1', 'data-size-h': '1'}
# | | | | | | | article[71]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | | | | div {'class': ['mt']}
# | | | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | | | h2 {}
# | | | | | | | | | | 	 Un bebé escapó de su casa y dos perros le salvaron la vida
# | | | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | | | 	 Quedó grabado
# | | | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | | | p {'class': ['section']}
# | | | | | | | | | | 	 Viste
# | | | | | | | | div {'class': ['wrap-figure']}
# | | | | | | div {'class': ['m-box', 'child', 'h300', 'col-sm-6', 'col-xs-12', 'pl-pr'], 'data-classes': 'm-box child h300 col-sm-6 col-xs-12 pl-pr ', 'data-name': 'content', 'data-size-w': '1', 'data-size-h': '1'}
# | | | | | | | article[72]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | | | | div {'class': ['mt']}
# | | | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | | | h2 {}
# | | | | | | | | | | 	 Tremenda lucha cuerpo a cuerpo entre un oso grizzly y dos estudiantes
# | | | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | | | 	 Mutilados, pero vivos
# | | | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | | | p {'class': ['section']}
# | | | | | | | | | | 	 Internacional
# | | | | | | | | div {'class': ['wrap-figure']}
# | | | div {'class': ['m-box', 'adv', 'h600', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p', 'size1x4'], 'data-size-w': '1', 'data-size-h': '2', 'data-classes': ' des-adv   m-box adv h600 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p size1x4', 'data-name': 'advert'}
# | | | | div {'id': 'div-gpt-ad-caja8', 'class': ['banner_center', 'ad-slot', 'box-adv']}
# | | | div {'class': ['m-box', 'h300', 'child', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p', 'list-format'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p list-format', 'data-name': 'content'}
# | | | | article[73]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | div {'class': ['mt']}
# | | | | | | div {'class': ['flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 La actriz de She-Hulk habla del final de la serie y de los pros y contras de Marvel
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 Entrevista a Tatiana Maslany
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | p {'class': ['author']}
# | | | | | | | 	 Marcelo Fernández Bitar
# | | | | | div {'class': ['wrap-figure']}
# | | | | | | div {'class': ['ico-tx-news']}
# | | | | | | | span {'class': ['content-ico', 'dsdsd']}
# | | | | | | | | div {'class': ['ico']}
# | | | | | | | | | div {'class': ['mdia', 'media-vid', 'onlyIcon']}
# | | | div {'class': ['m-box', 'child', 'h150', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p'], 'data-classes': 'm-box child h150 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p', 'data-size-w': '1', 'data-size-h': '0.5', 'data-name': 'content'}
# | | | | article[74]: {'class': ['content-nota', 'list-format', 'onexone_doble']}
# | | | | | div {'class': ['mt']}
# | | | | | | div {'class': ['flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 Un mago murió en plena actuación y la gente creyó que era un truco
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 En España
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | p {'class': ['section']}
# | | | | | | | 	 Viste
# | | | | | div {'class': ['wrap-figure']}
# | | | div {'class': ['m-box', 'child', 'h150', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p'], 'data-classes': 'm-box child h150 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p', 'data-size-w': '1', 'data-size-h': '0.5', 'data-name': 'content'}
# | | | | article[75]: {'class': ['content-nota', 'list-format', 'onexone_doble']}
# | | | | | div {'class': ['mt']}
# | | | | | | div {'class': ['flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 Cómo sos según tu signo lunar
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 Carta natal
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | p {'class': ['author']}
# | | | | | | | 	 Beatriz Leveratto
# | | | | | div {'class': ['wrap-figure']}

# %%
# BY <section> -- <section>[12]
dumptreeul(sections[12].parent, '')
# Out:
# div {'class': ['carcasaSkin']}
# | div {'class': ['full', 'item-content'], 'data-classes': 'full item-content ', 'data-name': 'separador', 'data-linkcontent': 'https://www.youtube.com/c/clarincom'}
# | | header[8]: {'class': ['separador-home']}
# | | 	 <CRLF><CRLF><CRLF>Video <CRLF><CRLF>
# | | | div {'class': ['content-separador']}
# | | | | h2 {'class': ['heading']}
# | | | | 	 Video
# | section[12]: {'data-name': 'cont1C', 'class': ['container', 'no-p', 'listado'], 'data-classes': 'container no-p listado ', 'data-type': 'container'}
# | | div {'class': ['count-first', 'bb-container', 'one-floor-C', 'bb-moduleId_1C_mod_201754205720610'], 'data-classes': ' ', 'data-count': '4'}
# | | | div {'class': ['m-box', 'child', 'h300', 'border', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p', 'data-name': 'content'}
# | | | | article[76]: {'class': ['onexone_foto_grey', 'content-nota', 'list-format']}
# | | | | | div {'class': ['mt']}
# | | | | | | div {'class': ['flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 Las predicciones para Argentina
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 Qatar 2022
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | p {'class': ['section']}
# | | | | | | | 	 deportes
# | | | | | div {'class': ['wrap-figure']}
# | | | | | | div {'class': ['ico-tx-news']}
# | | | | | | | div {'class': ['ico']}
# | | | | | | | | div {'class': ['mdia', 'media-vid', 'onlyIcon']}
# | | | div {'class': ['m-box', 'child', 'h300', 'border', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p', 'data-name': 'content'}
# | | | | article[77]: {'class': ['onexone_foto_grey', 'content-nota', 'list-format']}
# | | | | | div {'class': ['mt']}
# | | | | | | div {'class': ['flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 El asesino serial “que no mató a nadie”
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 Magnus Mefisto
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | p {'class': ['section']}
# | | | | | | | 	 Política
# | | | | | div {'class': ['wrap-figure']}
# | | | | | | div {'class': ['ico-tx-news']}
# | | | | | | | div {'class': ['ico']}
# | | | | | | | | div {'class': ['mdia', 'media-vid', 'onlyIcon']}
# | | | div {'class': ['m-box', 'child', 'h300', 'border', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p', 'data-name': 'content'}
# | | | | article[78]: {'class': ['onexone_foto_grey', 'content-nota', 'list-format']}
# | | | | | div {'class': ['mt']}
# | | | | | | div {'class': ['flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 A días del Mundial más esperado para los argentinos
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 Qatar 2022
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | p {'class': ['section']}
# | | | | | | | 	 Deportes
# | | | | | div {'class': ['wrap-figure']}
# | | | | | | div {'class': ['ico-tx-news']}
# | | | | | | | div {'class': ['ico']}
# | | | | | | | | div {'class': ['mdia', 'media-vid', 'onlyIcon']}
# | | | div {'class': ['m-box', 'child', 'h300', 'border', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p', 'data-name': 'content'}
# | | | | article[79]: {'class': ['onexone_foto_grey', 'content-nota', 'list-format']}
# | | | | | div {'class': ['mt']}
# | | | | | | div {'class': ['flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 Su origen y secretos
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 Fiesta Nacional en Mercedes
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | p {'class': ['section']}
# | | | | | | | 	 Espectáculos
# | | | | | div {'class': ['wrap-figure']}
# | | | | | | div {'class': ['ico-tx-news']}
# | | | | | | | div {'class': ['ico']}
# | | | | | | | | div {'class': ['mdia', 'media-vid', 'onlyIcon']}

# %%
# BY <section> -- <section>[13]
dumptreeul(sections[13].parent, '')
# Out:
# div {'class': ['container', 'father', 'no-p'], 'data-classes': 'container', 'data-type': 'container_father', 'data-name': 'container_father'}
# | div {'class': ['carcasaSkin']}
# | | div {'class': ['full', 'item-content'], 'data-classes': 'full item-content ', 'data-name': 'separador', 'data-linkcontent': ''}
# | | | header[7]: {'class': ['separador-home']}
# | | | 	 <CRLF><CRLF><CRLF>Clic<CRLF><CRLF>
# | | | | div {'class': ['content-separador']}
# | | | | | h2 {'class': ['heading']}
# | | | | | 	 Clic
# | | section[11]: {'data-name': 'cont2WB', 'class': ['container', 'no-p', 'listado'], 'data-classes': 'container listado ', 'data-type': 'container'}
# | | | div {'class': ['count-first', 'bb-container', 'two-floor-banner', 'bb-moduleId_2WB_mod_202164463708654'], 'data-count': '8', 'data-classes': ''}
# | | | | div {'class': ['border', 'box-large', 'col-lg-6', 'col-md-8', 'col-sm-12', 'col-xs-12', 'no-p', 'size2x2', 'twox_container', 'c-pad', 'special'], 'data-size-w': '2', 'data-size-h': '2', 'data-classes': 'border box-large col-lg-6 col-md-8 col-sm-12 col-xs-12 no-p size2x2 twox_container  special', 'data-name': 'container2x2'}
# | | | | | div {'class': ['top-head']}
# | | | | | | div {'class': ['count-first', 'row', 'bb-container', 'bb-moduleId_twoxtwo_mod_202164470166150'], 'data-count': '4'}
# | | | | | | | div {'class': ['m-box', 'child', 'h300', 'col-xs-12', 'pl-pr'], 'data-classes': 'm-box child h300  col-xs-12 pl-pr', 'data-name': 'content', 'data-size-w': '2', 'data-size-h': '1'}
# | | | | | | | | article[70]: {'class': ['visual', 'bottom_degrade', 'content-nota', 'twoxone_visual', 't-bottom', 't-left', 'list-format']}
# | | | | | | | | | div {'class': ['mt', 'title-top']}
# | | | | | | | | | | div {'class': ['max-h', 'flex-change']}
# | | | | | | | | | | | h2 {}
# | | | | | | | | | | | 	 Exhiben un modelo hiperrealista de Jesucristo con todas sus heridas
# | | | | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | | | | 	 Tiene cabello humano
# | | | | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | | | | p {'class': ['section']}
# | | | | | | | | | | | 	 Viste
# | | | | | | | | | div {'class': ['wrap-img', 'title-top']}
# | | | | | | | | | | div {'class': ['bg_picture_degree']}
# | | | | | | | | | div {'class': ['bg_picture_degree']}
# | | | | | | | div {'class': ['m-box', 'child', 'h300', 'col-sm-6', 'col-xs-12', 'pl-pr'], 'data-classes': 'm-box child h300 col-sm-6 col-xs-12 pl-pr ', 'data-name': 'content', 'data-size-w': '1', 'data-size-h': '1'}
# | | | | | | | | article[71]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | | | | | div {'class': ['mt']}
# | | | | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | | | | h2 {}
# | | | | | | | | | | | 	 Un bebé escapó de su casa y dos perros le salvaron la vida
# | | | | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | | | | 	 Quedó grabado
# | | | | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | | | | p {'class': ['section']}
# | | | | | | | | | | | 	 Viste
# | | | | | | | | | div {'class': ['wrap-figure']}
# | | | | | | | div {'class': ['m-box', 'child', 'h300', 'col-sm-6', 'col-xs-12', 'pl-pr'], 'data-classes': 'm-box child h300 col-sm-6 col-xs-12 pl-pr ', 'data-name': 'content', 'data-size-w': '1', 'data-size-h': '1'}
# | | | | | | | | article[72]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | | | | | div {'class': ['mt']}
# | | | | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | | | | h2 {}
# | | | | | | | | | | | 	 Tremenda lucha cuerpo a cuerpo entre un oso grizzly y dos estudiantes
# | | | | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | | | | 	 Mutilados, pero vivos
# | | | | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | | | | p {'class': ['section']}
# | | | | | | | | | | | 	 Internacional
# | | | | | | | | | div {'class': ['wrap-figure']}
# | | | | div {'class': ['m-box', 'adv', 'h600', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p', 'size1x4'], 'data-size-w': '1', 'data-size-h': '2', 'data-classes': ' des-adv   m-box adv h600 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p size1x4', 'data-name': 'advert'}
# | | | | | div {'id': 'div-gpt-ad-caja8', 'class': ['banner_center', 'ad-slot', 'box-adv']}
# | | | | div {'class': ['m-box', 'h300', 'child', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p', 'list-format'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p list-format', 'data-name': 'content'}
# | | | | | article[73]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | | div {'class': ['mt']}
# | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | h2 {}
# | | | | | | | | 	 La actriz de She-Hulk habla del final de la serie y de los pros y contras de Marvel
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | 	 Entrevista a Tatiana Maslany
# | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | p {'class': ['author']}
# | | | | | | | | 	 Marcelo Fernández Bitar
# | | | | | | div {'class': ['wrap-figure']}
# | | | | | | | div {'class': ['ico-tx-news']}
# | | | | | | | | span {'class': ['content-ico', 'dsdsd']}
# | | | | | | | | | div {'class': ['ico']}
# | | | | | | | | | | div {'class': ['mdia', 'media-vid', 'onlyIcon']}
# | | | | div {'class': ['m-box', 'child', 'h150', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p'], 'data-classes': 'm-box child h150 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p', 'data-size-w': '1', 'data-size-h': '0.5', 'data-name': 'content'}
# | | | | | article[74]: {'class': ['content-nota', 'list-format', 'onexone_doble']}
# | | | | | | div {'class': ['mt']}
# | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | h2 {}
# | | | | | | | | 	 Un mago murió en plena actuación y la gente creyó que era un truco
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | 	 En España
# | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | p {'class': ['section']}
# | | | | | | | | 	 Viste
# | | | | | | div {'class': ['wrap-figure']}
# | | | | div {'class': ['m-box', 'child', 'h150', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p'], 'data-classes': 'm-box child h150 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p', 'data-size-w': '1', 'data-size-h': '0.5', 'data-name': 'content'}
# | | | | | article[75]: {'class': ['content-nota', 'list-format', 'onexone_doble']}
# | | | | | | div {'class': ['mt']}
# | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | h2 {}
# | | | | | | | | 	 Cómo sos según tu signo lunar
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | 	 Carta natal
# | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | p {'class': ['author']}
# | | | | | | | | 	 Beatriz Leveratto
# | | | | | | div {'class': ['wrap-figure']}
# | div {'class': ['carcasaSkin']}
# | | div {'class': ['full', 'item-content'], 'data-classes': 'full item-content ', 'data-name': 'separador', 'data-linkcontent': 'https://www.youtube.com/c/clarincom'}
# | | | header[8]: {'class': ['separador-home']}
# | | | 	 <CRLF><CRLF><CRLF>Video <CRLF><CRLF>
# | | | | div {'class': ['content-separador']}
# | | | | | h2 {'class': ['heading']}
# | | | | | 	 Video
# | | section[12]: {'data-name': 'cont1C', 'class': ['container', 'no-p', 'listado'], 'data-classes': 'container no-p listado ', 'data-type': 'container'}
# | | | div {'class': ['count-first', 'bb-container', 'one-floor-C', 'bb-moduleId_1C_mod_201754205720610'], 'data-classes': ' ', 'data-count': '4'}
# | | | | div {'class': ['m-box', 'child', 'h300', 'border', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p', 'data-name': 'content'}
# | | | | | article[76]: {'class': ['onexone_foto_grey', 'content-nota', 'list-format']}
# | | | | | | div {'class': ['mt']}
# | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | h2 {}
# | | | | | | | | 	 Las predicciones para Argentina
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | 	 Qatar 2022
# | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | p {'class': ['section']}
# | | | | | | | | 	 deportes
# | | | | | | div {'class': ['wrap-figure']}
# | | | | | | | div {'class': ['ico-tx-news']}
# | | | | | | | | div {'class': ['ico']}
# | | | | | | | | | div {'class': ['mdia', 'media-vid', 'onlyIcon']}
# | | | | div {'class': ['m-box', 'child', 'h300', 'border', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p', 'data-name': 'content'}
# | | | | | article[77]: {'class': ['onexone_foto_grey', 'content-nota', 'list-format']}
# | | | | | | div {'class': ['mt']}
# | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | h2 {}
# | | | | | | | | 	 El asesino serial “que no mató a nadie”
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | 	 Magnus Mefisto
# | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | p {'class': ['section']}
# | | | | | | | | 	 Política
# | | | | | | div {'class': ['wrap-figure']}
# | | | | | | | div {'class': ['ico-tx-news']}
# | | | | | | | | div {'class': ['ico']}
# | | | | | | | | | div {'class': ['mdia', 'media-vid', 'onlyIcon']}
# | | | | div {'class': ['m-box', 'child', 'h300', 'border', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p', 'data-name': 'content'}
# | | | | | article[78]: {'class': ['onexone_foto_grey', 'content-nota', 'list-format']}
# | | | | | | div {'class': ['mt']}
# | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | h2 {}
# | | | | | | | | 	 A días del Mundial más esperado para los argentinos
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | 	 Qatar 2022
# | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | p {'class': ['section']}
# | | | | | | | | 	 Deportes
# | | | | | | div {'class': ['wrap-figure']}
# | | | | | | | div {'class': ['ico-tx-news']}
# | | | | | | | | div {'class': ['ico']}
# | | | | | | | | | div {'class': ['mdia', 'media-vid', 'onlyIcon']}
# | | | | div {'class': ['m-box', 'child', 'h300', 'border', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p', 'data-name': 'content'}
# | | | | | article[79]: {'class': ['onexone_foto_grey', 'content-nota', 'list-format']}
# | | | | | | div {'class': ['mt']}
# | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | h2 {}
# | | | | | | | | 	 Su origen y secretos
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | 	 Fiesta Nacional en Mercedes
# | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | p {'class': ['section']}
# | | | | | | | | 	 Espectáculos
# | | | | | | div {'class': ['wrap-figure']}
# | | | | | | | div {'class': ['ico-tx-news']}
# | | | | | | | | div {'class': ['ico']}
# | | | | | | | | | div {'class': ['mdia', 'media-vid', 'onlyIcon']}
# | div {'class': ['full', 'item-content'], 'data-classes': 'full item-content ', 'data-name': 'separador', 'data-linkcontent': 'https://www.clarin.com/fotogalerias'}
# | | header[9]: {'class': ['separador-home']}
# | | 	 <CRLF><CRLF><CRLF>FOTOGALERIA<CRLF><CRLF>
# | | | div {'class': ['content-separador']}
# | | | | h2 {'class': ['heading']}
# | | | | 	 FOTOGALERIA
# | section[13]: {'class': ['container', 'no-p'], 'data-classes': 'container', 'data-type': 'container', 'data-name': 'cont_news100'}
# | | div {}
# | | | div {'class': ['m-box', 'container', 'no-p', 'fotonoticia'], 'data-size-w': '0', 'data-size-h': '0', 'data-classes': 'm-box container no-p fotonoticia', 'data-name': 'content'}
# | | | | article[80]: {'class': ['visual', 'content-nota', 'full_visual', 't-bottom', 't-left']}
# | | | | | div {'class': ['mt', 'flex-change']}
# | | | | | | h2 {}
# | | | | | | 	 Las mejores imágenes de hoy en la Argentina y el mundo
# | | | | | | p {'class': ['volanta']}
# | | | | | | 	 Historias Visuales
# | | | | | div {'class': ['wrap-img']}
# | | | | | | div {'class': ['slide-show', 'glide', 'slide-jSJyfDX123']}
# | | | | | | | div {'class': ['glide__track'], 'data-glide-el': 'track'}
# | | | | | | | | ul {'class': ['glide__slides']}
# | | | | | | | | | li {'class': ['glide__slide']}
# | | | | | | | | | li {'class': ['glide__slide']}
# | | | | | | | | | li {'class': ['glide__slide']}
# | | | | | | | | | li {'class': ['glide__slide']}
# | | | | | | | | | li {'class': ['glide__slide']}
# | | | | | | | | | li {'class': ['glide__slide']}
# | | | | | | | | | li {'class': ['glide__slide']}
# | | | | | | | | | li {'class': ['glide__slide']}
# | | | | | | | | | li {'class': ['glide__slide']}
# | div {'class': ['carcasaSkin']}
# | | div {'class': ['full', 'item-content'], 'data-classes': 'full item-content ', 'data-name': 'separador', 'data-linkcontent': 'https://www.clarin.com/brandstudio/'}
# | | | header[10]: {'class': ['separador-home']}
# | | | 	 <CRLF><CRLF><CRLF> BRAND STUDIO<CRLF><CRLF>
# | | | | div {'class': ['content-separador']}
# | | | | | h2 {'class': ['heading']}
# | | | | | 	  BRAND STUDIO
# | | section[14]: {'data-name': 'cont2WB', 'class': ['container', 'no-p', 'listado'], 'data-classes': 'container listado ', 'data-type': 'container'}
# | | | div {'class': ['count-first', 'bb-container', 'two-floor-banner', 'bb-moduleId_2WB_mod_202212722620787'], 'data-count': '8', 'data-classes': ''}
# | | | | div {'class': ['border', 'box-large', 'col-lg-6', 'col-md-8', 'col-sm-12', 'col-xs-12', 'no-p', 'size2x2', 'twox_container', 'c-pad', 'special'], 'data-size-w': '2', 'data-size-h': '2', 'data-classes': 'border box-large col-lg-6 col-md-8 col-sm-12 col-xs-12 no-p size2x2 twox_container  special', 'data-name': 'container2x2'}
# | | | | | div {'class': ['top-head']}
# | | | | | | div {'class': ['count-first', 'row', 'bb-container', 'bb-moduleId_twoxtwo_mod_202212410011465'], 'data-count': '4'}
# | | | | | | | div {'class': ['m-box', 'child', 'h300', 'col-xs-12', 'pl-pr'], 'data-classes': 'm-box child h300  col-xs-12 pl-pr', 'data-name': 'content', 'data-size-w': '2', 'data-size-h': '1'}
# | | | | | | | | article[81]: {'class': ['visual', 'bottom_degrade', 'content-nota', 'twoxone_visual', 't-bottom', 't-left', 'list-format']}
# | | | | | | | | | div {'class': ['mt', 'title-bottom']}
# | | | | | | | | | | div {'class': ['max-h', 'flex-change']}
# | | | | | | | | | | | h2 {}
# | | | | | | | | | | | 	 Comida, vestimenta y viajes: una década de cambios en China
# | | | | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | | | | 	 Crecimiento
# | | | | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | | | | p {'class': ['section']}
# | | | | | | | | | | | 	 BrandStudio
# | | | | | | | | | div {'class': ['wrap-img', 'title-bottom']}
# | | | | | | | | | | div {'class': ['bg_picture_degree']}
# | | | | | | | | | div {'class': ['bg_picture_degree']}
# | | | | | | | div {'class': ['m-box', 'child', 'h300', 'col-sm-6', 'col-xs-12', 'pl-pr'], 'data-classes': 'm-box child h300 col-sm-6 col-xs-12 pl-pr ', 'data-name': 'content', 'data-size-w': '1', 'data-size-h': '1'}
# | | | | | | | | article[82]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | | | | | div {'class': ['mt']}
# | | | | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | | | | h2 {}
# | | | | | | | | | | | 	 “Pensá en grande”: la campaña innovadora del Banco Macro que se enfoca en las personas
# | | | | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | | | | 	 Continuo crecimiento
# | | | | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | | | | p {'class': ['section']}
# | | | | | | | | | | | 	 BrandStudio
# | | | | | | | | | div {'class': ['wrap-figure']}
# | | | | | | | div {'class': ['m-box', 'child', 'h300', 'col-sm-6', 'col-xs-12', 'pl-pr'], 'data-classes': 'm-box child h300 col-sm-6 col-xs-12 pl-pr ', 'data-name': 'content', 'data-size-w': '1', 'data-size-h': '1'}
# | | | | | | | | article[83]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | | | | | div {'class': ['mt']}
# | | | | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | | | | h2 {}
# | | | | | | | | | | | 	 Nerdearla llega a todos los hogares de Argentina
# | | | | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | | | | 	 Lo que se viene
# | | | | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | | | | p {'class': ['section']}
# | | | | | | | | | | | 	 BrandStudio
# | | | | | | | | | div {'class': ['wrap-figure']}
# | | | | div {'class': ['m-box', 'adv', 'h600', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p', 'size1x4'], 'data-size-w': '1', 'data-size-h': '2', 'data-classes': ' des-adv   m-box adv h600 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p size1x4', 'data-name': 'advert'}
# | | | | | div {'id': 'div-gpt-ad-caja9', 'class': ['banner_center', 'ad-slot', 'box-adv']}
# | | | | div {'class': ['m-box', 'h300', 'child', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p', 'list-format'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p list-format', 'data-name': 'content'}
# | | | | | article[84]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | | div {'class': ['mt']}
# | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | h2 {}
# | | | | | | | | 	 Isla Corona: un espacio para conectar con la naturaleza
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | 	 Un oasis exclusivo
# | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | p {'class': ['section']}
# | | | | | | | | 	 BrandStudio
# | | | | | | div {'class': ['wrap-figure']}
# | | | | div {'class': ['m-box', 'child', 'h150', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p'], 'data-classes': 'm-box child h150 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p', 'data-size-w': '1', 'data-size-h': '0.5', 'data-name': 'content'}
# | | | | | article[85]: {'class': ['content-nota', 'list-format', 'onexone_doble']}
# | | | | | | div {'class': ['mt']}
# | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | h2 {}
# | | | | | | | | 	 YPF y Editorial Planeta presentan “Una historia del Conurbano”, de Pedro Saborido
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | 	 Lanzamiento
# | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | p {'class': ['section']}
# | | | | | | | | 	 BrandStudio
# | | | | | | div {'class': ['wrap-figure']}
# | | | | div {'class': ['m-box', 'child', 'h150', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p'], 'data-classes': 'm-box child h150 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p', 'data-size-w': '1', 'data-size-h': '0.5', 'data-name': 'content'}
# | | | | | article[86]: {'class': ['content-nota', 'list-format', 'onexone_doble']}
# | | | | | | div {'class': ['mt']}
# | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | h2 {}
# | | | | | | | | 	 Una semana para analizar tus seguros y tener tranquilidad todo el año
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | 	 Tranqui Week
# | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | p {'class': ['section']}
# | | | | | | | | 	 BrandStudio
# | | | | | | div {'class': ['wrap-figure']}
# | div {'class': ['noBoxShadow', 'col-lg-12', 'no-p', 'htmlfreeLabel', 'full'], 'data-size-w': '0', 'data-size-h': '0', 'data-classes': 'noBoxShadow col-lg-12 no-p htmlfreeLabel full', 'data-name': 'htmlfree'}
# | | div {'class': ['ntymes-banner']}
# | div {'class': ['carcasaSkin']}
# | | section[15]: {'data-name': 'cont1B', 'class': ['container', 'no-p', 'listado'], 'data-classes': 'container listado', 'data-type': 'container'}
# | | | div {'class': ['count-first', 'bb-container', 'one-floor', 'bb-moduleId_1B_mod_201881263003819'], 'data-count': '4', 'data-classes': ''}
# | | | | div {'class': ['m-box', 'child', 'h300', 'col-lg-6', 'col-md-8', 'col-sm-12', 'col-xs-12', 'no-p', 'm2x1', 't-bottom', 't-right'], 'data-size-w': '2', 'data-size-h': '1', 'data-classes': 'm-box child h300  col-lg-6 col-md-8 col-sm-12 col-xs-12 no-p t-bottom t-right', 'data-name': 'content'}
# | | | | | article[87]: {'class': ['visual', 'bottom_degrade', 'content-nota', 'twoxone_visual', 't-bottom', 't-right', 'list-format']}
# | | | | | | div {'class': ['mt', 'title-bottom']}
# | | | | | | | div {'class': ['max-h', 'flex-change']}
# | | | | | | | | h2 {}
# | | | | | | | | 	 Guerra en Ucrania: ¿A dónde se han ido todos los hombres de Moscú?
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | 	 Escenario
# | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | p {'class': ['author']}
# | | | | | | | | 	 Valerie Hopkins
# | | | | | | div {'class': ['wrap-img', 'title-bottom']}
# | | | | | | | div {'class': ['bg_picture_degree']}
# | | | | | | div {'class': ['bg_picture_degree']}
# | | | | div {'class': ['m-box', 'h300', 'child', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p', 'list-format'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p list-format', 'data-name': 'content'}
# | | | | | article[88]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | | div {'class': ['mt']}
# | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | h2 {}
# | | | | | | | | 	 Preparándose para el chantaje republicano de la deuda
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | 	 Opinión
# | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | p {'class': ['author']}
# | | | | | | | | 	 Paul Krugman
# | | | | | | div {'class': ['wrap-figure']}
# | | | | div {'class': ['m-box', 'child', 'h150', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p'], 'data-classes': 'm-box child h150 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p', 'data-size-w': '1', 'data-size-h': '0.5', 'data-name': 'content'}
# | | | | | article[89]: {'class': ['content-nota', 'list-format', 'onexone_doble']}
# | | | | | | div {'class': ['mt']}
# | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | h2 {}
# | | | | | | | | 	 Irán envía entrenadores de drones a Crimea para ayudar al ejército ruso
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | 	 Guerra en Ucrania
# | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | p {'class': ['author']}
# | | | | | | | | 	 Julian E. Barnes
# | | | | | | div {'class': ['wrap-figure']}
# | | | | div {'class': ['m-box', 'child', 'h150', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p'], 'data-classes': 'm-box child h150 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p', 'data-size-w': '1', 'data-size-h': '0.5', 'data-name': 'content'}
# | | | | | article[90]: {'class': ['content-nota', 'list-format', 'onexone_doble']}
# | | | | | | div {'class': ['mt']}
# | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | h2 {}
# | | | | | | | | 	 Gracias Xi Jinping
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | 	 Opinión
# | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | p {'class': ['author']}
# | | | | | | | | 	 Bret Stephens
# | | | | | | div {'class': ['wrap-figure']}
# | div {'class': ['carcasaSkin']}
# | | div {'class': ['full', 'item-content'], 'data-classes': 'full item-content ', 'data-name': 'separador', 'data-linkcontent': 'https://www.clarin.com/zonales/'}
# | | | header[11]: {'class': ['separador-home']}
# | | | 	 <CRLF><CRLF><CRLF>Conurbano<CRLF><CRLF>
# | | | | div {'class': ['content-separador']}
# | | | | | h2 {'class': ['heading']}
# | | | | | 	 Conurbano
# | | section[16]: {'data-name': 'cont1A', 'class': ['container', 'no-p', 'listado'], 'data-classes': 'container no-p listado ', 'data-type': 'container'}
# | | | div {'class': ['count-first', 'bb-container', 'one-floor-A', 'bb-moduleId_1A_mod_202165832031849'], 'data-classes': ' ', 'data-count': '4'}
# | | | | div {'class': ['m-box', 'h300', 'child', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p', 'list-format'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p list-format', 'data-name': 'content'}
# | | | | | article[91]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | | div {'class': ['mt']}
# | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | h2 {}
# | | | | | | | | 	 Cuál es la línea de colectivos que sigue haciendo el recorrido con el que la crearon
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | 	 Desde hace 100 años
# | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | p {'class': ['author']}
# | | | | | | | | 	 Ariana López Pasquare
# | | | | | | div {'class': ['wrap-figure']}
# | | | | div {'class': ['m-box', 'h300', 'child', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p', 'list-format'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p list-format', 'data-name': 'content'}
# | | | | | article[92]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | | div {'class': ['mt']}
# | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | h2 {}
# | | | | | | | | 	 De chico estuvo 25 minutos en el fondo de una pileta y ahora se luce como rapero
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | 	 Mato Vive
# | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | p {'class': ['author']}
# | | | | | | | | 	 Tito Lescano
# | | | | | | div {'class': ['wrap-figure']}
# | | | | div {'class': ['m-box', 'h300', 'child', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p', 'list-format'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p list-format', 'data-name': 'content'}
# | | | | | article[93]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | | div {'class': ['mt']}
# | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | h2 {}
# | | | | | | | | 	 Tendencia que crece en el GBA: dónde estará la primera bicisenda de Moreno
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | 	 Cambio de cara
# | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | p {'class': ['section']}
# | | | | | | | | 	 Zonales
# | | | | | | div {'class': ['wrap-figure']}
# | | | | div {'class': ['m-box', 'h300', 'child', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p', 'list-format'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p list-format', 'data-name': 'content'}
# | | | | | article[94]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | | div {'class': ['mt']}
# | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | h2 {}
# | | | | | | | | 	 El ex intendente que se hizo un by pass gástrico para la campaña 2023
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | 	 “Tengo que estar en forma”
# | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | p {'class': ['author']}
# | | | | | | | | 	 Juan Pablo Estevez
# | | | | | | div {'class': ['wrap-figure']}
# | div {'class': ['carcasaSkin']}
# | | div {'class': ['full', 'item-content'], 'data-classes': 'full item-content ', 'data-name': 'separador', 'data-linkcontent': 'https://elle.clarin.com/'}
# | | | header[12]: {'class': ['separador-home']}
# | | | 	 <CRLF><CRLF><CRLF>Elle<CRLF><CRLF>
# | | | | div {'class': ['content-separador']}
# | | | | | h2 {'class': ['heading']}
# | | | | | 	 Elle
# | | section[17]: {'data-name': 'cont1B', 'class': ['container', 'no-p'], 'data-classes': 'container  no-p', 'data-type': 'container'}
# | | | ul {'class': ['count-first', 'bb-container', 'one-floor'], 'data-count': '4'}
# | | | | li {'class': ['m-box', 'child', 'h300', 'col-lg-6', 'col-md-8', 'col-sm-12', 'col-xs-12', 'no-p', 'm2x1'], 'data-size-w': '2', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-lg-6 col-md-8 col-sm-12 col-xs-12 no-p m2x1', 'data-name': 'content'}
# | | | | | article[95]: {'class': ['visual', 'content-nota', 'twoxone_visual', 'bottom_degrade']}
# | | | | | | div {'class': ['mt']}
# | | | | | | | div {'class': ['max-h', 'flex-change']}
# | | | | | | | | h2 {}
# | | | | | | | | 	 Claves para transitarla mejor
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | 	 Menopausia
# | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | | p {'class': ['section']}
# | | | | | | | | | 	 Belleza - Salud
# | | | | | | div {'class': ['wrap-img', 'title-bottom']}
# | | | | | | | div {'class': ['bg_picture_degree']}
# | | | | li {'class': ['m-box', 'h300', 'child', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p ', 'data-name': 'content'}
# | | | | | article[96]: {'class': ['content-nota', 'onexone_foto', 'flex-change']}
# | | | | | | div {'class': ['mt']}
# | | | | | | | div {'class': ['max-h', 'flex-change']}
# | | | | | | | | h2 {}
# | | | | | | | | 	  Tratamientos con ingredientes de origen natural
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | 	 Cuidado del cabello
# | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | | p {'class': ['section']}
# | | | | | | | | | 	 Belleza - Pelo
# | | | | | | div {'class': ['wrap-img']}
# | | | | li {'class': ['m-box', 'child', 'h150', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p'], 'data-classes': 'm-box child h150 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p', 'data-size-w': '1', 'data-size-h': '0.5', 'data-name': 'content'}
# | | | | | article[97]: {'class': ['content-nota', 'list-format', 'onexone_doble']}
# | | | | | | div {'class': ['mt']}
# | | | | | | | div {'class': ['max-h', 'flex-change']}
# | | | | | | | | h2 {}
# | | | | | | | | 	 Moda & tecnología
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | 	 Lifestyle
# | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | | p {'class': ['section']}
# | | | | | | | | | 	 Estilo de vida - Consumo
# | | | | | | div {'class': ['wrap-img']}
# | | | | li {'class': ['m-box', 'child', 'h150', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p'], 'data-classes': 'm-box child h150 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p', 'data-size-w': '1', 'data-size-h': '0.5', 'data-name': 'content'}
# | | | | | article[98]: {'class': ['content-nota', 'list-format', 'onexone_doble']}
# | | | | | | div {'class': ['mt']}
# | | | | | | | div {'class': ['max-h', 'flex-change']}
# | | | | | | | | h2 {}
# | | | | | | | | 	 El nuevo hit
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | 	 Delineador blanco
# | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | | p {'class': ['section']}
# | | | | | | | | | 	 Belleza - Maquillaje
# | | | | | | div {'class': ['wrap-img']}
# | div {'class': ['m-box-alternative'], 'data-size-w': '2', 'data-size-h': '2', 'data-classes': 'm-box-alternative', 'data-name': 'loMasVisto'}
# | | div {'class': ['The__most__seen']}
# | | | div {'class': ['separador-home']}
# | | | | h2 {'class': ['heading']}
# | | | | 	 Lo Más Visto por los suscriptores
# | | | ul {'xmlns': 'http://www.w3.org/1999/html', 'id': 'lmvmod_202190676452238'}
# | | | | li {'class': ['box-items']}
# | | | | | article[99]: {}
# | | | | | | div {'class': ['box-container']}
# | | | | | | | div {'class': ['mt']}
# | | | | | | | | h2 {}
# | | | | | | | | 	 El Gobierno pide una rectificación a Gran Hermano por la acusación de un participante del reality sobre Alberto Fernández
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | |
# | | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | | p {'class': ['author']}
# | | | | | | | | |
# | | | | | | div {}
# | | | | | | | span {'class': ['number']}
# | | | | li {'class': ['box-items']}
# | | | | | article[100]: {}
# | | | | | | div {'class': ['box-container']}
# | | | | | | | div {'class': ['mt']}
# | | | | | | | | h2 {}
# | | | | | | | | 	 Brutal pelea en la Antártida: el encargado de la Base Marambio fue atacado con una maza mientras dormía
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | |
# | | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | | p {'class': ['author']}
# | | | | | | | | |
# | | | | | | div {}
# | | | | | | | span {'class': ['number']}
# | | | | li {'class': ['box-items']}
# | | | | | article[101]: {}
# | | | | | | div {'class': ['box-container']}
# | | | | | | | div {'class': ['mt']}
# | | | | | | | | h2 {}
# | | | | | | | | 	 15 segundos de pánico en un avión de Aerolíneas: "Nunca sentí que estuve tan cercana a la muerte"
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | |
# | | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | | p {'class': ['author']}
# | | | | | | | | |
# | | | | | | div {}
# | | | | | | | span {'class': ['number']}
# | | | | li {'class': ['box-items']}
# | | | | | article[102]: {}
# | | | | | | div {'class': ['box-container']}
# | | | | | | | div {'class': ['mt']}
# | | | | | | | | h2 {}
# | | | | | | | | 	 Alerta en al aire: por qué se dan turbulencias como la que afectó al avión de Aerolíneas
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | |
# | | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | | p {'class': ['author']}
# | | | | | | | | |
# | | | | | | div {}
# | | | | | | | span {'class': ['number']}
# | | | | li {'class': ['box-items']}
# | | | | | article[103]: {}
# | | | | | | div {'class': ['box-container']}
# | | | | | | | div {'class': ['mt']}
# | | | | | | | | h2 {}
# | | | | | | | | 	 "Dejen de hacer papelones": duro cruce entre Diego Santilli, María Eugenia Vidal y Gabriela Cerruti por la acusación contra Gran Hermano
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | |
# | | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | | p {'class': ['author']}
# | | | | | | | | |
# | | | | | | div {}
# | | | | | | | span {'class': ['number']}
# | | | | li {'class': ['box-items']}
# | | | | | article[104]: {}
# | | | | | | div {'class': ['box-container']}
# | | | | | | | div {'class': ['mt']}
# | | | | | | | | h2 {}
# | | | | | | | | 	 Por los pasillos: la candidata tapada de Alberto Fernández, un dirigente social a los escobazos y el osobuco de De Loredo
# | | | | | | | | p {'class': ['volanta']}
# | | | | | | | |
# | | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | | p {'class': ['author']}
# | | | | | | | | |
# | | | | | | div {}
# | | | | | | | span {'class': ['number']}

# %%
# BY <section> -- <section>[14]
dumptreeul(sections[14].parent, '')
# Out:
# div {'class': ['carcasaSkin']}
# | div {'class': ['full', 'item-content'], 'data-classes': 'full item-content ', 'data-name': 'separador', 'data-linkcontent': 'https://www.clarin.com/brandstudio/'}
# | | header[10]: {'class': ['separador-home']}
# | | 	 <CRLF><CRLF><CRLF> BRAND STUDIO<CRLF><CRLF>
# | | | div {'class': ['content-separador']}
# | | | | h2 {'class': ['heading']}
# | | | | 	  BRAND STUDIO
# | section[14]: {'data-name': 'cont2WB', 'class': ['container', 'no-p', 'listado'], 'data-classes': 'container listado ', 'data-type': 'container'}
# | | div {'class': ['count-first', 'bb-container', 'two-floor-banner', 'bb-moduleId_2WB_mod_202212722620787'], 'data-count': '8', 'data-classes': ''}
# | | | div {'class': ['border', 'box-large', 'col-lg-6', 'col-md-8', 'col-sm-12', 'col-xs-12', 'no-p', 'size2x2', 'twox_container', 'c-pad', 'special'], 'data-size-w': '2', 'data-size-h': '2', 'data-classes': 'border box-large col-lg-6 col-md-8 col-sm-12 col-xs-12 no-p size2x2 twox_container  special', 'data-name': 'container2x2'}
# | | | | div {'class': ['top-head']}
# | | | | | div {'class': ['count-first', 'row', 'bb-container', 'bb-moduleId_twoxtwo_mod_202212410011465'], 'data-count': '4'}
# | | | | | | div {'class': ['m-box', 'child', 'h300', 'col-xs-12', 'pl-pr'], 'data-classes': 'm-box child h300  col-xs-12 pl-pr', 'data-name': 'content', 'data-size-w': '2', 'data-size-h': '1'}
# | | | | | | | article[81]: {'class': ['visual', 'bottom_degrade', 'content-nota', 'twoxone_visual', 't-bottom', 't-left', 'list-format']}
# | | | | | | | | div {'class': ['mt', 'title-bottom']}
# | | | | | | | | | div {'class': ['max-h', 'flex-change']}
# | | | | | | | | | | h2 {}
# | | | | | | | | | | 	 Comida, vestimenta y viajes: una década de cambios en China
# | | | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | | | 	 Crecimiento
# | | | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | | | p {'class': ['section']}
# | | | | | | | | | | 	 BrandStudio
# | | | | | | | | div {'class': ['wrap-img', 'title-bottom']}
# | | | | | | | | | div {'class': ['bg_picture_degree']}
# | | | | | | | | div {'class': ['bg_picture_degree']}
# | | | | | | div {'class': ['m-box', 'child', 'h300', 'col-sm-6', 'col-xs-12', 'pl-pr'], 'data-classes': 'm-box child h300 col-sm-6 col-xs-12 pl-pr ', 'data-name': 'content', 'data-size-w': '1', 'data-size-h': '1'}
# | | | | | | | article[82]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | | | | div {'class': ['mt']}
# | | | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | | | h2 {}
# | | | | | | | | | | 	 “Pensá en grande”: la campaña innovadora del Banco Macro que se enfoca en las personas
# | | | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | | | 	 Continuo crecimiento
# | | | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | | | p {'class': ['section']}
# | | | | | | | | | | 	 BrandStudio
# | | | | | | | | div {'class': ['wrap-figure']}
# | | | | | | div {'class': ['m-box', 'child', 'h300', 'col-sm-6', 'col-xs-12', 'pl-pr'], 'data-classes': 'm-box child h300 col-sm-6 col-xs-12 pl-pr ', 'data-name': 'content', 'data-size-w': '1', 'data-size-h': '1'}
# | | | | | | | article[83]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | | | | div {'class': ['mt']}
# | | | | | | | | | div {'class': ['flex-change']}
# | | | | | | | | | | h2 {}
# | | | | | | | | | | 	 Nerdearla llega a todos los hogares de Argentina
# | | | | | | | | | | p {'class': ['volanta']}
# | | | | | | | | | | 	 Lo que se viene
# | | | | | | | | | div {'class': ['data-txt']}
# | | | | | | | | | | p {'class': ['section']}
# | | | | | | | | | | 	 BrandStudio
# | | | | | | | | div {'class': ['wrap-figure']}
# | | | div {'class': ['m-box', 'adv', 'h600', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p', 'size1x4'], 'data-size-w': '1', 'data-size-h': '2', 'data-classes': ' des-adv   m-box adv h600 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p size1x4', 'data-name': 'advert'}
# | | | | div {'id': 'div-gpt-ad-caja9', 'class': ['banner_center', 'ad-slot', 'box-adv']}
# | | | div {'class': ['m-box', 'h300', 'child', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p', 'list-format'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p list-format', 'data-name': 'content'}
# | | | | article[84]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | div {'class': ['mt']}
# | | | | | | div {'class': ['flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 Isla Corona: un espacio para conectar con la naturaleza
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 Un oasis exclusivo
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | p {'class': ['section']}
# | | | | | | | 	 BrandStudio
# | | | | | div {'class': ['wrap-figure']}
# | | | div {'class': ['m-box', 'child', 'h150', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p'], 'data-classes': 'm-box child h150 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p', 'data-size-w': '1', 'data-size-h': '0.5', 'data-name': 'content'}
# | | | | article[85]: {'class': ['content-nota', 'list-format', 'onexone_doble']}
# | | | | | div {'class': ['mt']}
# | | | | | | div {'class': ['flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 YPF y Editorial Planeta presentan “Una historia del Conurbano”, de Pedro Saborido
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 Lanzamiento
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | p {'class': ['section']}
# | | | | | | | 	 BrandStudio
# | | | | | div {'class': ['wrap-figure']}
# | | | div {'class': ['m-box', 'child', 'h150', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p'], 'data-classes': 'm-box child h150 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p', 'data-size-w': '1', 'data-size-h': '0.5', 'data-name': 'content'}
# | | | | article[86]: {'class': ['content-nota', 'list-format', 'onexone_doble']}
# | | | | | div {'class': ['mt']}
# | | | | | | div {'class': ['flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 Una semana para analizar tus seguros y tener tranquilidad todo el año
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 Tranqui Week
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | p {'class': ['section']}
# | | | | | | | 	 BrandStudio
# | | | | | div {'class': ['wrap-figure']}

# %%
# BY <section> -- <section>[15]
dumptreeul(sections[15].parent, '')
# Out:
# div {'class': ['carcasaSkin']}
# | section[15]: {'data-name': 'cont1B', 'class': ['container', 'no-p', 'listado'], 'data-classes': 'container listado', 'data-type': 'container'}
# | | div {'class': ['count-first', 'bb-container', 'one-floor', 'bb-moduleId_1B_mod_201881263003819'], 'data-count': '4', 'data-classes': ''}
# | | | div {'class': ['m-box', 'child', 'h300', 'col-lg-6', 'col-md-8', 'col-sm-12', 'col-xs-12', 'no-p', 'm2x1', 't-bottom', 't-right'], 'data-size-w': '2', 'data-size-h': '1', 'data-classes': 'm-box child h300  col-lg-6 col-md-8 col-sm-12 col-xs-12 no-p t-bottom t-right', 'data-name': 'content'}
# | | | | article[87]: {'class': ['visual', 'bottom_degrade', 'content-nota', 'twoxone_visual', 't-bottom', 't-right', 'list-format']}
# | | | | | div {'class': ['mt', 'title-bottom']}
# | | | | | | div {'class': ['max-h', 'flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 Guerra en Ucrania: ¿A dónde se han ido todos los hombres de Moscú?
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 Escenario
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | p {'class': ['author']}
# | | | | | | | 	 Valerie Hopkins
# | | | | | div {'class': ['wrap-img', 'title-bottom']}
# | | | | | | div {'class': ['bg_picture_degree']}
# | | | | | div {'class': ['bg_picture_degree']}
# | | | div {'class': ['m-box', 'h300', 'child', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p', 'list-format'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p list-format', 'data-name': 'content'}
# | | | | article[88]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | div {'class': ['mt']}
# | | | | | | div {'class': ['flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 Preparándose para el chantaje republicano de la deuda
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 Opinión
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | p {'class': ['author']}
# | | | | | | | 	 Paul Krugman
# | | | | | div {'class': ['wrap-figure']}
# | | | div {'class': ['m-box', 'child', 'h150', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p'], 'data-classes': 'm-box child h150 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p', 'data-size-w': '1', 'data-size-h': '0.5', 'data-name': 'content'}
# | | | | article[89]: {'class': ['content-nota', 'list-format', 'onexone_doble']}
# | | | | | div {'class': ['mt']}
# | | | | | | div {'class': ['flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 Irán envía entrenadores de drones a Crimea para ayudar al ejército ruso
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 Guerra en Ucrania
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | p {'class': ['author']}
# | | | | | | | 	 Julian E. Barnes
# | | | | | div {'class': ['wrap-figure']}
# | | | div {'class': ['m-box', 'child', 'h150', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p'], 'data-classes': 'm-box child h150 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p', 'data-size-w': '1', 'data-size-h': '0.5', 'data-name': 'content'}
# | | | | article[90]: {'class': ['content-nota', 'list-format', 'onexone_doble']}
# | | | | | div {'class': ['mt']}
# | | | | | | div {'class': ['flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 Gracias Xi Jinping
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 Opinión
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | p {'class': ['author']}
# | | | | | | | 	 Bret Stephens
# | | | | | div {'class': ['wrap-figure']}

# %%
# BY <section> -- <section>[16]
dumptreeul(sections[16].parent, '')
# Out:
# div {'class': ['carcasaSkin']}
# | div {'class': ['full', 'item-content'], 'data-classes': 'full item-content ', 'data-name': 'separador', 'data-linkcontent': 'https://www.clarin.com/zonales/'}
# | | header[11]: {'class': ['separador-home']}
# | | 	 <CRLF><CRLF><CRLF>Conurbano<CRLF><CRLF>
# | | | div {'class': ['content-separador']}
# | | | | h2 {'class': ['heading']}
# | | | | 	 Conurbano
# | section[16]: {'data-name': 'cont1A', 'class': ['container', 'no-p', 'listado'], 'data-classes': 'container no-p listado ', 'data-type': 'container'}
# | | div {'class': ['count-first', 'bb-container', 'one-floor-A', 'bb-moduleId_1A_mod_202165832031849'], 'data-classes': ' ', 'data-count': '4'}
# | | | div {'class': ['m-box', 'h300', 'child', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p', 'list-format'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p list-format', 'data-name': 'content'}
# | | | | article[91]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | div {'class': ['mt']}
# | | | | | | div {'class': ['flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 Cuál es la línea de colectivos que sigue haciendo el recorrido con el que la crearon
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 Desde hace 100 años
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | p {'class': ['author']}
# | | | | | | | 	 Ariana López Pasquare
# | | | | | div {'class': ['wrap-figure']}
# | | | div {'class': ['m-box', 'h300', 'child', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p', 'list-format'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p list-format', 'data-name': 'content'}
# | | | | article[92]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | div {'class': ['mt']}
# | | | | | | div {'class': ['flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 De chico estuvo 25 minutos en el fondo de una pileta y ahora se luce como rapero
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 Mato Vive
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | p {'class': ['author']}
# | | | | | | | 	 Tito Lescano
# | | | | | div {'class': ['wrap-figure']}
# | | | div {'class': ['m-box', 'h300', 'child', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p', 'list-format'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p list-format', 'data-name': 'content'}
# | | | | article[93]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | div {'class': ['mt']}
# | | | | | | div {'class': ['flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 Tendencia que crece en el GBA: dónde estará la primera bicisenda de Moreno
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 Cambio de cara
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | p {'class': ['section']}
# | | | | | | | 	 Zonales
# | | | | | div {'class': ['wrap-figure']}
# | | | div {'class': ['m-box', 'h300', 'child', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p', 'list-format'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p list-format', 'data-name': 'content'}
# | | | | article[94]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | div {'class': ['mt']}
# | | | | | | div {'class': ['flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 El ex intendente que se hizo un by pass gástrico para la campaña 2023
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 “Tengo que estar en forma”
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | p {'class': ['author']}
# | | | | | | | 	 Juan Pablo Estevez
# | | | | | div {'class': ['wrap-figure']}

# %%
# BY <section> -- <section>[17]
dumptreeul(sections[17].parent, '')
# Out:
# div {'class': ['carcasaSkin']}
# | div {'class': ['full', 'item-content'], 'data-classes': 'full item-content ', 'data-name': 'separador', 'data-linkcontent': 'https://elle.clarin.com/'}
# | | header[12]: {'class': ['separador-home']}
# | | 	 <CRLF><CRLF><CRLF>Elle<CRLF><CRLF>
# | | | div {'class': ['content-separador']}
# | | | | h2 {'class': ['heading']}
# | | | | 	 Elle
# | section[17]: {'data-name': 'cont1B', 'class': ['container', 'no-p'], 'data-classes': 'container  no-p', 'data-type': 'container'}
# | | ul {'class': ['count-first', 'bb-container', 'one-floor'], 'data-count': '4'}
# | | | li {'class': ['m-box', 'child', 'h300', 'col-lg-6', 'col-md-8', 'col-sm-12', 'col-xs-12', 'no-p', 'm2x1'], 'data-size-w': '2', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-lg-6 col-md-8 col-sm-12 col-xs-12 no-p m2x1', 'data-name': 'content'}
# | | | | article[95]: {'class': ['visual', 'content-nota', 'twoxone_visual', 'bottom_degrade']}
# | | | | | div {'class': ['mt']}
# | | | | | | div {'class': ['max-h', 'flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 Claves para transitarla mejor
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 Menopausia
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | | p {'class': ['section']}
# | | | | | | | | 	 Belleza - Salud
# | | | | | div {'class': ['wrap-img', 'title-bottom']}
# | | | | | | div {'class': ['bg_picture_degree']}
# | | | li {'class': ['m-box', 'h300', 'child', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p ', 'data-name': 'content'}
# | | | | article[96]: {'class': ['content-nota', 'onexone_foto', 'flex-change']}
# | | | | | div {'class': ['mt']}
# | | | | | | div {'class': ['max-h', 'flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	  Tratamientos con ingredientes de origen natural
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 Cuidado del cabello
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | | p {'class': ['section']}
# | | | | | | | | 	 Belleza - Pelo
# | | | | | div {'class': ['wrap-img']}
# | | | li {'class': ['m-box', 'child', 'h150', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p'], 'data-classes': 'm-box child h150 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p', 'data-size-w': '1', 'data-size-h': '0.5', 'data-name': 'content'}
# | | | | article[97]: {'class': ['content-nota', 'list-format', 'onexone_doble']}
# | | | | | div {'class': ['mt']}
# | | | | | | div {'class': ['max-h', 'flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 Moda & tecnología
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 Lifestyle
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | | p {'class': ['section']}
# | | | | | | | | 	 Estilo de vida - Consumo
# | | | | | div {'class': ['wrap-img']}
# | | | li {'class': ['m-box', 'child', 'h150', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p'], 'data-classes': 'm-box child h150 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p', 'data-size-w': '1', 'data-size-h': '0.5', 'data-name': 'content'}
# | | | | article[98]: {'class': ['content-nota', 'list-format', 'onexone_doble']}
# | | | | | div {'class': ['mt']}
# | | | | | | div {'class': ['max-h', 'flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 El nuevo hit
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 Delineador blanco
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | | p {'class': ['section']}
# | | | | | | | | 	 Belleza - Maquillaje
# | | | | | div {'class': ['wrap-img']}

# %%
# BY <section> -- <section>[18]
dumptreeul(sections[15].parent, '')
# Out:
# div {'class': ['carcasaSkin']}
# | section[15]: {'data-name': 'cont1B', 'class': ['container', 'no-p', 'listado'], 'data-classes': 'container listado', 'data-type': 'container'}
# | | div {'class': ['count-first', 'bb-container', 'one-floor', 'bb-moduleId_1B_mod_201881263003819'], 'data-count': '4', 'data-classes': ''}
# | | | div {'class': ['m-box', 'child', 'h300', 'col-lg-6', 'col-md-8', 'col-sm-12', 'col-xs-12', 'no-p', 'm2x1', 't-bottom', 't-right'], 'data-size-w': '2', 'data-size-h': '1', 'data-classes': 'm-box child h300  col-lg-6 col-md-8 col-sm-12 col-xs-12 no-p t-bottom t-right', 'data-name': 'content'}
# | | | | article[87]: {'class': ['visual', 'bottom_degrade', 'content-nota', 'twoxone_visual', 't-bottom', 't-right', 'list-format']}
# | | | | | div {'class': ['mt', 'title-bottom']}
# | | | | | | div {'class': ['max-h', 'flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 Guerra en Ucrania: ¿A dónde se han ido todos los hombres de Moscú?
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 Escenario
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | p {'class': ['author']}
# | | | | | | | 	 Valerie Hopkins
# | | | | | div {'class': ['wrap-img', 'title-bottom']}
# | | | | | | div {'class': ['bg_picture_degree']}
# | | | | | div {'class': ['bg_picture_degree']}
# | | | div {'class': ['m-box', 'h300', 'child', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p', 'list-format'], 'data-size-w': '1', 'data-size-h': '1', 'data-classes': 'm-box child h300 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p list-format', 'data-name': 'content'}
# | | | | article[88]: {'class': ['content-nota', 'onexone_foto', 'list-format', 'flex-change']}
# | | | | | div {'class': ['mt']}
# | | | | | | div {'class': ['flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 Preparándose para el chantaje republicano de la deuda
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 Opinión
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | p {'class': ['author']}
# | | | | | | | 	 Paul Krugman
# | | | | | div {'class': ['wrap-figure']}
# | | | div {'class': ['m-box', 'child', 'h150', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p'], 'data-classes': 'm-box child h150 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p', 'data-size-w': '1', 'data-size-h': '0.5', 'data-name': 'content'}
# | | | | article[89]: {'class': ['content-nota', 'list-format', 'onexone_doble']}
# | | | | | div {'class': ['mt']}
# | | | | | | div {'class': ['flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 Irán envía entrenadores de drones a Crimea para ayudar al ejército ruso
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 Guerra en Ucrania
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | p {'class': ['author']}
# | | | | | | | 	 Julian E. Barnes
# | | | | | div {'class': ['wrap-figure']}
# | | | div {'class': ['m-box', 'child', 'h150', 'col-lg-3', 'col-md-4', 'col-sm-6', 'col-xs-12', 'no-p'], 'data-classes': 'm-box child h150 col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p', 'data-size-w': '1', 'data-size-h': '0.5', 'data-name': 'content'}
# | | | | article[90]: {'class': ['content-nota', 'list-format', 'onexone_doble']}
# | | | | | div {'class': ['mt']}
# | | | | | | div {'class': ['flex-change']}
# | | | | | | | h2 {}
# | | | | | | | 	 Gracias Xi Jinping
# | | | | | | | p {'class': ['volanta']}
# | | | | | | | 	 Opinión
# | | | | | | div {'class': ['data-txt']}
# | | | | | | | p {'class': ['author']}
# | | | | | | | 	 Bret Stephens
# | | | | | div {'class': ['wrap-figure']}

# %%
for i, section in enumerate(sections):
    for j, header in enumerate(headers):
        if header in section.previous_siblings:
            print('<header>', j, 'heads <section>', i, 'with text', header.text.strip())

# %%
hs = {i : list(soup.find_all('h' + str(i))) for i in range(1,7)}
print(list(hs.keys()))
print("Hello world")
# Out:
# [1, 2, 3, 4, 5, 6]
# Hello world
