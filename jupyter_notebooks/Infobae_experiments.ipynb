# %%
import requests                                                         # Jupyter keyboard shortcuts cheatsheet 
import bs4 as bs                                                        # Ctrl + Enter  :: runs currently selected cell, focus remains in current cell
import lxml                                                             # Shift + Enter :: runs current cell and insert new one immediately below
import html5lib                                                         # Esc Shift + L :: Toggle line numbering for full notebook
from pprint import pprint                                               # Alt + Enter   :: runs currently selected cell and insert new cell immediately below
from BSutils import BSdepth                           


httpaddr = "http://www.infobae.com"                                     # Esc dd        :: (Command mode) Esc *FOLLOWED* by D D. Erases current cell (pretty much like a line on Vim)
requests_ret = requests.get(httpaddr)                                   # Alt + <arrow> :: Move code cell
                                                                        # Esc M         :: (Command mode) Switch to typing markdown (on a new cell)
soup_html5lib = bs.BeautifulSoup(requests_ret.text, 'html5lib')         # Esc Y         :: (Command mode) Switch to typing code (on a new cell)
soup_lxml = bs.BeautifulSoup(requests_ret.text, 'lxml')                 # Esc L         :: Toggle line numbering for present cell
                                                                        
soup = soup_lxml    # parse both - choose one
# soup = soup_html5lib    # parse both - choose one

# %%
import re

h2_tags = soup.find_all('h2')
live_h2_tags = soup.find_all('h2', class_ = 'nd-liveBar_info_headline')  # descubrimiento fortuito -- Indica noticia en vivo
headline_h2_tags = soup.find_all('h2', class_ = 'dkt_fs_40')    # uses 'dkt_fs_40' tags for headlines -- sometimes, there's more than one
articles_h2_tags = soup.find_all('h2', class_ = re.compile('dkt_fs_'))

print("Live <h2> Tags:")
for (i, h) in enumerate(live_h2_tags):
    print("%04d|depth:%4d>>" % (i, BSdepth(h)), h)
print()

print("Headline <h2> Tags:")
for (i, h) in enumerate(headline_h2_tags):
    print("%04d|depth:%4d>>" % (i, BSdepth(h)), h)
print()

print("Articles <h2> Tags:")
for (i, h) in enumerate(articles_h2_tags):
    print("%04d|depth:%4d>>" % (i, BSdepth(h)), h)
print()

print("<h2> Tags:")
for (i, h) in enumerate(h2_tags):
    print("%04d|depth:%4d>>" % (i, BSdepth(h)), h)
# Out:
# Live <h2> Tags:
#
# Headline <h2> Tags:
#
# Articles <h2> Tags:
# 0000|depth:  11>> <h2 class="cst_hl dkt_fs_36"><span>En la reunión de Gabinete, Batakis expuso con crudeza la crisis económica y habló de un “panorama complejo en los próximos meses”</span></h2>
# 0001|depth:  11>> <h2 class="cst_hl dkt_fs_22"><span>Dólar hoy: la cotización libre sube a $313 y marca un nuevo récord histórico</span></h2>
# 0002|depth:  11>> <h2 class="cst_hl dkt_fs_22"><span>El mensaje de Grabois en la marcha piquetera: “Estamos dispuestos a dejar nuestra sangre en la calle”</span></h2>
# 0003|depth:   9>> <h2 class="cst_hl dkt_fs_38 color_red text_align_center"><span>El Gobierno evalúa ofrecer un dólar diferenciado para turistas</span></h2>
# 0004|depth:  10>> <h2 class="cst_hl dkt_fs_22"><span>Caos en la Ciudad de Buenos Aires por una masiva marcha de movimientos sociales</span></h2>
# 0005|depth:  10>> <h2 class="cst_hl dkt_fs_22"><span>La rueda virtuosa del campo está frenada</span></h2>
# ...

# %%
filtered_h2_tags = []   # some specific h2 tags seem to be irrelevant given that they're used for presentation, and not content

for h in h2_tags:
    if 'cst_hl' in h.attrs['class'] or 'opi_hl' in h.attrs['class']: filtered_h2_tags.append(h)

print("Filtered <h2> Tags:")
for (i, h) in enumerate(filtered_h2_tags):
    print("%04d|depth:%4d>>" % (i, BSdepth(h)), h)
# Out:
# Filtered <h2> Tags:
# 0000|depth:  11>> <h2 class="cst_hl dkt_fs_36"><span>En la reunión de Gabinete, Batakis expuso con crudeza la crisis económica y habló de un “panorama complejo en los próximos meses”</span></h2>
# 0001|depth:  11>> <h2 class="cst_hl dkt_fs_22"><span>Dólar hoy: la cotización libre sube a $313 y marca un nuevo récord histórico</span></h2>
# 0002|depth:  11>> <h2 class="cst_hl dkt_fs_22"><span>El mensaje de Grabois en la marcha piquetera: “Estamos dispuestos a dejar nuestra sangre en la calle”</span></h2>
# 0003|depth:   9>> <h2 class="cst_hl dkt_fs_38 color_red text_align_center"><span>El Gobierno evalúa ofrecer un dólar diferenciado para turistas</span></h2>
# 0004|depth:  10>> <h2 class="cst_hl dkt_fs_22"><span>Caos en la Ciudad de Buenos Aires por una masiva marcha de movimientos sociales</span></h2>
# 0005|depth:  10>> <h2 class="cst_hl dkt_fs_22"><span>La rueda virtuosa del campo está frenada</span></h2>
# ...

# %%
no_dkt_h2_tags = []

for h in filtered_h2_tags:
    if not h in articles_h2_tags: no_dkt_h2_tags.append(h)

pprint(no_dkt_h2_tags)
# Out:
# [<h2 class="cst_hl"><span>“Depredador: la presa” ya tiene fecha de estreno en Star+</span></h2>,
#  <h2 class="cst_hl"><span>“Bridgerton”, el éxito de Netflix, empezó a filmar su tercera temporada </span></h2>,
#  <h2 class="cst_hl"><span>“Halloween Ends”: el primer tráiler adelanta el final de la icónica saga de terror</span></h2>,
#  <h2 class="cst_hl"><span>Google Wallet, la nueva billetera que ya está disponible</span></h2>,
#  <h2 class="cst_hl"><span>WhatsApp alista reacciones con emojis a los estados </span></h2>,
#  <h2 class="cst_hl"><span>Starlink, el internet de Elon Musk, ya está en México y estos son los precios</span></h2>,
#  <h2 class="opi_hl"><span>Rockefeller y Elon Musk: crisis del ‘30 y criptomonedas</span></h2>,
#  <h2 class="opi_hl"><span>Lagos: un llamado a la reflexión</span></h2>,
#  <h2 class="opi_hl"><span>Fiesta de Olivos: sigue faltando un gesto real de justicia y arrepentimiento</span></h2>]

# %%
print(filtered_h2_tags[0].parent.prettify())
print()
print(no_dkt_h2_tags[0].parent.prettify())
# Out:
# <a aria-label="infobae story" class="cst_ctn" href="/politica/2022/07/20/en-la-reunion-de-gabinete-batakis-expuso-con-crudeza-la-crisis-economica-que-vive-el-pais-y-hablo-de-un-panorama-complejo-en-los-proximos-meses/" rel="canonical">
#  <h2 class="cst_hl dkt_fs_36">
#   <span>
#    En la reunión de Gabinete, Batakis expuso con crudeza la crisis económica y habló de un “panorama complejo en los próximos meses”
#   </span>
#  </h2>
#  <div class="cst_deck dkt_fs_19 dkt_lh_150">
#   La ministra participó del encuentro que se realizó en Casa Rosada y planteó los problemas sin rodeos. De todos modos, prometió ayuda para cada ministerio en el marco de una serie de recortes y en plena suba de la inflación
#  </div>
#  <div class="cst_img_ctn cst_img_ctn_16_9">
# ...

# %%
from requests import head


headline_tag = soup.find('h2')   # Puede haber mas de un headline
# headline_tag = headlines_tags[0]                      # me quedo con uno porque me tengo que quedar con alguno...

headline_title = str(headline_tag.string)
headline_parent = headline_tag.parent
headline_slug = headline_parent.attrs['href']
headline_category = headline_slug.split('/')[1]

# print("headline_title :: \n\t", headline_title)
# print("headline_parent :: \n\t", headline_parent.prettify())
# print("headline_slug :: \n\t", headline_slug)
# print("headline_category :: \n\t", headline_category)

headline_lead = headline_parent.find('div', class_ = re.compile("_deck")).string

print(headline_lead)
# Out:
# La ministra participó del encuentro que se realizó en Casa Rosada y planteó los problemas sin rodeos. De todos modos, prometió ayuda para cada ministerio en el marco de una serie de recortes y en plena suba de la inflación

# %%
articles_tags = list(soup.find_all('h2', class_ = 'cst_hl')) #  + list(soup.find_all('h2', class_ = 'opi_hl'))
for i, a in enumerate(articles_tags):
    print(i, '-' * 20)
    a_title = a.string
    a_parent = a.parent
    a_slug = a.parent.attrs['href']
    a_category = a_slug.split('/')[1]
    print(a_title, a_slug, a_category, sep = '\n')
# Out:
# 0 --------------------
# En la reunión de Gabinete, Batakis expuso con crudeza la crisis económica y habló de un “panorama complejo en los próximos meses”
# /politica/2022/07/20/en-la-reunion-de-gabinete-batakis-expuso-con-crudeza-la-crisis-economica-que-vive-el-pais-y-hablo-de-un-panorama-complejo-en-los-proximos-meses/
# politica
# 1 --------------------
# Dólar hoy: la cotización libre sube a $313 y marca un nuevo récord histórico
# /economia/2022/07/20/dolar-hoy-la-cotizacion-libre-sube-a-307-y-marca-un-nuevo-record-historico/
# economia
# 2 --------------------
# El mensaje de Grabois en la marcha piquetera: “Estamos dispuestos a dejar nuestra sangre en la calle”
# /politica/2022/07/20/el-mensaje-de-juan-grabois-estamos-dispuestos-a-dejar-nuestra-sangre-en-la-calle/
# politica
# 3 --------------------
# El Gobierno evalúa ofrecer un dólar diferenciado para turistas
# /politica/2022/07/20/el-gobierno-adelanto-que-trabaja-en-un-tipo-de-cambio-diferenciado-para-los-turistas/
# ...
