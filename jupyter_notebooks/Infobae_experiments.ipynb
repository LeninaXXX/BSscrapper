# %%
import requests
import bs4 as bs
import lxml

httpaddr = "https://www.infobae.com"

requests_ret = requests.get(httpaddr)
print(requests_ret, end = ' || ')
soup = bs.BeautifulSoup(requests_ret.text, 'lxml')
# Notas:
# Everything semmantically a header, is tagged with <h2>. To all scrapping practical
# purposes, all headers except h2 are deemded irrelevant
articles = soup.find_all("article"); print("articles :", len(articles), end = ' / ')
sections = soup.find_all("section"); print("sections :", len(sections), end = ' / ')
headers = soup.find_all("header"); print("headers :", len(headers), end = ' / ')
h1s = soup.find_all("h1"); print("h1s :", len(h1s), end = ' / ')
h2s = soup.find_all("h2"); print("h2s :", len(h2s), end = ' / ')
h3s = soup.find_all("h3"); print("h3s :", len(h3s), end = ' / ')
h4s = soup.find_all("h4"); print("h4s :", len(h4s), end = ' / ')
h5s = soup.find_all("h5"); print("h5s :", len(h5s), end = ' / ')
h6s = soup.find_all("h6"); print("h6s :", len(h6s))
# only <h2>s hold relevance
# the only <h1> holds an SVG graphic

for discard_tag in ("script", "style"):
    for t in soup.find_all(discard_tag): t.extract()
# Out:
# <Response [200]> || articles : 0 / sections : 0 / headers : 0 / h1s : 0 / h2s : 106 / h3s : 15 / h4s : 0 / h5s : 0 / h6s : 0

# %%
hs = {i : list(soup.find_all('h' + str(i))) for i in range(1, 7)}
print([len(hs[k]) for k in hs])

for i, h in enumerate(hs[2]):
    print(i, '>', h.get_text())
    print(i, '>', h)
# Out:
# [0, 106, 15, 0, 0, 0]
# 0 > Las nuevas facturas de luz y gas: quiénes serán los usuarios que tendrán una quita de subsidios
# 0 > <h2 class="cst_hl dkt_fs_42"><span>Las nuevas facturas de luz y gas: quiénes serán los usuarios que tendrán una quita de subsidios</span></h2>
# 1 > Con las importaciones trabadas, el Banco Central compró dólares por segundo día consecutivo
# 1 > <h2 class="cst_hl dkt_fs_22"><span>Con las importaciones trabadas, el Banco Central compró dólares por segundo día consecutivo</span></h2>
# 2 > Dos aviones F-16 de EEUU interceptaron a dos bombarderos rusos cerca de Alaska
# 2 > <h2 class="cst_hl dkt_fs_22"><span>Dos aviones F-16 de EEUU interceptaron a dos bombarderos rusos cerca de Alaska</span></h2>
# 3 > Incidentes y tensión tras el ataque a tiros a un merendero de Parque Avellaneda: denuncias cruzadas por narcotráfico
# 3 > <h2 class="cst_hl dkt_fs_22"><span>Incidentes y tensión tras el ataque a tiros a un merendero de Parque Avellaneda: denuncias cruzadas por narcotráfico</span></h2>
# 4 > Por la crisis energética, la Comisión Europea pidió a los países de la región bloquear la minería de criptomonedas
# 4 > <h2 class="cst_hl dkt_fs_22"><span>Por la crisis energética, la Comisión Europea pidió a los países de la región bloquear la minería de criptomonedas </span></h2>
# 5 > La Corte Suprema rechazó el planteo del juez Castelli y deberá dejar el tribunal de Comodoro Py
# 5 > <h2 class="cst_hl dkt_fs_22"><span>La Corte Suprema rechazó el planteo del juez Castelli y deberá dejar el tribunal de Comodoro Py</span></h2>
# 6 > Courtois explotó contra el Balón de Oro tras la premiación a Benzema
# 6 > <h2 class="cst_hl dkt_fs_22"><span>Courtois explotó contra el Balón de Oro tras la premiación a Benzema</span></h2>
# 7 > Massa amenazó con abrir la importación de ropa si no frenan los aumentos desmedidos de precios
# 7 > <h2 class="cst_hl dkt_fs_22"><span>Massa amenazó con abrir la importación de ropa si no frenan los aumentos desmedidos de precios</span></h2>
# 8 > Juan Manzur insiste con su idea de dejar el Gobierno el año que viene para regresar a Tucumán
# 8 > <h2 class="cst_hl dkt_fs_22"><span>Juan Manzur insiste con su idea de dejar el Gobierno el año que viene para regresar a Tucumán</span></h2>
# 9 > Imputaron a Sabag Montiel por pedofilia: tenía más de 100 fotos y videos de abusos de chicos
# 9 > <h2 class="cst_hl dkt_fs_22"><span>Imputaron a Sabag Montiel por pedofilia: tenía más de 100 fotos y videos de abusos de chicos</span></h2>
# 10 > Esto es lo que le pasa a tu cuerpo al dejar de fumar
# 10 > <h2 class="cst_hl dkt_fs_22"><span>Esto es lo que le pasa a tu cuerpo al dejar de fumar </span></h2>
# 11 > ¿Un submarino nazi en el Mar Argentino? Sorpresivo hallazgo a la altura de Quequén
# 11 > <h2 class="cst_hl dkt_fs_22"><span>¿Un submarino nazi en el Mar Argentino? Sorpresivo hallazgo a la altura de Quequén</span></h2>
# 12 > Misterio por la caída de un hombre en las Cataratas: apareció una zapatilla pero nadie pide por la víctima
# 12 > <h2 class="cst_hl dkt_fs_22"><span>Misterio por la caída de un hombre en las Cataratas: apareció una zapatilla pero nadie pide por la víctima </span></h2>
# 13 > Insultos en el aire: el audio increíble de la discusión entre dos pilotos antes de aterrizar en Aeroparque
# 13 > <h2 class="cst_hl dkt_fs_22"><span>Insultos en el aire: el audio increíble de la discusión entre dos pilotos antes de aterrizar en Aeroparque</span></h2>
# 14 > Quién es Romina Uhrig, la ex diputada kirchnerista que entró a la casa de Gran Hermano
# 14 > <h2 class="cst_hl dkt_fs_22"><span>Quién es Romina Uhrig, la ex diputada kirchnerista que entró a la casa de Gran Hermano</span></h2>
# 15 > Uno por uno, quiénes son los 18 participantes de Gran Hermano
# 15 > <h2 class="cst_hl dkt_fs_22"><span>Uno por uno, quiénes son los 18 participantes de Gran Hermano </span></h2>
# 16 > Georgina Barbarossa habló de su relación con Alfa, de Gran Hermano
# 16 > <h2 class="cst_hl dkt_fs_22"><span>Georgina Barbarossa habló de su relación con Alfa, de Gran Hermano</span></h2>
# 17 > Intriga en GH: ¿qué le pusieron a Tomás Holder en el bolsillo?
# 17 > <h2 class="cst_hl dkt_fs_22"><span>Intriga en GH: ¿qué le pusieron a Tomás Holder en el bolsillo?</span></h2>
# 18 > Una participante de GH generó repudio por una frase polémica
# 18 > <h2 class="cst_hl dkt_fs_22"><span>Una participante de GH generó repudio por una frase polémica</span></h2>
# 19 > Dónde se fabrica y cuánto cuesta la réplica oficial de la mítica camiseta 10 que usó Maradona en México ‘86
# 19 > <h2 class="cst_hl dkt_fs_22"><span>Dónde se fabrica y cuánto cuesta la réplica oficial de la mítica camiseta 10 que usó Maradona en México ‘86 </span></h2>
# 20 > Por qué señalan a un ex futbolista como el "culpable" de la tormentosa separación de Piqué y Shakira
# 20 > <h2 class="cst_hl dkt_fs_22"><span>Por qué señalan a un ex futbolista como el "culpable" de la tormentosa separación de Piqué y Shakira</span></h2>
# 21 > La Justicia aceptó como querellante a Cristina Kirchner en la causa contra Revolución Federal
# 21 > <h2 class="cst_hl dkt_fs_22"><span>La Justicia aceptó como querellante a Cristina Kirchner en la causa contra Revolución Federal</span></h2>
# 22 > Precios Justos: las empresas que congelen precios podrían acceder a un dólar especial para exportar y a otros beneficios
# 22 > <h2 class="cst_hl dkt_fs_22"><span>Precios Justos: las empresas que congelen precios podrían acceder a un dólar especial para exportar y a otros beneficios</span></h2>
# 23 > Defensa y Justicia vence a Colón en Santa Fe en un vibrante partido por la Liga Profesional
# 23 > <h2 class="cst_hl dkt_fs_22"><span>Defensa y Justicia vence a Colón en Santa Fe en un vibrante partido por la Liga Profesional</span></h2>
# 24 > Extraño final en un partido del Mundial femenino Sub 17: la inédita protesta de las futbolistas
# 24 > <h2 class="cst_hl dkt_fs_22"><span>Extraño final en un partido del Mundial femenino Sub 17: la inédita protesta de las futbolistas</span></h2>
# 25 > Los millennials son los nuevos viejos en internet
# 25 > <h2 class="cst_hl dkt_fs_22"><span>Los millennials son los nuevos viejos en internet</span></h2>
# 26 > Investigan si el padre de la jugadora que murió en un accidente mató al dirigente que manejaba el auto
# 26 > <h2 class="cst_hl dkt_fs_22"><span>Investigan si el padre de la jugadora que murió en un accidente mató al dirigente que manejaba el auto</span></h2>
# 27 > Dallas Mavericks presentó a Campazzo: el detalle del nuevo número que usará en la NBA
# 27 > <h2 class="cst_hl dkt_fs_22"><span>Dallas Mavericks presentó a Campazzo: el detalle del nuevo número que usará en la NBA</span></h2>
# 28 > Beneficiaron con prisión domiciliaria al abogado que atropelló y mató a un piloto en Vicente López
# 28 > <h2 class="cst_hl dkt_fs_22"><span>Beneficiaron con prisión domiciliaria al abogado que atropelló y mató a un piloto en Vicente López</span></h2>
# 29 > Demichelis asoma como el sucesor de Gallardo y otros ex River podrían sumarse al cuerpo técnico
# 29 > <h2 class="cst_hl dkt_fs_22"><span>Demichelis asoma como el sucesor de Gallardo y otros ex River podrían sumarse al cuerpo técnico</span></h2>
# 30 > "La convivencia con Riquelme fue un problema complejo para Bianchi", reveló Macri en su libro
# 30 > <h2 class="cst_hl dkt_fs_22"><span>"La convivencia con Riquelme fue un problema complejo para Bianchi", reveló Macri en su libro</span></h2>
# 31 > Comer queso, ¿es bueno o malo para la salud?
# 31 > <h2 class="cst_hl dkt_fs_22"><span>Comer queso, ¿es bueno o malo para la salud?</span></h2>
# 32 > El libro con documentos inéditos sobre la ayuda de Perú a la Argentina en la guerra de Malvinas
# 32 > <h2 class="cst_hl dkt_fs_22"><span>El libro con documentos inéditos sobre la ayuda de Perú a la Argentina en la guerra de Malvinas</span></h2>
# 33 > La Justicia pidió la captura del vicepresidente iraní Mohsen Rezai, acusado por el atentado a la AMIA
# 33 > <h2 class="cst_hl dkt_fs_22"><span>La Justicia pidió la captura del vicepresidente iraní Mohsen Rezai, acusado por el atentado a la AMIA</span></h2>
# 34 > La población mundial de animales silvestres disminuyó casi 70% en los últimos 50 años
# 34 > <h2 class="cst_hl dkt_fs_22"><span>La población mundial de animales silvestres disminuyó casi 70% en los últimos 50 años</span></h2>
# 35 > Pilar Sordo: "El gran problema hoy es la pérdida del sentido de la vida"
# 35 > <h2 class="cst_hl dkt_fs_22"><span>Pilar Sordo: "El gran problema hoy es la pérdida del sentido de la vida"</span></h2>
# 36 > Los reclamos en la Justicia contra el desarrollador de los famosos prófugo en Israel y el rol familiar
# 36 > <h2 class="cst_hl dkt_fs_22"><span>Los reclamos en la Justicia contra el desarrollador de los famosos prófugo en Israel y el rol familiar</span></h2>
# 37 > Escándalo en Chaco: acusan a un juez federal de colaborar con un clan narco y allanaron su despacho
# 37 > <h2 class="cst_hl dkt_fs_22"><span>Escándalo en Chaco: acusan a un juez federal de colaborar con un clan narco y allanaron su despacho</span></h2>
# 38 > Flavio Azzaro: de jugar a ser periodista en la infancia al éxito en los medios digitales
# 38 > <h2 class="cst_hl dkt_fs_22"><span>Flavio Azzaro: de jugar a ser periodista en la infancia al éxito en los medios digitales</span></h2>
# 39 > Los 50 mejores entrenadores de la actualidad: los cuatro argentinos que integran la lista
# 39 > <h2 class="cst_hl dkt_fs_22"><span>Los 50 mejores entrenadores de la actualidad: los cuatro argentinos que integran la lista</span></h2>
# 40 > Imagine Dragons pospone su show en la Argentina: los motivos
# 40 > <h2 class="cst_hl dkt_fs_22"><span>Imagine Dragons pospone su show en la Argentina: los motivos</span></h2>
# 41 > Desapareció un hincha español que viajaba caminando a Qatar para ir al Mundial: la hipótesis que investigan
# 41 > <h2 class="cst_hl dkt_fs_22"><span>Desapareció un hincha español que viajaba caminando a Qatar para ir al Mundial: la hipótesis que investigan</span></h2>
# 42 > Brutal femicidio en Belgrano: le robó una fortuna a su ex y la mató en la bañera de su casa
# 42 > <h2 class="cst_hl dkt_fs_22"><span>Brutal femicidio en Belgrano: le robó una fortuna a su ex y la mató en la bañera de su casa</span></h2>
# 43 > El detenido por el femicidio intentó hacerse prestamista en Fuerte Apache con el dinero robado
# 43 > <h2 class="cst_hl dkt_fs_22"><span>El detenido por el femicidio intentó hacerse prestamista en Fuerte Apache con el dinero robado</span></h2>
# 44 > La responsabilidad de "Nicolasito", el hijo del dictador Maduro, en la tragedia de Las Tejerías
# 44 > <h2 class="cst_hl dkt_fs_22"><span>La responsabilidad de "Nicolasito", el hijo del dictador Maduro, en la tragedia de Las Tejerías</span></h2>
# 45 > Presupuesto 2023: asigna menos partidas para los planes sociales y mantiene el gasto en personal del Estado
# 45 > <h2 class="cst_hl dkt_fs_22"><span>Presupuesto 2023: asigna menos partidas para los planes sociales y mantiene el gasto en personal del Estado</span></h2>
# 46 > Un grupo de drogas para la diabetes tipo 2 reduce las hospitalizaciones y muertes por insuficiencia cardíaca
# 46 > <h2 class="cst_hl dkt_fs_22"><span>Un grupo de drogas para la diabetes tipo 2 reduce las hospitalizaciones y muertes por insuficiencia cardíaca</span></h2>
# 47 > El gobierno porteño presentó un amparo para destrabar el ingreso al país de las pistolas taser
# 47 > <h2 class="cst_hl dkt_fs_22"><span>El gobierno porteño presentó un amparo para destrabar el ingreso al país de las pistolas taser</span></h2>
# 48 > Usurpaciones: Nunca Más
# 48 > <h2 class="cst_hl dkt_fs_22"><span>Usurpaciones: Nunca Más</span></h2>
# 49 > El "Salvator Mundi", el cuadro más caro de la historia, sería exhibido en un nuevo museo
# 49 > <h2 class="cst_hl dkt_fs_22"><span>El "Salvator Mundi", el cuadro más caro de la historia, sería exhibido en un nuevo museo</span></h2>
# 50 > La dieta de los porteños antes de la Revolución de Mayo: anguila, paloma y carnes a la olla
# 50 > <h2 class="cst_hl dkt_fs_22"><span>La dieta de los porteños antes de la Revolución de Mayo: anguila, paloma y carnes a la olla</span></h2>
# 51 > Preocupa a los expertos la falta de control de los factores de riesgo cardiovascular
# 51 > <h2 class="cst_hl dkt_fs_22"><span>Preocupa a los expertos la falta de control de los factores de riesgo cardiovascular</span></h2>
# 52 > Berazategui: mataron a un jubilado a puñaladas y detuvieron a su pareja, una mujer 24 años menor
# 52 > <h2 class="cst_hl dkt_fs_22"><span>Berazategui: mataron a un jubilado a puñaladas y detuvieron a su pareja, una mujer 24 años menor</span></h2>
# 53 > Reemplazar los alimentos ultraprocesados por una dieta saludable alarga la vida a cualquier edad
# 53 > <h2 class="cst_hl dkt_fs_22"><span>Reemplazar los alimentos ultraprocesados por una dieta saludable alarga la vida a cualquier edad</span></h2>
# 54 > Shehan Karunatilaka, ganador del prestigioso Booker Prize
# 54 > <h2 class="cst_hl dkt_fs_22"><span>Shehan Karunatilaka, ganador del prestigioso Booker Prize</span></h2>
# 55 > Cuál es la importancia de llevar un registro de comidas
# 55 > <h2 class="cst_hl dkt_fs_22"><span>Cuál es la importancia de llevar un registro de comidas</span></h2>
# 56 > Dos perras callejeras evitaron que motochorros asaltaran a un vecino
# 56 > <h2 class="cst_hl dkt_fs_22"><span>Dos perras callejeras evitaron que motochorros asaltaran a un vecino</span></h2>
# 57 > Fue campeón con San Lorenzo, dirigió a Boca y cuenta intimidades de Maradona y Riquelme
# 57 > <h2 class="cst_hl dkt_fs_22"><span>Fue campeón con San Lorenzo, dirigió a Boca y cuenta intimidades de Maradona y Riquelme</span></h2>
# 58 > Avión venezolano-iraní: los tripulantes que seguían retenidos se fueron hoy a Venezuela
# 58 > <h2 class="cst_hl dkt_fs_22"><span>Avión venezolano-iraní: los tripulantes que seguían retenidos se fueron hoy a Venezuela</span></h2>
# 59 > Suspendieron la Feria de arte de Córdoba, la segunda más grande del país, a menos de un mes de su inicio
# 59 > <h2 class="cst_hl dkt_fs_22"><span>Suspendieron la Feria de arte de Córdoba, la segunda más grande del país, a menos de un mes de su inicio</span></h2>
# 60 > ¿Qué escribe un presidente cuando no gobierna? Los best-sellers de los principales dirigentes políticos
# 60 > <h2 class="cst_hl dkt_fs_22"><span>¿Qué escribe un presidente cuando no gobierna? Los best-sellers de los principales dirigentes políticos</span></h2>
# 61 > El parisino fan de la Argentina: el tatuaje del sello de entrada al país y la cita más rara de su vida
# 61 > <h2 class="cst_hl dkt_fs_22"><span>El parisino fan de la Argentina: el tatuaje del sello de entrada al país y la cita más rara de su vida</span></h2>
# 62 > No sólo el dólar oficial: advierten que también las cotizaciones financieras están atrasadas
# 62 > <h2 class="cst_hl dkt_fs_22"><span>No sólo el dólar oficial: advierten que también las cotizaciones financieras están atrasadas</span></h2>
# 63 > 100 años de Antonio Di Benedetto, revivir su literatura entre reediciones y homenajes
# 63 > <h2 class="cst_hl dkt_fs_22"><span>100 años de Antonio Di Benedetto, revivir su literatura entre reediciones y homenajes</span></h2>
# 64 > Recomendadas AM
# 64 > <h2 class="newsletter-card-title-page-view">Recomendadas AM</h2>
# 65 > Fronteras afuera
# 65 > <h2 class="newsletter-card-title-page-view">Fronteras afuera </h2>
# 66 > La nueva movilidad
# 66 > <h2 class="newsletter-card-title-page-view">La nueva movilidad</h2>
# 67 > Por qué el Salón del automóvil de París debe mutar si quiere sobrevivir
# 67 > <h2 class="cst_hl dkt_fs_22"><span>Por qué el Salón del automóvil de París debe mutar si quiere sobrevivir</span></h2>
# 68 > L-Gante y Wanda Nara, cada vez más cerca: desnudos y en la cama
# 68 > <h2 class="cst_hl dkt_fs_22"><span>L-Gante y Wanda Nara, cada vez más cerca: desnudos y en la cama </span></h2>
# 69 > Los gatos y sus más insólitas características
# 69 > <h2 class="cst_hl dkt_fs_22"><span>Los gatos y sus más insólitas características</span></h2>
# 70 > Decir que no, o cómo tolerar que un hijo te odie
# 70 > <h2 class="cst_hl dkt_fs_22"><span>Decir que no, o cómo tolerar que un hijo te odie</span></h2>
# 71 > El Vaticano devuelve a Perú tres momias que tenía en sus museos
# 71 > <h2 class="cst_hl dkt_fs_22"><span>El Vaticano devuelve a Perú tres momias que tenía en sus museos</span></h2>
# 72 > La vocación de Salkantay Ventures por generar impactos positivos en la educación de América Latina
# 72 > <h2 class="cst_hl dkt_fs_22"><span>La vocación de Salkantay Ventures por generar impactos positivos en la educación de América Latina</span></h2>
# 73 > Quiénes son los grandes protagonistas de la próxima edición de Virtual Educa en Medellín
# 73 > <h2 class="cst_hl dkt_fs_22"><span>Quiénes son los grandes protagonistas de la próxima edición de Virtual Educa en Medellín</span></h2>
# 74 > Un profesor holograma, gafas de realidad virtual y más tecnología de vanguardia: la apuesta del Tec de Monterrey por la educación digital
# 74 > <h2 class="cst_hl dkt_fs_22"><span>Un profesor holograma, gafas de realidad virtual y más tecnología de vanguardia: la apuesta del Tec de Monterrey por la educación digital</span></h2>
# 75 > Apple: estos son los nuevos iPad y iPad Pro
# 75 > <h2 class="cst_hl"><span>Apple: estos son los nuevos iPad y iPad Pro</span></h2>
# 76 > Guía para para comenzar a hacer streaming en Twitch
# 76 > <h2 class="cst_hl"><span>Guía para para comenzar a hacer streaming en Twitch </span></h2>
# 77 > Google agregó  funciones para controlar lo que hacen los niños en  Family Link y Google TV
# 77 > <h2 class="cst_hl"><span>Google agregó  funciones para controlar lo que hacen los niños en  Family Link y Google TV</span></h2>
# 78 > 6 películas de Zac Efron para ver en streaming por el día de su cumpleaños
# 78 > <h2 class="cst_hl"><span>6 películas de Zac Efron para ver en streaming por el día de su cumpleaños</span></h2>
# 79 > Los “Teletubbies” están de regreso: mira el adelanto del reboot de Netflix
# 79 > <h2 class="cst_hl"><span>Los “Teletubbies” están de regreso: mira el adelanto del reboot de Netflix</span></h2>
# 80 > [EXCLUSIVO] Primer adelanto de “Creed 3″ con el debut como director de Michael B. Jordan
# 80 > <h2 class="cst_hl"><span>[EXCLUSIVO] Primer adelanto de “Creed 3″ con el debut como director de Michael B. Jordan </span></h2>
# 81 > Preocupante escenario en Portugal: Diogo Jota no jugará el Mundial y otros 3 jugadores están en riesgo
# 81 > <h2 class="cst_hl dkt_fs_22"><span>Preocupante escenario en Portugal: Diogo Jota no jugará el Mundial y otros 3 jugadores están en riesgo</span></h2>
# 82 > Los dueños del Inter de Milan pusieron el club a la venta por la gran cantidad de deudas
# 82 > <h2 class="cst_hl dkt_fs_22"><span>Los dueños del Inter de Milan pusieron el club a la venta por la gran cantidad de deudas</span></h2>
# 83 > Indonesia: demolerán el estadio donde se produjo una tragedia con más de 130 personas muertas
# 83 > <h2 class="cst_hl dkt_fs_22"><span>Indonesia: demolerán el estadio donde se produjo una tragedia con más de 130 personas muertas</span></h2>
# 84 > El duelo entre Gimnasia y Boca Juniors volvió a cambiar de día y horario de inicio
# 84 > <h2 class="cst_hl dkt_fs_22"><span>El duelo entre Gimnasia y Boca Juniors volvió a cambiar de día y horario de inicio</span></h2>
# 85 > Gran Hermano: Thiago trabaja en el Mercado Central y se perfila como uno de los preferidos
# 85 > <h2 class="cst_hl dkt_fs_22"><span>Gran Hermano: Thiago trabaja en el Mercado Central y se perfila como uno de los preferidos</span></h2>
# 86 > Volvió Gran Hermano y arrasó con el rating
# 86 > <h2 class="cst_hl dkt_fs_22"><span>Volvió Gran Hermano y arrasó con el rating</span></h2>
# 87 > De las guitarreadas en familia al apoyo del barrio: historias de los finalistas de Canta Conmigo Ahora
# 87 > <h2 class="cst_hl dkt_fs_22"><span>De las guitarreadas en familia al apoyo del barrio: historias de los finalistas de Canta Conmigo Ahora</span></h2>
# 88 > Spacey dijo que esperó hasta los 58 años para declararse gay porque su padre era  neonazi
# 88 > <h2 class="cst_hl dkt_fs_22"><span>Spacey dijo que esperó hasta los 58 años para declararse gay porque su padre era  neonazi</span></h2>
# 89 > Scorn, la experiencia que puede comenzar un nuevo género dentro del mundo del gaming
# 89 > <h2 class="cst_hl dkt_fs_22"><span>Scorn, la experiencia que puede comenzar un nuevo género dentro del mundo del gaming</span></h2>
# 90 > Llegó la hora: Konami le contará al mundo que sucederá con la franquicia de Silent Hill
# 90 > <h2 class="cst_hl dkt_fs_22"><span>Llegó la hora: Konami le contará al mundo que sucederá con la franquicia de Silent Hill</span></h2>
# 91 > Activision Blizzard patentó un proyecto para crear bandas de sonido únicas en los juegos
# 91 > <h2 class="cst_hl dkt_fs_22"><span>Activision Blizzard patentó un proyecto para crear bandas de sonido únicas en los juegos</span></h2>
# 92 > Los sonidos del arte de León Ferrari, a través de su "música no figurativa"
# 92 > <h2 class="cst_hl dkt_fs_22"><span>Los sonidos del arte de León Ferrari, a través de su "música no figurativa"</span></h2>
# 93 > "Veinte pitadas": Las vetas vivas de la madera debajo de la pintura
# 93 > <h2 class="cst_hl dkt_fs_22"><span>"Veinte pitadas": Las vetas vivas de la madera debajo de la pintura</span></h2>
# 94 > Un viaje nostálgico a la Nueva York de Edward Hopper en el Museo Whitney
# 94 > <h2 class="cst_hl dkt_fs_22"><span>Un viaje nostálgico a la Nueva York de Edward Hopper en el Museo Whitney</span></h2>
# 95 > Cómo saber el sexo del bebé en la octava semana de embarazo
# 95 > <h2 class="cst_hl dkt_fs_22"><span>Cómo saber el sexo del bebé en la octava semana de embarazo</span></h2>
# 96 > Recibo de sueldo digital: cómo solicitarlo y qué beneficios aporta
# 96 > <h2 class="cst_hl dkt_fs_22"><span>Recibo de sueldo digital: cómo solicitarlo y qué beneficios aporta</span></h2>
# 97 > Chile: el país vecino tiene nuevos motivos para visitarlo
# 97 > <h2 class="cst_hl dkt_fs_22"><span>Chile: el país vecino tiene nuevos motivos para visitarlo</span></h2>
# 98 > Un evento revelará los principales desafíos para los líderes de marketing en 2023
# 98 > <h2 class="cst_hl dkt_fs_22"><span>Un evento revelará los principales desafíos para los líderes de marketing en 2023</span></h2>
# 99 > Cumbre C40: cuáles serán las actividades artísticas y recreativas abiertas al público
# 99 > <h2 class="cst_hl dkt_fs_22"><span>Cumbre C40: cuáles serán las actividades artísticas y recreativas abiertas al público</span></h2>
# 100 > La IGJ y la sociedad de los poetas muertos: un debate en torno a la igualdad
# 100 > <h2 class="opi_hl"><span>La IGJ y la sociedad de los poetas muertos: un debate en torno a la igualdad</span></h2>
# 101 > “La política pide ajuste, pero es un error”
# 101 > <h2 class="opi_hl"><span>“La política pide ajuste, pero es un error”</span></h2>
# 102 > ¿Qué es ser un buen docente hoy?
# 102 > <h2 class="opi_hl"><span>¿Qué es ser un buen docente hoy?</span></h2>
# 103 > ÚLTIMAS NOTICIAS
# 103 > <h2 class="feed-column-heading"><a href="https://www.infobae.com/ultimas-noticias/"><span style="color: #D91023;font-size:20px;"><strong>ÚLTIMAS NOTICIAS</strong></span></a></h2>
# 104 > TELESHOW
# 104 > <h2 class="feed-column-heading"><a href="https://www.infobae.com/teleshow/"><span style="color: #D91023;font-size:20px;"><strong>TELESHOW</strong></span></a></h2>
# 105 > DEPORTES
# 105 > <h2 class="feed-column-heading"><a href="https://www.infobae.com/america/deportes/"><strong style="font-size:20px;">DEPORTES</strong></a></h2>
