# %%
import requests
import bs4 as bs
import lxml
from pprint import pprint

httpaddr = "https://www.infobae.com"
requests_ret = requests.get(httpaddr)
print(requests_ret, end = ' || ')
soup = bs.BeautifulSoup(requests_ret.text, 'lxml')
# discard <script> and <style> tags
for discard_tag in ("script", "style"):
    for t in soup.find_all(discard_tag): t.extract()
tags_tuple = ('article', 'section', 'header') + tuple(('h' + str(i) for i in range(1, 7)))
tags = {tag_str : soup.find_all(tag_str) for tag_str in tags_tuple}
for i, tag in enumerate(tags):
    print(f"{tag}s : {len(tags[tag])}", sep = '', end = '\n' if i == len(tags) - 1 else ' / ')
# Out:
# <Response [200]> || articles : 0 / sections : 0 / headers : 0 / h1s : 0 / h2s : 102 / h3s : 15 / h4s : 0 / h5s : 0 / h6s : 0

# %%
# Some utility functions - print_tag_subtree - depth
def print_tag_subtree(tag, prefix):
    stack = []
    stack.extend(reversed([ch for ch in tag.children if isinstance(ch, bs.element.Tag)]))
    text_payload = tag.get_text()
    print(prefix + tag.name + ': ' + 
        ('[' + str(tags['h2'].index(tag)) + '] : ' +
        tag.get_text() if tag.name == 'h2' else ''))

    while stack:
        print_tag_subtree(stack.pop(), ' | ' + prefix)

def depth(tag):
    tag_depth = 0
    while not isinstance(tag, bs.BeautifulSoup):
        tag_depth += 1
        tag = tag.parent
    return tag_depth

# %%
# Check for <h2> nesting
for i, h2_i in enumerate(tags['h2']):
    for j, h2_j in enumerate(tags['h2']):
        if h2_j == h2_i:
            continue
        if h2_j in list(h2_i.find_all('h2')):
            print(f'<h2> [{j}] in <h2> [{i}]')
#

# %%
# Clusters <h2>s according to the nearest upper tag containing more than one <h2>
# WARNING: This is brittle under some conditions like "Live streaming" & "News Flash"
# TOOD: ... exploit such brittleness to:
# ... 1) Detect "Live Streams" and "Newsflashes"
# -- this could be generalized and canned into a function -- 
clusters_list = []
clusters_dict = {}
for i, h2 in enumerate(tags['h2']):
    tag = h2.parent
    while len(list(tag.find_all('h2'))) == 1:
        tag = tag.parent
    h2_cluster = list(tag.find_all('h2'))
    if list(tag.find_all('h2')) in clusters_list: 
        continue
    else:
        clusters_list.append(list(tag.find_all('h2')))
        clusters_dict[tag] = list(tag.find_all('h2'))

    
#   print(i, '>', len(list(tag.find_all('h2'))))
#   for t in tag.find_all('h2'):
#       print('\t', t.get_text())
    # at this point, h2 is in a given cluster
print('Number of Clusters (list): ', len(clusters_list), sep = '')
print('Number of Clusters (dict): ', len(clusters_dict), sep = '')
print('-' * len('Number of Clusters (dict): ' + str(len(clusters_dict))))
for i, cluster in enumerate(clusters_list):
    if i == 0: continue
    print(f'Cluster Number {i} -- Number of members on the cluster {len(cluster)}')
    print('-' * len(f'Cluster Number {i} -- Number of members on the cluster {len(cluster)}'))
    for j, member in enumerate(cluster):
        print(f"|\tOrder within cluster {j} -- Order within headers {tags['h2'].index(member)}")
        print(f"|\tText :: {member.get_text()}")
        if j + 1 < len(cluster): print("|")
    print("End_Of_Cluster", '-' * 40, '\n')
# Out:
# Number of Clusters (list): 31
# Number of Clusters (dict): 31
# -----------------------------
# Cluster Number 1 -- Number of members on the cluster 3
# ------------------------------------------------------
# |	Order within cluster 0 -- Order within headers 3
# |	Text :: En el peronismo descuentan que la militancia se movilizará ante una eventual condena a CFK
# |
# |	Order within cluster 1 -- Order within headers 4
# |	Text :: El inició del dólar soja 2 incrementó las ventas pero en menor medida que en la primera etapa del plan
# |
# |	Order within cluster 2 -- Order within headers 5
# |	Text :: Quién es el sindicalista que amenaza con parar el Estado si la Justicia condena a Cristina Kirchner
# End_Of_Cluster ----------------------------------------
#
# Cluster Number 2 -- Number of members on the cluster 95
# -------------------------------------------------------
# |	Order within cluster 0 -- Order within headers 0
# |	Text :: Integrantes de los movimientos sociales amenazan con irse del Gobierno en medio de la tensión por los planes
# |
# |	Order within cluster 1 -- Order within headers 1
# |	Text :: Dos décadas después del crimen, la Justicia definirá hoy si condena a Nicolás Pachelo por la muerte de María Marta García Belsunce
# |
# |	Order within cluster 2 -- Order within headers 2
# |	Text :: El fenómeno Julián Álvarez, mezcla de fútbol de la calle con la academia
# |
# |	Order within cluster 3 -- Order within headers 3
# |	Text :: En el peronismo descuentan que la militancia se movilizará ante una eventual condena a CFK
# |
# |	Order within cluster 4 -- Order within headers 4
# |	Text :: El inició del dólar soja 2 incrementó las ventas pero en menor medida que en la primera etapa del plan
# |
# |	Order within cluster 5 -- Order within headers 5
# |	Text :: Quién es el sindicalista que amenaza con parar el Estado si la Justicia condena a Cristina Kirchner
# |
# |	Order within cluster 6 -- Order within headers 6
# |	Text :: AGENDA DE PARTIDOS DEL DÍA
# |
# |	Order within cluster 7 -- Order within headers 7
# |	Text :: El regalo que un millonario qatarí le hizo a una periodista argentina que está cubriendo el Mundial
# |
# |	Order within cluster 8 -- Order within headers 8
# |	Text :: Las quejas de los turistas que se alojan en carpas de la FIFA en el norte de Doha
# |
# |	Order within cluster 9 -- Order within headers 9
# |	Text :: Quién es Mati “Teclas”, el amigo de los jugadores que armó un ritual con los argentinos en Qatar
# |
# |	Order within cluster 10 -- Order within headers 10
# |	Text :: Los goles de Batistuta y el misil de Sorín: las perlitas del partido entre leyendas de Selección y periodistas
# |
# |	Order within cluster 11 -- Order within headers 11
# |	Text :: Así está hoy el cuadro de octavos de final del Mundial
# |
# |	Order within cluster 12 -- Order within headers 12
# |	Text :: La "trampa" que ayudó a Australia a avanzar a los octavos de final del Mundial 2022
# |
# |	Order within cluster 13 -- Order within headers 13
# |	Text :: La ilusión que nos condena
# |
# |	Order within cluster 14 -- Order within headers 14
# |	Text :: España no pudo revertir el resultado contra Japón y dejó afuera a Alemania: ¿tenía ganas de hacerlo?
# |
# |	Order within cluster 15 -- Order within headers 15
# |	Text :: Camellos y viaje en 4x4: la excursión al desierto que hicieron Antonela Roccuzzo y sus hijos
# |
# |	Order within cluster 16 -- Order within headers 16
# |	Text :: La Cámara de Comercio Argentino Israelí cerró el año y prevé más acuerdos de cooperación
# |
# |	Order within cluster 17 -- Order within headers 17
# |	Text :: 50 fotos: la Cámara de Comercio Argentino-Israelí celebró su evento anual
# |
# |	Order within cluster 18 -- Order within headers 18
# |	Text :: Los padres de Báez Sosa a un mes del juicio: “Estamos condenados a ser infelices para siempre”
# |
# |	Order within cluster 19 -- Order within headers 19
# |	Text :: Violento robo en Recoleta: un hombre fue apuñalado con una tijera cuando volvía de su trabajo
# |
# |	Order within cluster 20 -- Order within headers 20
# |	Text :: Violencia en Rosario: la ciudad registró 264 asesinatos e igualó su récord histórico
# |
# |	Order within cluster 21 -- Order within headers 21
# |	Text :: Cuántos pasos por día se deben caminar para estar saludable, según expertos de Harvard
# |
# |	Order within cluster 22 -- Order within headers 22
# |	Text :: COVID: cómo podría surgir una nueva variante más peligrosa y letal que Ómicron
# |
# |	Order within cluster 23 -- Order within headers 23
# |	Text :: Digamos la verdad de las cicatrices
# |
# |	Order within cluster 24 -- Order within headers 24
# |	Text :: Las vacaciones de la China Suárez en Qatar: amor en el desierto con Rusherking
# |
# |	Order within cluster 25 -- Order within headers 25
# |	Text :: Gran Hermano: la sorpresiva decisión de Romina que provocó el enojo de Alfa
# |
# |	Order within cluster 26 -- Order within headers 26
# |	Text :: Cómo es el nuevo avión presidencial que comprará el Gobierno
# |
# |	Order within cluster 27 -- Order within headers 27
# |	Text :: Así no podemos seguir
# |
# |	Order within cluster 28 -- Order within headers 28
# |	Text :: El final de Pablo Escobar en La Casa Azul acorralado junto a su familia, que lo vio llorar como un niño
# |
# |	Order within cluster 29 -- Order within headers 29
# |	Text :: Christine Jorgensen: la historia dolorosa y valiente de la primera transexual que alzó su voz
# |
# |	Order within cluster 30 -- Order within headers 30
# |	Text :: Escándalo en Diputados: entre gritos e insultos, JxC se retiró del recinto y se levantó la sesión
# |
# |	Order within cluster 31 -- Order within headers 31
# |	Text :: De niña manipulada por sus padres al desenfreno total y la salvación, la vertiginosa vida de Britney Spears
# |
# |	Order within cluster 32 -- Order within headers 32
# |	Text :: Yeyo De Gregorio: "A los 8 años ganaba más plata que mi papá, pero sin ellos no sé qué hubiera pasado"
# |
# |	Order within cluster 33 -- Order within headers 33
# |	Text :: Leé gratis la saga de Louisa May Alcott
# |
# |	Order within cluster 34 -- Order within headers 34
# |	Text :: Estas son las 10 ciudades del mundo más caras para vivir
# |
# |	Order within cluster 35 -- Order within headers 35
# |	Text :: Shakira y Piqué confirmaron su separación ante un juez en Barcelona
# |
# |	Order within cluster 36 -- Order within headers 36
# |	Text :: 30 fotos: la Fundación Ama Amoedo presentó sus nuevas iniciativas en The Bass Museum, en Miami
# |
# |	Order within cluster 37 -- Order within headers 37
# |	Text :: Twitter suspendió la cuenta de Kanye West por violar normas contra la violencia tras sus comentarios antisemitas
# |
# |	Order within cluster 38 -- Order within headers 38
# |	Text :: Solo siete de cada cien empresas en la Argentina tiene planes de reducir la jornada laboral
# |
# |	Order within cluster 39 -- Order within headers 39
# |	Text :: Clave para las reservas del BCRA: el dólar oficial le ganó a la inflación en noviembre
# |
# |	Order within cluster 40 -- Order within headers 40
# |	Text :: Se firmó un acuerdo para identificar a personas enterradas sin identificar
# |
# |	Order within cluster 41 -- Order within headers 41
# |	Text :: Feminista en falta: ¿por qué cuesta tanto denunciar la violencia?
# |
# |	Order within cluster 42 -- Order within headers 42
# |	Text :: Camino a una tragedia
# |
# |	Order within cluster 43 -- Order within headers 43
# |	Text :: Queremos tanto a Messi
# |
# |	Order within cluster 44 -- Order within headers 44
# |	Text :: ¿Es saludable llevar una dieta vegana?
# |
# |	Order within cluster 45 -- Order within headers 45
# |	Text :: Leloir, el genio humilde que ganó el Nobel: solo tenía un Fitito y pudo ser millonario por un invento
# |
# |	Order within cluster 46 -- Order within headers 46
# |	Text :: Reciclado de pilas gastadas y otros innovadores proyectos finalistas del IB50K
# |
# |	Order within cluster 47 -- Order within headers 47
# |	Text :: El 40% de las víctimas de violencia de género no denuncia por miedo a no poder mantener a sus hijos
# |
# |	Order within cluster 48 -- Order within headers 48
# |	Text :: La confesión que le hizo Anita Co a uno de los participantes de Canta Conmigo Ahora
# |
# |	Order within cluster 49 -- Order within headers 49
# |	Text :: 27 fotos de la cena por los 60 años de ADEPA
# |
# |	Order within cluster 50 -- Order within headers 50
# |	Text :: Prueban un anticonceptivo masculino que bloquea el paso del esperma
# |
# |	Order within cluster 51 -- Order within headers 51
# |	Text :: Qué leer el fin de semana: Gabriel Rolón y el bestseller "El monje que vendió su Ferrari"
# |
# |	Order within cluster 52 -- Order within headers 52
# |	Text :: Una web ayuda a personas con discapacidad a conocer sus derechos y qué pasos dar para hacerlos cumplir
# |
# |	Order within cluster 53 -- Order within headers 53
# |	Text :: Los 5 tríplex más costosos que están en venta en Buenos Aires
# |
# |	Order within cluster 54 -- Order within headers 54
# |	Text :: NEWSLETTERS
# |
# |	Order within cluster 55 -- Order within headers 55
# |	Text :: Recomendadas AM
# |
# |	Order within cluster 56 -- Order within headers 56
# |	Text :: Recomendadas PM
# |
# |	Order within cluster 57 -- Order within headers 57
# |	Text :: La semana en Europa
# |
# |	Order within cluster 58 -- Order within headers 58
# |	Text :: WEB STORIES
# |
# |	Order within cluster 59 -- Order within headers 59
# |	Text :: Arena, piedras y un desafío más extenuante: así será el Rally Dakar 2023 en Arabia Saudita
# |
# |	Order within cluster 60 -- Order within headers 60
# |	Text :: De todos los uruguayos que nos hicieron reír, hay uno que además nos hizo pensar mucho
# |
# |	Order within cluster 61 -- Order within headers 61
# |	Text :: El detrás de escena de la ceremonia del té, desde el siglo XVI hasta el mensaje que nos da en el presente
# |
# |	Order within cluster 62 -- Order within headers 62
# |	Text :: Por qué comer papa podría ayudar a perder peso, según la ciencia
# |
# |	Order within cluster 63 -- Order within headers 63
# |	Text :: ¡Pero qué monstruosa puede llegar a ser la gente rica!
# |
# |	Order within cluster 64 -- Order within headers 64
# |	Text :: Su padre carpintero le heredó la pasión por la artesanía pero la usó para ser poeta: José Watanabe
# |
# |	Order within cluster 65 -- Order within headers 65
# |	Text :: ART BASEL MIAMI BEACH 2022
# |
# |	Order within cluster 66 -- Order within headers 66
# |	Text :: Art Basel y Miami Art Week: agenda para el viernes 2
# |
# |	Order within cluster 67 -- Order within headers 67
# |	Text :: Arte, tecnología y Art Basel: lo que ayer era imposible, hoy está al alcance de los artistas jóvenes
# |
# |	Order within cluster 68 -- Order within headers 68
# |	Text :: “No Vacancy”: cerca de Art Basel, 12 hoteles icónicos de Miami Beach se visten de arte
# |
# |	Order within cluster 69 -- Order within headers 69
# |	Text :: El Perez Art Museum participa de Miami Art Week con una programación especial
# |
# |	Order within cluster 70 -- Order within headers 70
# |	Text :: CRIPTOMONEDAS
# |
# |	Order within cluster 71 -- Order within headers 71
# |	Text :: TECNOLOGÍA
# |
# |	Order within cluster 72 -- Order within headers 72
# |	Text :: Blessd, Tiago PZK, Karol G y El Yaki, los reyes de YouTube durante 2022 en Latinoamérica
# |
# |	Order within cluster 73 -- Order within headers 73
# |	Text :: WhatsApp:  cómo buscar un mensaje por fecha
# |
# |	Order within cluster 74 -- Order within headers 74
# |	Text :: Cuatro aplicaciones para no olvidar ningún cumpleaños
# |
# |	Order within cluster 75 -- Order within headers 75
# |	Text :: QUÉ PUEDO VER
# |
# |	Order within cluster 76 -- Order within headers 76
# |	Text :: “Love me”: de qué se trata esta conmovedora e impactante serie
# |
# |	Order within cluster 77 -- Order within headers 77
# |	Text :: “Ant-Man and The Wasp: Quantumania” lanzó un nuevo adelanto especial con el recorrido del héroe
# |
# |	Order within cluster 78 -- Order within headers 78
# |	Text :: “Guardianes de la galaxia Vol. 3” lanza su primer adelanto a unos meses de llegar al cine
# |
# |	Order within cluster 79 -- Order within headers 79
# |	Text :: TELESHOW
# |
# |	Order within cluster 80 -- Order within headers 80
# |	Text :: El conmovedor gesto del ganador de Los 8 escalones
# |
# |	Order within cluster 81 -- Order within headers 81
# |	Text :: Nazarena Vélez tuvo un accidente en el cumpleaños de Andrea Taboada
# |
# |	Order within cluster 82 -- Order within headers 82
# |	Text :: El Pollo Álvarez se encontró con su doble en Qatar: "Somos iguales"
# |
# |	Order within cluster 83 -- Order within headers 83
# |	Text :: Shakira sorprendió con imponente ‘look’ en la cita final con Piqué
# |
# |	Order within cluster 84 -- Order within headers 84
# |	Text :: LATIN POWER
# |
# |	Order within cluster 85 -- Order within headers 85
# |	Text :: PlayStation Plus le dio la bienvenida a diciembre con sus tres nuevos juegos gratuitos
# |
# |	Order within cluster 86 -- Order within headers 86
# |	Text :: Street Fighter 6 anunció las nuevas fechas para inscribirse en su segunda fase de prueba cerrada
# |
# |	Order within cluster 87 -- Order within headers 87
# |	Text :: Epic Games Store empezó el mes con dos opciones gratuitas: Fort Triumph y RPG in a Box
# |
# |	Order within cluster 88 -- Order within headers 88
# |	Text :: CULTURA
# |
# |	Order within cluster 89 -- Order within headers 89
# |	Text :: Raquel Forner y la conquista del cosmos a través de la belleza
# |
# |	Order within cluster 90 -- Order within headers 90
# |	Text :: Guía de Arte y Cultura: semana del 2 al 9 de diciembre
# |
# |	Order within cluster 91 -- Order within headers 91
# |	Text :: "El skate del diablo", cuando la maldición de una venganza viaja en patineta
# |
# |	Order within cluster 92 -- Order within headers 92
# |	Text :: Cómo calcular las cuotas para comprar un departamento en la Ciudad de Buenos Aires
# |
# |	Order within cluster 93 -- Order within headers 93
# |	Text :: Vacaciones en Mar del Plata: qué actividades ofrece este verano 2023
# |
# |	Order within cluster 94 -- Order within headers 94
# |	Text :: Así festejó 22 años de historia una reconocida firma de zapatos: regalos, descuentos y muchas celebridades
# End_Of_Cluster ----------------------------------------
#
# Cluster Number 3 -- Number of members on the cluster 4
# ------------------------------------------------------
# |	Order within cluster 0 -- Order within headers 7
# |	Text :: El regalo que un millonario qatarí le hizo a una periodista argentina que está cubriendo el Mundial
# |
# |	Order within cluster 1 -- Order within headers 8
# |	Text :: Las quejas de los turistas que se alojan en carpas de la FIFA en el norte de Doha
# |
# |	Order within cluster 2 -- Order within headers 9
# |	Text :: Quién es Mati “Teclas”, el amigo de los jugadores que armó un ritual con los argentinos en Qatar
# |
# |	Order within cluster 3 -- Order within headers 10
# |	Text :: Los goles de Batistuta y el misil de Sorín: las perlitas del partido entre leyendas de Selección y periodistas
# End_Of_Cluster ----------------------------------------
#
# Cluster Number 4 -- Number of members on the cluster 4
# ------------------------------------------------------
# |	Order within cluster 0 -- Order within headers 12
# |	Text :: La "trampa" que ayudó a Australia a avanzar a los octavos de final del Mundial 2022
# |
# |	Order within cluster 1 -- Order within headers 13
# |	Text :: La ilusión que nos condena
# |
# |	Order within cluster 2 -- Order within headers 14
# |	Text :: España no pudo revertir el resultado contra Japón y dejó afuera a Alemania: ¿tenía ganas de hacerlo?
# |
# |	Order within cluster 3 -- Order within headers 15
# |	Text :: Camellos y viaje en 4x4: la excursión al desierto que hicieron Antonela Roccuzzo y sus hijos
# End_Of_Cluster ----------------------------------------
#
# Cluster Number 5 -- Number of members on the cluster 2
# ------------------------------------------------------
# |	Order within cluster 0 -- Order within headers 16
# |	Text :: La Cámara de Comercio Argentino Israelí cerró el año y prevé más acuerdos de cooperación
# |
# |	Order within cluster 1 -- Order within headers 17
# |	Text :: 50 fotos: la Cámara de Comercio Argentino-Israelí celebró su evento anual
# End_Of_Cluster ----------------------------------------
#
# Cluster Number 6 -- Number of members on the cluster 3
# ------------------------------------------------------
# |	Order within cluster 0 -- Order within headers 18
# |	Text :: Los padres de Báez Sosa a un mes del juicio: “Estamos condenados a ser infelices para siempre”
# |
# |	Order within cluster 1 -- Order within headers 19
# |	Text :: Violento robo en Recoleta: un hombre fue apuñalado con una tijera cuando volvía de su trabajo
# |
# |	Order within cluster 2 -- Order within headers 20
# |	Text :: Violencia en Rosario: la ciudad registró 264 asesinatos e igualó su récord histórico
# End_Of_Cluster ----------------------------------------
#
# Cluster Number 7 -- Number of members on the cluster 4
# ------------------------------------------------------
# |	Order within cluster 0 -- Order within headers 21
# |	Text :: Cuántos pasos por día se deben caminar para estar saludable, según expertos de Harvard
# |
# |	Order within cluster 1 -- Order within headers 22
# |	Text :: COVID: cómo podría surgir una nueva variante más peligrosa y letal que Ómicron
# |
# |	Order within cluster 2 -- Order within headers 23
# |	Text :: Digamos la verdad de las cicatrices
# |
# |	Order within cluster 3 -- Order within headers 24
# |	Text :: Las vacaciones de la China Suárez en Qatar: amor en el desierto con Rusherking
# End_Of_Cluster ----------------------------------------
#
# Cluster Number 8 -- Number of members on the cluster 3
# ------------------------------------------------------
# |	Order within cluster 0 -- Order within headers 25
# |	Text :: Gran Hermano: la sorpresiva decisión de Romina que provocó el enojo de Alfa
# |
# |	Order within cluster 1 -- Order within headers 26
# |	Text :: Cómo es el nuevo avión presidencial que comprará el Gobierno
# |
# |	Order within cluster 2 -- Order within headers 27
# |	Text :: Así no podemos seguir
# End_Of_Cluster ----------------------------------------
#
# Cluster Number 9 -- Number of members on the cluster 2
# ------------------------------------------------------
# |	Order within cluster 0 -- Order within headers 28
# |	Text :: El final de Pablo Escobar en La Casa Azul acorralado junto a su familia, que lo vio llorar como un niño
# |
# |	Order within cluster 1 -- Order within headers 29
# |	Text :: Christine Jorgensen: la historia dolorosa y valiente de la primera transexual que alzó su voz
# End_Of_Cluster ----------------------------------------
#
# Cluster Number 10 -- Number of members on the cluster 2
# -------------------------------------------------------
# |	Order within cluster 0 -- Order within headers 30
# |	Text :: Escándalo en Diputados: entre gritos e insultos, JxC se retiró del recinto y se levantó la sesión
# |
# |	Order within cluster 1 -- Order within headers 31
# |	Text :: De niña manipulada por sus padres al desenfreno total y la salvación, la vertiginosa vida de Britney Spears
# End_Of_Cluster ----------------------------------------
#
# Cluster Number 11 -- Number of members on the cluster 4
# -------------------------------------------------------
# |	Order within cluster 0 -- Order within headers 32
# |	Text :: Yeyo De Gregorio: "A los 8 años ganaba más plata que mi papá, pero sin ellos no sé qué hubiera pasado"
# |
# |	Order within cluster 1 -- Order within headers 33
# |	Text :: Leé gratis la saga de Louisa May Alcott
# |
# |	Order within cluster 2 -- Order within headers 34
# |	Text :: Estas son las 10 ciudades del mundo más caras para vivir
# |
# |	Order within cluster 3 -- Order within headers 35
# |	Text :: Shakira y Piqué confirmaron su separación ante un juez en Barcelona
# End_Of_Cluster ----------------------------------------
#
# Cluster Number 12 -- Number of members on the cluster 2
# -------------------------------------------------------
# |	Order within cluster 0 -- Order within headers 36
# |	Text :: 30 fotos: la Fundación Ama Amoedo presentó sus nuevas iniciativas en The Bass Museum, en Miami
# |
# |	Order within cluster 1 -- Order within headers 37
# |	Text :: Twitter suspendió la cuenta de Kanye West por violar normas contra la violencia tras sus comentarios antisemitas
# End_Of_Cluster ----------------------------------------
#
# Cluster Number 13 -- Number of members on the cluster 3
# -------------------------------------------------------
# |	Order within cluster 0 -- Order within headers 38
# |	Text :: Solo siete de cada cien empresas en la Argentina tiene planes de reducir la jornada laboral
# |
# |	Order within cluster 1 -- Order within headers 39
# |	Text :: Clave para las reservas del BCRA: el dólar oficial le ganó a la inflación en noviembre
# |
# |	Order within cluster 2 -- Order within headers 40
# |	Text :: Se firmó un acuerdo para identificar a personas enterradas sin identificar
# End_Of_Cluster ----------------------------------------
#
# Cluster Number 14 -- Number of members on the cluster 4
# -------------------------------------------------------
# |	Order within cluster 0 -- Order within headers 41
# |	Text :: Feminista en falta: ¿por qué cuesta tanto denunciar la violencia?
# |
# |	Order within cluster 1 -- Order within headers 42
# |	Text :: Camino a una tragedia
# |
# |	Order within cluster 2 -- Order within headers 43
# |	Text :: Queremos tanto a Messi
# |
# |	Order within cluster 3 -- Order within headers 44
# |	Text :: ¿Es saludable llevar una dieta vegana?
# End_Of_Cluster ----------------------------------------
#
# Cluster Number 15 -- Number of members on the cluster 3
# -------------------------------------------------------
# |	Order within cluster 0 -- Order within headers 45
# |	Text :: Leloir, el genio humilde que ganó el Nobel: solo tenía un Fitito y pudo ser millonario por un invento
# |
# |	Order within cluster 1 -- Order within headers 46
# |	Text :: Reciclado de pilas gastadas y otros innovadores proyectos finalistas del IB50K
# |
# |	Order within cluster 2 -- Order within headers 47
# |	Text :: El 40% de las víctimas de violencia de género no denuncia por miedo a no poder mantener a sus hijos
# End_Of_Cluster ----------------------------------------
#
# Cluster Number 16 -- Number of members on the cluster 4
# -------------------------------------------------------
# |	Order within cluster 0 -- Order within headers 48
# |	Text :: La confesión que le hizo Anita Co a uno de los participantes de Canta Conmigo Ahora
# |
# |	Order within cluster 1 -- Order within headers 49
# |	Text :: 27 fotos de la cena por los 60 años de ADEPA
# |
# |	Order within cluster 2 -- Order within headers 50
# |	Text :: Prueban un anticonceptivo masculino que bloquea el paso del esperma
# |
# |	Order within cluster 3 -- Order within headers 51
# |	Text :: Qué leer el fin de semana: Gabriel Rolón y el bestseller "El monje que vendió su Ferrari"
# End_Of_Cluster ----------------------------------------
#
# Cluster Number 17 -- Number of members on the cluster 2
# -------------------------------------------------------
# |	Order within cluster 0 -- Order within headers 52
# |	Text :: Una web ayuda a personas con discapacidad a conocer sus derechos y qué pasos dar para hacerlos cumplir
# |
# |	Order within cluster 1 -- Order within headers 53
# |	Text :: Los 5 tríplex más costosos que están en venta en Buenos Aires
# End_Of_Cluster ----------------------------------------
#
# Cluster Number 18 -- Number of members on the cluster 3
# -------------------------------------------------------
# |	Order within cluster 0 -- Order within headers 55
# |	Text :: Recomendadas AM
# |
# |	Order within cluster 1 -- Order within headers 56
# |	Text :: Recomendadas PM
# |
# |	Order within cluster 2 -- Order within headers 57
# |	Text :: La semana en Europa
# End_Of_Cluster ----------------------------------------
#
# Cluster Number 19 -- Number of members on the cluster 2
# -------------------------------------------------------
# |	Order within cluster 0 -- Order within headers 59
# |	Text :: Arena, piedras y un desafío más extenuante: así será el Rally Dakar 2023 en Arabia Saudita
# |
# |	Order within cluster 1 -- Order within headers 60
# |	Text :: De todos los uruguayos que nos hicieron reír, hay uno que además nos hizo pensar mucho
# End_Of_Cluster ----------------------------------------
#
# Cluster Number 20 -- Number of members on the cluster 4
# -------------------------------------------------------
# |	Order within cluster 0 -- Order within headers 61
# |	Text :: El detrás de escena de la ceremonia del té, desde el siglo XVI hasta el mensaje que nos da en el presente
# |
# |	Order within cluster 1 -- Order within headers 62
# |	Text :: Por qué comer papa podría ayudar a perder peso, según la ciencia
# |
# |	Order within cluster 2 -- Order within headers 63
# |	Text :: ¡Pero qué monstruosa puede llegar a ser la gente rica!
# |
# |	Order within cluster 3 -- Order within headers 64
# |	Text :: Su padre carpintero le heredó la pasión por la artesanía pero la usó para ser poeta: José Watanabe
# End_Of_Cluster ----------------------------------------
#
# Cluster Number 21 -- Number of members on the cluster 4
# -------------------------------------------------------
# |	Order within cluster 0 -- Order within headers 66
# |	Text :: Art Basel y Miami Art Week: agenda para el viernes 2
# |
# |	Order within cluster 1 -- Order within headers 67
# |	Text :: Arte, tecnología y Art Basel: lo que ayer era imposible, hoy está al alcance de los artistas jóvenes
# |
# |	Order within cluster 2 -- Order within headers 68
# |	Text :: “No Vacancy”: cerca de Art Basel, 12 hoteles icónicos de Miami Beach se visten de arte
# |
# |	Order within cluster 3 -- Order within headers 69
# |	Text :: El Perez Art Museum participa de Miami Art Week con una programación especial
# End_Of_Cluster ----------------------------------------
#
# Cluster Number 22 -- Number of members on the cluster 3
# -------------------------------------------------------
# |	Order within cluster 0 -- Order within headers 72
# |	Text :: Blessd, Tiago PZK, Karol G y El Yaki, los reyes de YouTube durante 2022 en Latinoamérica
# |
# |	Order within cluster 1 -- Order within headers 73
# |	Text :: WhatsApp:  cómo buscar un mensaje por fecha
# |
# |	Order within cluster 2 -- Order within headers 74
# |	Text :: Cuatro aplicaciones para no olvidar ningún cumpleaños
# End_Of_Cluster ----------------------------------------
#
# Cluster Number 23 -- Number of members on the cluster 3
# -------------------------------------------------------
# |	Order within cluster 0 -- Order within headers 76
# |	Text :: “Love me”: de qué se trata esta conmovedora e impactante serie
# |
# |	Order within cluster 1 -- Order within headers 77
# |	Text :: “Ant-Man and The Wasp: Quantumania” lanzó un nuevo adelanto especial con el recorrido del héroe
# |
# |	Order within cluster 2 -- Order within headers 78
# |	Text :: “Guardianes de la galaxia Vol. 3” lanza su primer adelanto a unos meses de llegar al cine
# End_Of_Cluster ----------------------------------------
#
# Cluster Number 24 -- Number of members on the cluster 4
# -------------------------------------------------------
# |	Order within cluster 0 -- Order within headers 80
# |	Text :: El conmovedor gesto del ganador de Los 8 escalones
# |
# |	Order within cluster 1 -- Order within headers 81
# |	Text :: Nazarena Vélez tuvo un accidente en el cumpleaños de Andrea Taboada
# |
# |	Order within cluster 2 -- Order within headers 82
# |	Text :: El Pollo Álvarez se encontró con su doble en Qatar: "Somos iguales"
# |
# |	Order within cluster 3 -- Order within headers 83
# |	Text :: Shakira sorprendió con imponente ‘look’ en la cita final con Piqué
# End_Of_Cluster ----------------------------------------
#
# Cluster Number 25 -- Number of members on the cluster 3
# -------------------------------------------------------
# |	Order within cluster 0 -- Order within headers 85
# |	Text :: PlayStation Plus le dio la bienvenida a diciembre con sus tres nuevos juegos gratuitos
# |
# |	Order within cluster 1 -- Order within headers 86
# |	Text :: Street Fighter 6 anunció las nuevas fechas para inscribirse en su segunda fase de prueba cerrada
# |
# |	Order within cluster 2 -- Order within headers 87
# |	Text :: Epic Games Store empezó el mes con dos opciones gratuitas: Fort Triumph y RPG in a Box
# End_Of_Cluster ----------------------------------------
#
# Cluster Number 26 -- Number of members on the cluster 3
# -------------------------------------------------------
# |	Order within cluster 0 -- Order within headers 89
# |	Text :: Raquel Forner y la conquista del cosmos a través de la belleza
# |
# |	Order within cluster 1 -- Order within headers 90
# |	Text :: Guía de Arte y Cultura: semana del 2 al 9 de diciembre
# |
# |	Order within cluster 2 -- Order within headers 91
# |	Text :: "El skate del diablo", cuando la maldición de una venganza viaja en patineta
# End_Of_Cluster ----------------------------------------
#
# Cluster Number 27 -- Number of members on the cluster 3
# -------------------------------------------------------
# |	Order within cluster 0 -- Order within headers 92
# |	Text :: Cómo calcular las cuotas para comprar un departamento en la Ciudad de Buenos Aires
# |
# |	Order within cluster 1 -- Order within headers 93
# |	Text :: Vacaciones en Mar del Plata: qué actividades ofrece este verano 2023
# |
# |	Order within cluster 2 -- Order within headers 94
# |	Text :: Así festejó 22 años de historia una reconocida firma de zapatos: regalos, descuentos y muchas celebridades
# End_Of_Cluster ----------------------------------------
#
# Cluster Number 28 -- Number of members on the cluster 7
# -------------------------------------------------------
# |	Order within cluster 0 -- Order within headers 95
# |	Text :: OPINIÓN
# |
# |	Order within cluster 1 -- Order within headers 96
# |	Text :: Venezuela e Irán: una alianza siniestra
# |
# |	Order within cluster 2 -- Order within headers 97
# |	Text :: Problemas constitucionales
# |
# |	Order within cluster 3 -- Order within headers 98
# |	Text :: La OPS celebra sus 120 años: hitos de la organización de salud pública más antigua del mundo
# |
# |	Order within cluster 4 -- Order within headers 99
# |	Text :: ÚLTIMAS NOTICIAS
# |
# |	Order within cluster 5 -- Order within headers 100
# |	Text :: TELESHOW
# |
# |	Order within cluster 6 -- Order within headers 101
# |	Text :: DEPORTES
# End_Of_Cluster ----------------------------------------
#
# Cluster Number 29 -- Number of members on the cluster 3
# -------------------------------------------------------
# |	Order within cluster 0 -- Order within headers 96
# |	Text :: Venezuela e Irán: una alianza siniestra
# |
# |	Order within cluster 1 -- Order within headers 97
# |	Text :: Problemas constitucionales
# |
# |	Order within cluster 2 -- Order within headers 98
# |	Text :: La OPS celebra sus 120 años: hitos de la organización de salud pública más antigua del mundo
# End_Of_Cluster ----------------------------------------
#
# Cluster Number 30 -- Number of members on the cluster 3
# -------------------------------------------------------
# |	Order within cluster 0 -- Order within headers 99
# |	Text :: ÚLTIMAS NOTICIAS
# |
# |	Order within cluster 1 -- Order within headers 100
# |	Text :: TELESHOW
# |
# |	Order within cluster 2 -- Order within headers 101
# |	Text :: DEPORTES
# End_Of_Cluster ----------------------------------------

# %%
# Show the size of the cluster associated to each <h2>:
for i, h2 in enumerate(tags['h2']):
    cursor = h2.parent
    while len(list(cursor.find_all('h2'))) == 1:
        cursor = cursor.parent
    print(f" <h2> {i:03d} : {len(list(cursor.find_all('h2')))}", end = '\n' if (i + 1) % 6 == 0 else ' |')
# Out:
#  <h2> 000 : 3 | <h2> 001 : 3 | <h2> 002 : 3 | <h2> 003 : 3 | <h2> 004 : 3 | <h2> 005 : 3
#  <h2> 006 : 95 | <h2> 007 : 4 | <h2> 008 : 4 | <h2> 009 : 4 | <h2> 010 : 4 | <h2> 011 : 95
#  <h2> 012 : 4 | <h2> 013 : 4 | <h2> 014 : 4 | <h2> 015 : 4 | <h2> 016 : 2 | <h2> 017 : 2
#  <h2> 018 : 3 | <h2> 019 : 3 | <h2> 020 : 3 | <h2> 021 : 4 | <h2> 022 : 4 | <h2> 023 : 4
#  <h2> 024 : 4 | <h2> 025 : 3 | <h2> 026 : 3 | <h2> 027 : 3 | <h2> 028 : 2 | <h2> 029 : 2
#  <h2> 030 : 2 | <h2> 031 : 2 | <h2> 032 : 4 | <h2> 033 : 4 | <h2> 034 : 4 | <h2> 035 : 4
#  <h2> 036 : 2 | <h2> 037 : 2 | <h2> 038 : 3 | <h2> 039 : 3 | <h2> 040 : 3 | <h2> 041 : 4
#  <h2> 042 : 4 | <h2> 043 : 4 | <h2> 044 : 4 | <h2> 045 : 3 | <h2> 046 : 3 | <h2> 047 : 3
#  <h2> 048 : 4 | <h2> 049 : 4 | <h2> 050 : 4 | <h2> 051 : 4 | <h2> 052 : 2 | <h2> 053 : 2
#  <h2> 054 : 95 | <h2> 055 : 3 | <h2> 056 : 3 | <h2> 057 : 3 | <h2> 058 : 95 | <h2> 059 : 2
#  <h2> 060 : 2 | <h2> 061 : 4 | <h2> 062 : 4 | <h2> 063 : 4 | <h2> 064 : 4 | <h2> 065 : 95
#  <h2> 066 : 4 | <h2> 067 : 4 | <h2> 068 : 4 | <h2> 069 : 4 | <h2> 070 : 95 | <h2> 071 : 95
#  <h2> 072 : 3 | <h2> 073 : 3 | <h2> 074 : 3 | <h2> 075 : 95 | <h2> 076 : 3 | <h2> 077 : 3
#  <h2> 078 : 3 | <h2> 079 : 95 | <h2> 080 : 4 | <h2> 081 : 4 | <h2> 082 : 4 | <h2> 083 : 4
#  <h2> 084 : 95 | <h2> 085 : 3 | <h2> 086 : 3 | <h2> 087 : 3 | <h2> 088 : 95 | <h2> 089 : 3
#  <h2> 090 : 3 | <h2> 091 : 3 | <h2> 092 : 3 | <h2> 093 : 3 | <h2> 094 : 3 | <h2> 095 : 7
#  <h2> 096 : 3 | <h2> 097 : 3 | <h2> 098 : 3 | <h2> 099 : 3 | <h2> 100 : 3 | <h2> 101 : 3

# %%
# for i, h2 in enumerate(tags['h2']):
#     print(f'{i:3d}')
#     print(h2.parent.prettify())
#     print()  
opinion_h2s = []
for i, h2 in enumerate(tags['h2']):
    if 'opi_hl' in h2.get('class'):
        print(f'<h2>[{i}]'); print('-' * len(f'<h2>[{i}]'))
        print(h2.parent.parent.prettify())
        print()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\code\python\BSscrapper\jupyter_notebooks\Infobae_experiments.ipynb Celda 6 in <cell line: 6>()
#       <a href='vscode-notebook-cell:/c%3A/code/python/BSscrapper/jupyter_notebooks/Infobae_experiments.ipynb#W5sZmlsZQ%3D%3D?line=4'>5</a> opinion_h2s = []
#       <a href='vscode-notebook-cell:/c%3A/code/python/BSscrapper/jupyter_notebooks/Infobae_experiments.ipynb#W5sZmlsZQ%3D%3D?line=5'>6</a> for i, h2 in enumerate(tags['h2']):
# ----> <a href='vscode-notebook-cell:/c%3A/code/python/BSscrapper/jupyter_notebooks/Infobae_experiments.ipynb#W5sZmlsZQ%3D%3D?line=6'>7</a>     if 'opi_hl' in h2.get('class'):
#       <a href='vscode-notebook-cell:/c%3A/code/python/BSscrapper/jupyter_notebooks/Infobae_experiments.ipynb#W5sZmlsZQ%3D%3D?line=7'>8</a>         print(f'<h2>[{i}]'); print('-' * len(f'<h2>[{i}]'))
#       <a href='vscode-notebook-cell:/c%3A/code/python/BSscrapper/jupyter_notebooks/Infobae_experiments.ipynb#W5sZmlsZQ%3D%3D?line=8'>9</a>         print(h2.parent.parent.prettify())
#
# TypeError: argument of type 'NoneType' is not iterable

# %%
for i, h2 in enumerate(tags['h2']):
    print(f'<h2>[{i:3d}]>', h2.get_text())
# Out:
# <h2>[  0]> Horacio Rodríguez Larreta rechazó cambios en el sistema electoral en 2023: “Está mal, es querer hacer trampa”
# <h2>[  1]> Cansado de intentar producir autos eléctricos en el país, se va a Brasil: “Te desaniman día a día”
# <h2>[  2]> Caso García Belsunce: las palabras de Pachelo ante los jueces tras el pedido de prisión perpetua
# <h2>[  3]> “La próxima te rompo la cara”: fuerte cruce entre Patricia Bullrich y un hombre de confianza de Larreta
# <h2>[  4]> “No voy a pedir disculpas”: Patricia Bullrich habló de su ataque a Felipe de Miguel
# <h2>[  5]> Laura Blaquier: “El país es una ruleta rusa, cada día hay familias destruidas por la inseguridad”
# <h2>[  6]> Los aumentos que llegan en noviembre: tarifas de gas, luz, colegios privados y alquileres
# <h2>[  7]> Son 24 las argentinas camino a ser santas: las causas de las mujeres pueden esperar
# <h2>[  8]> Ni la "grieta" es un invento argentino ni la esclavitud terminó: leé gratis el libro que explica por qué
# <h2>[  9]> Un influencer se coló en la casa de Gran Hermano 2022 y dejó un regalo en el patio
# <h2>[ 10]> En qué consiste el hábito sencillo para acelerar el metabolismo y quemar grasas
# <h2>[ 11]> Es abogada, modelo, tuvo dos bandas de cumbia pop y porta apellido famoso: la vida de Delfina Burlando
# <h2>[ 12]> SpaceX lanza su cohete más poderoso e intentará hacer un triple aterrizaje
# <h2>[ 13]> La confesión de Messi sobre cómo lo impactó la derrota ante Alemania en el Mundial 2014
# <h2>[ 14]> La mamá de Sofía Herrera ve a su hija 'muy parecida' a una chica de San Juan: ¿qué pasó con el ADN?
# <h2>[ 15]> El kirchnerismo apuesta a congelar precios para recuperar el ingreso y enfrentar la campaña electoral
# <h2>[ 16]> Ahora es oficial: Europa cierra la puerta definitivamente a los motores de combustión
# <h2>[ 17]> Lula será el próximo presidente de Brasil: ahora viene la parte difícil
# <h2>[ 18]> Terror en Ecuador: una madrugada con cuatro coches bomba, dos policías muertos y motines en las cárceles
# <h2>[ 19]> Se entregó el encargado de manejar la “plata personal” de Cositorto en Generación Zoe
# <h2>[ 20]> Aumento a empleadas domésticas: cómo queda la escala salarial a partir de noviembre
# <h2>[ 21]> "Vos no me podés tocar”: la agresión de un policía a una joven al salir de un boliche en Mar del Plata
# <h2>[ 22]> 66 fotos: Mauricio Macri y Juliana Awada en la cena anual de la Fundación Margarita Barrientos
# <h2>[ 23]> Alberto Fernández se reunirá con Xi Jinping en el G20 de Bali para anunciar una posible ampliación del Swap e inversiones en Litio
# <h2>[ 24]> Importaciones con dólares propios: las empresas no podrán comprar divisas para hacer los pagos
# <h2>[ 25]> Un fiscal pidió investigar a Macri por un presunto plan de espionaje con fines políticos y personales
# <h2>[ 26]> Cap Arcona, el barco que fue campo de concentración de los nazis y bombardearon los ingleses
# <h2>[ 27]> El increíble legado del primer ingeniero graduado en el país y la polémica por el puerto de Buenos Aires
# <h2>[ 28]> Alberto Fernández se aferra a las PASO y resiste los pedidos para abrir una negociación con los K
# <h2>[ 29]> Murió a los 25 años el hijo del actor Tim Roth
# <h2>[ 30]> Cómo impacta la dieta vegana en el cuerpo, según tres profesionales de la salud
# <h2>[ 31]> Tras la polémica por las elecciones, De Pedro descarta una reforma constitucional en breve
# <h2>[ 32]> Dura réplica de la fiscalía a la defensa de Pachelo: “Quiso explicar que en vez de matar a María Marta, le estaba haciendo la leche al nene”
# <h2>[ 33]> La bomba que mató a Alberto Villar, el comisario de la Policía Federal que Juan Domingo Perón designó para "poner orden"
# <h2>[ 34]> Los desafíos de avanzar en el financiamiento climático para mantener vivo el Acuerdo de París
# <h2>[ 35]> Cuáles son las cuatro formas en que el cambio climático afecta la salud mental
# <h2>[ 36]> Miss Argentina y Miss Puerto Rico anunciaron su matrimonio en un video publicado en redes
# <h2>[ 37]> CyberMonday 2022: todo lo que hay que saber para prevenir estafas en la jornada de descuentos
# <h2>[ 38]> En dólares, pesos o cripto: crean una app para los que tienen que cobrar trabajos desde el exterior
# <h2>[ 39]> El amor prohibido entre una profesora y su exalumna de un colegio de monjas
# <h2>[ 40]> Tres delincuentes en un auto robado chocaron con un colectivo y huyeron: hay 13 heridos
# <h2>[ 41]> Comienza en el Senado la discusión del Presupuesto: el oficialismo quiere aprobarlo en noviembre
# <h2>[ 42]> Vino al país por la inseguridad de Caracas y fundó una panadería venezolana que es todo un éxito
# <h2>[ 43]> Becas Progresar: quiénes reciben los 7.600 pesos por mes que paga el Gobierno para estudiar
# <h2>[ 44]> ¿Cómo se ayuda a morir a una madre? Todo lo que les cuesta a las hijas el vínculo más difícil
# <h2>[ 45]> Día mundial del Veganismo: las 10 mejores recetas para comer rico y sano en casa
# <h2>[ 46]> El día que la Primera Guerra Mundial se trasladó a las costas de Chile
# <h2>[ 47]> El extraño caso del arquero español que se enteró en una entrevista que no está en la lista del Mundial
# <h2>[ 48]> ¿Se apaga la estrella de Simeone en el Atlético Madrid? Las “señales de agotamiento”
# <h2>[ 49]> El BCRA cerró el mes con saldo negativo y crece la preocupación por la falta de dólares en el verano
# <h2>[ 50]> La Justicia dictó prisión preventiva para la enfermera acusada de ser la responsable por la muerte de cinco bebés en Córdoba
# <h2>[ 51]> Balacera en Rosario: una niña de 8 años permanece en estado critico tras recibir un tiro en la cabeza
# <h2>[ 52]> Industrialización del litio en Argentina: cómo puede impactar en la producción de energía para el mundo
# <h2>[ 53]> Día de Todos Los Santos: desde cuándo y por qué se celebra esta tradición
# <h2>[ 54]> El escenario es de recesión con inflación
# <h2>[ 55]> La activista vegana que les da una nueva vida a gallinas, vacas, chanchos, caballos y perros
# <h2>[ 56]> Detuvieron en Guernica al capo prófugo de una temida mafia italiana: cobraba una pensión argentina
# <h2>[ 57]> El mexicano detenido por ser testaferro del secretario de los Kirchner dijo que firmó papeles sin saber qué eran
# <h2>[ 58]> Recomendadas AM
# <h2>[ 59]> Eco - lógico
# <h2>[ 60]> Global
# <h2>[ 61]> Los gauchos rapean en una nueva adaptación teatral del Martín Fierro para los más chicos
# <h2>[ 62]> El Estado Nacional explotó una ciudad
# <h2>[ 63]> Qué es la lumbalgia y cómo puede tratarse
# <h2>[ 64]> Rosario estrenó una nueva media maratón con aires de Fórmula 1
# <h2>[ 65]> Beneficios y desventajas de tener amigos en el ámbito laboral
# <h2>[ 66]> Alicia Zorrilla: "No existe el lenguaje inclusivo"
# <h2>[ 67]> Por qué pintarse tiene mala reputación
# <h2>[ 68]> Steve Jobs y las personas más importantes en su vida
# <h2>[ 69]> Tres aplicaciones escondidas en Play Store que están robando datos y es mejor eliminar
# <h2>[ 70]> Cómo eliminar un tweet antiguo sin buscarlo en todo el perfil de la red social
# <h2>[ 71]> 6 series argentinas que puedes ver en Prime Video
# <h2>[ 72]> Keegan-Michael Key habló con Infobae sobre su nueva serie en Star+ y sentenció: “Todos aman a un perdedor”
# <h2>[ 73]> El impactante thriller inglés lleno de intriga y oscuridad de los creadores de “Sherlock”
# <h2>[ 74]> NBA: el documental que cuenta como EEUU se levantó de los golpes que le dio Argentina
# <h2>[ 75]> Japón es la primera selección en anunciar sus 26 convocados para el Mundial de Qatar
# <h2>[ 76]> La agenda de la definición de la fase de grupos de Champions League: hora y TV de todos los partidos
# <h2>[ 77]> El picante mensaje de Arturo Vidal a Real Madrid tras ganar la Libertadores con Flamengo
# <h2>[ 78]> Nequi Galotti reveló que tiene nuevo novio: "Nunca me imaginé conocer a alguien por Instagram"
# <h2>[ 79]> El furcio de Locho que hizo reír a todos en Canta Conmigo Ahora
# <h2>[ 80]> Flor Vigna se realizó un jugado tatuaje y mostró el resultado: “Más feliz y libre”
# <h2>[ 81]> Luciano Castro: "Uruguay es muy genuino, y yo vivo en un país donde hay mucho caretaje"
# <h2>[ 82]> Goat Simulator 3, Sable y más: los juegos independientes que llegan en noviembre a PlayStation
# <h2>[ 83]> MultiVersus: ya se puede usar a Black Adam y disfrutar de su modo arcade de forma gratuita
# <h2>[ 84]> Electronic Arts y Marvel forman una alianza para crear tres nuevos juegos de superhéroes
# <h2>[ 85]> Como en un "Pokémon Go" del arte, las obras en NFT invaden Buenos Aires
# <h2>[ 86]> Rosa Passos, de la bossa nova y el jazz a una celebración de 38 años de "matrimonio" musical
# <h2>[ 87]> Vicente Zito Lema y Jacobo Fijman, un encuentro entre la poesía, la locura y la belleza hecha teatro
# <h2>[ 88]> Junto a Pampita, Juan Marconi y Santi Talledo, una automotriz presentó dos nuevos modelos
# <h2>[ 89]> Cómo funciona la nueva medicación oncológica que actúa sobre los genes del tumor
# <h2>[ 90]> Cómo cocinar con mayonesa vegana en la era de la alimentación saludable
# <h2>[ 91]> Una fintech celebra su aniversario regalando 7 millones de pesos
# <h2>[ 92]> La figurita con Lula
# <h2>[ 93]> Democracia de proyectos versus democracia de candidatos
# <h2>[ 94]> Colegios tomados: educar también es enseñar valores
# <h2>[ 95]> Discapacidad e inclusión: de la ley a los hechos
# <h2>[ 96]> ÚLTIMAS NOTICIAS
# <h2>[ 97]> TELESHOW
# <h2>[ 98]> DEPORTES

# %%
for i, h3 in enumerate(tags['h3']):
    print(f'<h3>[{i}]'); print(len(f'<h3>[{i}]') * '-')
    print(h3.parent.prettify())
    print('-' * 80)
# Out:
# <h3>[0]
# -------
# <a class="headline-link" href="/politica/2022/11/01/no-voy-a-pedir-a-disculpas-patricia-bullrich-hablo-de-su-ataque-a-felipe-de-miguel/">
#  <h3 class="headline-feed-column">
#   <span>
#    “No voy a pedir disculpas”: Patricia Bullrich habló de su ataque a Felipe Miguel
#   </span>
#  </h3>
# </a>
# --------------------------------------------------------------------------------
# <h3>[1]
# -------
# <a class="headline-link feed-column-card" href="/sociedad/2022/11/01/laura-blaquier-el-pais-es-una-ruleta-rusa-todos-los-dias-hay-familias-destruidas-por-la-inseguridad/">
#  <h3 class="headline-feed-column">
#   <span>
#    Laura Blaquier: “El país es una ruleta rusa, todos los días hay familias destruidas por la inseguridad”
#   </span>
#  </h3>
# </a>
#
# --------------------------------------------------------------------------------
# <h3>[2]
# -------
# <a class="headline-link feed-column-card" href="/economia/campo/2022/11/01/altisima-presion-fiscal-el-estado-se-lleva-casi-la-mitad-de-los-dolares-producidos-en-cada-hectarea-de-soja/">
#  <h3 class="headline-feed-column">
#   <span>
#    Altísima presión fiscal: el Estado se lleva casi la mitad de los dólares producidos en cada hectárea de soja
#   </span>
#  </h3>
# </a>
#
# --------------------------------------------------------------------------------
# <h3>[3]
# -------
# <a class="headline-link feed-column-card" href="/economia/2022/11/01/los-aumentos-que-llegan-en-noviembre-tarifas-de-gas-electricidad-luz-colegios-privados-y-alquileres/">
#  <h3 class="headline-feed-column">
#   <span>
#    Los aumentos que llegan en noviembre: tarifas de gas, luz, colegios privados y alquileres
#   </span>
#  </h3>
# </a>
#
# --------------------------------------------------------------------------------
# <h3>[4]
# -------
# <a class="headline-link feed-column-card" href="/sociedad/policiales/2022/11/01/dura-replica-de-la-fiscalia-a-la-defensa-de-nicolas-pachelo-intento-explicar-que-en-vez-de-estar-matando-a-maria-marta-le-estaba-haciendo-la-leche-al-nene/">
#  <h3 class="headline-feed-column">
#   <span>
#    Dura réplica de la fiscalía a la defensa de Nicolás Pachelo: “Intentó explicar que en vez de estar matando a María Marta, le estaba haciendo la leche al nene”
#   </span>
#  </h3>
# </a>
# --------------------------------------------------------------------------------
# <h3>[5]
# -------
# <a class="headline-link" href="/teleshow/2022/11/01/flor-vigna-se-realizo-un-jugado-tatuaje-y-mostro-el-resultado-mas-feliz-y-libre/">
#  <h3 class="headline-feed-column">
#   <span>
#    Flor Vigna se realizó un jugado tatuaje y mostró el resultado: “Más feliz y libre”
#   </span>
#  </h3>
# </a>
# --------------------------------------------------------------------------------
# <h3>[6]
# -------
# <a class="headline-link feed-column-card" href="/teleshow/2022/11/01/los-8-escalones-de-los-dos-millones-la-emocion-de-un-participante-al-recordar-a-su-pareja-fallecida-cuatro-meses-antes-de-casarse/">
#  <h3 class="headline-feed-column">
#   <span>
#    Los 8 escalones de los dos millones: la emoción de un participante al recordar a su pareja, fallecida cuatro meses antes de casarse
#   </span>
#  </h3>
# </a>
#
# --------------------------------------------------------------------------------
# <h3>[7]
# -------
# <a class="headline-link feed-column-card" href="/teleshow/2022/11/01/un-influencer-se-colo-en-la-casa-de-gran-hermano-2022-y-dejo-un-regalo-en-el-patio/">
#  <h3 class="headline-feed-column">
#   <span>
#    Un influencer se coló en la casa de Gran Hermano 2022 y dejó un regalo en el patio
#   </span>
#  </h3>
# </a>
#
# --------------------------------------------------------------------------------
# <h3>[8]
# -------
# <a class="headline-link feed-column-card" href="/teleshow/2022/11/01/es-abogada-modelo-tuvo-dos-bandas-de-cumbia-pop-y-porta-apellido-famoso-la-asombrosa-vida-de-delfina-burlando/">
#  <h3 class="headline-feed-column">
#   <span>
#    Es abogada, modelo, tuvo dos bandas de cumbia pop y porta apellido famoso: la asombrosa vida de Delfina Burlando
#   </span>
#  </h3>
# </a>
#
# --------------------------------------------------------------------------------
# <h3>[9]
# -------
# <a class="headline-link feed-column-card" href="/america/entretenimiento/2022/11/01/instagram-suspendio-por-30-dias-la-cuenta-del-rapero-kanye-west-por-violar-las-normas-de-contenido/">
#  <h3 class="headline-feed-column">
#   <span>
#    Instagram suspendió por 30 días la cuenta del rapero Kanye West por violar las normas de contenido
#   </span>
#  </h3>
# </a>
# --------------------------------------------------------------------------------
# <h3>[10]
# --------
# <a class="headline-link" href="/america/deportes/2022/11/01/qatar-2022-luis-fernando-suarez-dio-a-conocer-a-su-primer-convocado-a-la-seleccion-de-costa-rica/">
#  <h3 class="headline-feed-column">
#   <span>
#    Qatar 2022: Luis Fernando Suárez dio a conocer a su primer convocado a la selección de Costa Rica
#   </span>
#  </h3>
# </a>
# --------------------------------------------------------------------------------
# <h3>[11]
# --------
# <a class="headline-link feed-column-card" href="/america/deportes/futbol-europeo/2022/11/01/el-extrano-caso-del-arquero-espanol-que-se-entero-en-una-entrevista-que-no-esta-en-la-lista-del-mundial/">
#  <h3 class="headline-feed-column">
#   <span>
#    El extraño caso del arquero español que se enteró en una entrevista que no está en la lista del Mundial
#   </span>
#  </h3>
# </a>
#
# --------------------------------------------------------------------------------
# <h3>[12]
# --------
# <a class="headline-link feed-column-card" href="/america/deportes/futbol-europeo/2022/11/01/porto-vs-atletico-de-madrid-en-vivo-hora-tv-formaciones-y-todo-lo-que-hay-que-saber-del-partido-por-la-champions-league/">
#  <h3 class="headline-feed-column">
#   <span>
#    Porto vs Atlético de Madrid en vivo: hora, TV, formaciones y todo lo que hay que saber del partido por la Champions League
#   </span>
#  </h3>
# </a>
#
# --------------------------------------------------------------------------------
# <h3>[13]
# --------
# <a class="headline-link feed-column-card" href="/america/deportes/2022/11/01/la-agenda-de-la-definicion-de-la-fase-de-grupos-de-champions-league-hora-y-tv-de-todos-los-partidos/">
#  <h3 class="headline-feed-column">
#   <span>
#    La agenda de la definición de la fase de grupos de Champions League: hora y TV de todos los partidos
#   </span>
#  </h3>
# </a>
#
# --------------------------------------------------------------------------------
# <h3>[14]
# --------
# <a class="headline-link feed-column-card" href="/america/deportes/2022/11/01/japon-se-convirtio-en-la-primera-seleccion-en-anunciar-sus-26-convocados-para-el-mundial-de-qatar/">
#  <h3 class="headline-feed-column">
#   <span>
#    Japón se convirtió en la primera selección en anunciar sus 26 convocados para el Mundial de Qatar
#   </span>
#  </h3>
# </a>
# --------------------------------------------------------------------------------
