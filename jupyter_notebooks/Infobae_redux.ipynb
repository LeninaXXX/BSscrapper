# %%
import requests, bs4 as bs, lxml, copy
from pprint import pprint

httpaddr = "https://www.infobae.com"
requests_ret = requests.get(httpaddr)
print(requests_ret, end = ' || ')
soup = bs.BeautifulSoup(requests_ret.text, 'lxml')
for discard_tag in ("script", "style"):
    for t in soup.find_all(discard_tag): t.extract()
tags_tuple = ('article', 'section', 'header') + tuple(('h' + str(i) for i in range(1, 7)))
tags = {tag_str : soup.find_all(tag_str) for tag_str in tags_tuple}
for i, tag in enumerate(tags):
    print(f"{tag}s : {len(tags[tag])}", sep = '', end = '\n' if i == len(tags) - 1 else ' / ')

datamodel_dict = {'UKEY'                    : None,
                  'JOB'                     : None,
                  'TITLE'                   : None,
                  'TITLE_WORD_COUNT'        : None,
                  'ARTICLE'                 : None,     # New field - Article number among articles
                  'CLUSTER'                 : None,     # New field - Cluster number to which this article belongs
                  'CLUSTER_INDEX'           : None,     # New field - Article number inside cluster
                  'CLUSTER_SIZE'            : None,     # New field - Size of the cluster to which this belongs
                  'CLUSTER_UNIQUE'          : None,     # New field - does this artice belong to a single cluster?
                  'AUTHOR'                  : None,
                  'SUMMARY'                 : None,
                  'VOLANTA'                 : None,
                  'CATEGORY'                : None,
                  'SUBCATEGORY'             : None,     # New field - 
                  'SLUG'                    : None,
                  'SLUG_INTERNAL'           : None, 
                  'Origen'                  : None,
                  'FechaFiltro'             : None,
                  'FechaCreacion'           : None,
                  'FechaModificacion'       : None,
                 }
# Out:
# <Response [200]> || articles : 0 / sections : 0 / headers : 0 / h1s : 0 / h2s : 103 / h3s : 15 / h4s : 0 / h5s : 0 / h6s : 0

# %%
import datetime
anchored_articles = {}      # Pivoting on <h2>s
non_anchored_articles = {}  # 

for i, h2 in enumerate(tags['h2']):
    try:
        tuple(map(lambda tag: tag.name.lower(), h2.parents)).index('a')
    except ValueError:
        non_anchored_articles[h2] = h2
        print(f'Non-anchored <h2> found: [{i}]')
        continue
    anchored_articles[h2] = copy.copy(datamodel_dict)   # set a datamodel_dict apart 

for i, h2 in enumerate(anchored_articles):
    # Routine data
    anchored_articles[h2]['UKEY'] = 1234567890
    anchored_articles[h2]['JOB'] = 'Infobae'
    anchored_articles[h2]['VOLANTA'] = "N/A -- INFOBAE HAS NO VOLANTAS"
    anchored_articles[h2]['Origen'] = httpaddr
    anchored_articles[h2]['FechaFiltro'] = datetime.datetime.now()
    anchored_articles[h2]['FechaCreacion'] = datetime.datetime.now()
    anchored_articles[h2]['FechaModificacion'] = datetime.datetime.now()

    # ARTICLE : order of <h2> tag within <h2>s tags
    ARTICLE = str(tags['h2'].index(h2))
    anchored_articles[h2]['ARTICLE'] = ARTICLE

    # TITLE extraction
    TITLE = h2.get_text().strip()
    anchored_articles[h2]['TITLE'] = TITLE
    
    # AUTHOR extraction
    # AdHoc sanitization of AUTHOR fields
    anchor_cursor = h2
    while anchor_cursor.name.lower() != 'a':
        anchor_cursor = anchor_cursor.parent
    author_candidates_list = list(map(lambda tag: tag.get_text(), anchor_cursor.find_all(class_ = 'overlay_ctn')))
    author_candidate = author_candidates_list[0] if len(author_candidates_list) != 0 else None

    if author_candidate and isinstance(author_candidate, str):    # If at least there's an author_candidate and is a string (just in case)...
        if author_candidate.find(',') != -1: # Sometimes a clarification is made with a comma in the middle...
            author_candidate = author_candidate[: author_candidate.find(',')]   # ... strip it
        if author_candidate.find('-') != -1: # Sometimes accompanying VIDEO/AUDIO is denoted separated by '-' 
            author_candidate = author_candidate[: author_candidate.find('-')]
        author_candidate = author_candidate.strip()     # ... just to be sure...

        # Starting 'Por' denotes autorship...
        if author_candidate[0:4] == 'Por ':
            author_candidate = author_candidate[3:].strip() # At this point, compromise into assuming it's an author
        
        if author_candidate.upper() == author_candidate:    # If it's all uppercase, almost certainly ain't an author
            author_candidate = None
    else:
        author_candidate = None     # explicitly default to None if None or not-a-string, just for clarity

    AUTHOR = author_candidate
    anchored_articles[h2]['AUTHOR'] = AUTHOR

    # SUMMARY extraction
    summary_candidates_list = list(map(lambda tag: tag.get_text(), anchor_cursor.find_all(class_ = 'cst_deck')))
    summary_candidate = summary_candidates_list[0] if len(summary_candidates_list) != 0 else None
    
    SUMMARY = summary_candidate
    anchored_articles[h2]['SUMMARY'] = SUMMARY

    # SLUG extraction
    SLUG = h2.parent.get('href') # This is only going one parent upwards
    # I might wanna be looking for the nearest <a> tag upwards...
    # print(f'{i:3d}', tuple(map(lambda tag: tag.name, h2.parents))) # index of the nearest upwards <a>nchor tag
    anchored_articles[h2]['SLUG'] = SLUG
    
    # CATEGORY & SUBCATEGORY extraction
    if SLUG:    # Only if there's a SLUG present attempt to extract
        if SLUG[0] == '/':  # CATEGORY: Only if Relative address -- SLUG EXTERNAL == False
            anchored_articles[h2]['SLUG_INTERNAL'] = True
            anchored_articles[h2]['CATEGORY'] = SLUG.split('/')[1]
            if (SLUG.split('/')[2][0] in tuple(map(chr, range(ord('a'), ord('z') + 1))) + tuple(map(chr, range(ord('A'), ord('Z') + 1)))):
                anchored_articles[h2]['SUBCATEGORY'] = SLUG.split('/')[2]
        elif SLUG[0:4].lower() in ('http://', 'https://'):
            anchored_articles[h2]['SLUG_INTERNAL'] = False
            anchored_articles[h2]['CATEGORY'] = False
            anchored_articles[h2]['SUBCATEGORY'] = False
        else:
            anchored_articles[h2]['CATEGORY'] = None
            anchored_articles[h2]['SUBCATEGORY'] = None
            anchored_articles[h2]['SLUG_INTERNAL'] = None
    else:   # if SLUG is None 'Category' should be None too
        anchored_articles[h2]['CATEGORY'] = None
        anchored_articles[h2]['SUBCATEGORY'] = None
        anchored_articles[h2]['SLUG_INTERNAL'] = None
    
    anchored_articles[h2]['TITLE_WORD_COUNT'] = len(h2.get_text().strip().split(' '))
    # anchored_articles[h2]['DBG_TITLE_WORDS'] = h2.get_text().strip().split(' ')

# Summary of processed data
print('Summary Report')
print(f'\t<h2>s :', len(tags['h2']))
print(f'\tvalidated <h2>s :', len(anchored_articles))
print('=' * 80)
#
# for i, h2 in enumerate(tags['h2']):
# for i, h2 in enumerate(anchored_articles):
#     idx = tags['h2'].index(h2)
#     print(f'{idx:3d} :', tuple(map(lambda tag: tag.name, h2.parents)), '//', h2.attrs)

for i, h2 in enumerate(anchored_articles):
    if anchored_articles[h2]['AUTHOR']:
        print(f"<h2>[{tags['h2'].index(h2)}] :", anchored_articles[h2]['AUTHOR'])
print('=' * 100)

for i, h2 in enumerate(anchored_articles):
    print(f"{i:3d}")
    print('-' * len(f"{i:3d}"))
    for field in anchored_articles[h2]:
        if anchored_articles[h2][field] != None:
            print(f'\t{field}:: {anchored_articles[h2][field]}')
    print(f'{" " * 40}{"-" * 40}')
    
    print(f'PREV SIBLINGS:')
    for prev_sibling in h2.previous_siblings:
        print('\t', prev_sibling.name, prev_sibling.attrs, prev_sibling.get_text())
    
    print(f'NEXT SIBLINGS:')
    for next_sibling in h2.next_siblings:
        print('\t', next_sibling.name, next_sibling.attrs, next_sibling.get_text())
    
    print(f'=' * 80)
# Out:
# Non-anchored <h2> found: [62]
# Non-anchored <h2> found: [63]
# Non-anchored <h2> found: [64]
# Non-anchored <h2> found: [100]
# Non-anchored <h2> found: [101]
# Non-anchored <h2> found: [102]
# Summary Report
# 	<h2>s : 103
# 	validated <h2>s : 97
# ================================================================================
# <h2>[6] : Ximena Casas
# <h2>[7] : Nunzia Locatelli y Cintia Suárez
# <h2>[8] : Silvana Boschi
# <h2>[13] : Federico Cristofanelli
# <h2>[17] : María Laura Balonga
# <h2>[18] : Gisele Sousa Días
# <h2>[19] : Pablo Wende
# <h2>[20] : Diego Zorrero
# <h2>[21] : The Economist
# <h2>[22] : Yalilé Loaiza
# <h2>[23] : Federico Fahsbender
# <h2>[26] : Soledad Blardone
# <h2>[27] : Román Lejtman
# <h2>[28] : Mariano Boettner
# <h2>[29] : Patricia Blanco y Martín Angulo
# <h2>[30] : Alberto Amato
# <h2>[31] : Adrián Pignatelli
# <h2>[32] : Facundo Chaves
# <h2>[34] : Fernanda Jara
# <h2>[35] : Joaquín Mugica Díaz
# <h2>[37] : Juan Bautista Tata Yofre
# <h2>[38] : Laura Rocha
# <h2>[42] : Fernando Meaños
# <h2>[45] : David Cayón
# <h2>[46] : Gabriela Cicero
# <h2>[47] : Maximiliano Fernández
# <h2>[48] : Luciano Lutereau
# <h2>[50] : Luis Furlán
# <h2>[52] : Sergio Levinsky
# <h2>[53] : Virginia Porcella
# <h2>[58] : Roberto Cachanosky
# <h2>[59] : Fernanda Jara
# <h2>[60] : Federico Fahsbender
# <h2>[61] : Omar Lavieri
# <h2>[66] : Gabriela Brouwer de Koning
# <h2>[67] : Alberto Cormillot
# <h2>[68] : Santiago García
# <h2>[69] : Alejandro Melamed
# <h2>[70] : Gabriela Mayer
# <h2>[71] : Pablo Nardi
# <h2>[78] : Julián Mozo
# <h2>[89] : Nadia Paz
# <h2>[90] : Ricardo Carpena
# <h2>[91] : Ana Yovino
# ====================================================================================================
#   0
# ---
# 	UKEY:: 1234567890
# 	JOB:: Infobae
# 	TITLE:: Elisa Carrió: “Si en Juntos por el Cambio no nos garantizan una lista honesta iremos con mi candidatura”
# 	TITLE_WORD_COUNT:: 18
# 	ARTICLE::

# 	SLUG_INTERNAL:: True
# 	Origen:: https://www.infobae.com
# 	FechaFiltro:: 2022-11-01 11:50:20.530621
# 	FechaCreacion:: 2022-11-01 11:50:20.530621
# 	FechaModificacion:: 2022-11-01 11:50:20.530621
#                                         ----------------------------------------
# PREV SIBLINGS:
# NEXT SIBLINGS:
# 	 div {'class': ['cst_img_ctn', 'cst_img_ctn_16_9']}
# 	 div {'class': ['overlay_ctn']} Por Ximena Casas
# ================================================================================
#   7
# ---
# 	UKEY:: 1234567890
# 	JOB:: Infobae
# 	TITLE:: Son 24 las argentinas camino a ser santas: las causas de las mujeres pueden esperar
# 	TITLE_WORD_COUNT:: 15
# 	ARTICLE:: 7
# 	AUTHOR:: Nunzia Locatelli y Cintia Suárez
# 	VOLANTA:: N/A -- INFOBAE HAS NO VOLANTAS
# 	CATEGORY:: sociedad
# 	SLUG:: /sociedad/2022/11/01/son-24-las-argentinas-camino-a-ser-santas-las-causas-de-las-mujeres-pueden-esperar/
# 	SLUG_INTERNAL:: True
# 	Origen:: https://www.infobae.com
# 	FechaFiltro:: 2022-11-01 11:50:20.531619
# 	FechaCreacion:: 2022-11-01 11:50:20.531619
# 	FechaModificacion:: 2022-11-01 11:50:20.531619
#                                         ----------------------------------------
# PREV SIBLINGS:
# NEXT SIBLINGS:
# 	 div {'class': ['cst_img_ctn', 'cst_img_ctn_16_9']}
# 	 div {'class': ['overlay_ctn']} Por Nunzia Locatelli y Cintia Suárez
# ================================================================================
#   8
# ---
# 	UKEY:: 1234567890
# 	JOB:: Infobae
# 	TITLE:: Ni la "grieta" es un invento argentino ni la esclavitud terminó: leé gratis el libro que explica por qué
# 	TITLE_WORD_COUNT:: 19
# 	ARTICLE:: 8
# 	AUTHOR:: Silvana Boschi
# 	VOLANTA:: N/A -- INFOBAE HAS NO VOLANTAS
# 	CATEGORY:: leamos
# 	SLUG:: /leamos/2022/11/01/ni-la-grieta-es-un-invento-argentino-ni-la-esclavitud-termino-lee-gratis-el-libro-que-explica-por-que/
# 	SLUG_INTERNAL:: True
# 	Origen:: https://www.infobae.com
# 	FechaFiltro:: 2022-11-01 11:50:20.531619
# 	FechaCreacion:: 2022-11-01 11:50:20.531619
# 	FechaModificacion:: 2022-11-01 11:50:20.531619
#                                         ----------------------------------------
# PREV SIBLINGS:
# NEXT SIBLINGS:
# 	 div {'class': ['cst_img_ctn', 'cst_img_ctn_16_9']}
# 	 div {'class': ['overlay_ctn']} Por Silvana Boschi
# ================================================================================
#   9
# ---
# 	UKEY:: 1234567890
# 	JOB:: Infobae
# 	TITLE:: Un influencer se coló en la casa de Gran Hermano 2022 y dejó un regalo en el patio
# 	TITLE_WORD_COUNT:: 18
# 	ARTICLE:: 9
# 	VOLANTA:: N/A -- INFOBAE HAS NO VOLANTAS
# 	CATEGORY:: teleshow
# 	SLUG:: /teleshow/2022/11/01/un-influencer-se-colo-en-la-casa-de-gran-hermano-2022-y-dejo-un-regalo-en-el-patio/
# 	SLUG_INTERNAL:: True
# 	Origen:: https://www.infobae.com
# 	FechaFiltro:: 2022-11-01 11:50:20.532616
# 	FechaCreacion:: 2022-11-01 11:50:20.532616
# 	FechaModificacion:: 2022-11-01 11:50:20.532616
#                                         ----------------------------------------
# PREV SIBLINGS:
# NEXT SIBLINGS:
# 	 div {'class': ['cst_img_ctn', 'cst_img_ctn_16_9']}
# 	 div {'class': ['overlay_ctn']} VIDEO
# ================================================================================
#  10
# ---
# 	UKEY:: 1234567890
# 	JOB:: Infobae
# 	TITLE:: En qué consiste el hábito sencillo para acelerar el metabolismo y quemar grasas
# 	TITLE_WORD_COUNT:: 13
# 	ARTICLE:: 10
# 	VOLANTA:: N/A -- INFOBAE HAS NO VOLANTAS
# 	CATEGORY:: america
# 	SUBCATEGORY:: tendencias-america
# 	SLUG:: /america/tendencias-america/2022/11/01/en-que-consiste-el-habito-sencillo-para-acelerar-el-metabolismo-y-quemar-grasas/
# 	SLUG_INTERNAL:: True
# 	Origen:: https://www.infobae.com
# 	FechaFiltro:: 2022-11-01 11:50:20.532616
# 	FechaCreacion:: 2022-11-01 11:50:20.532616
# 	FechaModificacion:: 2022-11-01 11:50:20.532616
#                                         ----------------------------------------
# PREV SIBLINGS:
# NEXT SIBLINGS:
# 	 div {'class': ['cst_img_ctn', 'cst_img_ctn_16_9']}
# ================================================================================
#  11
# ---
# 	UKEY:: 1234567890
# 	JOB:: Infobae
# 	TITLE:: Es abogada, modelo, tuvo dos bandas de cumbia pop y porta apellido famoso: la vida de Delfina Burlando
# 	TITLE_WORD_COUNT:: 18
# 	ARTICLE:: 11
# 	VOLANTA:: N/A -- INFOBAE HAS NO VOLANTAS
# 	CATEGORY:: teleshow
# 	SLUG:: /teleshow/2022/11/01/es-abogada-modelo-tuvo-dos-bandas-de-cumbia-pop-y-porta-apellido-famoso-la-asombrosa-vida-de-delfina-burlando/
# 	SLUG_INTERNAL:: True
# 	Origen:: https://www.infobae.com
# 	FechaFiltro:: 2022-11-01 11:50:20.533613
# 	FechaCreacion:: 2022-11-01 11:50:20.533613
# 	FechaModificacion:: 2022-11-01 11:50:20.533613
#                                         ----------------------------------------
# PREV SIBLINGS:
# NEXT SIBLINGS:
# 	 div {'class': ['cst_img_ctn', 'cst_img_ctn_16_9']}
# ================================================================================
#  12
# ---
# 	UKEY:: 1234567890
# 	JOB:: Infobae
# 	TITLE:: SpaceX lanza su cohete más poderoso e intentará hacer un triple aterrizaje
# 	TITLE_WORD_COUNT:: 12
# 	ARTICLE:: 12
# 	VOLANTA:: N/A -- INFOBAE HAS NO VOLANTAS
# 	CATEGORY:: america
# 	SUBCATEGORY:: ciencia-america
# 	SLUG:: /america/ciencia-america/2022/11/01/en-vivo-spacex-lanza-su-cohete-mas-poderoso-e-intentara-hacer-un-triple-aterrizaje/
# 	SLUG_INTERNAL:: True
# 	Origen:: https://www.infobae.com
# 	FechaFiltro:: 2022-11-01 11:50:20.533613
# 	FechaCreacion:: 2022-11-01 11:50:20.533613
# 	FechaModificacion:: 2022-11-01 11:50:20.534610
#                                         ----------------------------------------
# PREV SIBLINGS:
# 	 div {'class': ['badge', 'background_red']} En vivo
# NEXT SIBLINGS:
# 	 div {'class': ['cst_img_ctn', 'cst_img_ctn_16_9']}
# 	 div {'class': ['overlay_ctn']} VIDEO
# ================================================================================
#  13
# ---
# 	UKEY:: 1234567890
# 	JOB:: Infobae
# 	TITLE:: La confesión de Messi sobre cómo lo impactó la derrota ante Alemania en el Mundial 2014
# 	TITLE_WORD_COUNT:: 16
# 	ARTICLE:: 13
# 	AUTHOR:: Federico Cristofanelli
# 	VOLANTA:: N/A -- INFOBAE HAS NO VOLANTAS
# 	CATEGORY:
#                                         ----------------------------------------
# PREV SIBLINGS:
# NEXT SIBLINGS:
# 	 div {'class': ['cst_img_ctn', 'cst_img_ctn_16_9']}
# 	 div {'class': ['overlay_ctn']} Por Pablo Wende
# ================================================================================
#  20
# ---
# 	UKEY:: 1234567890
# 	JOB:: Infobae
# 	TITLE:: Ahora es oficial: Europa cierra la puerta definitivamente a los motores de combustión
# 	TITLE_WORD_COUNT:: 13
# 	ARTICLE:: 20
# 	AUTHOR:: Diego Zorrero
# 	VOLANTA:: N/A -- INFOBAE HAS NO VOLANTAS
# 	CATEGORY:: autos
# 	SLUG:: /autos/2022/10/31/ahora-es-oficial-europa-cierra-la-puerta-definitivamente-a-los-motores-de-combustion/
# 	SLUG_INTERNAL:: True
# 	Origen:: https://www.infobae.com
# 	FechaFiltro:: 2022-11-01 11:50:20.540596
# 	FechaCreacion:: 2022-11-01 11:50:20.540596
# 	FechaModificacion:: 2022-11-01 11:50:20.540596
#                                         ----------------------------------------
# PREV SIBLINGS:
# NEXT SIBLINGS:
# 	 div {'class': ['cst_img_ctn', 'cst_img_ctn_16_9']}
# 	 div {'class': ['overlay_ctn']} Por Diego Zorrero
# ================================================================================
#  21
# ---
# 	UKEY:: 1234567890
# 	JOB:: Infobae
# 	TITLE:: Lula será el próximo presidente de Brasil: ahora viene la parte difícil
# 	TITLE_WORD_COUNT:: 12
# 	ARTICLE:: 21
# 	AUTHOR:: The Economist
# 	VOLANTA:: N/A -- INFOBAE HAS NO VOLANTAS
# 	CATEGORY:: america
# 	SUBCATEGORY:: economist
# 	SLUG:: /america/economist/2022/11/01/lula-sera-el-proximo-presidente-de-brasil-ahora-viene-la-parte-dificil/
# 	SLUG_INTERNAL:: True
# 	Origen:: https://www.infobae.com
# 	FechaFiltro:: 2022-11-01 11:50:20.541592
# 	FechaCreacion:: 2022-11-01 11:50:20.541592
# 	FechaModificacion:: 2022-11-01 11:50:20.542589
#                                         ----------------------------------------
# PREV SIBLINGS:
# NEXT SIBLINGS:
# 	 div {'class': ['cst_img_ctn', 'cst_img_ctn_16_9']}
# 	 div {'class': ['overlay_ctn']} The Economist
# ================================================================================
#  22
# ---
# 	UKEY:: 1234567890
# 	JOB:: Infobae
# 	TITLE:: Terror en Ecuador: una madrugada con cuatro coches bomba, dos policías muertos y motines en las cárceles
# 	TITLE_WORD_COUNT:: 17
# 	ARTICLE:: 22
# 	AUTHOR:: Yalilé Loaiza
# 	VOLANTA:: N/A -- INFOBAE HAS NO VOLANTAS
# 	CATEGORY:: america
# 	SUBCATEGORY:: america-latina
# 	SLUG:: /america/america-latina/2022/11/01/terror-en-ecuador-una-madrugada-con-cuatro-coches-bomba-dos-policias-muertos-y-motines-en-las-carceles/
# 	SLUG_INTERNAL:: True
# 	Origen:: https://www.infobae.com
# 	FechaFiltro:: 2022-11-01 11:50:20.543586
# 	FechaCreacion:: 2022-11-01 11:50:20.543586
# 	FechaModificacion:: 2022-11-01 11:50:20.543586
#                                         ----------------------------------------
# PREV SIBLINGS:
# NEXT SIBLINGS:
# 	 div {'class': ['cst_img_ctn', 'cst_img_ctn_16_9']}
# 	 div {'class': ['overlay_ctn']} Por Yalilé Loaiza
# ================================================================================
#  23
# ---
# 	UKEY:: 1234567890
# 	JOB:: Infobae
# 	TITLE:: Se entregó el encargado de manejar la “plata personal” de Cositorto en Generación Zoe
# 	TITLE_WORD_COUNT:: 14
# 	ARTICLE:: 23
# 	AUTHOR:: Federico Fahsbender
# 	VOLANTA:: N/A -- INFOBAE HAS NO VOLANTAS
# 	CATEGORY:: sociedad
# 	SUBCATEGORY:: policiales
# 	SLUG:: /sociedad/policiales/2022/11/01/se-entrego-miguel-echegaray-el-encargado-de-manejar-la-plata-personal-de-cositorto-en-generacion-zoe/
# 	SLUG_INTERNAL:: True
# 	Origen:: https://www.infobae.com
# 	FechaFiltro:: 2022-11-01 11:50:20.544583
# 	FechaCreacion:: 2022-11-01 11:50:20.544583
# 	FechaModificacion:: 2022-11-01 11:50:20.544583
#                                         ----------------------------------------
# PREV SIBLINGS:
# NEXT SIBLINGS:
# 	 div {'class': ['cst_img_ctn', 'cst_img_ctn_16_9']}
# 	 div {'class': ['overlay_ctn']} Por Federico Fahsbender
# ================================================================================
#  24
# ---
# 	UKEY:: 1234567890
# 	JOB:: Infobae
# 	TITLE:: Aumento a empleadas domésticas: cómo queda la escala salarial a partir de noviembre
# 	TITLE_WORD_COUNT:: 13
# 	ARTICLE:: 24
# 	VOLANTA:: N/A -- INFOBAE HAS NO VOLANTAS
# 	CATEGORY:: economia
# 	SLUG:: /economia/2022/11/01/aumento-a-empleadas-domesticas-como-queda-la-escala-salarial-a-partir-de-noviembre/
# 	SLUG_INTERNAL:: True
# 	Origen:: https://www.infobae.com
# 	FechaFiltro:: 2022-11-01 11:50:20.545583
# 	FechaCreacion:: 2022-11-01 11:50:20.545583
# 	FechaModificacion:: 2022-11-01 11:50:20.546580
#                                         ----------------------------------------
# PREV SIBLINGS:
# NEXT SIBLINGS:
# 	 div {'class': ['cst_img_ctn', 'cst_img_ctn_16_9']}
# ================================================================================
#  25
# ---
# 	UKEY:: 1234567890
# 	JOB:: Infobae
# 	TITLE:: "Vos no me podés tocar”: la agresión de un policía a una joven al salir de un boliche en Mar del Plata
# 	TITLE_WORD_COUNT:: 22
# 	ARTICLE:: 25
# 	VOLANTA:: N/A -- INFOBAE HAS NO VOLANTAS
# 	CATEGORY:: sociedad
# 	SUBCATEGORY:: policiales
# 	SLUG:: /sociedad/policiales/2022/11/01/vos-a-mi-no-me-podes-tocar-la-agresion-de-un-policia-a-una-joven-a-la-salida-de-un-boliche-en-mar-del-plata/
# 	SLUG_INTERNAL:: True
# 	Origen:: https://www.infobae.com
# 	FechaFiltro:: 2022-11-01 11:50:20.546580
# 	FechaCreacion:: 2022-11-01 11:50:20.546580
# 	FechaModificacion:: 2022-11-01 11:50:20.546580
#                                         ----------------------------------------
# PREV SIBLINGS:
# NEXT SIBLINGS:
# 	 div {'class': ['cst_img_ctn', 'cst_img_ctn_16_9']}
# 	 div {'class': ['overlay_ctn']} VIDEO
# ================================================================================
#  26
# ---
# 	UKEY:: 1234567890
# 	JOB:: Infobae
# 	TITLE:: 66 fotos: Mauricio Macri y Juliana Awada en la cena anual de la Fundación Margarita Barrientos
# 	TITLE_WORD_COUNT:: 16
# 	ARTICLE:: 26
# 	AUTHOR:: Soledad Blardone
# 	VOLANTA:: N/A -- INFOBAE HAS NO VOLANTAS
# 	CATEGORY:
# ---
# 	UKEY:: 1234567890
# 	JOB:: Infobae
# 	TITLE:: Vino al país por la inseguridad de Caracas y fundó una panadería venezolana que es todo un éxito
# 	TITLE_WORD_COUNT:: 18
# 	ARTICLE:: 46
# 	AUTHOR:: Gabriela Cicero
# 	VOLANTA:: N/A -- INFOBAE HAS NO VOLANTAS
# 	CATEGORY:: sociedad
# 	SLUG:: /sociedad/2022/11/01/vino-a-la-argentina-por-la-inseguridad-de-caracas-y-fundo-la-primera-panaderia-venezolana-que-es-todo-un-exito/
# 	SLUG_INTERNAL:: True
# 	Origen:: https://www.infobae.com
# 	FechaFiltro:: 2022-11-01 11:50:20.562535
# 	FechaCreacion:: 2022-11-01 11:50:20.562535
# 	FechaModificacion:: 2022-11-01 11:50:20.562535
#                                         ----------------------------------------
# PREV SIBLINGS:
# NEXT SIBLINGS:
# 	 div {'class': ['cst_img_ctn', 'cst_img_ctn_16_9']}
# 	 div {'class': ['overlay_ctn']} Por Gabriela Cicero
# ================================================================================
#  47
# ---
# 	UKEY:: 1234567890
# 	JOB:: Infobae
# 	TITLE:: Becas Progresar: quiénes reciben los 7.600 pesos por mes que paga el Gobierno para estudiar
# 	TITLE_WORD_COUNT:: 15
# 	ARTICLE:: 47
# 	AUTHOR:: Maximiliano Fernández
# 	VOLANTA:: N/A -- INFOBAE HAS NO VOLANTAS
# 	CATEGORY:: educacion
# 	SLUG:: /educacion/2022/11/01/becas-progresar-quienes-reciben-los-7600-pesos-por-mes-que-paga-el-gobierno-para-estudiar/
# 	SLUG_INTERNAL:: True
# 	Origen:: https://www.infobae.com
# 	FechaFiltro:: 2022-11-01 11:50:20.563533
# 	FechaCreacion:: 2022-11-01 11:50:20.563533
# 	FechaModificacion:: 2022-11-01 11:50:20.563533
#                                         ----------------------------------------
# PREV SIBLINGS:
# NEXT SIBLINGS:
# 	 div {'class': ['cst_img_ctn', 'cst_img_ctn_16_9']}
# 	 div {'class': ['overlay_ctn']} Por Maximiliano Fernández
# ================================================================================
#  48
# ---
# 	UKEY:: 1234567890
# 	JOB:: Infobae
# 	TITLE:: ¿Cómo se ayuda a morir a una madre? Todo lo que les cuesta a las hijas el vínculo más difícil
# 	TITLE_WORD_COUNT:: 20
# 	ARTICLE:: 48
# 	AUTHOR:: Luciano Lutereau
# 	VOLANTA:: N/A -- INFOBAE HAS NO VOLANTAS
# 	CATEGORY:: leamos
# 	SLUG:: /leamos/2022/11/01/como-se-ayuda-a-morir-a-una-madre-todo-lo-que-les-cuesta-a-las-hijas-el-vinculo-mas-dificil/
# 	SLUG_INTERNAL:: True
# 	Origen:: https://www.infobae.com
# 	FechaFiltro:: 2022-11-01 11:50:20.564531
# 	FechaCreacion:: 2022-11-01 11:50:20.564531
# 	FechaModificacion:: 2022-11-01 11:50:20.564531
#                                         ----------------------------------------
# PREV SIBLINGS:
# NEXT SIBLINGS:
# 	 div {'class': ['cst_img_ctn', 'cst_img_ctn_16_9']}
# 	 div {'class': ['overlay_ctn']} Por Luciano Lutereau
# ================================================================================
#  49
# ---
# 	UKEY:: 1234567890
# 	JOB:: Infobae
# 	TITLE:: Día mundial del Veganismo: las 10 mejores recetas para comer rico y sano en casa
# 	TITLE_WORD_COUNT:: 15
# 	ARTICLE:: 49
# 	VOLANTA:: N/A -- INFOBAE HAS NO VOLANTAS
# 	CATEGORY:: tendencias
# 	SLUG:: /tendencias/2022/11/01/dia-mundial-del-veganismo-las-10-mejores-recetas-para-comer-rico-y-sano-en-casa/
# 	SLUG_INTERNAL:: True
# 	Origen:: https://www.infobae.com
# 	FechaFiltro:: 2022-11-01 11:50:20.564531
# 	FechaCreacion:: 2022-11-01 11:50:20.565528
# 	FechaModificacion:: 2022-11-01 11:50:20.565528
#                                         ----------------------------------------
# PREV SIBLINGS:
# NEXT SIBLINGS:
# 	 div {'class': ['cst_img_ctn', 'cst_img_ctn_16_9']}
# ================================================================================
#  50
# ---
# 	UKEY:: 1234567890
# 	JOB:: Infobae
# 	TITLE:: El día que la Primera Guerra Mundial se trasladó a las costas de Chile
# 	TITLE_WORD_COUNT:: 14
# 	ARTICLE:: 50
# 	AUTHOR:: Luis Furlán
# 	VOLANTA:: N/A -- INFOBAE HAS NO VOLANTAS
# 	CATEGORY:: historia
# 	SLUG:: /historia/2022/11/01/el-dia-que-la-primera-guerra-mundial-se-traslado-a-las-costas-de-chile-en-la-batalla-de-coronel/
# 	SLUG_INTERNAL:: True
# 	Origen:: https://www.infobae.com
# 	FechaFiltro:: 2022-11-01 11:50:20.565528
# 	FechaCreacion:: 2022-11-01 11:50:20.565528
# 	FechaModificacion:: 2022-11-01 11:50:20.565528
#                                         ----------------------------------------
# PREV SIBLINGS:
# NEXT SIBLINGS:
# 	 div {'class': ['cst_img_ctn', 'cst_img_ctn_16_9']}
# 	 div {'class': ['overlay_ctn']} Por Luis Furlán
# ================================================================================
#  51
# ---
# 	UKEY:: 1234567890
# 	JOB:: Infobae
# 	TITLE:: El extraño caso del arquero español que se enteró en una entrevista que no está en la lista del Mundial
# 	TITLE_WORD_COUNT:: 20
# 	ARTICLE:: 51
# 	VOLANTA:: N/A -- INFOBAE HAS NO VOLANTAS
# 	CATEGORY:: america
# 	SUBCATEGORY:: deportes
# 	SLUG:: /america/deportes/futbol-europeo/2022/11/01/el-extrano-caso-del-arquero-espanol-que-se-entero-en-una-entrevista-que-no-esta-en-la-lista-del-mundial/
# 	SLUG_INTERNAL:: True
# 	Origen:: https://www.infobae.com
# 	FechaFiltro:: 2022-11-01 11:50:20.566526
# 	FechaCreacion:: 2022-11-01 11:50:20.566526
# 	FechaModificacion:: 2022-11-01 11:50:20.566526
#                                         ----------------------------------------
# PREV SIBLINGS:
# NEXT SIBLINGS:
# 	 div {'class': ['cst_img_ctn', 'cst_img_ctn_16_9']}
# 	 div {'class': ['overlay_ctn']} AUDIO
# ================================================================================
#  52
# ---
# 	UKEY:: 1234567890
# 	JOB:: Infobae
# 	TITLE:: ¿Se apaga la estrella de Simeone en el Atlético Madrid? Las “señales de agotamiento”
# 	TITLE_WORD_COUNT:: 14
# 	ARTICLE:: 52
# 	AUTHOR:: Sergio Levinsky
# 	VOLANTA:: N/A -- INFOBAE HAS NO VOLANTAS
# 	CATEGORY:: america
# 	SUBCATEGORY:: deportes
# ...
# 	Origen:: https://www.infobae.com
# 	FechaFiltro:: 2022-11-01 11:50:20.598439
# 	FechaCreacion:: 2022-11-01 11:50:20.598439
# 	FechaModificacion:: 2022-11-01 11:50:20.598439
#                                         ----------------------------------------
# PREV SIBLINGS:
# NEXT SIBLINGS:
# 	 div {'class': ['cst_img_ctn', 'cst_img_ctn_16_9']}
# ================================================================================
#  77
# ---
# 	UKEY:: 1234567890
# 	JOB:: Infobae
# 	TITLE:: La agenda de la definición de la fase de grupos de Champions League: hora y TV de todos los partidos
# 	TITLE_WORD_COUNT:: 20
# 	ARTICLE:: 80
# 	VOLANTA:: N/A -- INFOBAE HAS NO VOLANTAS
# 	CATEGORY:: america
# 	SUBCATEGORY:: deportes
# 	SLUG:: /america/deportes/2022/11/01/la-agenda-de-la-definicion-de-la-fase-de-grupos-de-champions-league-hora-y-tv-de-todos-los-partidos/
# 	SLUG_INTERNAL:: True
# 	Origen:: https://www.infobae.com
# 	FechaFiltro:: 2022-11-01 11:50:20.600435
# 	FechaCreacion:: 2022-11-01 11:50:20.600435
# 	FechaModificacion:: 2022-11-01 11:50:20.600435
#                                         ----------------------------------------
# PREV SIBLINGS:
# NEXT SIBLINGS:
# 	 div {'class': ['cst_img_ctn', 'cst_img_ctn_16_9']}
# ================================================================================
#  78
# ---
# 	UKEY:: 1234567890
# 	JOB:: Infobae
# 	TITLE:: El picante mensaje de Arturo Vidal a Real Madrid tras ganar la Libertadores con Flamengo
# 	TITLE_WORD_COUNT:: 15
# 	ARTICLE:: 81
# 	VOLANTA:: N/A -- INFOBAE HAS NO VOLANTAS
# 	CATEGORY:: america
# 	SUBCATEGORY:: deportes
# 	SLUG:: /america/deportes/2022/11/01/el-picante-mensaje-de-arturo-vidal-al-real-madrid-tras-ganar-la-copa-libertadores-con-el-flamengo/
# 	SLUG_INTERNAL:: True
# 	Origen:: https://www.infobae.com
# 	FechaFiltro:: 2022-11-01 11:50:20.601431
# 	FechaCreacion:: 2022-11-01 11:50:20.601431
# 	FechaModificacion:: 2022-11-01 11:50:20.602428
#                                         ----------------------------------------
# PREV SIBLINGS:
# NEXT SIBLINGS:
# 	 div {'class': ['cst_img_ctn', 'cst_img_ctn_16_9']}
# 	 div {'class': ['overlay_ctn']} VIDEO
# ================================================================================
#  79
# ---
# 	UKEY:: 1234567890
# 	JOB:: Infobae
# 	TITLE:: Nequi Galotti reveló que tiene nuevo novio: "Nunca me imaginé conocer a alguien por Instagram"
# 	TITLE_WORD_COUNT:: 15
# 	ARTICLE:: 82
# 	VOLANTA:: N/A -- INFOBAE HAS NO VOLANTAS
# 	CATEGORY:: teleshow
# 	SLUG:: /teleshow/2022/11/01/nequi-galotti-revelo-que-tiene-nuevo-novio-nunca-me-imagine-que-iba-a-conocer-a-alguien-por-instagram/
# 	SLUG_INTERNAL:: True
# 	Origen:: https://www.infobae.com
# 	FechaFiltro:: 2022-11-01 11:50:20.603426
# 	FechaCreacion:: 2022-11-01 11:50:20.603426
# 	FechaModificacion:: 2022-11-01 11:50:20.603426
#                                         ----------------------------------------
# PREV SIBLINGS:
# NEXT SIBLINGS:
# 	 div {'class': ['cst_img_ctn', 'cst_img_ctn_16_9']}
# 	 div {'class': ['overlay_ctn']} VIDEO
# ================================================================================
#  80
# ---
# 	UKEY:: 1234567890
# 	JOB:: Infobae
# 	TITLE:: El furcio de Locho que hizo reír a todos en Canta Conmigo Ahora
# 	TITLE_WORD_COUNT:: 13
# 	ARTICLE:: 83
# 	VOLANTA:: N/A -- INFOBAE HAS NO VOLANTAS
# 	CATEGORY:: teleshow
# 	SLUG:: /teleshow/2022/11/01/el-furcio-de-locho-que-hizo-reir-a-todos-en-canta-conmigo-ahora/
# 	SLUG_INTERNAL:: True
# 	Origen:: https://www.infobae.com
# 	FechaFiltro:: 2022-11-01 11:50:20.604423
# 	FechaCreacion:: 2022-11-01 11:50:20.604423
# 	FechaModificacion:: 2022-11-01 11:50:20.604423
#                                         ----------------------------------------
# PREV SIBLINGS:
# NEXT SIBLINGS:
# 	 div {'class': ['cst_img_ctn', 'cst_img_ctn_16_9']}
# 	 div {'class': ['overlay_ctn']} VIDEO
# ================================================================================
#  81
# ---
# 	UKEY:: 1234567890
# 	JOB:: Infobae
# 	TITLE:: Flor Vigna se realizó un jugado tatuaje y mostró el resultado: “Más feliz y libre”
# 	TITLE_WORD_COUNT:: 15
# 	ARTICLE:: 84
# 	VOLANTA:: N/A -- INFOBAE HAS NO VOLANTAS
# 	CATEGORY:: teleshow
# 	SLUG:: /teleshow/2022/11/01/flor-vigna-se-realizo-un-jugado-tatuaje-y-mostro-el-resultado-mas-feliz-y-libre/
# 	SLUG_INTERNAL:: True
# 	Origen:: https://www.infobae.com
# 	FechaFiltro:: 2022-11-01 11:50:20.606417
# 	FechaCreacion:: 2022-11-01 11:50:20.606417
# 	FechaModificacion:: 2022-11-01 11:50:20.606417
#                                         ----------------------------------------
# PREV SIBLINGS:
# NEXT SIBLINGS:
# 	 div {'class': ['cst_img_ctn', 'cst_img_ctn_16_9']}
# ================================================================================
#  82
# ---
# 	UKEY:: 1234567890
# 	JOB:: Infobae
# 	TITLE:: Los 8 escalones: emoción de un participante al recordar a su pareja que murió antes de casarse
# 	TITLE_WORD_COUNT:: 17
# 	ARTICLE:: 85
# 	VOLANTA:: N/A -- INFOBAE HAS NO VOLANTAS
# 	CATEGORY:: teleshow
# 	SLUG:: /teleshow/2022/11/01/los-8-escalones-de-los-dos-millones-la-emocion-de-un-participante-al-recordar-a-su-pareja-fallecida-cuatro-meses-antes-de-casarse/
# 	SLUG_INTERNAL:: True
# 	Origen:: https://www.infobae.com
# 	FechaFiltro:: 2022-11-01 11:50:20.608413
# 	FechaCreacion:: 2022-11-01 11:50:20.608413
# 	FechaModificacion:: 2022-11-01 11:50:20.608413
#                                         ----------------------------------------
# PREV SIBLINGS:
# NEXT SIBLINGS:
# 	 div {'class': ['cst_img_ctn', 'cst_img_ctn_16_9']}
# 	 div {'class': ['overlay_ctn']} VIDEO
# ================================================================================
#  83
# ---
# 	UKEY:: 1234567890
# 	JOB:: Infobae
# 	TITLE:: Goat Simulator 3, Sable y más: los juegos independientes que llegan en noviembre a PlayStation
# 	TITLE_WORD_COUNT:: 15
# 	ARTICLE:: 86
# 	VOLANTA:: N/A -- INFOBAE HAS NO VOLANTAS
# 	CATEGORY:: latinpower
# 	SUBCATEGORY:: gaming
# 	SLUG:: /latinpower/gaming/2022/11/01/goat-simulator-3-sable-y-mas-los-juegos-independientes-que-llegan-en-noviembre-a-playstation/
# 	SLUG_INTERNAL:: True
# 	Origen:: https://www.infobae.com
# 	FechaFiltro:: 2022-11-01 11:50:20.610407
# 	FechaCreacion:: 2022-11-01 11:50:20.610407
# 	FechaModificacion:: 2022-11-01 11:50:20.610407
#                                         ----------------------------------------
# PREV SIBLINGS:
# NEXT SIBLINGS:
# 	 div {'class': ['cst_img_ctn', 'cst_img_ctn_16_9']}
# ================================================================================
#  84
# ---
# 	UKEY:: 1234567890
# 	JOB:: Infobae
# 	TITLE:: MultiVersus: ya se puede usar a Black Adam y disfrutar de su modo arcade de forma gratuita
# 	TITLE_WORD_COUNT:: 17
# 	ARTICLE:: 87
# 	VOLANTA:: N/A -- INFOBAE HAS NO VOLANTAS
# 	CATEGORY:: latinpower
# 	SUBCATEGORY:: gaming
# 	SLUG:: /latinpower/gaming/2022/11/01/multiversus-no-para-de-crecer-ya-se-puede-usar-a-black-adam-y-disfrutar-de-su-modo-arcade-de-forma-gratuita/
# 	SLUG_INTERNAL:: True
# 	Origen:: https://www.infobae.com
# 	FechaFiltro:: 2022-11-01 11:50:20.612402
# 	FechaCreacion:: 2022-11-01 11:50:20.612402
# 	FechaModificacion:: 2022-11-01 11:50:20.612402
#                                         ----------------------------------------
# PREV SIBLINGS:
# NEXT SIBLINGS:
# 	 div {'class': ['cst_img_ctn', 'cst_img_ctn_16_9']}
# ================================================================================
#  85
# ---
# 	UKEY:: 1234567890
# 	JOB:: Infobae
# 	TITLE:: Electronic Arts y Marvel forman una alianza para crear tres nuevos juegos de superhéroes
# 	TITLE_WORD_COUNT:: 14
# 	ARTICLE:: 88
# 	VOLANTA:: N/A -- INFOBAE HAS NO VOLANTAS
# 	CATEGORY:: latinpower
# 	SUBCATEGORY:: gaming
# 	SLUG:: /latinpower/gaming/2022/11/01/electronic-arts-y-marvel-forman-una-alianza-para-crear-tres-nuevos-juegos-de-superheroes/
# 	SLUG_INTERNAL:: True
# 	Origen:: https://www.infobae.com
# 	FechaFiltro:: 2022-11-01 11:50:20.614396
# 	FechaCreacion:: 2022-11-01 11:50:20.614396
# 	FechaModificacion:: 2022-11-01 11:50:20.614396
#                                         ----------------------------------------
# PREV SIBLINGS:
# NEXT SIBLINGS:
# 	 div {'class': ['cst_img_ctn', 'cst_img_ctn_16_9']}
# ================================================================================
#  86
# ---
# 	UKEY:: 1234567890
# 	JOB:: Infobae
# 	TITLE:: Como en un "Pokémon Go" del arte, las obras en NFT invaden Buenos Aires
# 	TITLE_WORD_COUNT:: 14
# 	ARTICLE:: 89
# 	AUTHOR:: Nadia Paz
# 	VOLANTA:: N/A -- INFOBAE HAS NO VOLANTAS
# 	CATEGORY:: cultura
# 	SLUG:: /cultura/2022/11/01/como-en-un-pokemon-go-del-arte-las-obras-en-nft-invaden-buenos-aires/
# 	SLUG_INTERNAL:: True
# 	Origen:: https://www.infobae.com
# 	FechaFiltro:: 2022-11-01 11:50:20.616392
# 	FechaCreacion:: 2022-11-01 11:50:20.616392
# 	FechaModificacion:: 2022-11-01 11:50:20.616392
#                                         ----------------------------------------
# PREV SIBLINGS:
# NEXT SIBLINGS:
# 	 div {'class': ['cst_img_ctn', 'cst_img_ctn_16_9']}
# 	 div {'class': ['overlay_ctn']} Por Nadia Paz
# ================================================================================
#  87
# ---
# 	UKEY:: 1234567890
# 	JOB:: Infobae
# 	TITLE:: Rosa Passos, de la bossa nova y el jazz a una celebración de 38 años de "matrimonio" musical
# 	TITLE_WORD_COUNT:: 18
# 	ARTICLE:: 90
# 	AUTHOR:: Ricardo Carpena
# 	VOLANTA:: N/A -- INFOBAE HAS NO VOLANTAS
# 	CATEGORY:: cultura
# 	SLUG:: /cultura/2022/11/01/rosa-passos-de-la-bossa-nova-y-el-jazz-a-una-celebracion-de-38-anos-de-matrimonio-musical/
# 	SLUG_INTERNAL:: True
# 	Origen:: https://www.infobae.com
# 	FechaFiltro:: 2022-11-01 11:50:20.617390
# 	FechaCreacion:: 2022-11-01 11:50:20.617390
# 	FechaModificacion:: 2022-11-01 11:50:20.617390
#                                         ----------------------------------------
# PREV SIBLINGS:
# NEXT SIBLINGS:
# 	 div {'class': ['cst_img_ctn', 'cst_img_ctn_16_9']}
# 	 div {'class': ['overlay_ctn']} Por Ricardo Carpena
# ================================================================================
#  88
# ---
# 	UKEY:: 1234567890
# 	JOB:: Infobae
# 	TITLE:: Vicente Zito Lema y Jacobo Fijman, un encuentro entre la poesía, la locura y la belleza hecha teatro
# 	TITLE_WORD_COUNT:: 18
# 	ARTICLE:: 91
# 	AUTHOR:: Ana Yovino
# 	VOLANTA:: N/A -- INFOBAE HAS NO VOLANTAS
# 	CATEGORY:: cultura
# 	SLUG:: /cultura/2022/11/01/vicente-zito-lema-y-jacobo-fijman-un-encuentro-entre-la-poesia-la-locura-y-la-belleza-hecha-teatro/
# 	SLUG_INTERNAL:: True
# 	Origen:: https://www.infobae.com
# 	FechaFiltro:: 2022-11-01 11:50:20.618386
# 	FechaCreacion:: 2022-11-01 11:50:20.618386
# 	FechaModificacion:: 2022-11-01 11:50:20.618386
#                                         ----------------------------------------
# PREV SIBLINGS:
# NEXT SIBLINGS:
# 	 div {'class': ['cst_img_ctn', 'cst_img_ctn_16_9']}
# 	 div {'class': ['overlay_ctn']} Por Ana Yovino
# ================================================================================
#  89
# ---
# 	UKEY:: 1234567890
# 	JOB:: Infobae
# 	TITLE:: Junto a Pampita, Juan Marconi y Santi Talledo, una automotriz presentó dos nuevos modelos
# 	TITLE_WORD_COUNT:: 14
# 	ARTICLE:: 92
# 	VOLANTA:: N/A -- INFOBAE HAS NO VOLANTAS
# 	CATEGORY:: inhouse
# 	SLUG:: /inhouse/2022/11/01/junto-a-pampita-ardohain-juan-marconi-y-santi-talledo-entre-otras-celebrities-una-automotriz-presento-dos-nuevos-modelos-a-sus-clientes/
# 	SLUG_INTERNAL:: True
# 	Origen:: https://www.infobae.com
# 	FechaFiltro:: 2022-11-01 11:50:20.619383
# 	FechaCreacion:: 2022-11-01 11:50:20.619383
# 	FechaModificacion:: 2022-11-01 11:50:20.620381
#                                         ----------------------------------------
# PREV SIBLINGS:
# NEXT SIBLINGS:
# 	 div {'class': ['cst_img_ctn', 'cst_img_ctn_16_9']}
# ================================================================================
#  90
# ---
# 	UKEY:: 1234567890
# 	JOB:: Infobae
# 	TITLE:: Cómo funciona la nueva medicación oncológica que actúa sobre los genes del tumor
# 	TITLE_WORD_COUNT:: 13
# 	ARTICLE:: 93
# 	VOLANTA:: N/A -- INFOBAE HAS NO VOLANTAS
# 	CATEGORY:: inhouse
# 	SLUG:: /inhouse/2022/11/01/como-funciona-la-nueva-medicacion-oncologica-que-actua-sobre-los-genes-del-tumor/
# 	SLUG_INTERNAL:: True
# 	Origen:: https://www.infobae.com
# 	FechaFiltro:: 2022-11-01 11:50:20.622376
# 	FechaCreacion:: 2022-11-01 11:50:20.622376
# 	FechaModificacion:: 2022-11-01 11:50:20.622376
#                                         ----------------------------------------
# PREV SIBLINGS:
# NEXT SIBLINGS:
# 	 div {'class': ['cst_img_ctn', 'cst_img_ctn_16_9']}
# ================================================================================
#  91
# ---
# 	UKEY:: 1234567890
# 	JOB:: Infobae
# 	TITLE:: Cómo cocinar con mayonesa vegana en la era de la alimentación saludable
# 	TITLE_WORD_COUNT:: 12
# 	ARTICLE:: 94
# 	VOLANTA:: N/A -- INFOBAE HAS NO VOLANTAS
# 	CATEGORY:: inhouse
# 	SLUG:: /inhouse/2022/11/01/como-cocinar-con-mayonesa-vegana-en-la-era-de-la-alimentacion-saludable/
# 	SLUG_INTERNAL:: True
# 	Origen:: https://www.infobae.com
# 	FechaFiltro:: 2022-11-01 11:50:20.623374
# 	FechaCreacion:: 2022-11-01 11:50:20.623374
# 	FechaModificacion:: 2022-11-01 11:50:20.623374
#                                         ----------------------------------------
# PREV SIBLINGS:
# NEXT SIBLINGS:
# 	 div {'class': ['cst_img_ctn', 'cst_img_ctn_16_9']}
# ================================================================================
#  92
# ---
# 	UKEY:: 1234567890
# 	JOB:: Infobae
# 	TITLE:: Una fintech celebra su aniversario regalando 7 millones de pesos
# 	TITLE_WORD_COUNT:: 10
# 	ARTICLE:: 95
# 	VOLANTA:: N/A -- INFOBAE HAS NO VOLANTAS
# 	CATEGORY:: inhouse
# 	SLUG:: /inhouse/2022/11/01/una-fintech-celebra-su-aniversario-regalando-7-millones-de-pesos/
# 	SLUG_INTERNAL:: True
# 	Origen:: https://www.infobae.com
# 	FechaFiltro:: 2022-11-01 11:50:20.624375
# 	FechaCreacion:: 2022-11-01 11:50:20.624375
# 	FechaModificacion:: 2022-11-01 11:50:20.624375
#                                         ----------------------------------------
# PREV SIBLINGS:
# NEXT SIBLINGS:
# 	 div {'class': ['cst_img_ctn', 'cst_img_ctn_16_9']}
# ================================================================================
#  93
# ---
# 	UKEY:: 1234567890
# 	JOB:: Infobae
# 	TITLE:: La figurita con Lula
# 	TITLE_WORD_COUNT:: 4
# 	ARTICLE:: 96
# 	VOLANTA:: N/A -- INFOBAE HAS NO VOLANTAS
# 	Origen:: https://www.infobae.com
# 	FechaFiltro:: 2022-11-01 11:50:20.625370
# 	FechaCreacion:: 2022-11-01 11:50:20.625370
# 	FechaModificacion:: 2022-11-01 11:50:20.625370
#                                         ----------------------------------------
# PREV SIBLINGS:
# 	 div {'class': ['opi_aut']} Carlos  Ruckauf
# NEXT SIBLINGS:
# ================================================================================
#  94
# ---
# 	UKEY:: 1234567890
# 	JOB:: Infobae
# 	TITLE:: Democracia de proyectos versus democracia de candidatos
# 	TITLE_WORD_COUNT:: 7
# 	ARTICLE:: 97
# 	VOLANTA:: N/A -- INFOBAE HAS NO VOLANTAS
# 	Origen:: https://www.infobae.com
# 	FechaFiltro:: 2022-11-01 11:50:20.626368
# 	FechaCreacion:: 2022-11-01 11:50:20.626368
# 	FechaModificacion:: 2022-11-01 11:50:20.626368
#                                         ----------------------------------------
# PREV SIBLINGS:
# 	 div {'class': ['opi_aut']} María Herminia Grande
# NEXT SIBLINGS:
# ================================================================================
#  95
# ---
# 	UKEY:: 1234567890
# 	JOB:: Infobae
# 	TITLE:: Colegios tomados: educar también es enseñar valores
# 	TITLE_WORD_COUNT:: 7
# 	ARTICLE:: 98
# 	VOLANTA:: N/A -- INFOBAE HAS NO VOLANTAS
# 	Origen:: https://www.infobae.com
# 	FechaFiltro:: 2022-11-01 11:50:20.627363
# 	FechaCreacion:: 2022-11-01 11:50:20.627363
# 	FechaModificacion:: 2022-11-01 11:50:20.627363
#                                         ----------------------------------------
# PREV SIBLINGS:
# 	 div {'class': ['opi_aut']} Edgardo Zablotsky
# NEXT SIBLINGS:
# ================================================================================
#  96
# ---
# 	UKEY:: 1234567890
# 	JOB:: Infobae
# 	TITLE:: Discapacidad e inclusión: de la ley a los hechos
# 	TITLE_WORD_COUNT:: 9
# 	ARTICLE:: 99
# 	VOLANTA:: N/A -- INFOBAE HAS NO VOLANTAS
# 	Origen:: https://www.infobae.com
# 	FechaFiltro:: 2022-11-01 11:50:20.627363
# 	FechaCreacion:: 2022-11-01 11:50:20.627363
# 	FechaModificacion:: 2022-11-01 11:50:20.627363
#                                         ----------------------------------------
# PREV SIBLINGS:
# 	 div {'class': ['opi_aut']} Maria Cristina Gomez
# NEXT SIBLINGS:
# ================================================================================
